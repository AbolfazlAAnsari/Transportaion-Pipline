# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import matplotlib.ticker as ticker
import plotly.io as pio
from sklearn.cluster import KMeans
from mlxtend.frequent_patterns import apriori, association_rules
import csv

# %matplotlib inline

# %%
# Load Dataset

abs_path = Path.cwd()
data_address = abs_path.parent.parent / 'data/' / 'Cleaned_US.csv'
df = pd.read_csv(data_address)

# %%
# Give a Sample DF
sample_size = 100000
df = df.sample(n=sample_size, random_state=42)

# %% [markdown]
# # Static VS Dynamic

# %%
# Data Preprocess to create a flat dataset for static and dynamic

# %%
df['Weather_Condition'].value_counts().to_dict()
# Out:
# {'Fair': 1107140,
#  'Mostly Cloudy': 363949,
#  'Cloudy': 348752,
#  'Partly Cloudy': 249921,
#  'Clear': 173817,
#  'Light Rain': 128392,
#  'Overcast': 84878,
#  'Scattered Clouds': 45129,
#  'Light Snow': 43749,
#  'Fog': 41225,
#  'Haze': 36353,
#  'Rain': 31044,
#  'Fair / Windy': 15195,
#  'Heavy Rain': 11823,
#  'Smoke': 7200,
#  'Light Drizzle': 7040,
#  'Thunder in the Vicinity': 6943,
#  'Cloudy / Windy': 6838,
#  'T-Storm': 6546,
#  'Mostly Cloudy / Windy': 6297,
#  'Thunder': 6018,
#  'Snow': 5289,
#  'Light Rain with Thunder': 5287,
#  'Partly Cloudy / Windy': 3876,
#  'Wintry Mix': 3843,
#  'Heavy T-Storm': 3598,
#  'Light Rain / Windy': 3412,
#  'Light Snow / Windy': 2153,
#  'Drizzle': 1704,
#  'Heavy Snow': 1441,
#  'Rain / Windy': 1093,
#  'Light Thunderstorms and Rain': 1089,
#  'N/A Precipitation': 1079,
#  'Patches of Fog': 1046,
#  'Mist': 1011,
#  'Thunderstorm': 985,
#  'Shallow Fog': 952,
#  'Light Freezing Rain': 900,
#  'Heavy Rain / Windy': 725,
#  'Showers in the Vicinity': 650,
#  'Haze / Windy': 563,
#  'Heavy Thunderstorms and Rain': 510,
#  'Thunderstorms and Rain': 506,
#  'Snow / Windy': 401,
#  'Light Freezing Fog': 385,
#  'Heavy T-Storm / Windy': 382,
#  'Light Freezing Drizzle': 369,
#  'Fog / Windy': 270,
#  'T-Storm / Windy': 260,
#  'Thunder / Windy': 224,
#  'Heavy Snow / Windy': 210,
#  'Blowing Snow': 162,
#  'Blowing Dust / Windy': 148,
#  'Blowing Dust': 142,
#  'Heavy Drizzle': 140,
#  'Light Rain Shower': 133,
#  'Drizzle and Fog': 133,
#  'Snow and Sleet': 106,
#  'Light Drizzle / Windy': 103,
#  'Blowing Snow / Windy': 86,
#  'Light Ice Pellets': 75,
#  'Wintry Mix / Windy': 74,
#  'Light Sleet': 68,
#  'Widespread Dust': 50,
#  'Sleet': 46,
#  'Smoke / Windy': 46,
#  'Freezing Rain': 44,
#  'Light Snow and Sleet': 43,
#  'Light Rain Showers': 41,
#  'Rain Shower': 37,
#  'Ice Pellets': 36,
#  'Light Freezing Rain / Windy': 35,
#  'Small Hail': 31,
#  'Rain Showers': 30,
#  'Partial Fog': 27,
#  'Light Snow Shower': 26,
#  'Squalls / Windy': 20,
#  'Snow and Sleet / Windy': 18,
#  'Widespread Dust / Windy': 18,
#  'Light Snow and Sleet / Windy': 16,
#  'Sand / Dust Whirlwinds': 15,
#  'Heavy Sleet': 13,
#  'Squalls': 12,
#  'Freezing Drizzle': 11,
#  'Light Snow with Thunder': 10,
#  'Drizzle / Windy': 9,
#  'Tornado': 9,
#  'Snow Grains': 8,
#  'Light Sleet / Windy': 7,
#  'Light Rain Shower / Windy': 7,
#  'Light Thunderstorms and Snow': 6,
#  'Light Snow Showers': 6,
#  'Thunder / Wintry Mix': 6,
#  'Volcanic Ash': 4,
#  'Patches of Fog / Windy': 4,
#  'Heavy Thunderstorms and Snow': 3,
#  'Heavy Snow with Thunder': 3,
#  'Hail': 3,
#  'Heavy Rain Shower': 3,
#  'Sand / Windy': 2,
#  'Freezing Rain / Windy': 2,
#  'Funnel Cloud': 2,
#  'Duststorm': 2,
#  'Heavy Ice Pellets': 2,
#  'Light Blowing Snow': 2,
#  'Thunder / Wintry Mix / Windy': 2,
#  'Sand': 2,
#  'Heavy Freezing Drizzle': 2,
#  'Snow and Thunder / Windy': 2,
#  'Thunder and Hail': 2,
#  'Blowing Snow Nearby': 2,
#  'Light Haze': 1,
#  'Heavy Thunderstorms with Small Hail': 1,
#  'Low Drifting Snow': 1,
#  'Drifting Snow': 1,
#  'Heavy Blowing Snow': 1,
#  'Heavy Rain Showers': 1,
#  'Heavy Rain Shower / Windy': 1,
#  'Sand / Dust Whirls Nearby': 1,
#  'Dust Whirls': 1,
#  'Sleet / Windy': 1,
#  'Mist / Windy': 1,
#  'Blowing Sand': 1,
#  'Heavy Freezing Rain': 1,
#  'Sand / Dust Whirlwinds / Windy': 1,
#  'Light Fog': 1,
#  'Thunder and Hail / Windy': 1}

# %%
# Fair, Clear, Fair / Windy, 
# Overcast, Mostly Cloudy, Cloudy, Partly Cloudy, Scattered Clouds, 
# Light Rain, Rain, Heavy Rain
# Snow, 
# Haze, Smoke, 
# Drizzle, Thunder, Dust
# Fog


# Smoke: dud sukhtan
# Haze: ghobar

# Dust: very stong winds with solid
# Thunder: rad bargh

# Drizzle: barun ba ghatre kuchik

# Overcast: 100 percent cloud in sky

df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder and Hail / Windy', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sand / Dust Whirlwinds / Windy', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Freezing Rain', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Blowing Sand', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Mist / Windy', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sleet / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Dust Whirls', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sand / Dust Whirls Nearby', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Rain Shower / Windy', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Rain Showers', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Blowing Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Drifting Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Low Drifting Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Thunderstorms with Small Hail', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Haze', 'Haze')
df['Weather_Condition'] = df['Weather_Condition'].replace('Blowing Snow Nearby', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder and Hail', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Snow and Thunder / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Freezing Drizzle', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sand', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder / Wintry Mix / Windy', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Blowing Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Ice Pellets', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Duststorm', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Funnel Cloud', 'Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Freezing Rain / Windy', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sand / Windy', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Rain Shower', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Hail', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Snow with Thunder', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Thunderstorms and Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Patches of Fog / Windy', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Volcanic Ash', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder / Wintry Mix', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow Showers', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Thunderstorms and Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Rain Shower / Windy', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Sleet / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Snow Grains', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Tornado', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Drizzle / Windy', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow with Thunder', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Freezing Drizzle', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Squalls', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Sleet', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sand / Dust Whirlwinds', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow and Sleet / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Widespread Dust / Windy', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Snow and Sleet / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Squalls / Windy', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow Shower', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Partial Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Rain Showers', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Freezing Rain / Windy', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Small Hail', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Ice Pellets', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Rain Shower', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Rain Showers', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow and Sleet', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Freezing Rain', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Smoke / Windy', 'Smoke')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sleet', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Widespread Dust', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Sleet', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Wintry Mix / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Ice Pellets', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Blowing Snow / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Drizzle / Windy', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Snow and Sleet', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Drizzle and Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Rain Shower', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Drizzle', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Blowing Dust', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Blowing Dust / Windy', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Blowing Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Snow / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder / Windy', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('T-Storm / Windy', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Fog / Windy', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Freezing Drizzle', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy T-Storm / Windy', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Freezing Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Snow / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunderstorms and Rain', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Thunderstorms and Rain', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Haze / Windy', 'Haze')
df['Weather_Condition'] = df['Weather_Condition'].replace('Showers in the Vicinity', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Rain / Windy', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Freezing Rain', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Shallow Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunderstorm', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Mist', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Patches of Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('N/A Precipitation', 'Fair')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Thunderstorms and Rain', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Rain / Windy', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Drizzle', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Rain / Windy', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy T-Storm', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Wintry Mix', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Partly Cloudy / Windy', 'Partly Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Rain with Thunder', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Mostly Cloudy / Windy', 'Mostly Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('T-Storm', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Cloudy / Windy', 'Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder in the Vicinity', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Drizzle', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Smoke', 'Smoke')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Rain', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Fair / Windy', 'Fair / Windy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Rain', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Haze', 'Haze')
df['Weather_Condition'] = df['Weather_Condition'].replace('Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Scattered Clouds', 'Scatterred Clouds')
df['Weather_Condition'] = df['Weather_Condition'].replace('Overcast', 'Overcast')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Rain', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Clear', 'Clear')
df['Weather_Condition'] = df['Weather_Condition'].replace('Partly Cloudy', 'Partly Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Cloudy', 'Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Mostly Cloudy', 'Mostly Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Fair', 'Fair')

# %%
df['Weather_Condition'].value_counts().to_dict()
# Out:
# {'Fair': 1108219,
#  'Mostly Cloudy': 370246,
#  'Cloudy': 355592,
#  'Partly Cloudy': 253797,
#  'Clear': 173817,
#  'Light Rain': 138207,
#  'Overcast': 84878,
#  'Snow': 58956,
#  'Scatterred Clouds': 45129,
#  'Fog': 44044,
#  'Haze': 36917,
#  'Rain': 34449,
#  'Thunder': 24967,
#  'Fair / Windy': 15195,
#  'Heavy Rain': 13110,
#  'Drizzle': 9378,
#  'Smoke': 7246,
#  'Dust': 428}

# %%
df = pd.get_dummies(df, columns=['Weather_Condition'], prefix='Weather', dtype=bool)

# %%
df = pd.get_dummies(df, columns=['Weekday'], prefix='Weekday', dtype=bool)

# %%
df['Hour'] = df['Hour'].astype('float64')
df['Month'] = df['Month'].astype('float64')

# Step 1: Convert "Hour" to 4 boolean columns
hour_labels = ['Night (0-5)', 'Morning (6-11)', 'Afternoon (12-17)', 'Evening (18-23)']
hour_bins = [0, 5, 11, 17, 23]
df['Part_of_Day'] = pd.cut(df['Hour'], bins=hour_bins, labels=hour_labels, right=False)
df = pd.get_dummies(df, columns=['Part_of_Day'], prefix='Part_of_Day', dtype=bool)

# Step 2: Convert "Month" to 12 boolean columns
month_names = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
df['Month'] = df['Month'].astype(int)
df = pd.get_dummies(df, columns=['Month'], prefix='Month', dtype=bool)
df.rename(columns={'Month_'+str(i): month_names[i-1] for i in range(1, 13)}, inplace=True)

# Drop the original "Hour" column as it is no longer needed
df.drop(['Hour'], axis=1, inplace=True)

# %%
def static_convertor(df):

    weather_float_columns = ['Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
                             'Wind_Speed(mph)']

    # Define the thresholds for each weather column
    thresholds = {
    'Temperature(F)': [0, 20, 40, 60, 80, float('inf')],
    'Wind_Chill(F)': [-float('inf'), 0, 20, 50, 70, float('inf')],
    'Humidity(%)': [0, 20, 40, 60, 80, 100],
    'Pressure(in)': [0, 20, 25, 30, 35, float('inf')],
    'Wind_Speed(mph)': [0, 3, 5, 7, 10, float('inf')]
    }

    df_static_threshold = pd.DataFrame()

    # Discretize and encode weather columns using one-hot encoding
    for column in weather_float_columns:
        bins = thresholds[column]
        labels = range(len(bins) - 1)
        categories = pd.cut(df[column], bins=bins, labels=labels)
        encoded_cols = pd.get_dummies(categories, prefix=column)
        df_static_threshold = pd.concat([df_static_threshold, encoded_cols], axis=1)
        
    return df_static_threshold

# %%
def dynamic_convertor(df):
    # Define weather float columns
    weather_float_columns = ['Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
                             'Wind_Speed(mph)']

    # Create a new DataFrame for encoded columns
    df_dynamic_threshold = pd.DataFrame()

    # Create a dictionary to store the thresholds
    thresholds_dict = {}

    # Discretize and encode weather columns using one-hot encoding
    for column in weather_float_columns:
        column_values = df[column]
        
        # Adjust threshold percentages if they are the same
        if len(set(column_values)) == 1:
            min_value = column_values.min()
            max_value = column_values.max()
            if min_value == max_value:
                thresholds = [0, min_value, min_value + 1, float('inf')]
            else:
                thresholds = [0, min_value, max_value, float('inf')]
        else:
            thresholds = [0, 
                          np.percentile(column_values, 20),
                          np.percentile(column_values, 40),
                          np.percentile(column_values, 60),
                          np.percentile(column_values, 80), 
                          float('inf')]
        
        bins = np.unique(thresholds)  # Ensure unique bin edges
        labels = range(len(bins) - 1)
        categories = pd.cut(column_values, bins=bins, labels=labels)
        encoded_cols = pd.get_dummies(categories, prefix=column, dtype=bool)
        df_dynamic_threshold = pd.concat([df_dynamic_threshold, encoded_cols], axis=1)

        # Store the thresholds in the dictionary
        thresholds_dict[column] = thresholds
    
    # Save the thresholds dictionary to a CSV file
    with open('thresholds.csv', 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Column', 'Thresholds'])
        for column, thresholds in thresholds_dict.items():
            writer.writerow([column, thresholds])

    return df_dynamic_threshold

# %%
df_weather_bool_static = static_convertor(df)
df_weather_bool_dynamic = dynamic_convertor(df)

# %%
final_df_static = pd.concat([df, df_weather_bool_static], axis=1)
final_df_dynamic = pd.concat([df, df_weather_bool_dynamic], axis=1)

# %%
columns_to_drop = {'Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 
                   'End_Lat', 'End_Lng', 'Distance(mi)', 'City', 
                   'County', 'State', 'Temperature(F)', 'Wind_Chill(F)', 
                   'Humidity(%)', 'Pressure(in)', 'Visibility(mi)',
                    'Wind_Speed(mph)', 'Precipitation(in)'}

static_copy = final_df_static.copy()
dynamic_copy = final_df_dynamic.copy()

final_df_static.drop(columns_to_drop, axis=1, inplace=True)
final_df_dynamic.drop(columns_to_drop, axis=1, inplace=True)

# %%
def apply_apriori(df, min_support=0.2, min_threshold=0.2):
    # Apply Apriori algorithm
    frequent_itemsets = apriori(df, min_support=min_support, use_colnames=True)
    rules = association_rules(frequent_itemsets, metric="support", min_threshold=min_threshold)

    sorted_frequents = frequent_itemsets.sort_values('support', ascending=False)
    sorted_rules = rules.sort_values('support', ascending=False)
    print(sorted_frequents)
    print(sorted_rules)
    
    return sorted_frequents, sorted_rules

# %%
result_of_final_df_static = apply_apriori(final_df_static)
# Out:
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
#      support                                         itemsets
# 12  0.733589                                 (Pressure(in)_2)
# 7   0.451411                                (Wind_Chill(F)_3)
# 5   0.400555                               (Temperature(F)_3)
# 0   0.399419                                   (Weather_Fair)
# 2   0.369258                  (Part_of_Day_Afternoon (12-17))
# 22  0.314528                (Wind_Chill(F)_3, Pressure(in)_2)
# 16  0.310507                   (Weather_Fair, Pressure(in)_2)
# 8   0.302287                                (Wind_Chill(F)_4)
# 4   0.297626                               (Temperature(F)_2)
# 11  0.296751                                  (Humidity(%)_4)
# 10   0.29546                                  (Humidity(%)_3)
# 21  0.293551               (Pressure(in)_2, Temperature(F)_3)
# 17   0.27414  (Part_of_Day_Afternoon (12-17), Pressure(in)_2)
# 3   0.270119                    (Part_of_Day_Evening (18-23))
# 13  0.254792                                 (Pressure(in)_3)
# 23  0.239451                (Wind_Chill(F)_4, Pressure(in)_2)
# 9   0.236953                                  (Humidity(%)_2)
# 14  0.236407                              (Wind_Speed(mph)_3)
# 1    0.23562                     (Part_of_Day_Morning (6-11))
# 20  0.233157              (Wind_Chill(F)_3, Temperature(F)_3)
# 15  0.226847                              (Wind_Speed(mph)_4)
# 25  0.219063                  (Humidity(%)_4, Pressure(in)_2)
# 19  0.211431               (Temperature(F)_2, Pressure(in)_2)
# 24  0.208299                  (Humidity(%)_3, Pressure(in)_2)
# 6   0.206156                                (Wind_Chill(F)_2)
# 18  0.205488    (Part_of_Day_Evening (18-23), Pressure(in)_2)
#                         antecedents                      consequents  \
# 13                 (Pressure(in)_2)                (Wind_Chill(F)_3)
# 12                (Wind_Chill(F)_3)                 (Pressure(in)_2)
# 0                    (Weather_Fair)                 (Pressure(in)_2)
# 1                  (Pressure(in)_2)                   (Weather_Fair)
# 11               (Temperature(F)_3)                 (Pressure(in)_2)
# 10                 (Pressure(in)_2)               (Temperature(F)_3)
# 3                  (Pressure(in)_2)  (Part_of_Day_Afternoon (12-17))
# 2   (Part_of_Day_Afternoon (12-17))                 (Pressure(in)_2)
#
#  14  Weather_Cloudy                 bool
#  15  Weather_Drizzle                bool
#  16  Weather_Dust                   bool
#  17  Weather_Fair                   bool
#  18  Weather_Fair / Windy           bool
#  19  Weather_Fog                    bool
#  20  Weather_Haze                   bool
#  21  Weather_Heavy Rain             bool
#  22  Weather_Light Rain             bool
#  23  Weather_Mostly Cloudy          bool
#  24  Weather_Overcast               bool
#  25  Weather_Partly Cloudy          bool
#  26  Weather_Rain                   bool
#  27  Weather_Scatterred Clouds      bool
#  28  Weather_Smoke                  bool
#  29  Weather_Snow                   bool
#  30  Weather_Thunder                bool
#  31  Weekday_Friday                 bool
#  32  Weekday_Monday                 bool
#  33  Weekday_Saturday               bool
#  34  Weekday_Sunday                 bool
#  35  Weekday_Thursday               bool
#  36  Weekday_Tuesday                bool
#  37  Weekday_Wednesday              bool
#  38  Part_of_Day_Night (0-5)        bool
#  39  Part_of_Day_Morning (6-11)     bool
#  40  Part_of_Day_Afternoon (12-17)  bool
#  41  Part_of_Day_Evening (18-23)    bool
#  42  January                        bool
#  43  February                       bool
#  44  March                          bool
#  45  April                          bool
#  46  May                            bool
#  47  June                           bool
#  48  July                           bool
#  49  August                         bool
#  50  September                      bool
#  51  October                        bool
#  52  November                       bool
#  53  December                       bool
#  54  Temperature(F)_0               uint8
#  55  Temperature(F)_1               uint8
#  56  Temperature(F)_2               uint8
#  57  Temperature(F)_3               uint8
#  58  Temperature(F)_4               uint8
#  59  Wind_Chill(F)_0                uint8
#  60  Wind_Chill(F)_1                uint8
#  61  Wind_Chill(F)_2                uint8
#  62  Wind_Chill(F)_3                uint8
#  63  Wind_Chill(F)_4                uint8
#  64  Humidity(%)_0                  uint8
#  65  Humidity(%)_1                  uint8
#  66  Humidity(%)_2                  uint8
#  67  Humidity(%)_3                  uint8
#  68  Humidity(%)_4                  uint8
#  69  Pressure(in)_0                 uint8
#  70  Pressure(in)_1                 uint8
#  71  Pressure(in)_2                 uint8
#  72  Pressure(in)_3                 uint8
#  73  Pressure(in)_4                 uint8
#  74  Wind_Speed(mph)_0              uint8
#  75  Wind_Speed(mph)_1              uint8
#  76  Wind_Speed(mph)_2              uint8
#  77  Wind_Speed(mph)_3              uint8
#  78  Wind_Speed(mph)_4              uint8
# dtypes: bool(54), uint8(25)
# memory usage: 209.0 MB

# %%
result_of_final_df_dynamic = apply_apriori(final_df_dynamic)
# Out:
#      support                         itemsets
# 0   0.399419                   (Weather_Fair)
# 2   0.369258  (Part_of_Day_Afternoon (12-17))
# 7   0.315295                (Wind_Chill(F)_1)
# 3   0.270119    (Part_of_Day_Evening (18-23))
# 1   0.235620     (Part_of_Day_Morning (6-11))
# 9   0.217764                  (Humidity(%)_3)
# 5   0.210809               (Temperature(F)_2)
# 13  0.210490              (Wind_Speed(mph)_1)
# 8   0.209803                  (Humidity(%)_0)
# 12  0.209093                 (Pressure(in)_2)
# 4   0.203744               (Temperature(F)_0)
# 11  0.202609                 (Pressure(in)_1)
# 10  0.201682                 (Pressure(in)_0)
# 6   0.200558                (Wind_Chill(F)_0)
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []

# %% [markdown]
# # Cluster VS NonCluster

# %% [markdown]
# ## Static Mode

# %%
# Number of Clusters
n_clusters = 12

# Clustering
X = static_copy[['End_Lng', 'End_Lat']]
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
static_copy['Cluster'] = kmeans.fit_predict(X)

# Plot
plt.figure(figsize=(12, 8))
scatter = plt.scatter(static_copy['End_Lng'], static_copy['End_Lat'], c=static_copy['Cluster'], cmap='tab20', s=0.3)
plt.xlabel('End Longitude')
plt.ylabel('End Latitude')
plt.title('Sample US Accident Location with Clusters')

# Add colorbar
cbar = plt.colorbar(scatter, ticks=range(12))
cbar.set_label('Cluster')

plt.show()


# Create a dict to store the dataframes for each cluster
cluster_data = {}

# Iterate over unique cluster labels
for cluster_label in static_copy['Cluster'].unique():
    # Filter the dataframe based on the cluster label
    cluster_data[cluster_label] = static_copy[static_copy['Cluster'] == cluster_label].copy()

# %%
results_of_dynamic_clusters = []

for i in range(n_clusters):
    columns_to_drop = {'Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 
                   'End_Lat', 'End_Lng', 'Distance(mi)', 'City', 
                   'County', 'State', 'Temperature(F)', 'Wind_Chill(F)', 
                   'Humidity(%)', 'Pressure(in)', 'Visibility(mi)',
                    'Wind_Speed(mph)', 'Precipitation(in)', 'Cluster'}

    cluster_data[i].drop(columns_to_drop, axis=1, inplace=True)
    
    print(f"#################################### Result of Cluster {i} ####################################")
    
    frequent_itemsets, rules = apply_apriori(cluster_data[i])
    results_of_dynamic_clusters.append((frequent_itemsets, rules))


    # Save frequent itemsets and rules to separate CSV files
    frequent_itemsets.to_csv(f"cluster_{i}_itemsets_static.csv", index=False)
    rules.to_csv(f"cluster_{i}_rules_static.csv", index=False)
# Out:
# #################################### Result of Cluster 0 ####################################
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
#      support                                           itemsets
# 7   0.691792                                  (Wind_Chill(F)_4)
# 4   0.571216                                 (Temperature(F)_3)
# 12  0.527564                                   (Pressure(in)_3)
# 11  0.472436                                   (Pressure(in)_2)
# 2   0.433296                    (Part_of_Day_Afternoon (12-17))
# 0   0.409651                                     (Weather_Fair)
# 9    0.39067                                    (Humidity(%)_3)
# 22  0.376393                (Wind_Chill(F)_4, Temperature(F)_3)
# 29  0.362847                  (Wind_Chill(F)_4, Pressure(in)_2)
# 5   0.360026                                 (Temperature(F)_4)
# 19  0.353957   (Wind_Chill(F)_4, Part_of_Day_Afternoon (12-17))
# 25  0.328956                 (Pressure(in)_3, Temperature(F)_3)
# 30  0.328945                  (Wind_Chill(F)_4, Pressure(in)_3)
# 10   0.32767                                    (Humidity(%)_4)
# 26  0.315399                (Wind_Chill(F)_4, Temperature(F)_4)
# 6   0.291383                                  (Wind_Chill(F)_3)
# 14  0.288588                                (Wind_Speed(mph)_4)
# 28  0.288286                   (Wind_Chill(F)_4, Humidity(%)_3)
# 16  0.287933                    (Wind_Chill(F)_4, Weather_Fair)
# 23  0.266662                  (Humidity(%)_4, Temperature(F)_3)
# 13  0.262845                                (Wind_Speed(mph)_3)
# 3   0.248115                      (Part_of_Day_Evening (18-23))
# 8   0.247742                                    (Humidity(%)_2)
# 24   0.24226                 (Pressure(in)_2, Temperature(F)_3)
# 15  0.241232                   (Weather_Fair, Temperature(F)_3)
# 18  0.232497  (Part_of_Day_Afternoon (12-17), Temperature(F)_4)
# 17  0.230907                     (Pressure(in)_3, Weather_Fair)
# 21  0.223647    (Pressure(in)_3, Part_of_Day_Afternoon (12-17))
# 31  0.214579               (Wind_Chill(F)_4, Wind_Speed(mph)_4)
# 32  0.210574                    (Pressure(in)_3, Humidity(%)_3)
# 1   0.210059                       (Part_of_Day_Morning (6-11))
# 27  0.209904                 (Pressure(in)_2, Temperature(F)_4)
# 20  0.209649    (Part_of_Day_Afternoon (12-17), Pressure(in)_2)
# 33  0.207701  (Wind_Chill(F)_4, Part_of_Day_Afternoon (12-17...
# 34  0.206972  (Wind_Chill(F)_4, Pressure(in)_3, Temperature(...
#                                           antecedents  \
# 15                                 (Temperature(F)_3)
# 14                                  (Wind_Chill(F)_4)
# 29                                   (Pressure(in)_2)
# 28                                  (Wind_Chill(F)_4)
# 8                                   (Wind_Chill(F)_4)
# 9                     (Part_of_Day_Afternoon (12-17))
# 21                                 (Temperature(F)_3)
# 20                                   (Pressure(in)_3)
# 30                                  (Wind_Chill(F)_4)
# 31                                   (Pressure(in)_3)
# 23                                 (Temperature(F)_4)
# 22                                  (Wind_Chill(F)_4)
# 27                                    (Humidity(%)_3)
# 26                                  (Wind_Chill(F)_4)
# 3                                      (Weather_Fair)
# 2                                   (Wind_Chill(F)_4)
# 17                                 (Temperature(F)_3)
# 16                                    (Humidity(%)_4)
# 18                                   (Pressure(in)_2)
# 19                                 (Temperature(F)_3)
# 1                                  (Temperature(F)_3)
# 0                                      (Weather_Fair)
# 7                                  (Temperature(F)_4)
# 6                     (Part_of_Day_Afternoon (12-17))
# 5                                      (Weather_Fair)
# 4                                    (Pressure(in)_3)
# 13                    (Part_of_Day_Afternoon (12-17))
# 12                                   (Pressure(in)_3)
# 32                                  (Wind_Chill(F)_4)
# 33                                (Wind_Speed(mph)_4)
# 34                                   (Pressure(in)_3)
# 35                                    (Humidity(%)_3)
# 24                                   (Pressure(in)_2)
# 25                                 (Temperature(F)_4)
# 11                                   (Pressure(in)_2)
# 10                    (Part_of_Day_Afternoon (12-17))
# 36   (Wind_Chill(F)_4, Part_of_Day_Afternoon (12-17))
# 37                (Wind_Chill(F)_4, Temperature(F)_4)
# 38  (Part_of_Day_Afternoon (12-17), Temperature(F)_4)
# 39                                  (Wind_Chill(F)_4)
# 40                    (Part_of_Day_Afternoon (12-17))
# 41                                 (Temperature(F)_4)
# 42                  (Wind_Chill(F)_4, Pressure(in)_3)
# 43                (Wind_Chill(F)_4, Temperature(F)_3)
# 44                 (Pressure(in)_3, Temperature(F)_3)
# 45                                  (Wind_Chill(F)_4)
# 46                                   (Pressure(in)_3)
# 47                                 (Temperature(F)_3)
#
#                                           consequents  antecedent support  \
# 15                                  (Wind_Chill(F)_4)            0.571216
# 14                                 (Temperature(F)_3)            0.691792
# 29                                  (Wind_Chill(F)_4)            0.472436
# 28                                   (Pressure(in)_2)            0.691792
# 8                     (Part_of_Day_Afternoon (12-17))            0.691792
# 9                                   (Wind_Chill(F)_4)            0.433296
# 21                                   (Pressure(in)_3)            0.571216
# 20                                 (Temperature(F)_3)            0.527564
# 30                                   (Pressure(in)_3)            0.691792
# 31                                  (Wind_Chill(F)_4)            0.527564
# 23                                  (Wind_Chill(F)_4)            0.360026
# 22                                 (Temperature(F)_4)            0.691792
# 27                                  (Wind_Chill(F)_4)            0.390670
# 26                                    (Humidity(%)_3)            0.691792
# 3                                   (Wind_Chill(F)_4)            0.409651
# 2                                      (Weather_Fair)            0.691792
####################################
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
#      support                                          itemsets
# 12  0.705732                                  (Pressure(in)_2)
# 7   0.555993                                 (Wind_Chill(F)_3)
# 0   0.498591                                    (Weather_Fair)
# 4   0.484514                                (Temperature(F)_2)
# 17  0.372132                    (Weather_Fair, Pressure(in)_2)
# 26  0.371221                 (Wind_Chill(F)_3, Pressure(in)_2)
# 2   0.357038                   (Part_of_Day_Afternoon (12-17))
# 5   0.337609                                (Temperature(F)_3)
# 23  0.301002                (Temperature(F)_2, Pressure(in)_2)
# 21  0.298697               (Temperature(F)_2, Wind_Chill(F)_3)
# 11  0.291579                                   (Humidity(%)_4)
# 3   0.290863                     (Part_of_Day_Evening (18-23))
# 13   0.27513                                  (Pressure(in)_3)
# 10   0.26379                                   (Humidity(%)_3)
# 19  0.260956   (Part_of_Day_Afternoon (12-17), Pressure(in)_2)
# 25  0.260895                (Pressure(in)_2, Temperature(F)_3)
# 24  0.239223               (Wind_Chill(F)_3, Temperature(F)_3)
# 6   0.239129                                 (Wind_Chill(F)_2)
# 22  0.231498                 (Humidity(%)_4, Temperature(F)_2)
# 16  0.225553                   (Weather_Fair, Wind_Chill(F)_3)
# 1   0.220843                      (Part_of_Day_Morning (6-11))
# 15  0.219542                               (Wind_Speed(mph)_4)
# 20  0.210282     (Part_of_Day_Evening (18-23), Pressure(in)_2)
# 9    0.20563                                   (Humidity(%)_2)
# 18  0.203358  (Part_of_Day_Afternoon (12-17), Wind_Chill(F)_3)
# 14  0.203241                               (Wind_Speed(mph)_3)
# 8   0.200123                                 (Wind_Chill(F)_4)
#                         antecedents                      consequents  \
# 2                    (Weather_Fair)                 (Pressure(in)_2)
# 3                  (Pressure(in)_2)                   (Weather_Fair)
# 21                 (Pressure(in)_2)                (Wind_Chill(F)_3)
# 20                (Wind_Chill(F)_3)                 (Pressure(in)_2)
# 15                 (Pressure(in)_2)               (Temperature(F)_2)
# 14               (Temperature(F)_2)                 (Pressure(in)_2)
# 10               (Temperature(F)_2)                (Wind_Chill(F)_3)
# 11                (Wind_Chill(F)_3)               (Temperature(F)_2)
# 7                  (Pressure(in)_2)  (Part_of_Day_Afternoon (12-17))
# 6   (Part_of_Day_Afternoon (12-17))                 (Pressure(in)_2)
# 18                 (Pressure(in)_2)               (Temperature(F)_3)
# 19               (Temperature(F)_3)                 (Pressure(in)_2)
# 16                (Wind_Chill(F)_3)               (Temperature(F)_3)
# 17               (Temperature(F)_3)                (Wind_Chill(F)_3)
# 12                  (Humidity(%)_4)               (Temperature(F)_2)
# 13               (Temperature(F)_2)                  (Humidity(%)_4)
# 1                 (Wind_Chill(F)_3)                   (Weather_Fair)
# 0                    (Weather_Fair)                (Wind_Chill(F)_3)
# 8     (Part_of_Day_Evening (18-23))                 (Pressure(in)_2)
# 9                  (Pressure(in)_2)    (Part_of_Day_Evening (18-23))
# 5                 (Wind_Chill(F)_3)  (Part_of_Day_Afternoon (12-17))
# 4   (Part_of_Day_Afternoon (12-17))                (Wind_Chill(F)_3)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 2             0.498591            0.705732  0.372132    0.746366  1.057578
# 3             0.705732            0.498591  0.372132    0.527299  1.057578
# 21            0.705732            0.555993  0.371221    0.526009  0.946072
# 20            0.555993            0.705732  0.371221    0.667673  0.946072
# 15            0.705732            0.484514  0.301002    0.426510  0.880284
# 14            0.484514            0.705732  0.301002    0.621244  0.880284
# 10            0.484514            0.555993  0.298697    0.616487  1.108805
# 11            0.555993            0.484514  0.298697    0.537232  1.108805
# 7             0.705732            0.357038  0.260956    0.369767  1.035652
# 6             0.357038            0.705732  0.260956    0.730892  1.035652
# 7             0.339420            0.405093  0.204548    0.602640  1.487659
#
#     leverage  conviction  zhangs_metric
# 12 -0.010663    0.919014      -0.061521
# 13 -0.010663    0.975078      -0.115481
# 2   0.008700    1.088843       0.052230
# 3   0.008700    1.019671       0.112440
# 8   0.012426    1.027562       0.166091
# 9   0.012426    1.139677       0.075105
# 14  0.020375    1.276579       0.123307
# 15  0.020375    1.044282       0.282838
# 0   0.000359    1.003571       0.002286
# 1   0.000359    1.000775       0.005066
# 4  -0.005606    0.946421      -0.035646
# 5  -0.005606    0.988183      -0.076400
# 10 -0.009606    0.912598      -0.060173
# 11 -0.009606    0.979796      -0.124630
# 6   0.067051    1.334346       0.551016
# 7   0.067051    1.497150       0.496235
# #################################### Result of Cluster 4 ####################################
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
#      support                                           itemsets
# 12  0.817482                                   (Pressure(in)_2)
# 7    0.45468                                  (Wind_Chill(F)_3)
# 5   0.435607                                 (Temperature(F)_3)
# 8   0.405576                                  (Wind_Chill(F)_4)
# 23  0.386616                  (Wind_Chill(F)_4, Pressure(in)_2)
# 0   0.371026                                     (Weather_Fair)
# 19  0.357991                 (Pressure(in)_2, Temperature(F)_3)
# 2   0.345926                    (Part_of_Day_Afternoon (12-17))
# 15  0.335302                     (Weather_Fair, Pressure(in)_2)
# 22  0.326084                  (Wind_Chill(F)_3, Pressure(in)_2)
# 14  0.292636                                (Wind_Speed(mph)_4)
# 10  0.290021                                    (Humidity(%)_3)
# 16  0.287663    (Part_of_Day_Afternoon (12-17), Pressure(in)_2)
# 11  0.280553                                    (Humidity(%)_4)
# 6    0.28019                                 (Temperature(F)_4)
# 9   0.279535                                    (Humidity(%)_2)
# 3   0.276813                      (Part_of_Day_Evening (18-23))
# 13  0.262944                                (Wind_Speed(mph)_3)
# 21  0.255781                 (Pressure(in)_2, Temperature(F)_4)
# 1   0.244937                       (Part_of_Day_Morning (6-11))
# 18  0.243692                (Wind_Chill(F)_3, Temperature(F)_3)
# 28   0.24078                (Pressure(in)_2, Wind_Speed(mph)_4)
# 17   0.23657      (Part_of_Day_Evening (18-23), Pressure(in)_2)
# 25  0.236255                    (Humidity(%)_3, Pressure(in)_2)
# 24  0.234307                    (Humidity(%)_2, Pressure(in)_2)
# 4   0.229603                                 (Temperature(F)_2)
# 26  0.224785                    (Humidity(%)_4, Pressure(in)_2)
# 20  0.213662                (Wind_Chill(F)_4, Temperature(F)_4)
# 27  0.210899                (Pressure(in)_2, Wind_Speed(mph)_3)
# 29  0.208011  (Wind_Chill(F)_4, Pressure(in)_2, Temperature(...
#                             antecedents                          consequents  \
# 17                     (Pressure(in)_2)                    (Wind_Chill(F)_4)
# 16                    (Wind_Chill(F)_4)                     (Pressure(in)_2)
# 8                      (Pressure(in)_2)                   (Temperature(F)_3)
# 9                    (Temperature(F)_3)                     (Pressure(in)_2)
# 1                      (Pressure(in)_2)                       (Weather_Fair)
# 0                        (Weather_Fair)                     (Pressure(in)_2)
# 14                    (Wind_Chill(F)_3)                     (Pressure(in)_2)
# 15                     (Pressure(in)_2)                    (Wind_Chill(F)_3)
# 3                      (Pressure(in)_2)      (Part_of_Day_Afternoon (12-17))
# 14   0.26453                    (Weather_Fair, Wind_Chill(F)_3)
# 30  0.262458   (Weather_Fair, Temperature(F)_3, Pressure(in)_2)
# 7    0.25507                                  (Wind_Chill(F)_4)
# 27  0.249787                  (Wind_Chill(F)_4, Pressure(in)_2)
# 25  0.244712                   (Wind_Chill(F)_3, Humidity(%)_3)
# 8   0.237499                                    (Humidity(%)_2)
# 20  0.237379      (Part_of_Day_Evening (18-23), Pressure(in)_2)
# 1   0.234903                       (Part_of_Day_Morning (6-11))
# 31  0.233906    (Weather_Fair, Wind_Chill(F)_3, Pressure(in)_2)
# 17    0.2274  (Part_of_Day_Afternoon (12-17), Temperature(F)_3)
# 33  0.215973  (Temperature(F)_2, Wind_Chill(F)_3, Pressure(i...
# 11  0.214443                                (Wind_Speed(mph)_3)
# 35  0.209584   (Wind_Chill(F)_3, Humidity(%)_3, Pressure(in)_2)
# 28  0.208157                    (Humidity(%)_2, Pressure(in)_2)
# 18  0.207688   (Part_of_Day_Afternoon (12-17), Wind_Chill(F)_3)
# 15   0.20653                    (Wind_Chill(F)_4, Weather_Fair)
# 32  0.202305    (Wind_Chill(F)_4, Weather_Fair, Pressure(in)_2)
# 12  0.200437      (Weather_Fair, Part_of_Day_Afternoon (12-17))
#                           antecedents                      consequents  \
# 28                  (Wind_Chill(F)_3)                 (Pressure(in)_2)
# 29                   (Pressure(in)_2)                (Wind_Chill(F)_3)
# 9                    (Pressure(in)_2)                   (Weather_Fair)
# 8                      (Weather_Fair)                 (Pressure(in)_2)
# 25                 (Temperature(F)_3)                 (Pressure(in)_2)
# ..                                ...                              ...
# 50     (Weather_Fair, Pressure(in)_2)                (Wind_Chill(F)_4)
# 49  (Wind_Chill(F)_4, Pressure(in)_2)                   (Weather_Fair)
# 48    (Wind_Chill(F)_4, Weather_Fair)                 (Pressure(in)_2)
# 1     (Part_of_Day_Afternoon (12-17))                   (Weather_Fair)
# 0                      (Weather_Fair)  (Part_of_Day_Afternoon (12-17))
#
#     antecedent support  consequent support   support  confidence      lift  \
# 28            0.648118            0.877392  0.542706    0.837357  0.954371
# 29            0.877392            0.648118  0.542706    0.618545  0.954371
# 9             0.877392            0.527120  0.483377    0.550925  1.045162
# 8             0.527120            0.877392  0.483377    0.917016  1.045162
# 25            0.510385            0.877392  0.451555    0.884733  1.008367
# ..                 ...                 ...       ...         ...       ...
# 50            0.483377            0.255070  0.202305    0.418523  1.640817
# 49            0.249787            0.527120  0.202305    0.809910  1.536483
# 48            0.206530            0.877392  0.202305    0.979542  1.116425
# 1             0.370953            0.527120  0.200437    0.540330  1.025062
# 0             0.527120            0.370953  0.200437    0.380250  1.025062
#
#     leverage  conviction  zhangs_metric
# 28 -0.025947    0.753850      -0.119618
# 29 -0.025947    0.922473      -0.280547
# 9   0.020887    1.053011       0.352427
# 8   0.020887    1.477500       0.091377
# 25  0.003747    1.063689       0.016947
# ..       ...         ...            ...
# 50  0.079010    1.281100       0.755963
# 49  0.070637    2.487670       0.465418
# 48  0.021097    5.993216       0.131427
# 1   0.004900    1.028739       0.038866
# 0   0.004900    1.015001       0.051702
#
# [72 rows x 10 columns]
# #################################### Result of Cluster 6 ####################################
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
#      support                                         itemsets
# 11  0.704221                                 (Pressure(in)_2)
# 5   0.462424                               (Temperature(F)_2)
# 8   0.441713                                (Wind_Chill(F)_3)
# 10  0.408674                                  (Humidity(%)_4)
# 7   0.407269                                (Wind_Chill(F)_2)
# 2   0.360329                  (Part_of_Day_Afternoon (12-17))
# 20  0.301643               (Temperature(F)_2, Pressure(in)_2)
# 22  0.295892                (Wind_Chill(F)_2, Pressure(in)_2)
# 12  0.289415                                 (Pressure(in)_3)
# 24  0.289088                  (Humidity(%)_4, Pressure(in)_2)
# 9   0.277319                                  (Humidity(%)_3)
# 23  0.274699                (Wind_Chill(F)_3, Pressure(in)_2)
# 3   0.270877                    (Part_of_Day_Evening (18-23))
# 0   0.267008                                   (Weather_Fair)
# ...
#   DeprecationWarning,
#      support                                         itemsets
# 14  0.630797                                 (Pressure(in)_2)
# 7   0.372218                                (Wind_Chill(F)_2)
# 2   0.348825                  (Part_of_Day_Afternoon (12-17))
# 4   0.343202                               (Temperature(F)_1)
# 8     0.3067                                (Wind_Chill(F)_3)
# 0   0.290479                                   (Weather_Fair)
# 1   0.282105                     (Part_of_Day_Morning (6-11))
# 16  0.276253                              (Wind_Speed(mph)_4)
# 5   0.271075                               (Temperature(F)_2)
# 3   0.261378                    (Part_of_Day_Evening (18-23))
# 21  0.247825                (Wind_Chill(F)_2, Pressure(in)_2)
# 13  0.243536                                 (Pressure(in)_1)
# 9   0.237769                                  (Humidity(%)_1)
# 15  0.234681                              (Wind_Speed(mph)_3)
# 19  0.234452              (Wind_Chill(F)_2, Temperature(F)_1)
# 12  0.223242                                  (Humidity(%)_4)
# 18  0.217006  (Part_of_Day_Afternoon (12-17), Pressure(in)_2)
# 20   0.21023               (Temperature(F)_1, Pressure(in)_2)
# 11  0.209136                                  (Humidity(%)_3)
# 6   0.203453                               (Temperature(F)_3)
# 17  0.202228                   (Weather_Fair, Pressure(in)_2)
# 10  0.201182                                  (Humidity(%)_2)
#                        antecedents                      consequents  \
# 8                (Wind_Chill(F)_2)                 (Pressure(in)_2)
# 9                 (Pressure(in)_2)                (Wind_Chill(F)_2)
# 4                (Wind_Chill(F)_2)               (Temperature(F)_1)
# 5               (Temperature(F)_1)                (Wind_Chill(F)_2)
# 2  (Part_of_Day_Afternoon (12-17))                 (Pressure(in)_2)
# 3                 (Pressure(in)_2)  (Part_of_Day_Afternoon (12-17))
# 6               (Temperature(F)_1)                 (Pressure(in)_2)
# 7                 (Pressure(in)_2)               (Temperature(F)_1)
# 0                   (Weather_Fair)                 (Pressure(in)_2)
# 1                 (Pressure(in)_2)                   (Weather_Fair)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 8            0.372218            0.630797  0.247825    0.665806  1.055499
# 9            0.630797            0.372218  0.247825    0.392876  1.055499
# 4            0.372218            0.343202  0.234452    0.629878  1.835300
# 5            0.343202            0.372218  0.234452    0.683133  1.835300
# 2            0.348825            0.630797  0.217006    0.622107  0.986223
# 3            0.630797            0.348825  0.217006    0.344019  0.986223
# 6            0.343202            0.630797  0.210230    0.612554  0.971079
# 7            0.630797            0.343202  0.210230    0.333276  0.971079
# 0            0.290479            0.630797  0.202228    0.696186  1.103661
# 8    0.36496                                 (Temperature(F)_4)
# 7   0.361613                                 (Temperature(F)_3)
# 32  0.359576                  (Wind_Chill(F)_3, Pressure(in)_2)
# 35  0.358661                    (Pressure(in)_2, Humidity(%)_0)
# 31  0.352677                 (Pressure(in)_2, Temperature(F)_4)
# 12  0.351099                                    (Humidity(%)_1)
# 4   0.343047                    (Part_of_Day_Afternoon (12-17))
# 20  0.330055                    (Wind_Chill(F)_4, Weather_Fair)
# 40  0.318894    (Wind_Chill(F)_4, Weather_Fair, Pressure(in)_2)
# 28  0.317331                 (Pressure(in)_2, Temperature(F)_3)
# 36  0.311916                    (Humidity(%)_1, Pressure(in)_2)
# 5   0.304922                      (Part_of_Day_Evening (18-23))
# 25  0.302933    (Part_of_Day_Afternoon (12-17), Pressure(in)_2)
# 29  0.290714                (Wind_Chill(F)_4, Temperature(F)_4)
# 43  0.282805  (Wind_Chill(F)_4, Pressure(in)_2, Temperature(...
# 33  0.271896                   (Wind_Chill(F)_4, Humidity(%)_0)
# 26  0.271281      (Part_of_Day_Evening (18-23), Pressure(in)_2)
# 21  0.263435                      (Weather_Fair, Humidity(%)_0)
# 45   0.26214   (Wind_Chill(F)_4, Pressure(in)_2, Humidity(%)_0)
# 41  0.250695      (Pressure(in)_2, Weather_Fair, Humidity(%)_0)
# 30  0.241949                  (Temperature(F)_4, Humidity(%)_0)
# 44  0.234434  (Pressure(in)_2, Temperature(F)_4, Humidity(%)_0)
# 15  0.226588                                (Wind_Speed(mph)_3)
# 3   0.224504                       (Part_of_Day_Morning (6-11))
# 19  0.224157                   (Weather_Fair, Temperature(F)_4)
# 6   0.222405                                 (Temperature(F)_2)
# 37  0.221536  (Wind_Chill(F)_4, Weather_Fair, Temperature(F)_4)
# 39   0.21961     (Wind_Chill(F)_4, Weather_Fair, Humidity(%)_0)
# 38  0.219105   (Pressure(in)_2, Weather_Fair, Temperature(F)_4)
# 46  0.216532  (Wind_Chill(F)_4, Pressure(in)_2, Weather_Fair...
# 22   0.21609                      (Humidity(%)_1, Weather_Fair)
# 14  0.215222                                (Wind_Speed(mph)_2)
# 0    0.21448                                         (Crossing)
# 1   0.213927                                   (Traffic_Signal)
# 47  0.212696  (Wind_Chill(F)_4, Pressure(in)_2, Weather_Fair...
# 16  0.209617                         (Crossing, Pressure(in)_2)
# 18  0.208086                   (Weather_Fair, Temperature(F)_3)
# 17  0.207076                   (Traffic_Signal, Pressure(in)_2)
# 27  0.206602                (Wind_Chill(F)_3, Temperature(F)_3)
# 24   0.20155   (Wind_Chill(F)_4, Part_of_Day_Afternoon (12-17))
# 42  0.201345      (Humidity(%)_1, Weather_Fair, Pressure(in)_2)
#                         antecedents                      consequents  \
# 15                 (Pressure(in)_2)                   (Weather_Fair)
# 14                   (Weather_Fair)                 (Pressure(in)_2)
# 36                (Wind_Chill(F)_4)                 (Pressure(in)_2)
# 37                 (Pressure(in)_2)                (Wind_Chill(F)_4)
# 32                (Wind_Chill(F)_3)                 (Pressure(in)_2)
# ..                              ...                              ...
# 76                   (Weather_Fair)  (Humidity(%)_1, Pressure(in)_2)
# 75                  (Humidity(%)_1)   (Weather_Fair, Pressure(in)_2)
# 74   (Weather_Fair, Pressure(in)_2)                  (Humidity(%)_1)
# 73  (Humidity(%)_1, Pressure(in)_2)                   (Weather_Fair)
# 72    (Humidity(%)_1, Weather_Fair)                 (Pressure(in)_2)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 15            0.868401            0.584112  0.537778    0.619274  1.060196
# 14            0.584112            0.868401  0.537778    0.920676  1.060196
# 36            0.445725            0.868401  0.428533    0.961429  1.107126
# 37            0.868401            0.445725  0.428533    0.493474  1.107126
# 32            0.431864            0.868401  0.359576    0.832614  0.958790
# ..                 ...                 ...       ...         ...       ...
# 76            0.584112            0.311916  0.201345    0.344703  1.105114
# 75            0.351099            0.537778  0.201345    0.573471  1.066372
# 74            0.537778            0.351099  0.201345    0.374402  1.066372
# 73            0.311916            0.584112  0.201345    0.645511  1.105114
# 72            0.216090            0.868401  0.201345    0.931765  1.072966
#
#     leverage  conviction  zhangs_metric
# 15  0.030534    1.092353       0.431451
# 14  0.030534    1.658998       0.136524
# 36  0.041465    3.411904       0.174571
# 37  0.041465    1.094267       0.735268
# 32 -0.015455    0.786202      -0.070332
# ..       ...         ...            ...
# 76  0.019151    1.050033       0.228706
# 75  0.012532    1.083683       0.095917
# 74  0.012532    1.037249       0.134656
# 73  0.019151    1.173203       0.138233
# 72  0.013692    1.928614       0.086750
#
# [124 rows x 10 columns]

# %% [markdown]
# ## Dynamic Mode

# %%
# Number of Clusters
n_clusters = 12

# Clustering
X = dynamic_copy[['End_Lng', 'End_Lat']]
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
dynamic_copy['Cluster'] = kmeans.fit_predict(X)

# Plot
plt.figure(figsize=(12, 8))
scatter = plt.scatter(dynamic_copy['End_Lng'], dynamic_copy['End_Lat'], c=dynamic_copy['Cluster'], cmap='tab20', s=0.3)
plt.xlabel('End Longitude')
plt.ylabel('End Latitude')
plt.title('Sample US Accident Location with Clusters')

# Add colorbar
cbar = plt.colorbar(scatter, ticks=range(12))
cbar.set_label('Cluster')

plt.show()


# Create a dict to store the dataframes for each cluster
cluster_data = {}

# Iterate over unique cluster labels
for cluster_label in dynamic_copy['Cluster'].unique():
    # Filter the dataframe based on the cluster label
    cluster_data[cluster_label] = dynamic_copy[dynamic_copy['Cluster'] == cluster_label].copy()

# %%
results_of_dynamic_clusters = []

for i in range(n_clusters):
    columns_to_drop = {'Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 
                   'End_Lat', 'End_Lng', 'Distance(mi)', 'City', 
                   'County', 'State', 'Temperature(F)', 'Wind_Chill(F)', 
                   'Humidity(%)', 'Pressure(in)', 'Visibility(mi)',
                    'Wind_Speed(mph)', 'Precipitation(in)', 'Cluster'}

    cluster_data[i].drop(columns_to_drop, axis=1, inplace=True)
    
    print(f"#################################### Result of Cluster {i} ####################################")
    
    frequent_itemsets, rules = apply_apriori(cluster_data[i])
    results_of_dynamic_clusters.append((frequent_itemsets, rules))


    # Save frequent itemsets and rules to separate CSV files
    frequent_itemsets.to_csv(f"cluster_{i}_itemsets_dynamic.csv", index=False)
    rules.to_csv(f"cluster_{i}_rules_dynamic.csv", index=False)
# Out:
# #################################### Result of Cluster 0 ####################################
#      support                                           itemsets
# 7   0.491808                                  (Wind_Chill(F)_4)
# 5   0.452256                                 (Temperature(F)_4)
# 2   0.433296                    (Part_of_Day_Afternoon (12-17))
# 11  0.431995                                   (Pressure(in)_3)
# 0   0.409651                                     (Weather_Fair)
# 18  0.401755                (Wind_Chill(F)_4, Temperature(F)_4)
# 12  0.375623                                   (Pressure(in)_4)
# 4   0.347355                                 (Temperature(F)_3)
# 6   0.295571                                  (Wind_Chill(F)_3)
# 16  0.287334   (Wind_Chill(F)_4, Part_of_Day_Afternoon (12-17))
# 15  0.278313  (Part_of_Day_Afternoon (12-17), Temperature(F)_4)
# 10  0.263229                                    (Humidity(%)_3)
# 9   0.261496                                    (Humidity(%)_2)
# 21  0.251071  (Wind_Chill(F)_4, Part_of_Day_Afternoon (12-17...
# 20  0.248539                  (Wind_Chill(F)_4, Pressure(in)_3)
# 3   0.248115                      (Part_of_Day_Evening (18-23))
# 13  0.245857                                (Wind_Speed(mph)_3)
# 19  0.227528                 (Pressure(in)_3, Temperature(F)_4)
# 8   0.224901                                    (Humidity(%)_1)
# 17  0.222930                (Wind_Chill(F)_3, Temperature(F)_3)
# 1   0.210059                       (Part_of_Day_Morning (6-11))
# 14  0.209086                                (Wind_Speed(mph)_4)
# 22  0.205734  (Wind_Chill(F)_4, Pressure(in)_3, Temperature(...
#                                           antecedents  \
# 6                                   (Wind_Chill(F)_4)
# 7                                  (Temperature(F)_4)
# 2                                   (Wind_Chill(F)_4)
# 3                     (Part_of_Day_Afternoon (12-17))
# 0                     (Part_of_Day_Afternoon (12-17))
# 1                                  (Temperature(F)_4)
# 17                                 (Temperature(F)_4)
# 16                    (Part_of_Day_Afternoon (12-17))
# 15                                  (Wind_Chill(F)_4)
# 14  (Part_of_Day_Afternoon (12-17), Temperature(F)_4)
# 13                (Wind_Chill(F)_4, Temperature(F)_4)
# 12   (Wind_Chill(F)_4, Part_of_Day_Afternoon (12-17))
# 11                                   (Pressure(in)_3)
# 10                                  (Wind_Chill(F)_4)
# 9                                  (Temperature(F)_4)
# 8                                    (Pressure(in)_3)
# 5                                  (Temperature(F)_3)
# 4                                   (Wind_Chill(F)_3)
# 18                  (Wind_Chill(F)_4, Pressure(in)_3)
# 19                (Wind_Chill(F)_4, Temperature(F)_4)
# 20                 (Pressure(in)_3, Temperature(F)_4)
# 21                                  (Wind_Chill(F)_4)
# 22                                   (Pressure(in)_3)
# 23                                 (Temperature(F)_4)
#
#                                           consequents  antecedent support  \
# 6                                  (Temperature(F)_4)            0.491808
# 7                                   (Wind_Chill(F)_4)            0.452256
# 2                     (Part_of_Day_Afternoon (12-17))            0.491808
# 3                                   (Wind_Chill(F)_4)            0.433296
# 0                                  (Temperature(F)_4)            0.433296
# 1                     (Part_of_Day_Afternoon (12-17))            0.452256
# 17   (Wind_Chill(F)_4, Part_of_Day_Afternoon (12-17))            0.452256
# 16                (Wind_Chill(F)_4, Temperature(F)_4)            0.433296
# 15  (Part_of_Day_Afternoon (12-17), Temperature(F)_4)            0.491808
# 14                                  (Wind_Chill(F)_4)            0.278313
# 13                    (Part_of_Day_Afternoon (12-17))            0.401755
# 12                                 (Temperature(F)_4)            0.287334
# 11                                  (Wind_Chill(F)_4)            0.431995
# 10                                   (Pressure(in)_3)            0.491808
# 9                                    (Pressure(in)_3)            0.452256
# 8                                  (Temperature(F)_4)            0.431995
# 5                                   (Wind_Chill(F)_3)            0.347355
# 4                                  (Temperature(F)_3)            0.295571
# 18                                 (Temperature(F)_4)            0.248539
# 19                                   (Pressure(in)_3)            0.401755
# 20                                  (Wind_Chill(F)_4)            0.227528
# 21                 (Pressure(in)_3, Temperature(F)_4)            0.491808
# 22                (Wind_Chill(F)_4, Temperature(F)_4)            0.431995
# 23                  (Wind_Chill(F)_4, Pressure(in)_3)            0.452256
#
#     consequent support   support  confidence      lift  leverage  conviction  \
#
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.441089  0.315463    0.933589  2.116554  0.166417    8.415981
# 1            0.337903  0.315463    0.715190  2.116554  0.166417    2.324697
#
#    zhangs_metric
# 0       0.796762
# 1       0.943861
# #################################### Result of Cluster 2 ####################################
#      support                             itemsets
# 3   0.387015                   (Temperature(F)_0)
# 4   0.369925                    (Wind_Chill(F)_0)
# 5   0.366349                    (Wind_Chill(F)_1)
# 1   0.351181      (Part_of_Day_Afternoon (12-17))
# 15  0.351085  (Temperature(F)_0, Wind_Chill(F)_0)
# 10  0.332723                     (Pressure(in)_1)
# 13  0.276731                  (Wind_Speed(mph)_3)
# 0   0.274549         (Part_of_Day_Morning (6-11))
# 2   0.270057        (Part_of_Day_Evening (18-23))
# 8   0.248583                      (Humidity(%)_3)
# 14  0.244721                  (Wind_Speed(mph)_4)
# 9   0.227230                     (Pressure(in)_0)
# 7   0.217590                      (Humidity(%)_2)
# 11  0.217342                     (Pressure(in)_4)
# 6   0.213022                      (Humidity(%)_1)
# 12  0.200570                  (Wind_Speed(mph)_1)
#           antecedents         consequents  antecedent support  \
# 0  (Temperature(F)_0)   (Wind_Chill(F)_0)            0.387015
# 1   (Wind_Chill(F)_0)  (Temperature(F)_0)            0.369925
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.369925  0.351085    0.907161  2.452285  0.207919    6.786779
# 1            0.387015  0.351085    0.949071  2.452285  0.207919   12.036117
#
#    zhangs_metric
# 0       0.966120
# 1       0.939915
# #################################### Result of Cluster 3 ####################################
#      support                             itemsets
# 2   0.356946      (Part_of_Day_Afternoon (12-17))
# 5   0.343915                    (Wind_Chill(F)_0)
# 4   0.339859                   (Temperature(F)_0)
# 0   0.338124                       (Weather_Fair)
# 14  0.319800  (Temperature(F)_0, Wind_Chill(F)_0)
# 6   0.288373                    (Wind_Chill(F)_1)
# 3   0.267981        (Part_of_Day_Evening (18-23))
# 9   0.257209                     (Pressure(in)_1)
# 11  0.250880                     (Pressure(in)_4)
# 1   0.244866         (Part_of_Day_Morning (6-11))
# 10  0.242632                     (Pressure(in)_2)
# 7   0.229198                      (Humidity(%)_1)
# 12  0.208759                  (Wind_Speed(mph)_1)
# 8   0.206656                      (Humidity(%)_4)
# 13  0.200408                  (Wind_Speed(mph)_3)
#           antecedents         consequents  antecedent support  \
# 0  (Temperature(F)_0)   (Wind_Chill(F)_0)            0.339859
# 1   (Wind_Chill(F)_0)  (Temperature(F)_0)            0.343915
#
#    consequent support  support  confidence     lift  leverage  conviction  \
# 0            0.343915   0.3198    0.940980  2.73608  0.202918   11.116377
# 1            0.339859   0.3198    0.929881  2.73608  0.202918    9.414590
#
#    zhangs_metric
# 0       0.961179
# 1       0.967122
# #################################### Result of Cluster 4 ####################################
#      support                             itemsets
# 12  0.417748                     (Pressure(in)_1)
# 0   0.371026                       (Weather_Fair)
# 2   0.345926      (Part_of_Day_Afternoon (12-17))
# 5   0.322345                   (Temperature(F)_4)
# 4  0.141355   19.371422       0.765101
# 5  0.141355    1.833921       0.977762
# 2  0.053486    1.171850       0.523916
# 3  0.053486    1.580080       0.358066
# 0  0.004900    1.015001       0.051702
# 1  0.004900    1.028739       0.038866
# #################################### Result of Cluster 6 ####################################
#      support                             itemsets
# 4   0.403465                   (Temperature(F)_0)
# 6   0.394071                    (Wind_Chill(F)_0)
# 7   0.376533                    (Wind_Chill(F)_1)
# 14  0.362281  (Temperature(F)_0, Wind_Chill(F)_0)
# 2   0.360329      (Part_of_Day_Afternoon (12-17))
# 5   0.280539                   (Temperature(F)_1)
# 3   0.270877        (Part_of_Day_Evening (18-23))
# 0   0.267008                       (Weather_Fair)
# 8   0.265538                      (Humidity(%)_3)
# 9   0.260174                      (Humidity(%)_4)
# 10  0.259203                     (Pressure(in)_0)
# 1   0.250244         (Part_of_Day_Morning (6-11))
# 15  0.248750  (Temperature(F)_1, Wind_Chill(F)_1)
# 11  0.239267                     (Pressure(in)_4)
# 12  0.234397                  (Wind_Speed(mph)_1)
# 13  0.201572                  (Wind_Speed(mph)_2)
#           antecedents         consequents  antecedent support  \
# 0  (Temperature(F)_0)   (Wind_Chill(F)_0)            0.403465
# 1   (Wind_Chill(F)_0)  (Temperature(F)_0)            0.394071
# 2  (Temperature(F)_1)   (Wind_Chill(F)_1)            0.280539
# 3   (Wind_Chill(F)_1)  (Temperature(F)_1)            0.376533
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.394071  0.362281    0.897925  2.278590  0.203288    5.936145
# 1            0.403465  0.362281    0.919330  2.278590  0.203288    7.394804
# 2            0.376533  0.248750    0.886684  2.354865  0.143118    5.502039
# 3            0.280539  0.248750    0.660632  2.354865  0.143118    2.120004
#
#    zhangs_metric
# 0       0.940652
# 1       0.926069
# 2       0.799692
# 3       0.922819
# #################################### Result of Cluster 7 ####################################
#      support                         itemsets
# 0   0.385675                   (Weather_Fair)
# 2   0.361951  (Part_of_Day_Afternoon (12-17))
# 7   0.321969                (Wind_Chill(F)_1)
# 11  0.316834                 (Pressure(in)_1)
# 3   0.281894    (Part_of_Day_Evening (18-23))
# 9   0.275681                  (Humidity(%)_4)
# 10  0.270657                 (Pressure(in)_0)
# 12  0.241734              (Wind_Speed(mph)_1)
# 8   0.224679                (Wind_Chill(F)_3)
# 1   0.220119     (Part_of_Day_Morning (6-11))
# 5   0.217503               (Temperature(F)_2)
# 6   0.209777               (Temperature(F)_3)
# 4   0.200512               (Temperature(F)_1)
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []
# #################################### Result of Cluster 8 ####################################
#      support                                           itemsets
# 10  0.634576                                   (Pressure(in)_0)
# 5   0.553818                                 (Temperature(F)_0)
# 6   0.483822                                  (Wind_Chill(F)_0)
# 16  0.468796                (Temperature(F)_0, Wind_Chill(F)_0)
# 0   0.381381                                     (Weather_Fair)
# 18  0.359052                 (Temperature(F)_0, Pressure(in)_0)
# 2   0.343118                    (Part_of_Day_Afternoon (12-17))
# 19  0.323048                  (Pressure(in)_0, Wind_Chill(F)_0)
# 20  0.312045  (Pressure(in)_0, Temperature(F)_0, Wind_Chill(...
# 8   0.279142                                    (Humidity(%)_3)
# 3   0.276958                      (Part_of_Day_Evening (18-23))
# 14  0.265699                     (Weather_Fair, Pressure(in)_0)
# 13  0.253270                                (Wind_Speed(mph)_4)
# 1   0.247994                       (Part_of_Day_Morning (6-11))
# 12  0.230431                                (Wind_Speed(mph)_3)
# 11  0.225433                                   (Pressure(in)_1)
# 15  0.225395    (Part_of_Day_Afternoon (12-17), Pressure(in)_0)
# 4   0.218393                                         (December)
# 7   0.209957                                    (Humidity(%)_2)
# 9   0.208673                                    (Humidity(%)_4)
# 17  0.202721                  (Temperature(F)_0, Humidity(%)_3)
#                             antecedents                          consequents  \
# 4                    (Temperature(F)_0)                    (Wind_Chill(F)_0)
# 5                     (Wind_Chill(F)_0)                   (Temperature(F)_0)
# 9                      (Pressure(in)_0)                   (Temperature(F)_0)
# 8                    (Temperature(F)_0)                     (Pressure(in)_0)
# 11                    (Wind_Chill(F)_0)                     (Pressure(in)_0)
# 10                     (Pressure(in)_0)                    (Wind_Chill(F)_0)
# 16                   (Temperature(F)_0)    (Wind_Chill(F)_0, Pressure(in)_0)
# 15                     (Pressure(in)_0)  (Temperature(F)_0, Wind_Chill(F)_0)
# 14  (Temperature(F)_0, Wind_Chill(F)_0)                     (Pressure(in)_0)
# 13    (Wind_Chill(F)_0, Pressure(in)_0)                   (Temperature(F)_0)
# 12   (Temperature(F)_0, Pressure(in)_0)                    (Wind_Chill(F)_0)
# 17                    (Wind_Chill(F)_0)   (Temperature(F)_0, Pressure(in)_0)
# 1                      (Pressure(in)_0)                       (Weather_Fair)
# 0                        (Weather_Fair)                     (Pressure(in)_0)
# 3                      (Pressure(in)_0)      (Part_of_Day_Afternoon (12-17))
# 2       (Part_of_Day_Afternoon (12-17))                     (Pressure(in)_0)
# 7                       (Humidity(%)_3)                   (Temperature(F)_0)
# 6                    (Temperature(F)_0)                      (Humidity(%)_3)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 4             0.553818            0.483822  0.468796    0.846481  1.749571
# 5             0.483822            0.553818  0.468796    0.968943  1.749571
# 9             0.634576            0.553818  0.359052    0.565814  1.021661
# 8             0.553818            0.634576  0.359052    0.648322  1.021661
# 11            0.483822            0.634576  0.323048    0.667701  1.052200
# 10            0.634576            0.483822  0.323048    0.509078  1.052200
# 16            0.553818            0.323048  0.312045    0.563444  1.744149
# 15            0.634576            0.468796  0.312045    0.491739  1.048939
# 14            0.468796            0.634576  0.312045    0.665631  1.048939
# 13            0.323048            0.553818  0.312045    0.965940  1.744149
# 12            0.359052            0.483822  0.312045    0.869082  1.796284
# 17            0.483822            0.359052  0.312045    0.644959  1.796284
# 1             0.634576            0.381381  0.265699    0.418704  1.097864
# 0             0.381381            0.634576  0.265699    0.696678  1.097864
# 3             0.634576            0.343118  0.225395    0.355190  1.035185
# 2             0.343118            0.634576  0.225395    0.656903  1.035185
# 7             0.279142            0.553818  0.202721    0.726231  1.311319
# 6             0.553818            0.279142  0.202721    0.366044  1.311319
#
#     leverage  conviction  zhangs_metric
# 4   0.200847    3.362311       0.960216
# 5   0.200847   14.366760       0.830007
# 9   0.007613    1.027629       0.058020
# 8   0.007613    1.039086       0.047518
# 11  0.016027    1.099684       0.096111
# 10  0.016027    1.051445       0.135761
# 16  0.133136    1.550665       0.956233
# 15  0.014559    1.045139       0.127675
# 14  0.014559    1.092878       0.087830
# 13  0.133136   13.099987       0.630258
# 12  0.138328    3.942749       0.691624
# 17  0.138328    1.805280       0.858803
# 1   0.023685    1.064207       0.243937
# 0   0.023685    1.204740       0.144096
# 3   0.007661    1.018723       0.093013
# 2   0.007661    1.065076       0.051743
# 7   0.048128    1.629779       0.329342
# 6   0.048128    1.137079       0.532089
# #################################### Result of Cluster 9 ####################################
#      support                                           itemsets
# 8   0.785505                                   (Pressure(in)_0)
# 4   0.500865                                 (Temperature(F)_0)
# 5   0.475008                                  (Wind_Chill(F)_0)
# 16  0.452480                (Temperature(F)_0, Wind_Chill(F)_0)
# 7   0.408516                                    (Humidity(%)_0)
# 18  0.381626                  (Pressure(in)_0, Wind_Chill(F)_0)
# 17  0.378130                 (Temperature(F)_0, Pressure(in)_0)
# 20  0.360468  (Pressure(in)_0, Temperature(F)_0, Wind_Chill(...
# 2   0.348825                    (Part_of_Day_Afternoon (12-17))
# 19  0.334779                    (Pressure(in)_0, Humidity(%)_0)
# 0   0.290479                                     (Weather_Fair)
# 11  0.290371                     (Weather_Fair, Pressure(in)_0)
# 1   0.282105                       (Part_of_Day_Morning (6-11))
# 14  0.273970    (Part_of_Day_Afternoon (12-17), Pressure(in)_0)
# 3   0.261378                      (Part_of_Day_Evening (18-23))
# 6   0.236663                                  (Wind_Chill(F)_1)
# 9   0.218773                                (Wind_Speed(mph)_1)
# 10  0.217727                                (Wind_Speed(mph)_4)
# 15  0.217295      (Part_of_Day_Evening (18-23), Pressure(in)_0)
# 13  0.205231     (Part_of_Day_Afternoon (12-17), Humidity(%)_0)
# 12  0.202696       (Part_of_Day_Morning (6-11), Pressure(in)_0)
#                             antecedents                          consequents  \
# 11                    (Wind_Chill(F)_0)                   (Temperature(F)_0)
# 10                   (Temperature(F)_0)                    (Wind_Chill(F)_0)
# 15                    (Wind_Chill(F)_0)                     (Pressure(in)_0)
# 14                     (Pressure(in)_0)                    (Wind_Chill(F)_0)
# 12                   (Temperature(F)_0)                     (Pressure(in)_0)
# 13                     (Pressure(in)_0)                   (Temperature(F)_0)
# 22                   (Temperature(F)_0)    (Wind_Chill(F)_0, Pressure(in)_0)
# 21                     (Pressure(in)_0)  (Temperature(F)_0, Wind_Chill(F)_0)
# 20  (Temperature(F)_0, Wind_Chill(F)_0)                     (Pressure(in)_0)
# 19    (Wind_Chill(F)_0, Pressure(in)_0)                   (Temperature(F)_0)
# 18   (Temperature(F)_0, Pressure(in)_0)                    (Wind_Chill(F)_0)
# 23                    (Wind_Chill(F)_0)   (Temperature(F)_0, Pressure(in)_0)
# 16                     (Pressure(in)_0)                      (Humidity(%)_0)
# 17                      (Humidity(%)_0)                     (Pressure(in)_0)
# #################################### Result of Cluster 10 ####################################
#      support                             itemsets
# 2   0.377809      (Part_of_Day_Afternoon (12-17))
# 0   0.368987                       (Weather_Fair)
# 12  0.362258                     (Pressure(in)_1)
# 8   0.258900                    (Wind_Chill(F)_3)
# 10  0.256978                      (Humidity(%)_3)
# 9   0.256672                    (Wind_Chill(F)_4)
# 3   0.254593        (Part_of_Day_Evening (18-23))
# 7   0.249167                    (Wind_Chill(F)_1)
# 6   0.238985                   (Temperature(F)_4)
# 11  0.233972                      (Humidity(%)_4)
# 1   0.228525         (Part_of_Day_Morning (6-11))
# 5   0.227258                   (Temperature(F)_3)
# 15  0.227016                  (Wind_Speed(mph)_1)
# 4   0.217567                   (Temperature(F)_2)
# 17  0.215018  (Wind_Chill(F)_4, Temperature(F)_4)
# 14  0.205548                     (Pressure(in)_4)
# 16  0.202864                  (Wind_Speed(mph)_2)
# 13  0.202679                     (Pressure(in)_2)
#           antecedents         consequents  antecedent support  \
# 0   (Wind_Chill(F)_4)  (Temperature(F)_4)            0.256672
# 1  (Temperature(F)_4)   (Wind_Chill(F)_4)            0.238985
#
#    consequent support   support  confidence     lift  leverage  conviction  \
# 0            0.238985  0.215018    0.837716  3.50531  0.153677    4.689414
# 1            0.256672  0.215018    0.899714  3.50531  0.153677    7.412083
#
#    zhangs_metric
# 0       0.961511
# 1       0.939165
# #################################### Result of Cluster 11 ####################################
#      support                                           itemsets
# 10  0.797455                                   (Pressure(in)_0)
# 9   0.775227                                    (Humidity(%)_0)
# 27  0.634235                    (Pressure(in)_0, Humidity(%)_0)
# 2   0.584112                                     (Weather_Fair)
# 16  0.571688                     (Weather_Fair, Pressure(in)_0)
# 15  0.501152                      (Weather_Fair, Humidity(%)_0)
# 33  0.491459      (Pressure(in)_0, Weather_Fair, Humidity(%)_0)
# 6   0.398522                                 (Temperature(F)_4)
# 22  0.371843                  (Temperature(F)_4, Humidity(%)_0)
# 8   0.351541                                  (Wind_Chill(F)_4)
# 26  0.346347                  (Wind_Chill(F)_4, Pressure(in)_0)
# 4   0.343047                    (Part_of_Day_Afternoon (12-17))
# 25  0.327340                   (Wind_Chill(F)_4, Humidity(%)_0)
# 39  0.322651   (Wind_Chill(F)_4, Pressure(in)_0, Humidity(%)_0)
# 21  0.320725                (Wind_Chill(F)_4, Temperature(F)_4)
# 23  0.319225                 (Pressure(in)_0, Temperature(F)_4)
# 37  0.316036  (Wind_Chill(F)_4, Pressure(in)_0, Temperature(...
# 7   0.312626                                  (Wind_Chill(F)_1)
# 5   0.304922                      (Part_of_Day_Evening (18-23))
# 17  0.304496     (Part_of_Day_Afternoon (12-17), Humidity(%)_0)
# 36  0.300534  (Wind_Chill(F)_4, Temperature(F)_4, Humidity(%...
# 38  0.299444  (Pressure(in)_0, Temperature(F)_4, Humidity(%)_0)
# 44  0.296287  (Wind_Chill(F)_4, Pressure(in)_0, Temperature(...
# 18  0.278716    (Part_of_Day_Afternoon (12-17), Pressure(in)_0)
# 14  0.265108                    (Wind_Chill(F)_4, Weather_Fair)
# 32  0.260798    (Wind_Chill(F)_4, Weather_Fair, Pressure(in)_0)
# 31  0.254041     (Wind_Chill(F)_4, Weather_Fair, Humidity(%)_0)
# 19  0.253962       (Part_of_Day_Evening (18-23), Humidity(%)_0)
# 43  0.250142  (Wind_Chill(F)_4, Pressure(in)_0, Weather_Fair...
# 34  0.249590  (Pressure(in)_0, Part_of_Day_Afternoon (12-17)...
# 20  0.249432      (Part_of_Day_Evening (18-23), Pressure(in)_0)
# 11  0.248990                                (Wind_Speed(mph)_1)
# 13  0.245595                   (Weather_Fair, Temperature(F)_4)
# 28  0.242801  (Wind_Chill(F)_4, Weather_Fair, Temperature(F)_4)
# 30  0.241617   (Pressure(in)_0, Weather_Fair, Temperature(F)_4)
# 41  0.238933  (Wind_Chill(F)_4, Pressure(in)_0, Weather_Fair...
# 29  0.235997    (Weather_Fair, Temperature(F)_4, Humidity(%)_0)
# 40  0.233219  (Wind_Chill(F)_4, Weather_Fair, Temperature(F)...
# 42  0.232366  (Pressure(in)_0, Weather_Fair, Temperature(F)_...
# 45  0.229698  (Pressure(in)_0, Wind_Chill(F)_4, Temperature(...
# 3   0.224504                       (Part_of_Day_Morning (6-11))
# 0   0.214480                                         (Crossing)
# 1   0.213927                                   (Traffic_Signal)
# 35  0.211117  (Pressure(in)_0, Part_of_Day_Evening (18-23), ...
# 24  0.208749                   (Humidity(%)_0, Wind_Chill(F)_1)
# 12  0.205386                                (Wind_Speed(mph)_2)
#                       antecedents  \
# 28               (Pressure(in)_0)
# 29                (Humidity(%)_0)
# 6                  (Weather_Fair)
# 7                (Pressure(in)_0)
# 4                  (Weather_Fair)
# ..                            ...
# 75               (Pressure(in)_0)
# 76  (Part_of_Day_Evening (18-23))
# 77                (Humidity(%)_0)
# 22                (Humidity(%)_0)
# 23              (Wind_Chill(F)_1)
#
#                                       consequents  antecedent support  \
# 28                                (Humidity(%)_0)            0.797455
# 29                               (Pressure(in)_0)            0.775227
# 6                                (Pressure(in)_0)            0.584112
# 7                                  (Weather_Fair)            0.797455
# 4                                 (Humidity(%)_0)            0.584112
# ..                                            ...                 ...
# 75   (Part_of_Day_Evening (18-23), Humidity(%)_0)            0.797455
# 76                (Pressure(in)_0, Humidity(%)_0)            0.304922
# 77  (Part_of_Day_Evening (18-23), Pressure(in)_0)            0.775227
# 22                              (Wind_Chill(F)_1)            0.775227
# 23                                (Humidity(%)_0)            0.312626
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 28            0.775227  0.634235    0.795324  1.025924  0.016026    1.098188
# 29            0.797455  0.634235    0.818128  1.025924  0.016026    1.113668
# 6             0.797455  0.571688    0.978730  1.227316  0.105885    9.522438
# 7             0.584112  0.571688    0.716890  1.227316  0.105885    1.468999
# 4             0.775227  0.501152    0.857973  1.106737  0.048333    1.582605
# ..                 ...       ...         ...       ...       ...         ...
# 75            0.253962  0.211117    0.264738  1.042431  0.008593    1.014656
# 76            0.634235  0.211117    0.692363  1.091651  0.017725    1.188951
# 77            0.249432  0.211117    0.272329  1.091799  0.017751    1.031467
# 22            0.312626  0.208749    0.269275  0.861331 -0.033607    0.940673
# 23            0.775227  0.208749    0.667727  0.861331 -0.033607    0.676470
#
#     zhangs_metric
# 28       0.124756
# 29       0.112419
# 6        0.445346
# 7        0.914435
# 4        0.231897
# ..            ...
# 75       0.200964
# 76       0.120787
# 77       0.374069
# 22      -0.417336
# 23      -0.189769
#
# [202 rows x 10 columns]

# %%
result_of_final_df_static
# Out:
# (     support                                         itemsets
#  9   0.733589                                 (Pressure(in)_2)
#  5   0.451411                                (Wind_Chill(F)_3)
#  4   0.400555                               (Temperature(F)_3)
#  0   0.399419                                   (Weather_Fair)
#  1   0.369258                  (Part_of_Day_Afternoon (12-17))
#  14  0.314528                (Wind_Chill(F)_3, Pressure(in)_2)
#  11  0.310507                   (Pressure(in)_2, Weather_Fair)
#  6   0.302287                                (Wind_Chill(F)_4)
#  3   0.297626                               (Temperature(F)_2)
#  8   0.296751                                  (Humidity(%)_4)
#  7    0.29546                                  (Humidity(%)_3)
#  13  0.293551               (Pressure(in)_2, Temperature(F)_3)
#  12   0.27414  (Pressure(in)_2, Part_of_Day_Afternoon (12-17))
#  2   0.270119                    (Part_of_Day_Evening (18-23))
#  10  0.254792                                 (Pressure(in)_3),
#  Empty DataFrame
#  Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
#  Index: [])

# %%
result_of_final_df_dynamic
# Out:
# (     support                                           itemsets
#  2   0.399419                                     (Weather_Fair)
#  11  0.369258                    (Part_of_Day_Afternoon (12-17))
#  22  0.315295                                  (Wind_Chill(F)_1)
#  12  0.270119                      (Part_of_Day_Evening (18-23))
#  10  0.235620                       (Part_of_Day_Morning (6-11))
#  28  0.217764                                    (Humidity(%)_3)
#  18  0.210809                                 (Temperature(F)_2)
#  35  0.210490                                (Wind_Speed(mph)_1)
#  25  0.209803                                    (Humidity(%)_0)
#  32  0.209093                                   (Pressure(in)_2)
#  16  0.203744                                 (Temperature(F)_0)
#  31  0.202609                                   (Pressure(in)_1)
#  30  0.201682                                   (Pressure(in)_0)
#  21  0.200558                                  (Wind_Chill(F)_0)
#  20  0.199591                                 (Temperature(F)_4)
#  24  0.199389                                  (Wind_Chill(F)_4)
#  37  0.198647                                (Wind_Speed(mph)_3)
#  26  0.197986                                    (Humidity(%)_1)
#  23  0.197408                                  (Wind_Chill(F)_3)
#  34  0.196470                                   (Pressure(in)_4)
#  17  0.194713                                 (Temperature(F)_1)
#  27  0.192508                                    (Humidity(%)_2)
#  36  0.190165                                (Wind_Speed(mph)_2)
#  33  0.190147                                   (Pressure(in)_3)
#  19  0.188472                                 (Temperature(F)_3)
#  48  0.184718                (Wind_Chill(F)_0, Temperature(F)_0)
#  29  0.181938                                    (Humidity(%)_4)
#  49  0.178873                (Temperature(F)_1, Wind_Chill(F)_1)
#  4   0.173325                                   (Weekday_Friday)
#  15  0.166892                                         (December)
#  51  0.165899                (Wind_Chill(F)_4, Temperature(F)_4)
#  38  0.163769                                (Wind_Speed(mph)_4)
#  7   0.163250                                 (Weekday_Thursday)
#  9   0.160335                                (Weekday_Wednesday)
#  8   0.156398                                  (Weekday_Tuesday)
#  5   0.147698                                   (Weekday_Monday)
#  39  0.141973      (Weather_Fair, Part_of_Day_Afternoon (12-17))
#  3   0.133442                            (Weather_Mostly Cloudy)
#  43  0.130328                      (Humidity(%)_0, Weather_Fair)
#  1   0.128161                                   (Weather_Cloudy)
#  14  0.125921                                         (November)
#  44  0.122494  (Part_of_Day_Afternoon (12-17), Temperature(F)_4)
#  46  0.121975     (Humidity(%)_0, Part_of_Day_Afternoon (12-17))
#  50  0.120945                (Wind_Chill(F)_3, Temperature(F)_3)
#  45  0.118504   (Wind_Chill(F)_4, Part_of_Day_Afternoon (12-17))
#  40  0.117923        (Weather_Fair, Part_of_Day_Evening (18-23))
#  6   0.109227                                 (Weekday_Saturday)
#  42  0.105883                    (Wind_Chill(F)_4, Weather_Fair)
#  13  0.105318                                          (October)
#  47  0.103398     (Humidity(%)_1, Part_of_Day_Afternoon (12-17))
#  52  0.102823  (Wind_Chill(F)_4, Part_of_Day_Afternoon (12-17...
#  41  0.102584                    (Wind_Chill(F)_3, Weather_Fair)
#  0   0.102037                                         (Junction),
#                                            antecedents  \
#  19                                 (Temperature(F)_0)
#  18                                  (Wind_Chill(F)_0)
#  21                                  (Wind_Chill(F)_1)
#  20                                 (Temperature(F)_1)
#  25                                 (Temperature(F)_4)
#  24                                  (Wind_Chill(F)_4)
#  1                     (Part_of_Day_Afternoon (12-17))
#  0                                      (Weather_Fair)
#  8                                     (Humidity(%)_0)
#  9                                      (Weather_Fair)
#  10                    (Part_of_Day_Afternoon (12-17))
#  11                                 (Temperature(F)_4)
#  14                                    (Humidity(%)_0)
#  15                    (Part_of_Day_Afternoon (12-17))
#  22                                  (Wind_Chill(F)_3)
#  23                                 (Temperature(F)_3)
#  12                                  (Wind_Chill(F)_4)
#  13                    (Part_of_Day_Afternoon (12-17))
#  3                       (Part_of_Day_Evening (18-23))
#  2                                      (Weather_Fair)
#  7                                      (Weather_Fair)
#  6                                   (Wind_Chill(F)_4)
#  16                                    (Humidity(%)_1)
#  17                    (Part_of_Day_Afternoon (12-17))
#  26   (Wind_Chill(F)_4, Part_of_Day_Afternoon (12-17))
#  27                (Wind_Chill(F)_4, Temperature(F)_4)
#  28  (Part_of_Day_Afternoon (12-17), Temperature(F)_4)
#  29                                  (Wind_Chill(F)_4)
#  30                    (Part_of_Day_Afternoon (12-17))
#  31                                 (Temperature(F)_4)
#  5                                      (Weather_Fair)
#  4                                   (Wind_Chill(F)_3)
#
#                                            consequents  antecedent support  \
#  19                                  (Wind_Chill(F)_0)            0.203744
#  18                                 (Temperature(F)_0)            0.200558
#  21                                 (Temperature(F)_1)            0.315295
#  20                                  (Wind_Chill(F)_1)            0.194713
#  25                                  (Wind_Chill(F)_4)            0.199591
#  24                                 (Temperature(F)_4)            0.199389
#  1                                      (Weather_Fair)            0.369258
#  0                     (Part_of_Day_Afternoon (12-17))            0.399419
#  8                                      (Weather_Fair)            0.209803
#  9                                     (Humidity(%)_0)            0.399419
#  10                                 (Temperature(F)_4)            0.369258
#  11                    (Part_of_Day_Afternoon (12-17))            0.199591
#  14                    (Part_of_Day_Afternoon (12-17))            0.209803
#  15                                    (Humidity(%)_0)            0.369258
#  22                                 (Temperature(F)_3)            0.197408
#  5             0.197408  0.102584    0.256832  1.301021  0.023735    1.079960
#  4             0.399419  0.102584    0.519653  1.301021  0.023735    1.250306
#
#      zhangs_metric
#  19       0.978057
#  18       0.974160
#  21       0.959220
#  20       0.815589
#  25       0.949662
#  24       0.949422
#  1       -0.058022
#  0       -0.060759
#  8        0.451800
#  9        0.594444
#  10       0.631534
#  11       0.497664
#  14       0.461732
#  15       0.578461
#  22       0.862672
#  23       0.853173
#  12       0.473017
#  13       0.600408
#  3        0.116554
#  2        0.141647
#  7        0.412681
#  6        0.309574
#  16       0.365263
#  17       0.464447
#  26       0.873482
#  27       0.484621
#  28       0.868901
#  29       0.952354
#  30       0.640869
#  31       0.961972
#  5        0.385249
#  4        0.288282  )

# %%
# Lift: Lift is a measure of how much more often the antecedent and consequent of
#     a rule occur together compared to their individual occurrences. 
#     It is defined as the ratio of the observed support of both items occurring 
#     together to the expected support if they were independent. 

# A lift value 
#     greater than 1 indicates a positive correlation between the items, 
#     where values significantly higher than 1 indicate a strong association

# Note: Wind Chill and Temperature


# Leverage: Leverage measures the difference between the observed frequency of 
#     co-occurrence of the antecedent and consequent and the expected 
#     frequency if they were independent. It calculates the difference between 
#     the observed support and the expected support. A leverage value of 0 
#     indicates independence, while values greater than 0 indicate a positive 
#     association.

# Conviction: Conviction is a measure that quantifies the degree of dependency 
#     between the antecedent and consequent of a rule. It is defined as the 
#     ratio of the expected frequency of the consequent given the independence 
#     of the antecedent and consequent to the observed frequency. Conviction 
#     values greater than 1 indicate a strong association, with higher values 
#     indicating stronger dependency.

# Zhang's Metric: Zhang's metric is an evaluation measure that combines lift, 
#     leverage, and conviction to assess the strength of association rules. 
#     It provides a single score that takes into account multiple aspects of 
#     association rule quality. The formula for Zhang's metric incorporates 
#     these measures in a weighted manner to compute a combined score.

# %% [markdown]
# # Final Dynamic on whole dataset:

# %%
# Load Dataset

abs_path = Path.cwd()
data_address = abs_path.parent.parent / 'data/' / 'Cleaned_US.csv'
df = pd.read_csv(data_address)

# %%
# Fair, Clear, Fair / Windy, 
# Overcast, Mostly Cloudy, Cloudy, Partly Cloudy, Scattered Clouds, 
# Light Rain, Rain, Heavy Rain
# Snow, 
# Haze, Smoke, 
# Drizzle, Thunder, Dust
# Fog


# Smoke: dud sukhtan
# Haze: ghobar

# Dust: very stong winds with solid
# Thunder: rad bargh

# Drizzle: barun ba ghatre kuchik

# Overcast: 100 percent cloud in sky

df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder and Hail / Windy', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sand / Dust Whirlwinds / Windy', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Freezing Rain', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Blowing Sand', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Mist / Windy', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sleet / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Dust Whirls', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sand / Dust Whirls Nearby', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Rain Shower / Windy', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Rain Showers', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Blowing Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Drifting Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Low Drifting Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Thunderstorms with Small Hail', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Haze', 'Haze')
df['Weather_Condition'] = df['Weather_Condition'].replace('Blowing Snow Nearby', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder and Hail', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Snow and Thunder / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Freezing Drizzle', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sand', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder / Wintry Mix / Windy', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Blowing Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Ice Pellets', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Duststorm', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Funnel Cloud', 'Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Freezing Rain / Windy', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sand / Windy', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Rain Shower', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Hail', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Snow with Thunder', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Thunderstorms and Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Patches of Fog / Windy', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Volcanic Ash', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder / Wintry Mix', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow Showers', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Thunderstorms and Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Rain Shower / Windy', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Sleet / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Snow Grains', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Tornado', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Drizzle / Windy', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow with Thunder', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Freezing Drizzle', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Squalls', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Sleet', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sand / Dust Whirlwinds', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow and Sleet / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Widespread Dust / Windy', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Snow and Sleet / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Squalls / Windy', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow Shower', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Partial Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Rain Showers', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Freezing Rain / Windy', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Small Hail', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Ice Pellets', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Rain Shower', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Rain Showers', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow and Sleet', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Freezing Rain', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Smoke / Windy', 'Smoke')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sleet', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Widespread Dust', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Sleet', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Wintry Mix / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Ice Pellets', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Blowing Snow / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Drizzle / Windy', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Snow and Sleet', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Drizzle and Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Rain Shower', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Drizzle', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Blowing Dust', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Blowing Dust / Windy', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Blowing Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Snow / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder / Windy', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('T-Storm / Windy', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Fog / Windy', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Freezing Drizzle', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy T-Storm / Windy', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Freezing Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Snow / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunderstorms and Rain', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Thunderstorms and Rain', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Haze / Windy', 'Haze')
df['Weather_Condition'] = df['Weather_Condition'].replace('Showers in the Vicinity', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Rain / Windy', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Freezing Rain', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Shallow Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunderstorm', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Mist', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Patches of Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('N/A Precipitation', 'Fair')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Thunderstorms and Rain', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Rain / Windy', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Drizzle', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Rain / Windy', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy T-Storm', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Wintry Mix', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Partly Cloudy / Windy', 'Partly Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Rain with Thunder', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Mostly Cloudy / Windy', 'Mostly Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('T-Storm', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Cloudy / Windy', 'Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder in the Vicinity', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Drizzle', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Smoke', 'Smoke')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Rain', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Fair / Windy', 'Fair / Windy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Rain', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Haze', 'Haze')
df['Weather_Condition'] = df['Weather_Condition'].replace('Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Scattered Clouds', 'Scatterred Clouds')
df['Weather_Condition'] = df['Weather_Condition'].replace('Overcast', 'Overcast')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Rain', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Clear', 'Clear')
df['Weather_Condition'] = df['Weather_Condition'].replace('Partly Cloudy', 'Partly Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Cloudy', 'Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Mostly Cloudy', 'Mostly Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Fair', 'Fair')

# %%
df = pd.get_dummies(df, columns=['Weather_Condition'], prefix='Weather', dtype=bool)
df = pd.get_dummies(df, columns=['Weekday'], prefix='Weekday', dtype=bool)

df['Hour'] = df['Hour'].astype('float64')
df['Month'] = df['Month'].astype('float64')

# Step 1: Convert "Hour" to 4 boolean columns
hour_labels = ['Night (0-5)', 'Morning (6-11)', 'Afternoon (12-17)', 'Evening (18-23)']
hour_bins = [0, 5, 11, 17, 23]
df['Part_of_Day'] = pd.cut(df['Hour'], bins=hour_bins, labels=hour_labels, right=False)
df = pd.get_dummies(df, columns=['Part_of_Day'], prefix='Part_of_Day', dtype=bool)

# Step 2: Convert "Month" to 12 boolean columns
month_names = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
df['Month'] = df['Month'].astype(int)
df = pd.get_dummies(df, columns=['Month'], prefix='Month', dtype=bool)
df.rename(columns={'Month_'+str(i): month_names[i-1] for i in range(1, 13)}, inplace=True)

# Drop the original "Hour" column as it is no longer needed
df.drop(['Hour'], axis=1, inplace=True)

# %%
def dynamic_convertor(df):
    # Define weather float columns
    weather_float_columns = ['Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)', 'Wind_Speed(mph)']

    # Create a new DataFrame for encoded columns
    df_dynamic_threshold = pd.DataFrame()

    # Create a dictionary to store the thresholds
    thresholds_dict = {}

    # Discretize and encode weather columns using one-hot encoding
    for column in weather_float_columns:
        column_values = df[column]
        
        # Adjust threshold percentages if they are the same
        if len(set(column_values)) == 1:
            min_value = column_values.min()
            max_value = column_values.max()
            if min_value == max_value:
                thresholds = [0, min_value, min_value + 1, float('inf')]
            else:
                thresholds = [0, min_value, max_value, float('inf')]
        else:
            thresholds = [0, 
                          np.percentile(column_values, 20),
                          np.percentile(column_values, 40),
                          np.percentile(column_values, 60),
                          np.percentile(column_values, 80), 
                          float('inf')]
                
        bins = np.unique(thresholds)  # Ensure unique bin edges
        labels = range(len(bins) - 1)
        categories = pd.cut(column_values, bins=bins, labels=labels)
        encoded_cols = pd.get_dummies(categories, prefix=column, dtype=bool)
        df_dynamic_threshold = pd.concat([df_dynamic_threshold, encoded_cols], axis=1)

        # Store the thresholds in the dictionary
        thresholds_dict[column] = thresholds
    
    # Save the thresholds dictionary to a CSV file
    with open('thresholds.csv', 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(['Column', 'Thresholds'])
        for column, thresholds in thresholds_dict.items():
            writer.writerow([column, thresholds])

    return df_dynamic_threshold
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_477/711838882.py in <module>
#       1 results_of_dynamic_clusters = []
#       2
# ----> 3 for i in range(n_clusters):
#       4     columns_to_drop = {'Severity', 'Start_Time', 'Start_Lat', 'Start_Lng',
#       5                    'End_Lat', 'End_Lng', 'Distance(mi)', 'City',
#
# NameError: name 'n_clusters' is not defined

# %%
# Need some description on One-Hot Encoding

# %%
df_weather = dynamic_convertor(df)
final_df = pd.concat([df, df_weather], axis=1)

columns_to_drop = {'Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 
                   'End_Lat', 'End_Lng', 'Distance(mi)', 'City', 
                   'County', 'State', 'Temperature(F)', 'Wind_Chill(F)', 
                   'Humidity(%)', 'Pressure(in)', 'Visibility(mi)',
                    'Wind_Speed(mph)', 'Precipitation(in)',
                    'Weather_Clear', 'Weather_Cloudy', 
                    'Weather_Drizzle', 'Weather_Dust',
                    'Weather_Dust', 'Weather_Fair', 
                    'Weather_Fair / Windy', 'Weather_Fog',
                    'Weather_Haze', 'Weather_Heavy Rain',
                    'Weather_Light Rain', 'Weather_Mostly Cloudy',
                    'Weather_Overcast', 'Weather_Partly Cloudy',
                    'Weather_Rain', 'Weather_Scatterred Clouds',
                    'Weather_Smoke', 'Weather_Snow', 'Weather_Thunder'
                    }

final_df.drop(columns_to_drop, axis=1, inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2774575 entries, 0 to 2774574
# Data columns (total 61 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   Amenity                        bool
#  1   Bump                           bool
#  2   Crossing                       bool
#  3   Give_Way                       bool
#  4   Junction                       bool
#  5   No_Exit                        bool
#  6   Railway                        bool
#  7   Roundabout                     bool
#  8   Station                        bool
#  9   Stop                           bool
#  10  Traffic_Calming                bool
#  11  Traffic_Signal                 bool
#  12  Turning_Loop                   bool
#  13  Weekday_Friday                 bool
#  14  Weekday_Monday                 bool
#  15  Weekday_Saturday               bool
#  16  Weekday_Sunday                 bool
#  17  Weekday_Thursday               bool
#  18  Weekday_Tuesday                bool
#  19  Weekday_Wednesday              bool
#  20  Part_of_Day_Night (0-5)        bool
#  21  Part_of_Day_Morning (6-11)     bool
#  22  Part_of_Day_Afternoon (12-17)  bool
#  23  Part_of_Day_Evening (18-23)    bool
#  24  January                        bool
#  25  February                       bool
#  26  March                          bool
#  27  April                          bool
#  28  May                            bool
#  29  June                           bool
#  30  July                           bool
#  31  August                         bool
#  32  September                      bool
#  33  October                        bool
#  34  November                       bool
#  35  December                       bool
#  36  Temperature(F)_0               bool
#  37  Temperature(F)_1               bool
#  38  Temperature(F)_2               bool
#  39  Temperature(F)_3               bool
#  40  Temperature(F)_4               bool
#  41  Wind_Chill(F)_0                bool
#  42  Wind_Chill(F)_1                bool
#  43  Wind_Chill(F)_2                bool
#  44  Wind_Chill(F)_3                bool
#  45  Wind_Chill(F)_4                bool
#  46  Humidity(%)_0                  bool
#  47  Humidity(%)_1                  bool
#  48  Humidity(%)_2                  bool
#  49  Humidity(%)_3                  bool
#  50  Humidity(%)_4                  bool
#  51  Pressure(in)_0                 bool
#  52  Pressure(in)_1                 bool
#  53  Pressure(in)_2                 bool
#  54  Pressure(in)_3                 bool
#  55  Pressure(in)_4                 bool
#  56  Wind_Speed(mph)_0              bool
#  57  Wind_Speed(mph)_1              bool
#  58  Wind_Speed(mph)_2              bool
#  59  Wind_Speed(mph)_3              bool
#  60  Wind_Speed(mph)_4              bool
# dtypes: bool(61)
# memory usage: 161.4 MB

# %%
def apply_apriori(df, min_support=0.05, min_threshold=0.05):
    # Apply Apriori algorithm
    frequent_itemsets = apriori(df, min_support=min_support, use_colnames=True)
    rules = association_rules(frequent_itemsets, metric="support", min_threshold=min_threshold)

    sorted_frequents = frequent_itemsets.sort_values('support', ascending=False)
    sorted_rules = rules.sort_values('support', ascending=False)
    print(sorted_frequents)
    print(sorted_rules)
    
    return sorted_frequents, sorted_rules

# %%
result_final_df = apply_apriori(final_df)
result_final_df

# %%
# Save final result

itemsets_result = pd.DataFrame(result_final_df[0])
rules_result = pd.DataFrame(result_final_df[1])

itemsets_result.to_csv('itemsets_result.csv', index=False)
rules_result.to_csv('rules_result.csv', index=False)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2774575 entries, 0 to 2774574
# Data columns (total 79 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   Amenity                        bool
#  1   Bump                           bool
#  2   Crossing                       bool
#  3   Give_Way                       bool
#  4   Junction                       bool
#  5   No_Exit                        bool
#  6   Railway                        bool
#  7   Roundabout                     bool
#  8   Station                        bool
#  9   Stop                           bool
#  10  Traffic_Calming                bool
#  11  Traffic_Signal                 bool
#  12  Turning_Loop                   bool
#  13  Weather_Clear                  bool
#  14  Weather_Cloudy                 bool
#  15  Weather_Drizzle                bool
#  16  Weather_Dust                   bool
#  17  Weather_Fair                   bool
#  18  Weather_Fair / Windy           bool
#  19  Weather_Fog                    bool
#  20  Weather_Haze                   bool
#  21  Weather_Heavy Rain             bool
#  22  Weather_Light Rain             bool
#  23  Weather_Mostly Cloudy          bool
#  24  Weather_Overcast               bool
#  25  Weather_Partly Cloudy          bool
#  26  Weather_Rain                   bool
#  27  Weather_Scatterred Clouds      bool
#  28  Weather_Smoke                  bool
#  29  Weather_Snow                   bool
#  30  Weather_Thunder                bool
#  31  Weekday_Friday                 bool
#  32  Weekday_Monday                 bool
#  33  Weekday_Saturday               bool
#  34  Weekday_Sunday                 bool
#  35  Weekday_Thursday               bool
#  36  Weekday_Tuesday                bool
#  37  Weekday_Wednesday              bool
#  38  Part_of_Day_Night (0-5)        bool
#  39  Part_of_Day_Morning (6-11)     bool
#  40  Part_of_Day_Afternoon (12-17)  bool
#  41  Part_of_Day_Evening (18-23)    bool
#  42  January                        bool
#  43  February                       bool
#  44  March                          bool
#  45  April                          bool
#  46  May                            bool
#  47  June                           bool
#  48  July                           bool
#  49  August                         bool
#  50  September                      bool
#  51  October                        bool
#  52  November                       bool
#  53  December                       bool
#  54  Temperature(F)_0               bool
#  55  Temperature(F)_1               bool
#  56  Temperature(F)_2               bool
#  57  Temperature(F)_3               bool
#  58  Temperature(F)_4               bool
#  59  Wind_Chill(F)_0                bool
#  60  Wind_Chill(F)_1                bool
#  61  Wind_Chill(F)_2                bool
#  62  Wind_Chill(F)_3                bool
#  63  Wind_Chill(F)_4                bool
#  64  Humidity(%)_0                  bool
#  65  Humidity(%)_1                  bool
#  66  Humidity(%)_2                  bool
#  67  Humidity(%)_3                  bool
#  68  Humidity(%)_4                  bool
#  69  Pressure(in)_0                 bool
#  70  Pressure(in)_1                 bool
#  71  Pressure(in)_2                 bool
#  72  Pressure(in)_3                 bool
#  73  Pressure(in)_4                 bool
#  74  Wind_Speed(mph)_0              bool
#  75  Wind_Speed(mph)_1              bool
#  76  Wind_Speed(mph)_2              bool
#  77  Wind_Speed(mph)_3              bool
#  78  Wind_Speed(mph)_4              bool
# dtypes: bool(79)
# memory usage: 209.0 MB

# %%
# Without high volume columns
columns_to_drop = {
    'Temperature(F)_0',              
    'Temperature(F)_1',              
    'Temperature(F)_2',  
    'Temperature(F)_3',              
    'Temperature(F)_4',
    'Wind_Chill(F)_0',                 
    'Wind_Chill(F)_1',                
    'Wind_Chill(F)_2',   
    'Wind_Chill(F)_3',                
    'Wind_Chill(F)_4',
    'Humidity(%)_0',               
    'Humidity(%)_1',                 
    'Humidity(%)_2',   
    'Humidity(%)_3',                 
    'Humidity(%)_4',
    'Pressure(in)_0',                
    'Pressure(in)_1',               
    'Pressure(in)_2', 
    'Pressure(in)_3',               
    'Pressure(in)_4', 
    'Wind_Speed(mph)_0',             
    'Wind_Speed(mph)_1',              
    'Wind_Speed(mph)_2',             
    'Wind_Speed(mph)_3',             
    'Wind_Speed(mph)_4'
}

final_df.drop(columns_to_drop, axis=1, inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2774575 entries, 0 to 2774574
# Data columns (total 54 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   Amenity                        bool
#  1   Bump                           bool
#  2   Crossing                       bool
#  3   Give_Way                       bool
#  4   Junction                       bool
#  5   No_Exit                        bool
#  6   Railway                        bool
#  7   Roundabout                     bool
#  8   Station                        bool
#  9   Stop                           bool
#  10  Traffic_Calming                bool
#  11  Traffic_Signal                 bool
#  12  Turning_Loop                   bool
#  13  Weather_Clear                  bool
#  14  Weather_Cloudy                 bool
#  15  Weather_Drizzle                bool
#  16  Weather_Dust                   bool
#  17  Weather_Fair                   bool
#  18  Weather_Fair / Windy           bool
#  19  Weather_Fog                    bool
#  20  Weather_Haze                   bool
#  21  Weather_Heavy Rain             bool
#  22  Weather_Light Rain             bool
#  23  Weather_Mostly Cloudy          bool
#  24  Weather_Overcast               bool
#  25  Weather_Partly Cloudy          bool
#  26  Weather_Rain                   bool
#  27  Weather_Scatterred Clouds      bool
#  28  Weather_Smoke                  bool
#  29  Weather_Snow                   bool
#  30  Weather_Thunder                bool
#  31  Weekday_Friday                 bool
#  32  Weekday_Monday                 bool
#  33  Weekday_Saturday               bool
#  34  Weekday_Sunday                 bool
#  35  Weekday_Thursday               bool
#  36  Weekday_Tuesday                bool
#  37  Weekday_Wednesday              bool
#  38  Part_of_Day_Night (0-5)        bool
#  39  Part_of_Day_Morning (6-11)     bool
#  40  Part_of_Day_Afternoon (12-17)  bool
#  41  Part_of_Day_Evening (18-23)    bool
#  42  January                        bool
#  43  February                       bool
#  44  March                          bool
#  45  April                          bool
#  46  May                            bool
#  47  June                           bool
#  48  July                           bool
#  49  August                         bool
#  50  September                      bool
#  51  October                        bool
#  52  November                       bool
#  53  December                       bool
# dtypes: bool(54)
# memory usage: 142.9 MB

# %%
result_final_df_1 = apply_apriori(final_df, 0.03, 0.03)
result_final_df_1
# Out:
#      support                                         itemsets
# 5   0.399419                                   (Weather_Fair)
# 19  0.369258                  (Part_of_Day_Afternoon (12-17))
# 20  0.270119                    (Part_of_Day_Evening (18-23))
# 18  0.235620                     (Part_of_Day_Morning (6-11))
# 10  0.173325                                 (Weekday_Friday)
# ..       ...                                              ...
# 72  0.031253                     (Weekday_Thursday, December)
# 35  0.031130                         (Weather_Fair, Junction)
# 68  0.030958  (Weekday_Saturday, Part_of_Day_Evening (18-23))
# 8   0.030591                               (Weather_Overcast)
# 34  0.030459                         (Crossing, Weather_Fair)
#
# [87 rows x 2 columns]
#                         antecedents                      consequents  \
# 37  (Part_of_Day_Afternoon (12-17))                   (Weather_Fair)
# 36                   (Weather_Fair)  (Part_of_Day_Afternoon (12-17))
# 39    (Part_of_Day_Evening (18-23))                   (Weather_Fair)
# 38                   (Weather_Fair)    (Part_of_Day_Evening (18-23))
# 35                   (Weather_Fair)     (Part_of_Day_Morning (6-11))
# ..                              ...                              ...
# 4                    (Weather_Fair)                       (Junction)
# 70               (Weekday_Saturday)    (Part_of_Day_Evening (18-23))
# 71    (Part_of_Day_Evening (18-23))               (Weekday_Saturday)
# 3                    (Weather_Fair)                       (Crossing)
# 2                        (Crossing)                   (Weather_Fair)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 37            0.369258            0.399419  0.141973    0.384482  0.962602
# 36            0.399419            0.369258  0.141973    0.355449  0.962602
# 39            0.270119            0.399419  0.117923    0.436557  1.092980
# 38            0.399419            0.270119  0.117923    0.295235  1.092980
# 35            0.399419            0.235620  0.082516    0.206591  0.876798
# ..                 ...                 ...       ...         ...       ...
# 4             0.399419            0.102037  0.031130    0.077938  0.763821
# 70            0.109227            0.270119  0.030958    0.283428  1.049269
# 71            0.270119            0.109227  0.030958    0.114608  1.049269
# 3             0.399419            0.071072  0.030459    0.076258  1.072977
# 2             0.071072            0.399419  0.030459    0.428568  1.072977
#
#     leverage  conviction  zhangs_metric
# 37 -0.005516    0.975732      -0.058022
# 36 -0.005516    0.978575      -0.060759
# 39  0.010032    1.065913       0.116554
# 38  0.010032    1.035637       0.141647
# 35 -0.011595    0.963412      -0.189603
# ..       ...         ...            ...
# 4  -0.009626    0.973864      -0.339867
# 70  0.001454    1.018572       0.052713
# 71  0.001454    1.006078       0.064333
# 3   0.002072    1.005615       0.113246
# 2   0.002072    1.051009       0.073217
#
# [108 rows x 10 columns]
# (     support                                         itemsets
#  5   0.399419                                   (Weather_Fair)
#  19  0.369258                  (Part_of_Day_Afternoon (12-17))
#  20  0.270119                    (Part_of_Day_Evening (18-23))
#  18  0.235620                     (Part_of_Day_Morning (6-11))
#  10  0.173325                                 (Weekday_Friday)
#  ..       ...                                              ...
#  72  0.031253                     (Weekday_Thursday, December)
#  35  0.031130                         (Weather_Fair, Junction)
#  68  0.030958  (Weekday_Saturday, Part_of_Day_Evening (18-23))
#  8   0.030591                               (Weather_Overcast)
#  34  0.030459                         (Crossing, Weather_Fair)
#
#  [87 rows x 2 columns],
#                          antecedents                      consequents  \
#  37  (Part_of_Day_Afternoon (12-17))                   (Weather_Fair)
#  36                   (Weather_Fair)  (Part_of_Day_Afternoon (12-17))
#  39    (Part_of_Day_Evening (18-23))                   (Weather_Fair)
#  38                   (Weather_Fair)    (Part_of_Day_Evening (18-23))
#  35                   (Weather_Fair)     (Part_of_Day_Morning (6-11))
#  ..                              ...                              ...
#  4                    (Weather_Fair)                       (Junction)
#  70               (Weekday_Saturday)    (Part_of_Day_Evening (18-23))
#  71    (Part_of_Day_Evening (18-23))               (Weekday_Saturday)
#  3                    (Weather_Fair)                       (Crossing)
#  2                        (Crossing)                   (Weather_Fair)
#
#      antecedent support  consequent support   support  confidence      lift  \
#  37            0.369258            0.399419  0.141973    0.384482  0.962602
#  36            0.399419            0.369258  0.141973    0.355449  0.962602
#  39            0.270119            0.399419  0.117923    0.436557  1.092980
#  38            0.399419            0.270119  0.117923    0.295235  1.092980
#  35            0.399419            0.235620  0.082516    0.206591  0.876798
#  ..                 ...                 ...       ...         ...       ...
#  4             0.399419            0.102037  0.031130    0.077938  0.763821
#  70            0.109227            0.270119  0.030958    0.283428  1.049269
#  71            0.270119            0.109227  0.030958    0.114608  1.049269
#  3             0.399419            0.071072  0.030459    0.076258  1.072977
#  2             0.071072            0.399419  0.030459    0.428568  1.072977
#
#      leverage  conviction  zhangs_metric
#  37 -0.005516    0.975732      -0.058022
#  36 -0.005516    0.978575      -0.060759
#  39  0.010032    1.065913       0.116554
#  38  0.010032    1.035637       0.141647
#  35 -0.011595    0.963412      -0.189603
#  ..       ...         ...            ...
#  4  -0.009626    0.973864      -0.339867
#  70  0.001454    1.018572       0.052713
#  71  0.001454    1.006078       0.064333
#  3   0.002072    1.005615       0.113246
#  2   0.002072    1.051009       0.073217
#
#  [108 rows x 10 columns])

# %%
# Save Dumb final result

dumb_itemsets_result = pd.DataFrame(result_final_df_1[0])
dumb_rules_result = pd.DataFrame(result_final_df_1[1])

dumb_itemsets_result.to_csv('without_weather_itemsets_result.csv', index=False)
dumb_rules_result.to_csv('without_weather_rules_result.csv', index=False)

# %% [markdown]
# ## Spacified One-Hot Encoding

# %%
# Load Dataset

abs_path = Path.cwd()
data_address = abs_path.parent.parent / 'data/' / 'Cleaned_US.csv'
df = pd.read_csv(data_address)

# %%
df
# Out:
#          Severity           Start_Time  Start_Lat   Start_Lng    End_Lat  \
# 0               3  2016-02-08 00:37:08  40.108910  -83.092860  40.112060
# 1               2  2016-02-08 05:56:20  39.865420  -84.062800  39.865010
# 2               2  2016-02-08 06:15:39  39.102660  -84.524680  39.102090
# 3               2  2016-02-08 06:51:45  41.062130  -81.537840  41.062170
# 4               3  2016-02-08 07:53:43  39.172393  -84.492792  39.170476
# ...           ...                  ...        ...         ...        ...
# 2774570         2  2021-07-19 16:15:41  25.953810  -80.205651  25.942621
# 2774571         2  2021-12-16 21:54:00  38.426953 -120.588087  38.426690
# 2774572         2  2021-12-12 16:12:00  39.750573  -84.191238  39.749632
# 2774573         2  2021-05-01 11:28:00  39.754339  -84.192260  39.753289
# 2774574         2  2021-12-08 15:36:00  37.694587 -122.143773  37.621164
#
#             End_Lng  Distance(mi)         City      County State  ...  \
# 0        -83.031870         3.230       Dublin    Franklin    OH  ...
# 1        -84.048730         0.747       Dayton  Montgomery    OH  ...
# 2        -84.523960         0.055   Cincinnati    Hamilton    OH  ...
# 3        -81.535470         0.123        Akron      Summit    OH  ...
# 4        -84.501798         0.500   Cincinnati    Hamilton    OH  ...
# ...             ...           ...          ...         ...   ...  ...
# 2774570  -80.205285         0.773        Miami  Miami-Dade    FL  ...
# 2774571 -120.587706         0.027      Pioneer      Amador    CA  ...
# 2774572  -84.190979         0.066       Dayton  Montgomery    OH  ...
# 2774573  -84.191977         0.074       Dayton  Montgomery    OH  ...
# 2774574 -122.077127         6.247  San Leandro     Alameda    CA  ...
#
#          Railway  Roundabout  Station   Stop  Traffic_Calming  Traffic_Signal  \
# 0          False       False    False  False            False           False
# 1          False       False    False  False            False           False
# 2          False       False    False  False            False           False
# 3          False       False    False  False            False           False
# 4          False       False    False  False            False           False
# ...          ...         ...      ...    ...              ...             ...
# 2774570    False       False     True  False            False           False
# 2774571    False       False    False  False            False           False
# 2774572    False       False    False  False            False           False
# 2774573    False       False    False  False            False           False
# 2774574    False       False    False  False            False           False
#
#          Turning_Loop    Weekday  Hour  Month
# 0               False     Monday     0      2
# 1               False     Monday     5      2
# 2               False     Monday     6      2
# 3               False     Monday     6      2
# 4               False     Monday     7      2
# ...               ...        ...   ...    ...
# 2774570         False     Monday    16      7
# 2774571         False   Thursday    21     12
# 2774572         False     Sunday    16     12
# 2774573         False   Saturday    11      5
# 2774574         False  Wednesday    15     12
#
# [2774575 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2774575 entries, 0 to 2774574
# Data columns (total 34 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Severity           int64
#  1   Start_Time         object
#  2   Start_Lat          float64
#  3   Start_Lng          float64
#  4   End_Lat            float64
#  5   End_Lng            float64
#  6   Distance(mi)       float64
#  7   City               object
#  8   County             object
#  9   State              object
#  10  Temperature(F)     float64
#  11  Wind_Chill(F)      float64
#  12  Humidity(%)        float64
#  13  Pressure(in)       float64
#  14  Visibility(mi)     float64
#  15  Wind_Speed(mph)    float64
#  16  Precipitation(in)  float64
#  17  Weather_Condition  object
#  18  Amenity            bool
#  19  Bump               bool
#  20  Crossing           bool
#  21  Give_Way           bool
#  22  Junction           bool
#  23  No_Exit            bool
#  24  Railway            bool
#  25  Roundabout         bool
#  26  Station            bool
#  27  Stop               bool
#  28  Traffic_Calming    bool
#  29  Traffic_Signal     bool
#  30  Turning_Loop       bool
#  31  Weekday            object
#  32  Hour               int64
#  33  Month              int64
# dtypes: bool(13), float64(12), int64(3), object(6)
# memory usage: 478.9+ MB

# %%
# Assuming your dataframe is named 'df'

# Selecting the columns you want to keep
selected_columns = ['Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)', 'Wind_Speed(mph)']
df_selected = df[selected_columns]



# Printing the final dataframe
df_selected
# Out:
#          Temperature(F)  Wind_Chill(F)  Humidity(%)  Pressure(in)  \
# 0                  42.1       36.10000         58.0         29.76
# 1                  36.9       59.66357         91.0         29.68
# 2                  36.0       59.66357         97.0         29.70
# 3                  39.0       59.66357         55.0         29.65
# 4                  37.0       29.80000         93.0         29.69
# ...                 ...            ...          ...           ...
# 2774570            89.0       89.00000         57.0         30.06
# 2774571            37.0       29.00000         81.0         27.43
# 2774572            47.0       40.00000         32.0         29.36
# 2774573            57.0       57.00000         41.0         29.22
# 2774574            54.0       54.00000         86.0         29.96
#
#          Wind_Speed(mph)
# 0              10.400000
# 1               7.396954
# 2               7.396954
# 3               7.396954
# 4              10.400000
# ...                  ...
# 2774570        14.000000
# 2774571        13.000000
# 2774572        16.000000
# 2774573        12.000000
# 2774574         6.000000
#
# [2774575 rows x 5 columns]

# %%
df_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2774575 entries, 0 to 2774574
# Data columns (total 5 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Temperature(F)   float64
#  1   Wind_Chill(F)    float64
#  2   Humidity(%)      float64
#  3   Pressure(in)     float64
#  4   Wind_Speed(mph)  float64
# dtypes: float64(5)
# memory usage: 105.8 MB

# %%
import pandas as pd

# Assuming your dataframe is named 'df'

# Columns you want to process
columns_to_process = ['Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)', 'Wind_Speed(mph)']

# Calculate the number of rows to exclude from each end
exclude_rows = int(0.15 * df_selected.shape[0])

# Exclude data from both ends for all columns
df_sorted = df_selected.sort_values(by=columns_to_process)
df_no_edges = df_sorted.iloc[exclude_rows:-exclude_rows]

# Resulting dataframe with edges excluded
df_no_edges
# Out:
#          Temperature(F)  Wind_Chill(F)  Humidity(%)  Pressure(in)  \
# 1509218            42.0           37.0         65.0         29.67
# 1413967            42.0           37.0         65.0         29.68
# 1694562            42.0           37.0         65.0         29.68
# 384433             42.0           37.0         65.0         29.70
# 423493             42.0           37.0         65.0         29.70
# ...                 ...            ...          ...           ...
# 2570484            81.0           81.0         65.0         28.65
# 801451             81.0           81.0         65.0         28.65
# 856464             81.0           81.0         65.0         28.66
# 92737              81.0           81.0         65.0         28.66
# 1034546            81.0           81.0         65.0         28.66
#
#          Wind_Speed(mph)
# 1509218              9.0
# 1413967              8.0
# 1694562              8.0
# 384433               9.0
# 423493               9.0
# ...                  ...
# 2570484              5.0
# 801451               9.0
# 856464               9.0
# 92737               10.0
# 1034546             10.0
#
# [1942203 rows x 5 columns]

# %%
df_no_edges.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1942203 entries, 1509218 to 1034546
# Data columns (total 5 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   Temperature(F)   float64
#  1   Wind_Chill(F)    float64
#  2   Humidity(%)      float64
#  3   Pressure(in)     float64
#  4   Wind_Speed(mph)  float64
# dtypes: float64(5)
# memory usage: 88.9 MB

# %%
# Analys best cuts for features
# Temperature(F)

temperature_data = df_no_edges['Temperature(F)']

# Plot distribution
plt.hist(temperature_data, bins=40)
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.xlim(-40,140)
plt.title('Distribution of Temperature')
plt.savefig('Distribution of Temperature')
# 50, 90

# %%
# Analys best cuts for features
# Temperature(F)

temperature_data = df_no_edges['Wind_Chill(F)']

# Plot distribution
plt.hist(temperature_data, bins=40)
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.xlim(-40,140)
plt.title('Distribution of Temperature')
plt.savefig('Distribution of Temperature')
# 50, 90

# %%
# Analys best cuts for features
# Temperature(F)

temperature_data = df_no_edges['Humidity(%)']

# Plot distribution
plt.hist(temperature_data, bins=40)
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.xlim(-40,140)
plt.title('Distribution of Temperature')
plt.savefig('Distribution of Temperature')
# 50, 90

# %%
# Analys best cuts for features
# Temperature(F)

temperature_data = df_no_edges['Pressure(in)']

# Plot distribution
plt.hist(temperature_data, bins=40)
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.xlim(-40,140)
plt.title('Distribution of Temperature')
plt.savefig('Distribution of Temperature')
# 50, 90

# %%
# Analys best cuts for features
# Temperature(F)

temperature_data = df_no_edges['Wind_Speed(mph)']

# Plot distribution
plt.hist(temperature_data, bins=1000)
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.xlim(0,70)
plt.title('Distribution of Temperature')
plt.savefig('Distribution of Temperature')
# 50, 90

# %%
# Assuming your dataframe is named 'df'

# Calculate the number of rows to exclude from each end
exclude_rows = int(0.15 * df.shape[0])

# Exclude data from both ends for all columns
df_no_edges = df.iloc[exclude_rows:-exclude_rows]

# Resulting dataframe with edges excluded
df_no_edges
# Out:
#          Severity           Start_Time  Start_Lat   Start_Lng    End_Lat  \
# 416186          2  2021-06-16 17:53:00  30.068789  -81.926466  30.070451
# 416187          2  2021-08-21 08:28:00  42.045053  -87.993053  42.055673
# 416188          2  2021-12-13 14:50:00  27.438026  -82.530540  27.429215
# 416189          2  2021-07-30 08:24:13  40.726035  -73.903086  40.743375
# 416190          2  2021-03-15 07:19:00  42.600158  -83.946855  42.589881
# ...           ...                  ...        ...         ...        ...
# 2358384         2  2018-08-03 12:44:24  47.622950 -122.188580  47.626200
# 2358385         2  2018-08-03 12:44:24  47.625790 -122.188890  47.623700
# 2358386         2  2018-08-03 12:54:50  47.742100 -122.329650  47.740571
# 2358387         3  2018-08-03 13:00:50  47.529400 -122.197710  47.532250
# 2358388         2  2018-08-03 13:15:09  47.527440 -122.197820  47.515210
#
#             End_Lng  Distance(mi)               City      County State  ...  \
# 416186   -81.929544         0.217         Middleburg        Clay    FL  ...
# 416187   -88.017273         1.443  Arlington Heights        Cook    IL  ...
# 416188   -82.530569         0.609          Bradenton     Manatee    FL  ...
# 416189   -73.835919         3.715            Maspeth      Queens    NY  ...
# 416190   -83.933430         0.985             Howell  Livingston    MI  ...
# ...             ...           ...                ...         ...   ...  ...
# 2358384 -122.188630         0.225           Bellevue        King    WA  ...
# 2358385 -122.188890         0.144           Bellevue        King    WA  ...
# 2358386 -122.328779         0.113            Seattle        King    WA  ...
# 2358387 -122.197410         0.197             Renton        King    WA  ...
# 2358388 -122.198460         0.846             Renton        King    WA  ...
#
#          Railway  Roundabout  Station   Stop  Traffic_Calming  Traffic_Signal  \
# 416186     False       False    False  False            False           False
# 416187     False       False    False  False            False           False
# 416188     False       False    False  False            False           False
# 416189     False       False    False  False            False           False
# 416190     False       False    False  False            False           False
# ...          ...         ...      ...    ...              ...             ...
# 2358384    False       False    False  False            False           False
# 2358385    False       False    False  False            False           False
# 2358386    False       False    False  False            False           False
# 2358387    False       False    False  False            False           False
# 2358388    False       False    False  False            False           False
#
#          Turning_Loop    Weekday  Hour  Month
# 416186          False  Wednesday    17      6
# 416187          False   Saturday     8      8
# 416188          False     Monday    14     12
# 416189          False     Friday     8      7
# 416190          False     Monday     7      3
# ...               ...        ...   ...    ...
# 2358384         False     Friday    12      8
# 2358385         False     Friday    12      8
# 2358386         False     Friday    12      8
# 2358387         False     Friday    13      8
# 2358388         False     Friday    13      8
#
# [1942203 rows x 34 columns]

# %%
# Analys best cuts for features
# Temperature(F)

temperature_data = df_no_edges['Temperature(F)']

# Plot distribution
plt.hist(temperature_data, bins=40)
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.xlim(-40,140)
plt.title('Distribution of Temperature')
plt.savefig('Distribution of Temperature')
# 50, 90

# %%
temperature_data = df_final['Temperature(F)']
temperature_data
# Out:
# 415832     5
# 415833     8
# 415834     6
# 415835     7
# 415836     8
#           ..
# 2358679    7
# 2358680    7
# 2358681    7
# 2358682    8
# 2358683    8
# Name: Temperature(F), Length: 1927769, dtype: int64
