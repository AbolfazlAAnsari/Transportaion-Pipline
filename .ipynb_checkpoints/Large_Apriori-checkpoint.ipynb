# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import matplotlib.ticker as ticker
import plotly.io as pio
from sklearn.cluster import KMeans
from mlxtend.frequent_patterns import apriori, association_rules

# %matplotlib inline

# %%
# Load Dataset

abs_path = Path.cwd()
data_address = abs_path.parent.parent / 'data/' / 'Cleaned_US.csv'
df = pd.read_csv(data_address)

# %%
# Give a Sample DF
sample_size = 40000
df = df.sample(n=sample_size, random_state=42)

# %% [markdown]
# # Static VS Dynamic

# %%
# Data Preprocess to create a flat dataset for static and dynamic

# %%
df['Weather_Condition'].value_counts().to_dict()
# Out:
# {'Fair': 15926,
#  'Mostly Cloudy': 5199,
#  'Cloudy': 5132,
#  'Partly Cloudy': 3548,
#  'Clear': 2510,
#  'Light Rain': 1888,
#  'Overcast': 1209,
#  'Fog': 631,
#  'Scattered Clouds': 625,
#  'Light Snow': 607,
#  'Haze': 539,
#  'Rain': 425,
#  'Fair / Windy': 215,
#  'Heavy Rain': 167,
#  'Light Drizzle': 116,
#  'Smoke': 111,
#  'Thunder in the Vicinity': 107,
#  'T-Storm': 103,
#  'Cloudy / Windy': 99,
#  'Light Rain with Thunder': 99,
#  'Mostly Cloudy / Windy': 89,
#  'Thunder': 85,
#  'Snow': 80,
#  'Light Rain / Windy': 58,
#  'Partly Cloudy / Windy': 50,
#  'Wintry Mix': 49,
#  'Heavy T-Storm': 48,
#  'Light Snow / Windy': 35,
#  'N/A Precipitation': 26,
#  'Heavy Snow': 25,
#  'Drizzle': 21,
#  'Shallow Fog': 16,
#  'Light Thunderstorms and Rain': 14,
#  'Rain / Windy': 14,
#  'Light Freezing Rain': 13,
#  'Patches of Fog': 13,
#  'Mist': 12,
#  'Haze / Windy': 9,
#  'Heavy Rain / Windy': 9,
#  'Light Freezing Drizzle': 7,
#  'Thunderstorm': 7,
#  'Showers in the Vicinity': 7,
#  'Light Freezing Fog': 6,
#  'Heavy T-Storm / Windy': 6,
#  'Thunderstorms and Rain': 6,
#  'Heavy Thunderstorms and Rain': 5,
#  'T-Storm / Windy': 4,
#  'Fog / Windy': 4,
#  'Snow / Windy': 4,
#  'Heavy Snow / Windy': 3,
#  'Blowing Snow / Windy': 3,
#  'Blowing Snow': 2,
#  'Drizzle and Fog': 2,
#  'Heavy Drizzle': 2,
#  'Ice Pellets': 1,
#  'Thunder / Windy': 1,
#  'Snow and Sleet': 1,
#  'Rain Shower': 1,
#  'Blowing Dust / Windy': 1,
#  'Blowing Dust': 1,
#  'Light Rain Showers': 1,
#  'Smoke / Windy': 1,
#  'Light Drizzle / Windy': 1,
#  'Rain Showers': 1}

# %%
# Fair, Clear, Fair / Windy, 
# Overcast, Mostly Cloudy, Cloudy, Partly Cloudy, Scattered Clouds, 
# Light Rain, Rain, Heavy Rain
# Snow, 
# Haze, Smoke, 
# Drizzle, Thunder, Dust
# Fog


# Smoke: dud sukhtan
# Haze: ghobar

# Dust: very stong winds with solid
# Thunder: rad bargh

# Drizzle: barun ba ghatre kuchik

# Overcast: 100 percent cloud in sky

df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder and Hail / Windy', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sand / Dust Whirlwinds / Windy', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Freezing Rain', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Blowing Sand', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Mist / Windy', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sleet / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Dust Whirls', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sand / Dust Whirls Nearby', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Rain Shower / Windy', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Rain Showers', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Blowing Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Drifting Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Low Drifting Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Thunderstorms with Small Hail', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Haze', 'Haze')
df['Weather_Condition'] = df['Weather_Condition'].replace('Blowing Snow Nearby', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder and Hail', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Snow and Thunder / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Freezing Drizzle', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sand', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder / Wintry Mix / Windy', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Blowing Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Ice Pellets', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Duststorm', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Funnel Cloud', 'Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Freezing Rain / Windy', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sand / Windy', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Rain Shower', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Hail', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Snow with Thunder', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Thunderstorms and Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Patches of Fog / Windy', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Volcanic Ash', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder / Wintry Mix', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow Showers', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Thunderstorms and Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Rain Shower / Windy', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Sleet / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Snow Grains', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Tornado', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Drizzle / Windy', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow with Thunder', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Freezing Drizzle', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Squalls', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Sleet', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sand / Dust Whirlwinds', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow and Sleet / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Widespread Dust / Windy', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Snow and Sleet / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Squalls / Windy', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow Shower', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Partial Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Rain Showers', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Freezing Rain / Windy', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Small Hail', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Ice Pellets', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Rain Shower', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Rain Showers', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow and Sleet', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Freezing Rain', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Smoke / Windy', 'Smoke')
df['Weather_Condition'] = df['Weather_Condition'].replace('Sleet', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Widespread Dust', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Sleet', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Wintry Mix / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Ice Pellets', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Blowing Snow / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Drizzle / Windy', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Snow and Sleet', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Drizzle and Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Rain Shower', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Drizzle', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Blowing Dust', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Blowing Dust / Windy', 'Dust')
df['Weather_Condition'] = df['Weather_Condition'].replace('Blowing Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Snow / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder / Windy', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('T-Storm / Windy', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Fog / Windy', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Freezing Drizzle', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy T-Storm / Windy', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Freezing Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Snow / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunderstorms and Rain', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Thunderstorms and Rain', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Haze / Windy', 'Haze')
df['Weather_Condition'] = df['Weather_Condition'].replace('Showers in the Vicinity', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Rain / Windy', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Freezing Rain', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Shallow Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunderstorm', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Mist', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Patches of Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('N/A Precipitation', 'Fair')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Thunderstorms and Rain', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Rain / Windy', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Drizzle', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow / Windy', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Rain / Windy', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy T-Storm', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Wintry Mix', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Partly Cloudy / Windy', 'Partly Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Rain with Thunder', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Mostly Cloudy / Windy', 'Mostly Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('T-Storm', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Cloudy / Windy', 'Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Thunder in the Vicinity', 'Thunder')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Drizzle', 'Drizzle')
df['Weather_Condition'] = df['Weather_Condition'].replace('Smoke', 'Smoke')
df['Weather_Condition'] = df['Weather_Condition'].replace('Heavy Rain', 'Heavy Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Fair / Windy', 'Fair / Windy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Rain', 'Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Haze', 'Haze')
df['Weather_Condition'] = df['Weather_Condition'].replace('Fog', 'Fog')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Snow', 'Snow')
df['Weather_Condition'] = df['Weather_Condition'].replace('Scattered Clouds', 'Scatterred Clouds')
df['Weather_Condition'] = df['Weather_Condition'].replace('Overcast', 'Overcast')
df['Weather_Condition'] = df['Weather_Condition'].replace('Light Rain', 'Light Rain')
df['Weather_Condition'] = df['Weather_Condition'].replace('Clear', 'Clear')
df['Weather_Condition'] = df['Weather_Condition'].replace('Partly Cloudy', 'Partly Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Cloudy', 'Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Mostly Cloudy', 'Mostly Cloudy')
df['Weather_Condition'] = df['Weather_Condition'].replace('Fair', 'Fair')

# %%
df['Weather_Condition'].value_counts().to_dict()
# Out:
# {'Fair': 15952,
#  'Mostly Cloudy': 5288,
#  'Cloudy': 5231,
#  'Partly Cloudy': 3598,
#  'Clear': 2510,
#  'Light Rain': 2059,
#  'Overcast': 1209,
#  'Snow': 822,
#  'Fog': 672,
#  'Scatterred Clouds': 625,
#  'Haze': 548,
#  'Rain': 468,
#  'Thunder': 361,
#  'Fair / Windy': 215,
#  'Heavy Rain': 181,
#  'Drizzle': 147,
#  'Smoke': 112,
#  'Dust': 2}

# %%
df = pd.get_dummies(df, columns=['Weather_Condition'], prefix='Weather', dtype=bool)

# %%
df = pd.get_dummies(df, columns=['Weekday'], prefix='Weekday', dtype=bool)

# %%
df['Hour'] = df['Hour'].astype('float64')
df['Month'] = df['Month'].astype('float64')

# Step 1: Convert "Hour" to 4 boolean columns
hour_labels = ['Night (0-5)', 'Morning (6-11)', 'Afternoon (12-17)', 'Evening (18-23)']
hour_bins = [0, 5, 11, 17, 23]
df['Part_of_Day'] = pd.cut(df['Hour'], bins=hour_bins, labels=hour_labels, right=False)
df = pd.get_dummies(df, columns=['Part_of_Day'], prefix='Part_of_Day', dtype=bool)

# Step 2: Convert "Month" to 12 boolean columns
month_names = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
df['Month'] = df['Month'].astype(int)
df = pd.get_dummies(df, columns=['Month'], prefix='Month', dtype=bool)
df.rename(columns={'Month_'+str(i): month_names[i-1] for i in range(1, 13)}, inplace=True)

# Drop the original "Hour" column as it is no longer needed
df.drop(['Hour'], axis=1, inplace=True)

# %%
def static_convertor(df):

    weather_float_columns = ['Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
                             'Visibility(mi)', 'Wind_Speed(mph)', 'Precipitation(in)']

    # Define the thresholds for each weather column
    thresholds = {
    'Temperature(F)': [0, 32, 70, float('inf')],
    'Wind_Chill(F)': [-float('inf'), 20, 50, float('inf')],
    'Humidity(%)': [0, 40, 70, 100],
    'Pressure(in)': [0, 29.5, 30, float('inf')],
    'Visibility(mi)': [0, 2, 5, float('inf')],
    'Wind_Speed(mph)': [0, 5, 10, float('inf')],
    'Precipitation(in)': [0, 0.01, 0.1, float('inf')]
    }

    df_static_threshold = pd.DataFrame()

    # Discretize and encode weather columns using one-hot encoding
    for column in weather_float_columns:
        bins = thresholds[column]
        labels = range(len(bins) - 1)
        categories = pd.cut(df[column], bins=bins, labels=labels)
        encoded_cols = pd.get_dummies(categories, prefix=column)
        df_static_threshold = pd.concat([df_static_threshold, encoded_cols], axis=1)
        
    return df_static_threshold

# %%
def dynamic_convertor(df):
    # Define weather float columns
    weather_float_columns = ['Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
                             'Visibility(mi)', 'Wind_Speed(mph)', 'Precipitation(in)']

    # Create a new DataFrame for encoded columns
    df_dynamic_threshold = pd.DataFrame()

    # Discretize and encode weather columns using one-hot encoding
    for column in weather_float_columns:
        column_values = df[column]
        
        # Adjust threshold percentages if they are the same
        if len(set(column_values)) == 1:
            min_value = column_values.min()
            max_value = column_values.max()
            if min_value == max_value:
                thresholds = [0, min_value, min_value + 1, float('inf')]
            else:
                thresholds = [0, min_value, max_value, float('inf')]
        else:
            thresholds = [0, np.percentile(column_values, 15), np.percentile(column_values, 85), float('inf')]
        
        bins = np.unique(thresholds)  # Ensure unique bin edges
        labels = range(len(bins) - 1)
        categories = pd.cut(column_values, bins=bins, labels=labels)
        encoded_cols = pd.get_dummies(categories, prefix=column, dtype=bool)
        df_dynamic_threshold = pd.concat([df_dynamic_threshold, encoded_cols], axis=1)

    return df_dynamic_threshold

# %%
df_weather_bool_static = static_convertor(sample_df)
df_weather_bool_dynamic = dynamic_convertor(sample_df)

# %%
final_df_static = pd.concat([df, df_weather_bool_static], axis=1)
final_df_dynamic = pd.concat([df, df_weather_bool_dynamic], axis=1)

# %%
columns_to_drop = {'Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 
                   'End_Lat', 'End_Lng', 'Distance(mi)', 'City', 
                   'County', 'State', 'Temperature(F)', 'Wind_Chill(F)', 
                   'Humidity(%)', 'Pressure(in)', 'Visibility(mi)',
                    'Wind_Speed(mph)', 'Precipitation(in)'}

static_copy = final_df_static.copy()
dynamic_copy = final_df_dynamic.copy()

final_df_static.drop(columns_to_drop, axis=1, inplace=True)
final_df_dynamic.drop(columns_to_drop, axis=1, inplace=True)

# %%
def apply_apriori(df, min_support=0.3, min_threshold=0.6):
    # Apply Apriori algorithm
    frequent_itemsets = apriori(df, min_support=min_support, use_colnames=True)
    rules = association_rules(frequent_itemsets, metric="support", min_threshold=min_threshold)

    print(frequent_itemsets.sort_values('support', ascending=False))
    print(rules.sort_values('support', ascending=False))
    
    return frequent_itemsets, rules

# %%
apply_apriori(final_df_static)
# Out:
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
#      support                                           itemsets
# 9     0.8981                                 (Visibility(mi)_2)
# 4     0.7507                                  (Wind_Chill(F)_2)
# 21    0.6952                (Visibility(mi)_2, Wind_Chill(F)_2)
# 2   0.564575                                 (Temperature(F)_1)
# 16   0.49485               (Temperature(F)_1, Visibility(mi)_2)
# 6   0.443175                                    (Humidity(%)_2)
# 10    0.4241                                (Wind_Speed(mph)_1)
# 8    0.42065                                   (Pressure(in)_1)
# 0     0.3988                                     (Weather_Fair)
# 12   0.39195                   (Visibility(mi)_2, Weather_Fair)
# 26  0.386175              (Wind_Speed(mph)_1, Visibility(mi)_2)
# 5    0.38565                                    (Humidity(%)_1)
# 15  0.385125                (Temperature(F)_1, Wind_Chill(F)_2)
# 23  0.379425                  (Visibility(mi)_2, Humidity(%)_1)
# 25    0.3786                 (Pressure(in)_1, Visibility(mi)_2)
# 1     0.3682                    (Part_of_Day_Afternoon (12-17))
# 3   0.361775                                 (Temperature(F)_2)
# 17  0.361775                (Temperature(F)_2, Wind_Chill(F)_2)
# 29    0.3506  (Visibility(mi)_2, Temperature(F)_2, Wind_Chil...
# 18    0.3506               (Visibility(mi)_2, Temperature(F)_2)
# 24   0.34955                  (Visibility(mi)_2, Humidity(%)_2)
# 20   0.34225                  (Pressure(in)_1, Wind_Chill(F)_2)
# 28   0.34195  (Temperature(F)_1, Visibility(mi)_2, Wind_Chil...
# 14    0.3387  (Visibility(mi)_2, Part_of_Day_Afternoon (12-17))
# 22    0.3372               (Wind_Speed(mph)_1, Wind_Chill(F)_2)
# 7     0.3242                                   (Pressure(in)_0)
# 31    0.3147  (Pressure(in)_1, Visibility(mi)_2, Wind_Chill(...
# 32  0.314675  (Wind_Speed(mph)_1, Visibility(mi)_2, Wind_Chi...
# 13  0.310825   (Wind_Chill(F)_2, Part_of_Day_Afternoon (12-17))
# 11   0.30995                    (Wind_Chill(F)_2, Weather_Fair)
# 19  0.307875                   (Humidity(%)_1, Wind_Chill(F)_2)
# 27    0.3058  (Visibility(mi)_2, Wind_Chill(F)_2, Weather_Fair)
# 30   0.30275  (Visibility(mi)_2, Humidity(%)_1, Wind_Chill(F...
#           antecedents         consequents  antecedent support  \
# 0  (Visibility(mi)_2)   (Wind_Chill(F)_2)              0.8981
# 1   (Wind_Chill(F)_2)  (Visibility(mi)_2)              0.7507
#
#    consequent support  support  confidence      lift  leverage  conviction  \
# 0              0.7507   0.6952    0.774079  1.031142  0.020996    1.103481
# 1              0.8981   0.6952    0.926069  1.031142  0.020996    1.378312
#
#    zhangs_metric
# 0       0.296387
# 1       0.121147
# (     support                                           itemsets
#  0     0.3988                                     (Weather_Fair)
#  1     0.3682                    (Part_of_Day_Afternoon (12-17))
#  2   0.564575                                 (Temperature(F)_1)
#  3   0.361775                                 (Temperature(F)_2)
#  4     0.7507                                  (Wind_Chill(F)_2)
#  5    0.38565                                    (Humidity(%)_1)
#  6   0.443175                                    (Humidity(%)_2)
#  7     0.3242                                   (Pressure(in)_0)
#  8    0.42065                                   (Pressure(in)_1)
#  9     0.8981                                 (Visibility(mi)_2)
#  10    0.4241                                (Wind_Speed(mph)_1)
#  11   0.30995                    (Wind_Chill(F)_2, Weather_Fair)
#  12   0.39195                   (Visibility(mi)_2, Weather_Fair)
#  13  0.310825   (Wind_Chill(F)_2, Part_of_Day_Afternoon (12-17))
#  14    0.3387  (Visibility(mi)_2, Part_of_Day_Afternoon (12-17))
#  15  0.385125                (Temperature(F)_1, Wind_Chill(F)_2)
#  16   0.49485               (Temperature(F)_1, Visibility(mi)_2)
#  17  0.361775                (Temperature(F)_2, Wind_Chill(F)_2)
#  18    0.3506               (Visibility(mi)_2, Temperature(F)_2)
#  19  0.307875                   (Humidity(%)_1, Wind_Chill(F)_2)
#  20   0.34225                  (Pressure(in)_1, Wind_Chill(F)_2)
#  21    0.6952                (Visibility(mi)_2, Wind_Chill(F)_2)
#  22    0.3372               (Wind_Speed(mph)_1, Wind_Chill(F)_2)
#  23  0.379425                  (Visibility(mi)_2, Humidity(%)_1)
#  24   0.34955                  (Visibility(mi)_2, Humidity(%)_2)
#  25    0.3786                 (Pressure(in)_1, Visibility(mi)_2)
#  26  0.386175              (Wind_Speed(mph)_1, Visibility(mi)_2)
#  27    0.3058  (Visibility(mi)_2, Wind_Chill(F)_2, Weather_Fair)
#  28   0.34195  (Temperature(F)_1, Visibility(mi)_2, Wind_Chil...
#  29    0.3506  (Visibility(mi)_2, Temperature(F)_2, Wind_Chil...
#  30   0.30275  (Visibility(mi)_2, Humidity(%)_1, Wind_Chill(F...
#  31    0.3147  (Pressure(in)_1, Visibility(mi)_2, Wind_Chill(...
#  32  0.314675  (Wind_Speed(mph)_1, Visibility(mi)_2, Wind_Chi...,
#            antecedents         consequents  antecedent support  \
#  0  (Visibility(mi)_2)   (Wind_Chill(F)_2)              0.8981
#  1   (Wind_Chill(F)_2)  (Visibility(mi)_2)              0.7507
#
#     consequent support  support  confidence      lift  leverage  conviction  \
#  0              0.7507   0.6952    0.774079  1.031142  0.020996    1.103481
#  1              0.8981   0.6952    0.926069  1.031142  0.020996    1.378312
#
#     zhangs_metric
#  0       0.296387
#  1       0.121147  )

# %%
apply_apriori(final_df_dynamic)
# Out:
#      support                                           itemsets
# 6   0.827975                                 (Visibility(mi)_1)
# 7   0.722650                                (Wind_Speed(mph)_0)
# 4   0.716900                                    (Humidity(%)_1)
# 5   0.703225                                   (Pressure(in)_1)
# 2   0.701975                                 (Temperature(F)_1)
# 3   0.697650                                  (Wind_Chill(F)_1)
# 10  0.658925                (Wind_Chill(F)_1, Temperature(F)_1)
# 20  0.626850                  (Visibility(mi)_1, Humidity(%)_1)
# 24  0.608175              (Wind_Speed(mph)_0, Visibility(mi)_1)
# 13  0.582550               (Temperature(F)_1, Visibility(mi)_1)
# 22  0.582225                 (Pressure(in)_1, Visibility(mi)_1)
# 17  0.576650                (Wind_Chill(F)_1, Visibility(mi)_1)
# 27  0.543400  (Temperature(F)_1, Wind_Chill(F)_1, Visibility...
# 21  0.524675                 (Wind_Speed(mph)_0, Humidity(%)_1)
# 19  0.519000                    (Pressure(in)_1, Humidity(%)_1)
# 12  0.509875                 (Pressure(in)_1, Temperature(F)_1)
# 23  0.508925                (Pressure(in)_1, Wind_Speed(mph)_0)
# 11  0.507825                  (Temperature(F)_1, Humidity(%)_1)
# 16  0.505625                  (Pressure(in)_1, Wind_Chill(F)_1)
# 14  0.504625              (Wind_Speed(mph)_0, Temperature(F)_1)
# 18  0.504525               (Wind_Chill(F)_1, Wind_Speed(mph)_0)
# 15  0.499675                   (Wind_Chill(F)_1, Humidity(%)_1)
# 26  0.477750  (Pressure(in)_1, Wind_Chill(F)_1, Temperature(...
# 28  0.474475  (Wind_Chill(F)_1, Temperature(F)_1, Wind_Speed...
# 25  0.474450  (Wind_Chill(F)_1, Temperature(F)_1, Humidity(%...
# 43  0.465200  (Wind_Speed(mph)_0, Visibility(mi)_1, Humidity...
# 41  0.453975  (Pressure(in)_1, Visibility(mi)_1, Humidity(%)_1)
# 30  0.444025  (Temperature(F)_1, Visibility(mi)_1, Humidity(...
# 36  0.435700  (Wind_Chill(F)_1, Visibility(mi)_1, Humidity(%...
# 44  0.427925  (Pressure(in)_1, Wind_Speed(mph)_0, Visibility...
# 34  0.425400  (Temperature(F)_1, Wind_Speed(mph)_0, Visibili...
# 40  0.423675  (Wind_Chill(F)_1, Visibility(mi)_1, Wind_Speed...
# 32  0.417375  (Pressure(in)_1, Temperature(F)_1, Visibility(...
# 46  0.412825  (Temperature(F)_1, Wind_Chill(F)_1, Visibility...
# 38  0.412200  (Pressure(in)_1, Wind_Chill(F)_1, Visibility(m...
# 0   0.398800                                     (Weather_Fair)
# 50  0.397725  (Temperature(F)_1, Wind_Chill(F)_1, Visibility...
# 48  0.387925  (Pressure(in)_1, Wind_Chill(F)_1, Visibility(m...
# 42  0.380175  (Pressure(in)_1, Wind_Speed(mph)_0, Humidity(%...
# 29  0.376275  (Pressure(in)_1, Temperature(F)_1, Humidity(%)_1)
# 8   0.375650                   (Visibility(mi)_1, Weather_Fair)
# 31  0.370475  (Wind_Speed(mph)_0, Temperature(F)_1, Humidity...
# 1   0.368200                    (Part_of_Day_Afternoon (12-17))
# 35  0.367925   (Pressure(in)_1, Wind_Chill(F)_1, Humidity(%)_1)
# 37  0.366550  (Wind_Chill(F)_1, Humidity(%)_1, Wind_Speed(mp...
# 33  0.363700  (Pressure(in)_1, Wind_Speed(mph)_0, Temperatur...
# 39  0.361850  (Pressure(in)_1, Wind_Chill(F)_1, Wind_Speed(m...
# 45  0.350550  (Pressure(in)_1, Wind_Chill(F)_1, Temperature(...
# 47  0.346825  (Wind_Chill(F)_1, Temperature(F)_1, Humidity(%...
# 49  0.340500  (Pressure(in)_1, Wind_Chill(F)_1, Temperature(...
# 56  0.336325  (Pressure(in)_1, Wind_Speed(mph)_0, Visibility...
# 52  0.328650  (Temperature(F)_1, Wind_Speed(mph)_0, Visibili...
# 51  0.325700  (Pressure(in)_1, Temperature(F)_1, Visibility(...
# 55  0.324125  (Wind_Chill(F)_1, Visibility(mi)_1, Humidity(%...
# 9   0.318950  (Visibility(mi)_1, Part_of_Day_Afternoon (12-17))
# 54  0.317400  (Pressure(in)_1, Wind_Chill(F)_1, Visibility(m...
# 58  0.306275  (Wind_Speed(mph)_0, Visibility(mi)_1, Wind_Chi...
# 53  0.302675  (Pressure(in)_1, Wind_Speed(mph)_0, Visibility...
# 57  0.301475  (Pressure(in)_1, Wind_Chill(F)_1, Visibility(m...
#            antecedents          consequents  antecedent support  \
# 0    (Wind_Chill(F)_1)   (Temperature(F)_1)            0.697650
# 1   (Temperature(F)_1)    (Wind_Chill(F)_1)            0.701975
# 2   (Visibility(mi)_1)      (Humidity(%)_1)            0.827975
# 3      (Humidity(%)_1)   (Visibility(mi)_1)            0.716900
# 4  (Wind_Speed(mph)_0)   (Visibility(mi)_1)            0.722650
# 5   (Visibility(mi)_1)  (Wind_Speed(mph)_0)            0.827975
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.701975  0.658925    0.944492  1.345478  0.169192    5.369068
# 1            0.697650  0.658925    0.938673  1.345478  0.169192    4.930131
# 2            0.716900  0.626850    0.757088  1.056058  0.033275    1.165443
# 3            0.827975  0.626850    0.874390  1.056058  0.033275    1.369514
# 4            0.827975  0.608175    0.841590  1.016444  0.009839    1.085948
# 5            0.722650  0.608175    0.734533  1.016444  0.009839    1.044763
#
#    zhangs_metric
# 0       0.849247
# 1       0.861572
# 2       0.308574
# 3       0.187504
# 4       0.058330
# 5       0.094043
# (     support                                           itemsets
#  0   0.398800                                     (Weather_Fair)
#  1   0.368200                    (Part_of_Day_Afternoon (12-17))
#  2   0.701975                                 (Temperature(F)_1)
#  3   0.697650                                  (Wind_Chill(F)_1)
#  4   0.716900                                    (Humidity(%)_1)
#  5   0.703225                                   (Pressure(in)_1)
#  6   0.827975                                 (Visibility(mi)_1)
#  7   0.722650                                (Wind_Speed(mph)_0)
#  8   0.375650                   (Visibility(mi)_1, Weather_Fair)
#  9   0.318950  (Visibility(mi)_1, Part_of_Day_Afternoon (12-17))
#  10  0.658925                (Wind_Chill(F)_1, Temperature(F)_1)
#  11  0.507825                  (Temperature(F)_1, Humidity(%)_1)
#  12  0.509875                 (Pressure(in)_1, Temperature(F)_1)
#  13  0.582550               (Temperature(F)_1, Visibility(mi)_1)
#  14  0.504625              (Wind_Speed(mph)_0, Temperature(F)_1)
#  15  0.499675                   (Wind_Chill(F)_1, Humidity(%)_1)
#  16  0.505625                  (Pressure(in)_1, Wind_Chill(F)_1)
#  17  0.576650                (Wind_Chill(F)_1, Visibility(mi)_1)
#  18  0.504525               (Wind_Chill(F)_1, Wind_Speed(mph)_0)
#  19  0.519000                    (Pressure(in)_1, Humidity(%)_1)
#  20  0.626850                  (Visibility(mi)_1, Humidity(%)_1)
#  21  0.524675                 (Wind_Speed(mph)_0, Humidity(%)_1)
#  22  0.582225                 (Pressure(in)_1, Visibility(mi)_1)
#  23  0.508925                (Pressure(in)_1, Wind_Speed(mph)_0)
#  24  0.608175              (Wind_Speed(mph)_0, Visibility(mi)_1)
#  25  0.474450  (Wind_Chill(F)_1, Temperature(F)_1, Humidity(%...
#  26  0.477750  (Pressure(in)_1, Wind_Chill(F)_1, Temperature(...
#  27  0.543400  (Temperature(F)_1, Wind_Chill(F)_1, Visibility...
#  28  0.474475  (Wind_Chill(F)_1, Temperature(F)_1, Wind_Speed...
#  29  0.376275  (Pressure(in)_1, Temperature(F)_1, Humidity(%)_1)
#  30  0.444025  (Temperature(F)_1, Visibility(mi)_1, Humidity(...
#  31  0.370475  (Wind_Speed(mph)_0, Temperature(F)_1, Humidity...
#  32  0.417375  (Pressure(in)_1, Temperature(F)_1, Visibility(...
#  33  0.363700  (Pressure(in)_1, Wind_Speed(mph)_0, Temperatur...
#  34  0.425400  (Temperature(F)_1, Wind_Speed(mph)_0, Visibili...
#  35  0.367925   (Pressure(in)_1, Wind_Chill(F)_1, Humidity(%)_1)
#  36  0.435700  (Wind_Chill(F)_1, Visibility(mi)_1, Humidity(%...
#  37  0.366550  (Wind_Chill(F)_1, Humidity(%)_1, Wind_Speed(mp...
#  38  0.412200  (Pressure(in)_1, Wind_Chill(F)_1, Visibility(m...
#  39  0.361850  (Pressure(in)_1, Wind_Chill(F)_1, Wind_Speed(m...
#  40  0.423675  (Wind_Chill(F)_1, Visibility(mi)_1, Wind_Speed...
#  41  0.453975  (Pressure(in)_1, Visibility(mi)_1, Humidity(%)_1)
#  42  0.380175  (Pressure(in)_1, Wind_Speed(mph)_0, Humidity(%...
#  43  0.465200  (Wind_Speed(mph)_0, Visibility(mi)_1, Humidity...
#  44  0.427925  (Pressure(in)_1, Wind_Speed(mph)_0, Visibility...
#  45  0.350550  (Pressure(in)_1, Wind_Chill(F)_1, Temperature(...
#  46  0.412825  (Temperature(F)_1, Wind_Chill(F)_1, Visibility...
#  47  0.346825  (Wind_Chill(F)_1, Temperature(F)_1, Humidity(%...
#  48  0.387925  (Pressure(in)_1, Wind_Chill(F)_1, Visibility(m...
#  49  0.340500  (Pressure(in)_1, Wind_Chill(F)_1, Temperature(...
#  50  0.397725  (Temperature(F)_1, Wind_Chill(F)_1, Visibility...
#  51  0.325700  (Pressure(in)_1, Temperature(F)_1, Visibility(...
#  52  0.328650  (Temperature(F)_1, Wind_Speed(mph)_0, Visibili...
#  53  0.302675  (Pressure(in)_1, Wind_Speed(mph)_0, Visibility...
#  54  0.317400  (Pressure(in)_1, Wind_Chill(F)_1, Visibility(m...
#  55  0.324125  (Wind_Chill(F)_1, Visibility(mi)_1, Humidity(%...
#  56  0.336325  (Pressure(in)_1, Wind_Speed(mph)_0, Visibility...
#  57  0.301475  (Pressure(in)_1, Wind_Chill(F)_1, Visibility(m...
#  58  0.306275  (Wind_Speed(mph)_0, Visibility(mi)_1, Wind_Chi...,
#             antecedents          consequents  antecedent support  \
#  0    (Wind_Chill(F)_1)   (Temperature(F)_1)            0.697650
#  1   (Temperature(F)_1)    (Wind_Chill(F)_1)            0.701975
#  2   (Visibility(mi)_1)      (Humidity(%)_1)            0.827975
#  3      (Humidity(%)_1)   (Visibility(mi)_1)            0.716900
#  4  (Wind_Speed(mph)_0)   (Visibility(mi)_1)            0.722650
#  5   (Visibility(mi)_1)  (Wind_Speed(mph)_0)            0.827975
#
#     consequent support   support  confidence      lift  leverage  conviction  \
#  0            0.701975  0.658925    0.944492  1.345478  0.169192    5.369068
#  1            0.697650  0.658925    0.938673  1.345478  0.169192    4.930131
#  2            0.716900  0.626850    0.757088  1.056058  0.033275    1.165443
#  3            0.827975  0.626850    0.874390  1.056058  0.033275    1.369514
#  4            0.827975  0.608175    0.841590  1.016444  0.009839    1.085948
#  5            0.722650  0.608175    0.734533  1.016444  0.009839    1.044763
#
#     zhangs_metric
#  0       0.849247
#  1       0.861572
#  2       0.308574
#  3       0.187504
#  4       0.058330
#  5       0.094043  )

# %% [markdown]
# # Cluster VS NonCluster

# %% [markdown]
# ## Static Mode

# %%
# Number of Clusters
n_clusters = 12

# Clustering
X = static_copy[['End_Lng', 'End_Lat']]
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
static_copy['Cluster'] = kmeans.fit_predict(X)

# Plot
plt.figure(figsize=(12, 8))
scatter = plt.scatter(static_copy['End_Lng'], static_copy['End_Lat'], c=static_copy['Cluster'], cmap='tab20', s=0.3)
plt.xlabel('End Longitude')
plt.ylabel('End Latitude')
plt.title('Sample US Accident Location with Clusters')

# Add colorbar
cbar = plt.colorbar(scatter, ticks=range(12))
cbar.set_label('Cluster')

plt.show()


# Create a dict to store the dataframes for each cluster
cluster_data = {}

# Iterate over unique cluster labels
for cluster_label in static_copy['Cluster'].unique():
    # Filter the dataframe based on the cluster label
    cluster_data[cluster_label] = static_copy[static_copy['Cluster'] == cluster_label].copy()

# %%
for i in range(n_clusters):
    
    columns_to_drop = {'Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 
                   'End_Lat', 'End_Lng', 'Distance(mi)', 'City', 
                   'County', 'State', 'Temperature(F)', 'Wind_Chill(F)', 
                   'Humidity(%)', 'Pressure(in)', 'Visibility(mi)',
                    'Wind_Speed(mph)', 'Precipitation(in)', 'Cluster'}

    cluster_data[i].drop(columns_to_drop, axis=1, inplace=True)
    
    print(f"#################################### Result of Cluster {i} ####################################")
    
    apply_apriori(cluster_data[i])
# Out:
# #################################### Result of Cluster 0 ####################################
#      support                                           itemsets
# 9   0.926246                                 (Visibility(mi)_2)
# 4   0.851669                                  (Wind_Chill(F)_2)
# 23  0.799341                (Visibility(mi)_2, Wind_Chill(F)_2)
# 3   0.506799                                 (Temperature(F)_2)
# 17  0.506799                (Temperature(F)_2, Wind_Chill(F)_2)
# 18  0.491141               (Visibility(mi)_2, Temperature(F)_2)
# 33  0.491141  (Visibility(mi)_2, Temperature(F)_2, Wind_Chil...
# 2   0.473012                                 (Temperature(F)_1)
# 10  0.463535                                (Wind_Speed(mph)_1)
# 5   0.436341                                    (Humidity(%)_1)
# 25  0.433045                  (Visibility(mi)_2, Humidity(%)_1)
# 29  0.432221              (Wind_Speed(mph)_1, Visibility(mi)_2)
# 7   0.424804                                   (Pressure(in)_0)
# 16  0.423156               (Temperature(F)_1, Visibility(mi)_2)
# 24  0.406263               (Wind_Speed(mph)_1, Wind_Chill(F)_2)
# 6   0.402967                                    (Humidity(%)_2)
# 8    0.39967                                   (Pressure(in)_1)
# 27  0.397198                 (Visibility(mi)_2, Pressure(in)_0)
# 19  0.383601                   (Humidity(%)_1, Wind_Chill(F)_2)
# 34  0.381541  (Visibility(mi)_2, Humidity(%)_1, Wind_Chill(F...
# 0   0.381129                                     (Weather_Fair)
# 37  0.379893  (Wind_Speed(mph)_1, Visibility(mi)_2, Wind_Chi...
# 12  0.379069                   (Visibility(mi)_2, Weather_Fair)
# 21  0.376185                  (Pressure(in)_0, Wind_Chill(F)_2)
# 28  0.366708                 (Pressure(in)_1, Visibility(mi)_2)
# 35  0.358467  (Visibility(mi)_2, Pressure(in)_0, Wind_Chill(...
# 1   0.347342                    (Part_of_Day_Afternoon (12-17))
# 15  0.344458                (Temperature(F)_1, Wind_Chill(F)_2)
# 22  0.334569                  (Pressure(in)_1, Wind_Chill(F)_2)
# 26  0.332921                  (Visibility(mi)_2, Humidity(%)_2)
# 14  0.325917  (Visibility(mi)_2, Part_of_Day_Afternoon (12-17))
# 13  0.325917   (Wind_Chill(F)_2, Part_of_Day_Afternoon (12-17))
# 20  0.316028                   (Humidity(%)_2, Wind_Chill(F)_2)
# 11  0.313968                    (Wind_Chill(F)_2, Weather_Fair)
# 30   0.31232  (Visibility(mi)_2, Wind_Chill(F)_2, Weather_Fair)
# 31   0.31026  (Wind_Chill(F)_2, Visibility(mi)_2, Part_of_Da...
# 32  0.308199  (Temperature(F)_1, Visibility(mi)_2, Wind_Chil...
# 36  0.307787  (Pressure(in)_1, Visibility(mi)_2, Wind_Chill(...
#           antecedents         consequents  antecedent support  \
# 0  (Visibility(mi)_2)   (Wind_Chill(F)_2)            0.926246
# 1   (Wind_Chill(F)_2)  (Visibility(mi)_2)            0.851669
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.851669  0.799341    0.862989  1.013292  0.010486    1.082626
# 1            0.926246  0.799341    0.938558  1.013292  0.010486    1.200383
#
#    zhangs_metric
# 0       0.177861
# 1       0.088436
# #################################### Result of Cluster 1 ####################################
#      support                                           itemsets
# 4   0.908702                                  (Wind_Chill(F)_2)
# 9   0.886726                                 (Visibility(mi)_2)
# 25  0.814454                (Visibility(mi)_2, Wind_Chill(F)_2)
# 2   0.676549                                 (Temperature(F)_1)
# 16  0.587316                (Temperature(F)_1, Wind_Chill(F)_2)
# 19  0.572419               (Temperature(F)_1, Visibility(mi)_2)
# 0   0.530826                                     (Weather_Fair)
# 8   0.516519                                   (Pressure(in)_1)
# 13  0.512832                   (Visibility(mi)_2, Weather_Fair)
# 34  0.501475  (Temperature(F)_1, Visibility(mi)_2, Wind_Chil...
# 24  0.489086                  (Pressure(in)_1, Wind_Chill(F)_2)
# 12  0.479794                    (Wind_Chill(F)_2, Weather_Fair)
# 31  0.465044  (Visibility(mi)_2, Wind_Chill(F)_2, Weather_Fair)
# 29  0.454277                 (Pressure(in)_1, Visibility(mi)_2)
# 37  0.434808  (Pressure(in)_1, Visibility(mi)_2, Wind_Chill(...
# 5    0.39882                                    (Humidity(%)_1)
# 10  0.395723                                (Wind_Speed(mph)_1)
# 27  0.379499                  (Visibility(mi)_2, Humidity(%)_1)
# 26  0.378024               (Wind_Speed(mph)_1, Wind_Chill(F)_2)
# 22  0.375221                   (Humidity(%)_1, Wind_Chill(F)_2)
# 1   0.370059                    (Part_of_Day_Afternoon (12-17))
# 7   0.364749                                   (Pressure(in)_0)
# 14  0.362832   (Wind_Chill(F)_2, Part_of_Day_Afternoon (12-17))
# 30  0.356932              (Wind_Speed(mph)_1, Visibility(mi)_2)
# 36  0.356637  (Visibility(mi)_2, Humidity(%)_1, Wind_Chill(F...
# 38    0.3441  (Wind_Speed(mph)_1, Visibility(mi)_2, Wind_Chi...
# 18  0.343658                 (Pressure(in)_1, Temperature(F)_1)
# 15   0.34056  (Visibility(mi)_2, Part_of_Day_Afternoon (12-17))
# 32  0.337168  (Wind_Chill(F)_2, Visibility(mi)_2, Part_of_Da...
# 6   0.328909                                    (Humidity(%)_2)
# 28  0.323599                 (Visibility(mi)_2, Pressure(in)_0)
# 3   0.321386                                 (Temperature(F)_2)
# 20  0.321386                (Temperature(F)_2, Wind_Chill(F)_2)
# 33  0.316372  (Pressure(in)_1, Temperature(F)_1, Wind_Chill(...
# 21  0.312979               (Visibility(mi)_2, Temperature(F)_2)
# 35  0.312979  (Visibility(mi)_2, Temperature(F)_2, Wind_Chil...
# 17  0.312537                  (Temperature(F)_1, Humidity(%)_2)
# 11  0.312094                   (Temperature(F)_1, Weather_Fair)
# 23  0.310472                  (Pressure(in)_0, Wind_Chill(F)_2)
#           antecedents         consequents  antecedent support  \
# 0  (Visibility(mi)_2)   (Wind_Chill(F)_2)            0.886726
# 1   (Wind_Chill(F)_2)  (Visibility(mi)_2)            0.908702
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.908702  0.814454    0.918496  1.010778  0.008685    1.120170
# 1            0.886726  0.814454    0.896283  1.010778  0.008685    1.092149
#
#    zhangs_metric
# 0       0.094138
# 1       0.116798
# #################################### Result of Cluster 2 ####################################
#      support                                           itemsets
# 9   0.906379                                 (Visibility(mi)_2)
# 4   0.754681                                  (Wind_Chill(F)_2)
# 21  0.691526                (Visibility(mi)_2, Wind_Chill(F)_2)
# 2    0.60457                                 (Temperature(F)_1)
# 16   0.52999               (Temperature(F)_1, Visibility(mi)_2)
# 6   0.496668                                    (Humidity(%)_2)
# 7   0.451603                                   (Pressure(in)_0)
# 10  0.425579                                (Wind_Speed(mph)_1)
# 0   0.404316                                     (Weather_Fair)
# 24  0.403999                  (Visibility(mi)_2, Humidity(%)_2)
# 25  0.403047                 (Visibility(mi)_2, Pressure(in)_0)
# 11  0.401777                   (Visibility(mi)_2, Weather_Fair)
# 14  0.397334                (Temperature(F)_1, Wind_Chill(F)_2)
# 8   0.389718                                   (Pressure(in)_1)
# 27  0.383688              (Wind_Speed(mph)_1, Visibility(mi)_2)
# 5   0.372263                                    (Humidity(%)_1)
# 23  0.371311                  (Visibility(mi)_2, Humidity(%)_1)
# 26  0.356395                 (Pressure(in)_1, Visibility(mi)_2)
# 3   0.355125                                 (Temperature(F)_2)
# 17  0.355125                (Temperature(F)_2, Wind_Chill(F)_2)
# 19  0.354491                   (Humidity(%)_2, Wind_Chill(F)_2)
# 22  0.349096               (Wind_Speed(mph)_1, Wind_Chill(F)_2)
# 28  0.348143  (Temperature(F)_1, Visibility(mi)_2, Wind_Chil...
# 1   0.348143                    (Part_of_Day_Afternoon (12-17))
# 18  0.341162               (Visibility(mi)_2, Temperature(F)_2)
# 29  0.341162  (Visibility(mi)_2, Temperature(F)_2, Wind_Chil...
# 20   0.33894                  (Pressure(in)_0, Wind_Chill(F)_2)
# 15  0.336084                  (Temperature(F)_1, Humidity(%)_2)
# 13  0.324024  (Visibility(mi)_2, Part_of_Day_Afternoon (12-17))
# 31  0.319898  (Wind_Speed(mph)_1, Visibility(mi)_2, Wind_Chi...
# 30  0.308156  (Visibility(mi)_2, Pressure(in)_0, Wind_Chill(...
# 12  0.304665   (Wind_Chill(F)_2, Part_of_Day_Afternoon (12-17))
#           antecedents         consequents  antecedent support  \
# 0  (Visibility(mi)_2)   (Wind_Chill(F)_2)            0.906379
# 1   (Wind_Chill(F)_2)  (Visibility(mi)_2)            0.754681
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.754681  0.691526    0.762955  1.010964  0.007499    1.034905
# 1            0.906379  0.691526    0.916316  1.010964  0.007499    1.118748
#
#    zhangs_metric
# 0       0.115838
# 1       0.044207
# #################################### Result of Cluster 3 ####################################
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
#      support                                           itemsets
# 3   0.984598                                  (Wind_Chill(F)_2)
# 8   0.957877                                 (Visibility(mi)_2)
# 27  0.942847                (Visibility(mi)_2, Wind_Chill(F)_2)
# 2    0.76786                                 (Temperature(F)_2)
# 16   0.76786                (Temperature(F)_2, Wind_Chill(F)_2)
# ..       ...                                                ...
# 62  0.326962  (Wind_Speed(mph)_1, Visibility(mi)_2, Temperat...
# 14  0.302839     (Humidity(%)_1, Part_of_Day_Afternoon (12-17))
# 37  0.302654  (Wind_Chill(F)_2, Humidity(%)_1, Part_of_Day_A...
# 39  0.302282  (Visibility(mi)_2, Humidity(%)_1, Part_of_Day_...
# 57  0.302097  (Wind_Chill(F)_2, Visibility(mi)_2, Humidity(%...
#
# [63 rows x 2 columns]
#                              antecedents  \
# 4                     (Visibility(mi)_2)
# 5                      (Wind_Chill(F)_2)
# 0                     (Temperature(F)_2)
# 1                      (Wind_Chill(F)_2)
# 2                     (Visibility(mi)_2)
# 3                     (Temperature(F)_2)
# 6   (Temperature(F)_2, Visibility(mi)_2)
# 7    (Visibility(mi)_2, Wind_Chill(F)_2)
# 8    (Temperature(F)_2, Wind_Chill(F)_2)
# 9                     (Visibility(mi)_2)
# 10                    (Temperature(F)_2)
# 11                     (Wind_Chill(F)_2)
#
#                              consequents  antecedent support  \
# 4                      (Wind_Chill(F)_2)            0.957877
# 5                     (Visibility(mi)_2)            0.984598
# 0                      (Wind_Chill(F)_2)            0.767860
# 1                     (Temperature(F)_2)            0.984598
# 2                     (Temperature(F)_2)            0.957877
# 3                     (Visibility(mi)_2)            0.767860
# 6                      (Wind_Chill(F)_2)            0.744665
# 7                     (Temperature(F)_2)            0.942847
# 8                     (Visibility(mi)_2)            0.767860
# 9    (Temperature(F)_2, Wind_Chill(F)_2)            0.957877
# 10   (Visibility(mi)_2, Wind_Chill(F)_2)            0.767860
# 11  (Temperature(F)_2, Visibility(mi)_2)            0.984598
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 4             0.984598  0.942847    0.984308  0.999706 -0.000278    0.981528
# 5             0.957877  0.942847    0.957595  0.999706 -0.000278    0.993350
# 0             0.984598  0.767860    1.000000  1.015643  0.011826         inf
# 1             0.767860  0.767860    0.779872  1.015643  0.011826    1.054565
# 2             0.767860  0.744665    0.777412  1.012439  0.009149    1.042911
# 3             0.957877  0.744665    0.969792  1.012439  0.009149    1.394435
# 6             0.984598  0.744665    1.000000  1.015643  0.011469         inf
# 7             0.767860  0.744665    0.789805  1.028579  0.020690    1.104402
# 8             0.957877  0.744665    0.969792  1.012439  0.009149    1.394435
# 9             0.767860  0.744665    0.777412  1.012439  0.009149    1.042911
# 10            0.942847  0.744665    0.969792  1.028579  0.020690    1.892008
# 11            0.744665  0.744665    0.756314  1.015643  0.011469    1.047801
#
#     zhangs_metric
# 4       -0.006942
# 5       -0.018760
# 0        0.066347
# 1        1.000000
# 2        0.291674
# 3        0.052926
# 6        0.060320
# 7        0.486146
# 8        0.052926
# 9        0.291674
# 10       0.119691
# 11       1.000000
# #################################### Result of Cluster 4 ####################################
#      support                                           itemsets
# 9   0.824008                                 (Visibility(mi)_2)
# 8   0.818922                                   (Pressure(in)_0)
# 22  0.672431                 (Visibility(mi)_2, Pressure(in)_0)
# 7   0.552899                                    (Humidity(%)_2)
# 20    0.4588                    (Humidity(%)_2, Pressure(in)_0)
# 10  0.450153                                (Wind_Speed(mph)_1)
# 3   0.409461                                 (Temperature(F)_1)
# 2   0.388098                                 (Temperature(F)_0)
# 0   0.387589                                     (Weather_Fair)
# 5   0.384537                                  (Wind_Chill(F)_2)
# 21   0.38352                  (Visibility(mi)_2, Humidity(%)_2)
# 24  0.381994              (Wind_Speed(mph)_1, Visibility(mi)_2)
# 13  0.379451                   (Visibility(mi)_2, Weather_Fair)
# 16   0.36826               (Temperature(F)_1, Visibility(mi)_2)
# 23  0.366734                (Wind_Speed(mph)_1, Pressure(in)_0)
# 12  0.365209                     (Pressure(in)_0, Weather_Fair)
# 18  0.363174                (Visibility(mi)_2, Wind_Chill(F)_2)
# 25  0.357579   (Visibility(mi)_2, Pressure(in)_0, Weather_Fair)
# 6   0.355544                                    (Humidity(%)_1)
# 19  0.348932                  (Visibility(mi)_2, Humidity(%)_1)
# 1   0.342319                    (Part_of_Day_Afternoon (12-17))
# 15  0.342319                 (Temperature(F)_1, Pressure(in)_0)
# 4   0.323499                                  (Wind_Chill(F)_0)
# 14  0.321974                 (Temperature(F)_0, Pressure(in)_0)
# 11  0.319939                                (Wind_Speed(mph)_2)
# 27  0.318413  (Visibility(mi)_2, Humidity(%)_2, Pressure(in)_0)
# 26  0.312309  (Temperature(F)_1, Visibility(mi)_2, Pressure(...
# 28  0.312309  (Wind_Speed(mph)_1, Visibility(mi)_2, Pressure...
# 17  0.310783                  (Pressure(in)_0, Wind_Chill(F)_2)
#           antecedents         consequents  antecedent support  \
# 0  (Visibility(mi)_2)    (Pressure(in)_0)            0.824008
# 1    (Pressure(in)_0)  (Visibility(mi)_2)            0.818922
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.818922  0.672431    0.816049  0.996493 -0.002367    0.984386
# 1            0.824008  0.672431    0.821118  0.996493 -0.002367    0.983843
#
#    zhangs_metric
# 0      -0.019607
# 1      -0.019067
# #################################### Result of Cluster 5 ####################################
#      support                                           itemsets
# 7   0.853377                                 (Visibility(mi)_2)
# 1   0.737644                                 (Temperature(F)_1)
# 13  0.647446               (Temperature(F)_1, Visibility(mi)_2)
# 4   0.571252                                    (Humidity(%)_2)
# 3   0.558484                                  (Wind_Chill(F)_2)
# 17  0.505354                (Visibility(mi)_2, Wind_Chill(F)_2)
# 12  0.468287                  (Temperature(F)_1, Humidity(%)_2)
# 18  0.436573                  (Visibility(mi)_2, Humidity(%)_2)
# 8   0.422982                                (Wind_Speed(mph)_1)
# 2   0.397446                                  (Wind_Chill(F)_1)
# 11  0.395799                (Temperature(F)_1, Wind_Chill(F)_2)
# 6   0.388386                                   (Pressure(in)_1)
# 22  0.382619  (Temperature(F)_1, Visibility(mi)_2, Humidity(...
# 20   0.36285              (Wind_Speed(mph)_1, Visibility(mi)_2)
# 21  0.355848  (Temperature(F)_1, Visibility(mi)_2, Wind_Chil...
# 0   0.354201                    (Part_of_Day_Afternoon (12-17))
# 10  0.341845                (Wind_Chill(F)_1, Temperature(F)_1)
# 19   0.33402                 (Pressure(in)_1, Visibility(mi)_2)
# 16   0.32743                (Wind_Chill(F)_1, Visibility(mi)_2)
# 5   0.320016                                   (Pressure(in)_0)
# 15  0.318369                   (Wind_Chill(F)_1, Humidity(%)_2)
# 9   0.317545  (Visibility(mi)_2, Part_of_Day_Afternoon (12-17))
# 14  0.304366              (Wind_Speed(mph)_1, Temperature(F)_1)
#           antecedents         consequents  antecedent support  \
# 0  (Temperature(F)_1)  (Visibility(mi)_2)            0.737644
# 1  (Visibility(mi)_2)  (Temperature(F)_1)            0.853377
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.853377  0.647446    0.877722  1.028527  0.017958    1.199093
# 1            0.737644  0.647446    0.758687  1.028527  0.017958    1.087203
#
#    zhangs_metric
# 0       0.105720
# 1       0.189167
# #################################### Result of Cluster 6 ####################################
#      support                                           itemsets
# 7   0.883258                                 (Visibility(mi)_2)
# 2   0.755656                                 (Temperature(F)_1)
# 3   0.741403                                  (Wind_Chill(F)_2)
# 19  0.684842                (Visibility(mi)_2, Wind_Chill(F)_2)
# 17  0.652941               (Temperature(F)_1, Visibility(mi)_2)
# 6   0.586199                                   (Pressure(in)_1)
# 23  0.527149                 (Pressure(in)_1, Visibility(mi)_2)
# 14  0.513575                (Temperature(F)_1, Wind_Chill(F)_2)
# 0   0.488914                                     (Weather_Fair)
# 11  0.475792                   (Visibility(mi)_2, Weather_Fair)
# 18  0.475113                  (Pressure(in)_1, Wind_Chill(F)_2)
# 29  0.465158  (Temperature(F)_1, Visibility(mi)_2, Wind_Chil...
# 32  0.442308  (Pressure(in)_1, Visibility(mi)_2, Wind_Chill(...
# 5   0.424434                                    (Humidity(%)_2)
# 16  0.412443                 (Pressure(in)_1, Temperature(F)_1)
# 15  0.410181                  (Temperature(F)_1, Humidity(%)_2)
# 8   0.378054                                (Wind_Speed(mph)_1)
# 10  0.372172                    (Wind_Chill(F)_2, Weather_Fair)
# 26  0.366968  (Visibility(mi)_2, Wind_Chill(F)_2, Weather_Fair)
# 31  0.358145  (Pressure(in)_1, Temperature(F)_1, Visibility(...
# 1   0.356787                    (Part_of_Day_Afternoon (12-17))
# 24  0.345023              (Wind_Speed(mph)_1, Visibility(mi)_2)
# 4   0.342986                                    (Humidity(%)_1)
# 21  0.336199                  (Visibility(mi)_2, Humidity(%)_1)
# 9   0.326923                   (Temperature(F)_1, Weather_Fair)
# 13  0.325113  (Visibility(mi)_2, Part_of_Day_Afternoon (12-17))
# 12  0.324434   (Wind_Chill(F)_2, Part_of_Day_Afternoon (12-17))
# 22  0.322172                  (Visibility(mi)_2, Humidity(%)_2)
# 25  0.315385  (Temperature(F)_1, Visibility(mi)_2, Weather_F...
# 30   0.31448  (Temperature(F)_1, Visibility(mi)_2, Humidity(...
# 20  0.306109               (Wind_Speed(mph)_1, Wind_Chill(F)_2)
# 28  0.303167  (Pressure(in)_1, Temperature(F)_1, Wind_Chill(...
# 27   0.30181  (Wind_Chill(F)_2, Visibility(mi)_2, Part_of_Da...
#           antecedents         consequents  antecedent support  \
# 2  (Visibility(mi)_2)   (Wind_Chill(F)_2)            0.883258
# 3   (Wind_Chill(F)_2)  (Visibility(mi)_2)            0.741403
# 0  (Temperature(F)_1)  (Visibility(mi)_2)            0.755656
# 1  (Visibility(mi)_2)  (Temperature(F)_1)            0.883258
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 2            0.741403  0.684842    0.775359  1.045800  0.029992    1.151156
# 3            0.883258  0.684842    0.923711  1.045800  0.029992    1.530255
# 0            0.883258  0.652941    0.864072  0.978278 -0.014498    0.858851
# 1            0.755656  0.652941    0.739242  0.978278 -0.014498    0.937052
#
#    zhangs_metric
# 2       0.375133
# 3       0.169351
# 0      -0.083303
# 1      -0.159804
# #################################### Result of Cluster 7 ####################################
#      support                                           itemsets
# 9    0.89028                                 (Visibility(mi)_2)
# 2   0.632978                                 (Temperature(F)_1)
# 4   0.607943                                  (Wind_Chill(F)_2)
# 17  0.560346                (Visibility(mi)_2, Wind_Chill(F)_2)
# 15  0.558337               (Temperature(F)_1, Visibility(mi)_2)
# 7   0.480915                                   (Pressure(in)_1)
# 6   0.444754                                    (Humidity(%)_2)
# 20    0.4293                 (Pressure(in)_1, Visibility(mi)_2)
# 10  0.424355                                (Wind_Speed(mph)_1)
# 5   0.417246                                    (Humidity(%)_1)
# 18   0.41431                  (Visibility(mi)_2, Humidity(%)_1)
# 21  0.384639              (Wind_Speed(mph)_1, Visibility(mi)_2)
# 1   0.362386                    (Part_of_Day_Afternoon (12-17))
# 13  0.347396                (Temperature(F)_1, Wind_Chill(F)_2)
# 3    0.34276                                  (Wind_Chill(F)_1)
# 19  0.338124                  (Visibility(mi)_2, Humidity(%)_2)
# 0   0.330552                                     (Weather_Fair)
# 12  0.329006  (Visibility(mi)_2, Part_of_Day_Afternoon (12-17))
# 11  0.325761                   (Visibility(mi)_2, Weather_Fair)
# 16  0.322207                  (Pressure(in)_1, Wind_Chill(F)_2)
# 8   0.315098                                   (Pressure(in)_2)
# 22  0.310617  (Temperature(F)_1, Visibility(mi)_2, Wind_Chil...
# 14  0.305826                  (Temperature(F)_1, Humidity(%)_2)
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []
# #################################### Result of Cluster 8 ####################################
#      support                                           itemsets
# 6   0.877942                                 (Visibility(mi)_2)
# 2   0.586748                                  (Wind_Chill(F)_2)
# 1   0.548387                                 (Temperature(F)_1)
# 14  0.541412                (Visibility(mi)_2, Wind_Chill(F)_2)
# 5   0.491282                                   (Pressure(in)_0)
# 4   0.485615                                    (Humidity(%)_2)
# 13  0.470793               (Temperature(F)_1, Visibility(mi)_2)
# 7   0.456844                                (Wind_Speed(mph)_1)
# 17  0.431125                 (Visibility(mi)_2, Pressure(in)_0)
# 3    0.42415                                    (Humidity(%)_1)
# 15  0.418919                  (Visibility(mi)_2, Humidity(%)_1)
# 9   0.411072                              (Precipitation(in)_0)
# 18  0.407585              (Wind_Speed(mph)_1, Visibility(mi)_2)
# 20  0.370968            (Visibility(mi)_2, Precipitation(in)_0)
# 16  0.368788                  (Visibility(mi)_2, Humidity(%)_2)
# 0   0.357454                    (Part_of_Day_Afternoon (12-17))
# 8   0.345684                                (Wind_Speed(mph)_2)
# 10  0.319529  (Visibility(mi)_2, Part_of_Day_Afternoon (12-17))
# 12  0.314298                  (Temperature(F)_1, Humidity(%)_2)
# 11    0.3034                (Temperature(F)_1, Wind_Chill(F)_2)
# 19  0.300349              (Wind_Speed(mph)_2, Visibility(mi)_2)
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []
# #################################### Result of Cluster 9 ####################################
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
#      support                                           itemsets
# 8   0.984227                                 (Visibility(mi)_2)
# 5   0.869611                                  (Wind_Chill(F)_2)
# 27  0.861199                (Visibility(mi)_2, Wind_Chill(F)_2)
# 7   0.793901                                   (Pressure(in)_0)
# 32  0.780231                 (Visibility(mi)_2, Pressure(in)_0)
# ..       ...                                                ...
# 79  0.303891  (Pressure(in)_0, Weather_Fair, Temperature(F)_...
# 66  0.303891  (Temperature(F)_2, Humidity(%)_0, Pressure(in)...
# 82  0.303891  (Visibility(mi)_2, Pressure(in)_0, Weather_Fai...
# 85  0.303891  (Visibility(mi)_2, Pressure(in)_0, Weather_Fai...
# 58  0.300736  (Wind_Speed(mph)_1, Pressure(in)_0, Wind_Chill...
#
# [86 rows x 2 columns]
#                             antecedents                          consequents  \
# 4                    (Visibility(mi)_2)                    (Wind_Chill(F)_2)
# 5                     (Wind_Chill(F)_2)                   (Visibility(mi)_2)
# 8                    (Visibility(mi)_2)                     (Pressure(in)_0)
# 9                      (Pressure(in)_0)                   (Visibility(mi)_2)
# 6                    (Visibility(mi)_2)                      (Humidity(%)_0)
# 7                       (Humidity(%)_0)                   (Visibility(mi)_2)
# 2                      (Pressure(in)_0)                    (Wind_Chill(F)_2)
# 3                     (Wind_Chill(F)_2)                     (Pressure(in)_0)
# 0                     (Wind_Chill(F)_2)                      (Humidity(%)_0)
# 1                       (Humidity(%)_0)                    (Wind_Chill(F)_2)
# 13                   (Visibility(mi)_2)     (Wind_Chill(F)_2, Humidity(%)_0)
# 15                      (Humidity(%)_0)  (Visibility(mi)_2, Wind_Chill(F)_2)
# 14                    (Wind_Chill(F)_2)    (Visibility(mi)_2, Humidity(%)_0)
# 11    (Visibility(mi)_2, Humidity(%)_0)                    (Wind_Chill(F)_2)
# 12     (Wind_Chill(F)_2, Humidity(%)_0)                   (Visibility(mi)_2)
# 10  (Visibility(mi)_2, Wind_Chill(F)_2)                      (Humidity(%)_0)
# 16   (Visibility(mi)_2, Pressure(in)_0)                    (Wind_Chill(F)_2)
# 17  (Visibility(mi)_2, Wind_Chill(F)_2)                     (Pressure(in)_0)
# 18    (Wind_Chill(F)_2, Pressure(in)_0)                   (Visibility(mi)_2)
# 19                   (Visibility(mi)_2)    (Wind_Chill(F)_2, Pressure(in)_0)
# 20                     (Pressure(in)_0)  (Visibility(mi)_2, Wind_Chill(F)_2)
# 21                    (Wind_Chill(F)_2)   (Visibility(mi)_2, Pressure(in)_0)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 4             0.984227            0.869611  0.861199    0.875000  1.006197
# 5             0.869611            0.984227  0.861199    0.990326  1.006197
# 8             0.984227            0.793901  0.780231    0.792735  0.998531
# 9             0.793901            0.984227  0.780231    0.982781  0.998531
# 6             0.984227            0.721346  0.720294    0.731838  1.014545
# 7             0.721346            0.984227  0.720294    0.998542  1.014545
# 2             0.793901            0.869611  0.680336    0.856954  0.985445
# 3             0.869611            0.793901  0.680336    0.782346  0.985445
# 0             0.869611            0.721346  0.679285    0.781137  1.082888
# 1             0.721346            0.869611  0.679285    0.941691  1.082888
# 13            0.984227            0.679285  0.678233    0.689103  1.014453
# 15            0.721346            0.861199  0.678233    0.940233  1.091773
# 14            0.869611            0.720294  0.678233    0.779927  1.082790
# 11            0.720294            0.869611  0.678233    0.941606  1.082790
# 12            0.679285            0.984227  0.678233    0.998452  1.014453
# 10            0.861199            0.721346  0.678233    0.787546  1.091773
# 16            0.780231            0.869611  0.672976    0.862534  0.991862
# 17            0.861199            0.793901  0.672976    0.781441  0.984305
# 18            0.680336            0.984227  0.672976    0.989181  1.005033
# 19            0.984227            0.680336  0.672976    0.683761  1.005033
# 20            0.793901            0.861199  0.672976    0.847682  0.984305
# 21            0.869611            0.780231  0.672976    0.773881  0.991862
#
#     leverage  conviction  zhangs_metric
# 4   0.005304    1.043113       0.390476
# 5   0.005304    1.630521       0.047235
# 8  -0.001148    0.994374      -0.085306
# 9  -0.001148    0.916040      -0.007087
# 6   0.010326    1.039124       0.908905
# 7   0.010326   10.820189       0.051447
# 2  -0.010049    0.911516      -0.066873
# 3  -0.010049    0.946910      -0.101751
# 0   0.051995    1.273187       0.587037
# 1   0.051995    2.236172       0.274689
# 13  0.009663    1.031578       0.903256
# 15  0.057011    2.322382       0.301659
# 14  0.051858    1.270970       0.586397
# 11  0.051858    2.232913       0.273358
# 12  0.009663   10.189274       0.044422
# 10  0.057011    1.311596       0.605603
# 16 -0.005522    0.948517      -0.035992
# 17 -0.010731    0.942989      -0.103042
# 18  0.003370    1.457864       0.015666
# 19  0.003370    1.010828       0.317500
# 20 -0.010731    0.911260      -0.071812
# 21 -0.005522    0.971918      -0.059203
# #################################### Result of Cluster 10 ####################################
#      support                                           itemsets
# 8   0.875648                                 (Visibility(mi)_2)
# 7   0.805699                                   (Pressure(in)_0)
# 21  0.707254                 (Visibility(mi)_2, Pressure(in)_0)
# 2   0.501727                                 (Temperature(F)_1)
# 13  0.474093               (Temperature(F)_1, Visibility(mi)_2)
# 4   0.464594                                  (Wind_Chill(F)_2)
# 18  0.455959                (Visibility(mi)_2, Wind_Chill(F)_2)
# 9    0.42487                                (Wind_Speed(mph)_1)
# 12  0.404145                 (Temperature(F)_1, Pressure(in)_0)
# 25  0.379965  (Temperature(F)_1, Visibility(mi)_2, Pressure(...
# 23  0.377375              (Wind_Speed(mph)_1, Visibility(mi)_2)
# 17  0.366149                  (Pressure(in)_0, Wind_Chill(F)_2)
# 3   0.362694                                  (Wind_Chill(F)_1)
# 27  0.360104  (Visibility(mi)_2, Pressure(in)_0, Wind_Chill(...
# 5    0.35924                                    (Humidity(%)_0)
# 20  0.358377                  (Visibility(mi)_2, Humidity(%)_0)
# 6   0.341969                                    (Humidity(%)_2)
# 1   0.335924                    (Part_of_Day_Afternoon (12-17))
# 22   0.33506                (Wind_Speed(mph)_1, Pressure(in)_0)
# 10   0.30829                     (Pressure(in)_0, Weather_Fair)
# 19   0.30829                    (Pressure(in)_0, Humidity(%)_0)
# 0    0.30829                                     (Weather_Fair)
# 14  0.307427                  (Wind_Chill(F)_1, Pressure(in)_0)
# 28  0.307427  (Visibility(mi)_2, Pressure(in)_0, Humidity(%)_0)
# 15  0.306563                (Wind_Chill(F)_1, Visibility(mi)_2)
# 24  0.304836   (Visibility(mi)_2, Pressure(in)_0, Weather_Fair)
# 11  0.304836                   (Visibility(mi)_2, Weather_Fair)
# 16  0.303972                   (Wind_Chill(F)_2, Humidity(%)_0)
# 26  0.303109  (Visibility(mi)_2, Wind_Chill(F)_2, Humidity(%...
#           antecedents         consequents  antecedent support  \
# 0  (Visibility(mi)_2)    (Pressure(in)_0)            0.875648
# 1    (Pressure(in)_0)  (Visibility(mi)_2)            0.805699
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.805699  0.707254    0.807692  1.002473  0.001745    1.010363
# 1            0.875648  0.707254    0.877814  1.002473  0.001745    1.017726
#
#    zhangs_metric
# 0       0.019841
# 1       0.012698
# #################################### Result of Cluster 11 ####################################
#      support                                           itemsets
# 9   0.906433                                 (Visibility(mi)_2)
# 4   0.811696                                  (Wind_Chill(F)_2)
# 22   0.74191                (Visibility(mi)_2, Wind_Chill(F)_2)
# 2   0.553606                                 (Temperature(F)_1)
# 6    0.54425                                    (Humidity(%)_2)
# 16   0.48655               (Temperature(F)_1, Visibility(mi)_2)
# 10  0.452632                                (Wind_Speed(mph)_1)
# 25  0.452242                  (Visibility(mi)_2, Humidity(%)_2)
# 17  0.424172                (Temperature(F)_2, Wind_Chill(F)_2)
# 3   0.424172                                 (Temperature(F)_2)
# 20  0.420273                   (Humidity(%)_2, Wind_Chill(F)_2)
# 28  0.408187              (Wind_Speed(mph)_1, Visibility(mi)_2)
# 18  0.403119               (Visibility(mi)_2, Temperature(F)_2)
# 31  0.403119  (Visibility(mi)_2, Temperature(F)_2, Wind_Chil...
# 14  0.387524                (Temperature(F)_1, Wind_Chill(F)_2)
# 23  0.386745               (Wind_Speed(mph)_1, Wind_Chill(F)_2)
# 8   0.382456                                   (Pressure(in)_1)
# 1   0.369981                    (Part_of_Day_Afternoon (12-17))
# 0   0.357115                                     (Weather_Fair)
# 5   0.355945                                    (Humidity(%)_1)
# 7   0.355166                                   (Pressure(in)_0)
# 11  0.354776                   (Visibility(mi)_2, Weather_Fair)
# 24  0.354386                  (Visibility(mi)_2, Humidity(%)_1)
# 33  0.352047  (Visibility(mi)_2, Humidity(%)_2, Wind_Chill(F...
# 34  0.350487  (Wind_Speed(mph)_1, Visibility(mi)_2, Wind_Chi...
# 27  0.348928                 (Pressure(in)_1, Visibility(mi)_2)
# 13  0.341131  (Visibility(mi)_2, Part_of_Day_Afternoon (12-17))
# 12  0.338791   (Wind_Chill(F)_2, Part_of_Day_Afternoon (12-17))
# 30  0.338791  (Temperature(F)_1, Visibility(mi)_2, Wind_Chil...
# 15  0.333723                  (Temperature(F)_1, Humidity(%)_2)
# 26  0.317739                 (Visibility(mi)_2, Pressure(in)_0)
# 21    0.3154                  (Pressure(in)_1, Wind_Chill(F)_2)
# 29   0.31306  (Wind_Chill(F)_2, Visibility(mi)_2, Part_of_Da...
# 19  0.302924                   (Humidity(%)_1, Wind_Chill(F)_2)
# 32  0.301365  (Visibility(mi)_2, Humidity(%)_1, Wind_Chill(F...
#           antecedents         consequents  antecedent support  \
# 0  (Visibility(mi)_2)   (Wind_Chill(F)_2)            0.906433
# 1   (Wind_Chill(F)_2)  (Visibility(mi)_2)            0.811696
#
#    consequent support  support  confidence      lift  leverage  conviction  \
# 0            0.811696  0.74191    0.818495  1.008376  0.006163    1.037457
# 1            0.906433  0.74191    0.914025  1.008376  0.006163    1.088307
#
#    zhangs_metric
# 0       0.088774
# 1       0.044111
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,

# %% [markdown]
# ## Dynamic Mode

# %%
# Number of Clusters
n_clusters = 12

# Clustering
X = dynamic_copy[['End_Lng', 'End_Lat']]
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
dynamic_copy['Cluster'] = kmeans.fit_predict(X)

# Plot
plt.figure(figsize=(12, 8))
scatter = plt.scatter(dynamic_copy['End_Lng'], dynamic_copy['End_Lat'], c=dynamic_copy['Cluster'], cmap='tab20', s=0.3)
plt.xlabel('End Longitude')
plt.ylabel('End Latitude')
plt.title('Sample US Accident Location with Clusters')

# Add colorbar
cbar = plt.colorbar(scatter, ticks=range(12))
cbar.set_label('Cluster')

plt.show()


# Create a dict to store the dataframes for each cluster
cluster_data = {}

# Iterate over unique cluster labels
for cluster_label in dynamic_copy['Cluster'].unique():
    # Filter the dataframe based on the cluster label
    cluster_data[cluster_label] = dynamic_copy[dynamic_copy['Cluster'] == cluster_label].copy()

# %%
for i in range(n_clusters):
    
    columns_to_drop = {'Severity', 'Start_Time', 'Start_Lat', 'Start_Lng', 
                   'End_Lat', 'End_Lng', 'Distance(mi)', 'City', 
                   'County', 'State', 'Temperature(F)', 'Wind_Chill(F)', 
                   'Humidity(%)', 'Pressure(in)', 'Visibility(mi)',
                    'Wind_Speed(mph)', 'Precipitation(in)', 'Cluster'}

    cluster_data[i].drop(columns_to_drop, axis=1, inplace=True)
    
    print(f"#################################### Result of Cluster {i} ####################################")
    
    apply_apriori(cluster_data[i])
# Out:
# #################################### Result of Cluster 0 ####################################
#      support                                           itemsets
# 6   0.848785                                 (Visibility(mi)_1)
# 5   0.832715                                   (Pressure(in)_1)
# 7   0.756902                                (Wind_Speed(mph)_0)
# 4   0.750721                                    (Humidity(%)_1)
# 23  0.705810                 (Pressure(in)_1, Visibility(mi)_1)
# ..       ...                                                ...
# 64  0.310260  (Pressure(in)_1, Wind_Speed(mph)_0, Visibility...
# 10  0.304491  (Visibility(mi)_1, Part_of_Day_Afternoon (12-17))
# 26  0.304079   (Pressure(in)_1, Visibility(mi)_1, Weather_Fair)
# 54  0.302019  (Pressure(in)_1, Wind_Speed(mph)_0, Temperatur...
# 63  0.300783  (Wind_Speed(mph)_0, Visibility(mi)_1, Wind_Chi...
#
# [65 rows x 2 columns]
#             antecedents          consequents  antecedent support  \
# 6      (Pressure(in)_1)   (Visibility(mi)_1)            0.832715
# 7    (Visibility(mi)_1)     (Pressure(in)_1)            0.848785
# 4    (Visibility(mi)_1)      (Humidity(%)_1)            0.848785
# 5       (Humidity(%)_1)   (Visibility(mi)_1)            0.750721
# 10  (Wind_Speed(mph)_0)   (Visibility(mi)_1)            0.756902
# 11   (Visibility(mi)_1)  (Wind_Speed(mph)_0)            0.848785
# 0     (Wind_Chill(F)_1)   (Temperature(F)_1)            0.705398
# 1    (Temperature(F)_1)    (Wind_Chill(F)_1)            0.679440
# 8      (Pressure(in)_1)  (Wind_Speed(mph)_0)            0.832715
# 9   (Wind_Speed(mph)_0)     (Pressure(in)_1)            0.756902
# 2      (Pressure(in)_1)      (Humidity(%)_1)            0.832715
# 3       (Humidity(%)_1)     (Pressure(in)_1)            0.750721
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 6             0.848785  0.705810    0.847600  0.998605 -0.000986    0.992229
# 7             0.832715  0.705810    0.831553  0.998605 -0.000986    0.993102
# 4             0.750721  0.669139    0.788350  1.050123  0.031938    1.177786
# 5             0.848785  0.669139    0.891328  1.050123  0.031938    1.391488
# 10            0.848785  0.643593    0.850299  1.001785  0.001147    1.010119
# 11            0.756902  0.643593    0.758252  1.001785  0.001147    1.005588
# 0             0.679440  0.639473    0.906542  1.334250  0.160198    3.429996
# 1             0.705398  0.639473    0.941176  1.334250  0.160198    5.008241
# 8             0.756902  0.632880    0.760020  1.004120  0.002597    1.012994
# 9             0.832715  0.632880    0.836146  1.004120  0.002597    1.020937
# 2             0.750721  0.631644    0.758535  1.010409  0.006507    1.032362
# 3             0.832715  0.631644    0.841383  1.010409  0.006507    1.054646
#
#     zhangs_metric
# 6       -0.008283
# 7       -0.009156
# 4        0.315647
# 5        0.191475
# 10       0.007329
# 11       0.011782
# 0        0.850350
# 1        0.781491
# 8        0.024526
# 9        0.016877
# 2        0.061583
# 3        0.041327
# #################################### Result of Cluster 1 ####################################
#      support                                           itemsets
# 2   0.870354                                 (Temperature(F)_1)
# 3   0.869027                                  (Wind_Chill(F)_1)
# 15  0.844838                (Wind_Chill(F)_1, Temperature(F)_1)
# 5   0.775811                                   (Pressure(in)_1)
# 6   0.772566                                 (Visibility(mi)_1)
# ..       ...                                                ...
# 59  0.308260  (Wind_Chill(F)_1, Temperature(F)_1, Humidity(%...
# 14  0.306490  (Visibility(mi)_1, Part_of_Day_Afternoon (12-17))
# 62  0.305900  (Pressure(in)_1, Temperature(F)_1, Visibility(...
# 82  0.302655  (Pressure(in)_1, Wind_Speed(mph)_0, Visibility...
# 83  0.301327  (Pressure(in)_1, Wind_Speed(mph)_0, Visibility...
#
# [84 rows x 2 columns]
#                              antecedents  \
# 0                      (Wind_Chill(F)_1)
# 1                     (Temperature(F)_1)
# 11                     (Wind_Chill(F)_1)
# 10                      (Pressure(in)_1)
# 4                       (Pressure(in)_1)
# 5                     (Temperature(F)_1)
# 23    (Pressure(in)_1, Temperature(F)_1)
# 24   (Wind_Chill(F)_1, Temperature(F)_1)
# 25                      (Pressure(in)_1)
# 26                     (Wind_Chill(F)_1)
# 27                    (Temperature(F)_1)
# 22     (Pressure(in)_1, Wind_Chill(F)_1)
# 7                     (Visibility(mi)_1)
# 6                     (Temperature(F)_1)
# 3                        (Humidity(%)_1)
# 2                     (Temperature(F)_1)
# 13                    (Visibility(mi)_1)
# 12                     (Wind_Chill(F)_1)
# 9                        (Humidity(%)_1)
# 8                      (Wind_Chill(F)_1)
# 21                       (Humidity(%)_1)
# 17      (Wind_Chill(F)_1, Humidity(%)_1)
# 20                    (Temperature(F)_1)
# 19                     (Wind_Chill(F)_1)
# 18     (Temperature(F)_1, Humidity(%)_1)
# 16   (Wind_Chill(F)_1, Temperature(F)_1)
# 28   (Wind_Chill(F)_1, Temperature(F)_1)
# 29  (Temperature(F)_1, Visibility(mi)_1)
# 30   (Wind_Chill(F)_1, Visibility(mi)_1)
# 31                    (Temperature(F)_1)
# 32                     (Wind_Chill(F)_1)
# 33                    (Visibility(mi)_1)
# 15                    (Visibility(mi)_1)
# 14                      (Pressure(in)_1)
#
#                              consequents  antecedent support  \
# 0                     (Temperature(F)_1)            0.869027
# 1                      (Wind_Chill(F)_1)            0.870354
# 11                      (Pressure(in)_1)            0.869027
# 10                     (Wind_Chill(F)_1)            0.775811
# 4                     (Temperature(F)_1)            0.775811
# 5                       (Pressure(in)_1)            0.870354
# 23                     (Wind_Chill(F)_1)            0.694838
# 24                      (Pressure(in)_1)            0.844838
# 25   (Wind_Chill(F)_1, Temperature(F)_1)            0.775811
# 26    (Pressure(in)_1, Temperature(F)_1)            0.869027
# 27     (Pressure(in)_1, Wind_Chill(F)_1)            0.870354
# 22                    (Temperature(F)_1)            0.698673
# 7                     (Temperature(F)_1)            0.772566
# 6                     (Visibility(mi)_1)            0.870354
# 3                     (Temperature(F)_1)            0.694838
# 2                        (Humidity(%)_1)            0.870354
# 13                     (Wind_Chill(F)_1)            0.772566
# 12                    (Visibility(mi)_1)            0.869027
# 9                      (Wind_Chill(F)_1)            0.694838
# 8                        (Humidity(%)_1)            0.869027
# 21   (Wind_Chill(F)_1, Temperature(F)_1)            0.694838
# 17                    (Temperature(F)_1)            0.657080
# 20      (Wind_Chill(F)_1, Humidity(%)_1)            0.870354
# 19     (Temperature(F)_1, Humidity(%)_1)            0.869027
# 18                     (Wind_Chill(F)_1)            0.660619
# 16                       (Humidity(%)_1)            0.844838
# 28                    (Visibility(mi)_1)            0.844838
# 29                     (Wind_Chill(F)_1)            0.661209
# 30                    (Temperature(F)_1)            0.660472
# 31   (Wind_Chill(F)_1, Visibility(mi)_1)            0.870354
# 32  (Temperature(F)_1, Visibility(mi)_1)            0.869027
# 33   (Wind_Chill(F)_1, Temperature(F)_1)            0.772566
# 15                      (Pressure(in)_1)            0.772566
# 14                    (Visibility(mi)_1)            0.775811
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.870354  0.844838    0.972166  1.116977  0.088477    4.657770
# 1             0.869027  0.844838    0.970683  1.116977  0.088477    4.467482
# 11            0.775811  0.698673    0.803971  1.036298  0.024472    1.143654
# 10            0.869027  0.698673    0.900570  1.036298  0.024472    1.317247
# 4             0.870354  0.694838    0.895627  1.029038  0.019607    1.242146
# 5             0.775811  0.694838    0.798339  1.029038  0.019607    1.111713
# 23            0.869027  0.676549    0.973679  1.120424  0.072716    4.975935
# 24            0.775811  0.676549    0.800803  1.032214  0.021114    1.125463
# 25            0.844838  0.676549    0.872053  1.032214  0.021114    1.212709
# 26            0.694838  0.676549    0.778513  1.120424  0.072716    1.377790
# 27            0.698673  0.676549    0.777326  1.112575  0.068456    1.353222
# 22            0.870354  0.676549    0.968334  1.112575  0.068456    4.094221
# 7             0.870354  0.661209    0.855861  0.983348 -0.011197    0.899451
# 6             0.772566  0.661209    0.759702  0.983348 -0.011197    0.946464
# 3             0.870354  0.660619    0.950754  1.092376  0.055865    2.632597
# 2             0.694838  0.660619    0.759024  1.092376  0.055865    1.266359
# 13            0.869027  0.660472    0.854906  0.983752 -0.010909    0.902683
# 12            0.772566  0.660472    0.760014  0.983752 -0.010909    0.947694
# 9             0.869027  0.657080    0.945659  1.088182  0.053247    2.410218
# 8             0.694838  0.657080    0.756110  1.088182  0.053247    1.251229
# 21            0.844838  0.647935    0.932498  1.103760  0.060910    2.298646
# 17            0.870354  0.647935    0.986083  1.132968  0.076043    9.315694
# 20            0.657080  0.647935    0.744450  1.132968  0.076043    1.341892
# 19            0.660619  0.647935    0.745587  1.128618  0.073839    1.333976
# 18            0.869027  0.647935    0.980799  1.128618  0.073839    6.821280
# 16            0.694838  0.647935    0.766934  1.103760  0.060910    1.309340
# 28            0.772566  0.639233    0.756634  0.979377 -0.013460    0.934534
# 29            0.869027  0.639233    0.966763  1.112467  0.064624    3.940631
# 30            0.870354  0.639233    0.967843  1.112011  0.064389    4.031631
# 31            0.660472  0.639233    0.734452  1.112011  0.064389    1.278593
# 32            0.661209  0.639233    0.735574  1.112467  0.064624    1.281228
# 33            0.844838  0.639233    0.827415  0.979377 -0.013460    0.899048
# 15            0.775811  0.600147    0.776823  1.001304  0.000782    1.004535
# 14            0.772566  0.600147    0.773574  1.001304  0.000782    1.004451
#
#     zhangs_metric
# 0        0.799602
# 1        0.807789
# 11       0.267432
# 10       0.156236
# 4        0.125870
# 5        0.217659
# 23       0.352210
# 24       0.201135
# 25       0.139206
# 26       0.820633
# 27       0.780467
# 22       0.335796
# 7       -0.069296
# 6       -0.115526
# 3        0.277112
# 2        0.652269
# 13      -0.067705
# 12      -0.111984
# 9        0.265551
# 8        0.618722
# 21       0.308053
# 17       0.342244
# 20       0.905253
# 19       0.870107
# 18       0.335791
# 16       0.605858
# 28      -0.119492
# 29       0.298405
# 30       0.296670
# 31       0.776946
# 32       0.771889
# 33      -0.084739
# 15       0.005728
# 14       0.005811
# #################################### Result of Cluster 2 ####################################
#      support                                           itemsets
# 6   0.852428                                 (Visibility(mi)_1)
# 5   0.772771                                   (Pressure(in)_1)
# 3   0.736274                                  (Wind_Chill(F)_1)
# 2   0.731514                                 (Temperature(F)_1)
# 7   0.728023                                (Wind_Speed(mph)_0)
# ..       ...                                                ...
# 54  0.317994  (Temperature(F)_1, Wind_Speed(mph)_0, Visibili...
# 57  0.317994  (Wind_Chill(F)_1, Visibility(mi)_1, Humidity(%...
# 49  0.316090  (Wind_Chill(F)_1, Temperature(F)_1, Humidity(%...
# 60  0.312282  (Pressure(in)_1, Wind_Chill(F)_1, Visibility(m...
# 10  0.311012  (Visibility(mi)_1, Part_of_Day_Afternoon (12-17))
#
# [62 rows x 2 columns]
#             antecedents          consequents  antecedent support  \
# 0     (Wind_Chill(F)_1)   (Temperature(F)_1)            0.736274
# 1    (Temperature(F)_1)    (Wind_Chill(F)_1)            0.731514
# 8      (Pressure(in)_1)   (Visibility(mi)_1)            0.772771
# 9    (Visibility(mi)_1)     (Pressure(in)_1)            0.852428
# 6    (Visibility(mi)_1)      (Humidity(%)_1)            0.852428
# 7       (Humidity(%)_1)   (Visibility(mi)_1)            0.666772
# 10  (Wind_Speed(mph)_0)   (Visibility(mi)_1)            0.728023
# 11   (Visibility(mi)_1)  (Wind_Speed(mph)_0)            0.852428
# 4     (Wind_Chill(F)_1)   (Visibility(mi)_1)            0.736274
# 5    (Visibility(mi)_1)    (Wind_Chill(F)_1)            0.852428
# 2    (Temperature(F)_1)   (Visibility(mi)_1)            0.731514
# 3    (Visibility(mi)_1)   (Temperature(F)_1)            0.852428
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.731514  0.695652    0.944828  1.291606  0.157057    4.866312
# 1             0.736274  0.695652    0.950976  1.291606  0.157057    5.379540
# 8             0.852428  0.660425    0.854620  1.002572  0.001694    1.015080
# 9             0.772771  0.660425    0.774758  1.002572  0.001694    1.008824
# 6             0.666772  0.630276    0.739389  1.108908  0.061901    1.278642
# 7             0.852428  0.630276    0.945264  1.108908  0.061901    2.696080
# 10            0.852428  0.623612    0.856582  1.004874  0.003025    1.028968
# 11            0.728023  0.623612    0.731571  1.004874  0.003025    1.013219
# 4             0.852428  0.616630    0.837500  0.982488 -0.010991    0.908137
# 5             0.736274  0.616630    0.723380  0.982488 -0.010991    0.953388
# 2             0.852428  0.612187    0.836876  0.981756 -0.011376    0.904665
# 3             0.731514  0.612187    0.718168  0.981756 -0.011376    0.952647
#
#     zhangs_metric
# 0        0.856079
# 1        0.840900
# 8        0.011289
# 9        0.017383
# 6        0.665519
# 7        0.294730
# 10       0.017833
# 11       0.032867
# 4       -0.063308
# 5       -0.107767
# 2       -0.064733
# 3       -0.111840
# #################################### Result of Cluster 3 ####################################
#      support                                           itemsets
# 8   0.923177                                 (Visibility(mi)_1)
# 6   0.849323                                    (Humidity(%)_1)
# 30  0.815550                  (Visibility(mi)_1, Humidity(%)_1)
# 7   0.754685                                   (Pressure(in)_1)
# 9   0.747820                                (Wind_Speed(mph)_0)
# ..       ...                                                ...
# 57  0.306179   (Pressure(in)_1, Humidity(%)_1, Wind_Chill(F)_2)
# 67  0.303767  (Pressure(in)_1, Wind_Chill(F)_1, Temperature(...
# 72  0.303581  (Pressure(in)_1, Wind_Chill(F)_1, Visibility(m...
# 3   0.303581                                 (Temperature(F)_2)
# 40  0.300798  (Wind_Speed(mph)_0, Visibility(mi)_1, Part_of_...
#
# [76 rows x 2 columns]
#                               antecedents  \
# 7                         (Humidity(%)_1)
# 6                      (Visibility(mi)_1)
# 13                     (Visibility(mi)_1)
# 12                    (Wind_Speed(mph)_0)
# 11                     (Visibility(mi)_1)
# 10                       (Pressure(in)_1)
# 9                         (Humidity(%)_1)
# 8                     (Wind_Speed(mph)_0)
# 5                         (Humidity(%)_1)
# 4                        (Pressure(in)_1)
# 3                      (Visibility(mi)_1)
# 2                      (Temperature(F)_1)
# 20  (Wind_Speed(mph)_0, Visibility(mi)_1)
# 24                     (Visibility(mi)_1)
# 23                    (Wind_Speed(mph)_0)
# 22      (Visibility(mi)_1, Humidity(%)_1)
# 21     (Wind_Speed(mph)_0, Humidity(%)_1)
# 25                        (Humidity(%)_1)
# 1                      (Temperature(F)_1)
# 0                       (Wind_Chill(F)_1)
# 18                     (Visibility(mi)_1)
# 19                        (Humidity(%)_1)
# 17                       (Pressure(in)_1)
# 16      (Visibility(mi)_1, Humidity(%)_1)
# 15        (Pressure(in)_1, Humidity(%)_1)
# 14     (Pressure(in)_1, Visibility(mi)_1)
#
#                               consequents  antecedent support  \
# 7                      (Visibility(mi)_1)            0.849323
# 6                         (Humidity(%)_1)            0.923177
# 13                    (Wind_Speed(mph)_0)            0.923177
# 12                     (Visibility(mi)_1)            0.747820
# 11                       (Pressure(in)_1)            0.923177
# 10                     (Visibility(mi)_1)            0.754685
# 9                     (Wind_Speed(mph)_0)            0.849323
# 8                         (Humidity(%)_1)            0.747820
# 5                        (Pressure(in)_1)            0.849323
# 4                         (Humidity(%)_1)            0.754685
# 3                      (Temperature(F)_1)            0.923177
# 2                      (Visibility(mi)_1)            0.692707
# 20                        (Humidity(%)_1)            0.697346
# 24     (Wind_Speed(mph)_0, Humidity(%)_1)            0.923177
# 23      (Visibility(mi)_1, Humidity(%)_1)            0.747820
# 22                    (Wind_Speed(mph)_0)            0.815550
# 21                     (Visibility(mi)_1)            0.643348
# 25  (Wind_Speed(mph)_0, Visibility(mi)_1)            0.849323
# 1                       (Wind_Chill(F)_1)            0.692707
# 0                      (Temperature(F)_1)            0.642049
# 18        (Pressure(in)_1, Humidity(%)_1)            0.923177
# 19     (Pressure(in)_1, Visibility(mi)_1)            0.849323
# 17      (Visibility(mi)_1, Humidity(%)_1)            0.754685
# 16                       (Pressure(in)_1)            0.815550
# 15                     (Visibility(mi)_1)            0.632028
# 14                        (Humidity(%)_1)            0.689182
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 7             0.923177  0.815550    0.960236  1.040143  0.031475    1.931976
# 6             0.849323  0.815550    0.883417  1.040143  0.031475    1.292448
# 13            0.747820  0.697346    0.755377  1.010106  0.006977    1.030893
# 12            0.923177  0.697346    0.932506  1.010106  0.006977    1.138225
# 11            0.754685  0.689182    0.746533  0.989197 -0.007526    0.967835
# 10            0.923177  0.689182    0.913204  0.989197 -0.007526    0.885099
# 9             0.747820  0.643348    0.757483  1.012922  0.008207    1.039846
# 8             0.849323  0.643348    0.860298  1.012922  0.008207    1.078560
# 5             0.754685  0.632028    0.744156  0.986047 -0.008943    0.958843
# 4             0.849323  0.632028    0.837472  0.986047 -0.008943    0.927087
# 3             0.692707  0.622379    0.674171  0.973240 -0.017112    0.943110
# 2             0.923177  0.622379    0.898473  0.973240 -0.017112    0.756678
# 20            0.849323  0.620152    0.889303  1.047073  0.027880    1.361167
# 24            0.643348  0.620152    0.671759  1.044162  0.026229    1.086556
# 23            0.815550  0.620152    0.829280  1.016836  0.010268    1.080425
# 22            0.747820  0.620152    0.760410  1.016836  0.010268    1.052548
# 21            0.923177  0.620152    0.963946  1.044162  0.026229    2.130767
# 25            0.697346  0.620152    0.730173  1.047073  0.027880    1.121656
# 1             0.642049  0.604194    0.872221  1.358496  0.159442    2.801326
# 0             0.692707  0.604194    0.941040  1.358496  0.159442    5.211924
# 18            0.632028  0.604008    0.654271  1.035193  0.020534    1.064337
# 19            0.689182  0.604008    0.711165  1.031897  0.018671    1.076109
# 17            0.815550  0.604008    0.800344  0.981355 -0.011476    0.923839
# 16            0.754685  0.604008    0.740614  0.981355 -0.011476    0.945752
# 15            0.923177  0.604008    0.955666  1.035193  0.020534    1.732846
# 14            0.849323  0.604008    0.876414  1.031897  0.018671    1.219206
#
#     zhangs_metric
# 7        0.256135
# 6        0.502371
# 13       0.130229
# 12       0.039672
# 11      -0.124463
# 10      -0.042621
# 9        0.084666
# 8        0.050588
# 5       -0.085848
# 4       -0.054536
# 3       -0.263571
# 2       -0.082127
# 20       0.148542
# 24       0.550535
# 23       0.065654
# 22       0.089763
# 21       0.118585
# 25       0.298364
# 1        0.858765
# 0        0.737229
# 18       0.442534
# 19       0.205147
# 17      -0.071882
# 16      -0.093386
# 15       0.092390
# 14       0.099451
# #################################### Result of Cluster 4 ####################################
#      support                                           itemsets
# 6   0.768057                                    (Humidity(%)_1)
# 9   0.752798                                 (Visibility(mi)_1)
# 10  0.704985                                (Wind_Speed(mph)_0)
# 23  0.629196                  (Visibility(mi)_1, Humidity(%)_1)
# 24  0.549847                 (Wind_Speed(mph)_0, Humidity(%)_1)
# 28  0.548321              (Wind_Speed(mph)_0, Visibility(mi)_1)
# 2   0.511699                                 (Temperature(F)_0)
# 8   0.498983                                   (Pressure(in)_1)
# 33  0.462360  (Wind_Speed(mph)_0, Visibility(mi)_1, Humidity...
# 7   0.449135                                   (Pressure(in)_0)
# 4   0.431841                                  (Wind_Chill(F)_0)
# 13  0.415056                (Wind_Chill(F)_0, Temperature(F)_0)
# 22  0.405900                    (Pressure(in)_1, Humidity(%)_1)
# 14  0.404883                  (Temperature(F)_0, Humidity(%)_1)
# 26  0.398779                 (Pressure(in)_1, Visibility(mi)_1)
# 0   0.387589                                     (Weather_Fair)
# 5   0.384537                                  (Wind_Chill(F)_1)
# 3   0.378942                                 (Temperature(F)_1)
# 27  0.367243                (Pressure(in)_1, Wind_Speed(mph)_0)
# 12  0.363683                   (Visibility(mi)_1, Weather_Fair)
# 17  0.351475                (Wind_Chill(F)_1, Temperature(F)_1)
# 1   0.342319                    (Part_of_Day_Afternoon (12-17))
# 31  0.341302  (Pressure(in)_1, Visibility(mi)_1, Humidity(%)_1)
# 16  0.339268              (Temperature(F)_0, Wind_Speed(mph)_0)
# 20  0.335198                (Wind_Chill(F)_1, Visibility(mi)_1)
# 18  0.330112               (Temperature(F)_1, Visibility(mi)_1)
# 19  0.326551                   (Wind_Chill(F)_0, Humidity(%)_1)
# 15  0.324517               (Temperature(F)_0, Visibility(mi)_1)
# 21  0.319939                    (Humidity(%)_1, Pressure(in)_0)
# 29  0.314344  (Wind_Chill(F)_0, Humidity(%)_1, Temperature(F...
# 11  0.312309                      (Humidity(%)_1, Weather_Fair)
# 25  0.310783                 (Visibility(mi)_1, Pressure(in)_0)
# 30  0.307731  (Temperature(F)_1, Wind_Chill(F)_1, Visibility...
# 32  0.301628  (Pressure(in)_1, Wind_Speed(mph)_0, Humidity(%...
#           antecedents         consequents  antecedent support  \
# 0  (Visibility(mi)_1)     (Humidity(%)_1)            0.752798
# 1     (Humidity(%)_1)  (Visibility(mi)_1)            0.768057
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.768057  0.629196    0.835811  1.088215  0.051005    1.412657
# 1            0.752798  0.629196    0.819205  1.088215  0.051005    1.367310
#
#    zhangs_metric
# 0       0.327924
# 1       0.349498
# #################################### Result of Cluster 5 ####################################
#      support                                           itemsets
# 5   0.789539                                 (Visibility(mi)_1)
# 6   0.724053                                (Wind_Speed(mph)_0)
# 3   0.672570                                    (Humidity(%)_1)
# 2   0.664745                                  (Wind_Chill(F)_1)
# 1   0.657331                                 (Temperature(F)_1)
# 7   0.612850                (Wind_Chill(F)_1, Temperature(F)_1)
# 21  0.582372              (Wind_Speed(mph)_0, Visibility(mi)_1)
# 17  0.576606                  (Visibility(mi)_1, Humidity(%)_1)
# 4   0.557661                                   (Pressure(in)_1)
# 10  0.557249               (Temperature(F)_1, Visibility(mi)_1)
# 14  0.550659                (Wind_Chill(F)_1, Visibility(mi)_1)
# 24  0.517298  (Temperature(F)_1, Wind_Chill(F)_1, Visibility...
# 18  0.495470                 (Wind_Speed(mph)_0, Humidity(%)_1)
# 15  0.492998               (Wind_Chill(F)_1, Wind_Speed(mph)_0)
# 8   0.483114                  (Temperature(F)_1, Humidity(%)_1)
# 11  0.480643              (Wind_Speed(mph)_0, Temperature(F)_1)
# 12  0.476524                   (Wind_Chill(F)_1, Humidity(%)_1)
# 22  0.453048  (Wind_Chill(F)_1, Temperature(F)_1, Humidity(%...
# 25  0.452224  (Wind_Chill(F)_1, Temperature(F)_1, Wind_Speed...
# 19  0.436161                 (Pressure(in)_1, Visibility(mi)_1)
# 27  0.436161  (Temperature(F)_1, Visibility(mi)_1, Humidity(...
# 36  0.428748  (Wind_Speed(mph)_0, Visibility(mi)_1, Humidity...
# 31  0.425041  (Wind_Chill(F)_1, Visibility(mi)_1, Humidity(%...
# 30  0.413921  (Temperature(F)_1, Wind_Speed(mph)_0, Visibili...
# 34  0.413509  (Wind_Chill(F)_1, Visibility(mi)_1, Wind_Speed...
# 38  0.406507  (Temperature(F)_1, Wind_Chill(F)_1, Visibility...
# 9   0.405272                 (Pressure(in)_1, Temperature(F)_1)
# 13  0.404860                  (Pressure(in)_1, Wind_Chill(F)_1)
# 20  0.398682                (Pressure(in)_1, Wind_Speed(mph)_0)
# 41  0.388797  (Temperature(F)_1, Wind_Chill(F)_1, Visibility...
# 16  0.379736                    (Pressure(in)_1, Humidity(%)_1)
# 23  0.376030  (Pressure(in)_1, Wind_Chill(F)_1, Temperature(...
# 28  0.357496  (Wind_Speed(mph)_0, Temperature(F)_1, Humidity...
# 32  0.356260  (Wind_Chill(F)_1, Humidity(%)_1, Wind_Speed(mp...
# 0   0.354201                    (Part_of_Day_Afternoon (12-17))
# 39  0.338138  (Wind_Chill(F)_1, Temperature(F)_1, Humidity(%...
# 29  0.335667  (Pressure(in)_1, Temperature(F)_1, Visibility(...
# 33  0.326606  (Pressure(in)_1, Wind_Chill(F)_1, Visibility(m...
# 42  0.326194  (Temperature(F)_1, Wind_Speed(mph)_0, Visibili...
# 35  0.325371  (Pressure(in)_1, Visibility(mi)_1, Humidity(%)_1)
# 37  0.320840  (Pressure(in)_1, Wind_Speed(mph)_0, Visibility...
# 43  0.320428  (Wind_Chill(F)_1, Visibility(mi)_1, Humidity(%...
# 40  0.309308  (Pressure(in)_1, Wind_Chill(F)_1, Visibility(m...
# 44  0.307249  (Wind_Speed(mph)_0, Visibility(mi)_1, Wind_Chi...
# 26  0.306013  (Pressure(in)_1, Temperature(F)_1, Humidity(%)_1)
#           antecedents         consequents  antecedent support  \
# 0   (Wind_Chill(F)_1)  (Temperature(F)_1)            0.664745
# 1  (Temperature(F)_1)   (Wind_Chill(F)_1)            0.657331
#
#    consequent support  support  confidence     lift  leverage  conviction  \
# 0            0.657331  0.61285    0.921933  1.40254  0.175893    4.389425
# 1            0.664745  0.61285    0.932331  1.40254  0.175893    4.954329
#
#    zhangs_metric
# 0       0.856087
# 1       0.837566
# #################################### Result of Cluster 6 ####################################
#      support                                           itemsets
# 3   0.817647                                  (Wind_Chill(F)_1)
# 2   0.811991                                 (Temperature(F)_1)
# 6   0.807240                                 (Visibility(mi)_1)
# 15  0.786652                (Wind_Chill(F)_1, Temperature(F)_1)
# 5   0.759502                                   (Pressure(in)_1)
# ..       ...                                                ...
# 67  0.324661  (Pressure(in)_1, Wind_Chill(F)_1, Humidity(%)_...
# 71  0.322172  (Pressure(in)_1, Wind_Speed(mph)_0, Wind_Chill...
# 34  0.318552  (Wind_Speed(mph)_0, Visibility(mi)_1, Weather_...
# 14  0.303394  (Visibility(mi)_1, Part_of_Day_Afternoon (12-17))
# 10  0.300679                      (Humidity(%)_1, Weather_Fair)
#
# [74 rows x 2 columns]
#                              antecedents  \
# 0                      (Wind_Chill(F)_1)
# 1                     (Temperature(F)_1)
# 12                     (Wind_Chill(F)_1)
# 13                    (Visibility(mi)_1)
# 6                     (Temperature(F)_1)
# 7                     (Visibility(mi)_1)
# 26                     (Wind_Chill(F)_1)
# 25                    (Temperature(F)_1)
# 24   (Wind_Chill(F)_1, Visibility(mi)_1)
# 23  (Temperature(F)_1, Visibility(mi)_1)
# 22   (Wind_Chill(F)_1, Temperature(F)_1)
# 27                    (Visibility(mi)_1)
# 11                     (Wind_Chill(F)_1)
# 10                      (Pressure(in)_1)
# 5                     (Temperature(F)_1)
# 4                       (Pressure(in)_1)
# 15                    (Visibility(mi)_1)
# 14                      (Pressure(in)_1)
# 16     (Pressure(in)_1, Wind_Chill(F)_1)
# 17    (Pressure(in)_1, Temperature(F)_1)
# 18   (Wind_Chill(F)_1, Temperature(F)_1)
# 19                      (Pressure(in)_1)
# 20                     (Wind_Chill(F)_1)
# 21                    (Temperature(F)_1)
# 3                        (Humidity(%)_1)
# 2                     (Temperature(F)_1)
# 9                        (Humidity(%)_1)
# 8                      (Wind_Chill(F)_1)
#
#                              consequents  antecedent support  \
# 0                     (Temperature(F)_1)            0.817647
# 1                      (Wind_Chill(F)_1)            0.811991
# 12                    (Visibility(mi)_1)            0.817647
# 13                     (Wind_Chill(F)_1)            0.807240
# 6                     (Visibility(mi)_1)            0.811991
# 7                     (Temperature(F)_1)            0.807240
# 26  (Temperature(F)_1, Visibility(mi)_1)            0.817647
# 25   (Wind_Chill(F)_1, Visibility(mi)_1)            0.811991
# 24                    (Temperature(F)_1)            0.663348
# 23                     (Wind_Chill(F)_1)            0.661765
# 22                    (Visibility(mi)_1)            0.786652
# 27   (Wind_Chill(F)_1, Temperature(F)_1)            0.807240
# 11                      (Pressure(in)_1)            0.817647
# 10                     (Wind_Chill(F)_1)            0.759502
# 5                       (Pressure(in)_1)            0.811991
# 4                     (Temperature(F)_1)            0.759502
# 15                      (Pressure(in)_1)            0.807240
# 14                    (Visibility(mi)_1)            0.759502
# 16                    (Temperature(F)_1)            0.632353
# 17                     (Wind_Chill(F)_1)            0.632127
# 18                      (Pressure(in)_1)            0.786652
# 19   (Wind_Chill(F)_1, Temperature(F)_1)            0.759502
# 20    (Pressure(in)_1, Temperature(F)_1)            0.817647
# 21     (Pressure(in)_1, Wind_Chill(F)_1)            0.811991
# 3                     (Temperature(F)_1)            0.654072
# 2                        (Humidity(%)_1)            0.811991
# 9                      (Wind_Chill(F)_1)            0.654072
# 8                        (Humidity(%)_1)            0.817647
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.811991  0.786652    0.962092  1.184855  0.122730    4.959596
# 1             0.817647  0.786652    0.968794  1.184855  0.122730    5.843435
# 12            0.807240  0.663348    0.811289  1.005017  0.003311    1.021459
# 13            0.817647  0.663348    0.821749  1.005017  0.003311    1.023011
# 6             0.807240  0.661765    0.814990  1.009601  0.006293    1.041892
# 7             0.811991  0.661765    0.819787  1.009601  0.006293    1.043260
# 26            0.661765  0.640498    0.783343  1.183718  0.099408    1.561152
# 25            0.663348  0.640498    0.788799  1.189117  0.101865    1.593988
# 24            0.811991  0.640498    0.965553  1.189117  0.101865    5.457847
# 23            0.817647  0.640498    0.967863  1.183718  0.099408    5.674280
# 22            0.807240  0.640498    0.814208  1.008632  0.005481    1.037503
# 27            0.786652  0.640498    0.793442  1.008632  0.005481    1.032873
# 11            0.759502  0.632353    0.773381  1.018274  0.011348    1.061244
# 10            0.817647  0.632353    0.832589  1.018274  0.011348    1.089251
# 5             0.759502  0.632127    0.778490  1.025000  0.015418    1.085719
# 4             0.811991  0.632127    0.832291  1.025000  0.015418    1.121042
# 15            0.759502  0.620588    0.768778  1.012213  0.007488    1.040116
# 14            0.807240  0.620588    0.817099  1.012213  0.007488    1.053902
# 16            0.811991  0.610181    0.964937  1.188360  0.096716    5.362095
# 17            0.817647  0.610181    0.965283  1.180562  0.093324    5.252517
# 18            0.759502  0.610181    0.775669  1.021286  0.012717    1.072065
# 19            0.786652  0.610181    0.803396  1.021286  0.012717    1.085168
# 20            0.632127  0.610181    0.746265  1.180562  0.093324    1.449830
# 21            0.632353  0.610181    0.751463  1.188360  0.096716    1.479244
# 3             0.811991  0.603620    0.922864  1.136545  0.072519    2.437373
# 2             0.654072  0.603620    0.743383  1.136545  0.072519    1.348028
# 9             0.817647  0.601131    0.919059  1.124029  0.066331    2.252916
# 8             0.654072  0.601131    0.735196  1.124029  0.066331    1.306356
#
#     zhangs_metric
# 0        0.855567
# 1        0.829828
# 12       0.027373
# 13       0.025895
# 6        0.050582
# 7        0.049335
# 26       0.851118
# 25       0.845917
# 24       0.472418
# 23       0.458864
# 22       0.040112
# 27       0.044396
# 11       0.098413
# 10       0.074620
# 5        0.129729
# 4        0.101416
# 15       0.062594
# 14       0.050169
# 16       0.431131
# 17       0.415756
# 18       0.097690
# 19       0.086662
# 20       0.838734
# 21       0.843066
# 3        0.347299
# 2        0.639013
# 9        0.318978
# 8        0.605109
# #################################### Result of Cluster 7 ####################################
#      support                                           itemsets
# 6   0.826920                                 (Visibility(mi)_1)
# 4   0.738371                                    (Humidity(%)_1)
# 5   0.726163                                   (Pressure(in)_1)
# 7   0.713800                                (Wind_Speed(mph)_0)
# 20  0.658322                  (Visibility(mi)_1, Humidity(%)_1)
# 2   0.654767                                 (Temperature(F)_1)
# 3   0.643486                                  (Wind_Chill(F)_1)
# 10  0.608407                (Wind_Chill(F)_1, Temperature(F)_1)
# 24  0.598516              (Wind_Speed(mph)_0, Visibility(mi)_1)
# 22  0.591871                 (Pressure(in)_1, Visibility(mi)_1)
# 13  0.547829               (Temperature(F)_1, Visibility(mi)_1)
# 21  0.541647                 (Wind_Speed(mph)_0, Humidity(%)_1)
# 17  0.535775                (Wind_Chill(F)_1, Visibility(mi)_1)
# 19  0.534539                    (Pressure(in)_1, Humidity(%)_1)
# 23  0.509349                (Pressure(in)_1, Wind_Speed(mph)_0)
# 27  0.505641  (Temperature(F)_1, Wind_Chill(F)_1, Visibility...
# 43  0.486942  (Wind_Speed(mph)_0, Visibility(mi)_1, Humidity...
# 12  0.485860                 (Pressure(in)_1, Temperature(F)_1)
# 41  0.472879  (Pressure(in)_1, Visibility(mi)_1, Humidity(%)_1)
# 16  0.472570                  (Pressure(in)_1, Wind_Chill(F)_1)
# 14  0.472415              (Wind_Speed(mph)_0, Temperature(F)_1)
# 11  0.468861                  (Temperature(F)_1, Humidity(%)_1)
# 18  0.468397               (Wind_Chill(F)_1, Wind_Speed(mph)_0)
# 15  0.458353                   (Wind_Chill(F)_1, Humidity(%)_1)
# 26  0.450626  (Pressure(in)_1, Wind_Chill(F)_1, Temperature(...
# 28  0.442435  (Wind_Chill(F)_1, Temperature(F)_1, Wind_Speed...
# 25  0.432391  (Wind_Chill(F)_1, Temperature(F)_1, Humidity(%...
# 30  0.420955  (Temperature(F)_1, Visibility(mi)_1, Humidity(...
# 44  0.420646  (Pressure(in)_1, Wind_Speed(mph)_0, Visibility...
# 36  0.411374  (Wind_Chill(F)_1, Visibility(mi)_1, Humidity(%...
# 34  0.401638  (Temperature(F)_1, Wind_Speed(mph)_0, Visibili...
# 32  0.400711  (Pressure(in)_1, Temperature(F)_1, Visibility(...
# 40  0.396693  (Wind_Chill(F)_1, Visibility(mi)_1, Wind_Speed...
# 42  0.387575  (Pressure(in)_1, Wind_Speed(mph)_0, Humidity(%...
# 46  0.387421  (Temperature(F)_1, Wind_Chill(F)_1, Visibility...
# 38  0.387266  (Pressure(in)_1, Wind_Chill(F)_1, Visibility(m...
# 50  0.374440  (Temperature(F)_1, Wind_Chill(F)_1, Visibility...
# 48  0.368413  (Pressure(in)_1, Wind_Chill(F)_1, Visibility(m...
# 1   0.362386                    (Part_of_Day_Afternoon (12-17))
# 31  0.348478  (Wind_Speed(mph)_0, Temperature(F)_1, Humidity...
# 29  0.346623  (Pressure(in)_1, Temperature(F)_1, Humidity(%)_1)
# 54  0.345387  (Pressure(in)_1, Wind_Speed(mph)_0, Visibility...
# 37  0.344151  (Wind_Chill(F)_1, Humidity(%)_1, Wind_Speed(mp...
# 33  0.343069  (Pressure(in)_1, Wind_Speed(mph)_0, Temperatur...
# 39  0.335651  (Pressure(in)_1, Wind_Chill(F)_1, Wind_Speed(m...
# 35  0.334724   (Pressure(in)_1, Wind_Chill(F)_1, Humidity(%)_1)
# 0   0.330552                                     (Weather_Fair)
# 47  0.324834  (Wind_Chill(F)_1, Temperature(F)_1, Humidity(%...
# 49  0.321125  (Pressure(in)_1, Wind_Chill(F)_1, Temperature(...
# 45  0.318962  (Pressure(in)_1, Wind_Chill(F)_1, Temperature(...
# 52  0.316180  (Temperature(F)_1, Wind_Speed(mph)_0, Visibili...
# 8   0.313862                   (Visibility(mi)_1, Weather_Fair)
# 53  0.312162  (Wind_Chill(F)_1, Visibility(mi)_1, Humidity(%...
# 9   0.311853  (Visibility(mi)_1, Part_of_Day_Afternoon (12-17))
# 51  0.308453  (Pressure(in)_1, Temperature(F)_1, Visibility(...
#           antecedents         consequents  antecedent support  \
# 2  (Visibility(mi)_1)     (Humidity(%)_1)            0.826920
# 3     (Humidity(%)_1)  (Visibility(mi)_1)            0.738371
# 0   (Wind_Chill(F)_1)  (Temperature(F)_1)            0.643486
# 1  (Temperature(F)_1)   (Wind_Chill(F)_1)            0.654767
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 2            0.738371  0.658322    0.796113  1.078201  0.047748    1.283204
# 3            0.826920  0.658322    0.891586  1.078201  0.047748    1.596478
# 0            0.654767  0.608407    0.945485  1.444001  0.187073    6.332813
# 1            0.643486  0.608407    0.929195  1.444001  0.187073    5.035161
#
#    zhangs_metric
# 2       0.419052
# 3       0.277223
# 0       0.862463
# 1       0.890646
# #################################### Result of Cluster 8 ####################################
#      support                                           itemsets
# 7   0.809503                                 (Visibility(mi)_1)
# 5   0.796425                                    (Humidity(%)_1)
# 8   0.769834                                (Wind_Speed(mph)_0)
# 6   0.706626                                   (Pressure(in)_1)
# 21  0.690061                  (Visibility(mi)_1, Humidity(%)_1)
# 26  0.621622              (Wind_Speed(mph)_0, Visibility(mi)_1)
# 22  0.618134                 (Wind_Speed(mph)_0, Humidity(%)_1)
# 24  0.589364                 (Pressure(in)_1, Visibility(mi)_1)
# 4   0.584568                                  (Wind_Chill(F)_1)
# 2   0.575414                                 (Temperature(F)_1)
# 20  0.564080                    (Pressure(in)_1, Humidity(%)_1)
# 25  0.538797                (Pressure(in)_1, Wind_Speed(mph)_0)
# 47  0.538361  (Wind_Speed(mph)_0, Visibility(mi)_1, Humidity...
# 11  0.530514                (Wind_Chill(F)_1, Temperature(F)_1)
# 45  0.502616  (Pressure(in)_1, Visibility(mi)_1, Humidity(%)_1)
# 18  0.494769                (Wind_Chill(F)_1, Visibility(mi)_1)
# 14  0.483871               (Temperature(F)_1, Visibility(mi)_1)
# 19  0.465998               (Wind_Chill(F)_1, Wind_Speed(mph)_0)
# 31  0.448997  (Temperature(F)_1, Wind_Chill(F)_1, Visibility...
# 15  0.448126              (Wind_Speed(mph)_0, Temperature(F)_1)
# 16  0.445946                   (Wind_Chill(F)_1, Humidity(%)_1)
# 48  0.445510  (Pressure(in)_1, Wind_Speed(mph)_0, Visibility...
# 12  0.441151                  (Temperature(F)_1, Humidity(%)_1)
# 46  0.433304  (Pressure(in)_1, Wind_Speed(mph)_0, Humidity(%...
# 17  0.428509                  (Pressure(in)_1, Wind_Chill(F)_1)
# 13  0.422842                 (Pressure(in)_1, Temperature(F)_1)
# 32  0.420227  (Wind_Chill(F)_1, Temperature(F)_1, Wind_Speed...
# 29  0.406277  (Wind_Chill(F)_1, Temperature(F)_1, Humidity(%...
# 40  0.403226  (Wind_Chill(F)_1, Visibility(mi)_1, Humidity(%...
# 34  0.396687  (Temperature(F)_1, Visibility(mi)_1, Humidity(...
# 44  0.391020  (Wind_Chill(F)_1, Visibility(mi)_1, Wind_Speed...
# 30  0.390148  (Pressure(in)_1, Wind_Chill(F)_1, Temperature(...
# 58  0.386661  (Pressure(in)_1, Wind_Speed(mph)_0, Visibility...
# 9   0.383173                              (Precipitation(in)_0)
# 38  0.374019  (Temperature(F)_1, Wind_Speed(mph)_0, Visibili...
# 42  0.369224  (Pressure(in)_1, Wind_Chill(F)_1, Visibility(m...
# 50  0.366609  (Temperature(F)_1, Wind_Chill(F)_1, Visibility...
# 41  0.361378  (Wind_Chill(F)_1, Humidity(%)_1, Wind_Speed(mp...
# 36  0.360506  (Pressure(in)_1, Temperature(F)_1, Visibility(...
# 0   0.357454                    (Part_of_Day_Afternoon (12-17))
# 54  0.353095  (Temperature(F)_1, Wind_Chill(F)_1, Visibility...
# 35  0.349608  (Wind_Speed(mph)_0, Temperature(F)_1, Humidity...
# 52  0.335222  (Pressure(in)_1, Wind_Chill(F)_1, Visibility(m...
# 43  0.334350  (Pressure(in)_1, Wind_Chill(F)_1, Wind_Speed(m...
# 39  0.330863   (Pressure(in)_1, Wind_Chill(F)_1, Humidity(%)_1)
# 1   0.329555                                 (Temperature(F)_0)
# 27  0.328684            (Visibility(mi)_1, Precipitation(in)_0)
# 51  0.328248  (Wind_Chill(F)_1, Temperature(F)_1, Humidity(%...
# 33  0.326504  (Pressure(in)_1, Temperature(F)_1, Humidity(%)_1)
# 57  0.325632  (Wind_Chill(F)_1, Visibility(mi)_1, Humidity(%...
# 37  0.325196  (Pressure(in)_1, Wind_Speed(mph)_0, Temperatur...
# 3   0.320837                                  (Wind_Chill(F)_0)
# 28  0.316914           (Wind_Speed(mph)_0, Precipitation(in)_0)
# 55  0.313862  (Temperature(F)_1, Wind_Speed(mph)_0, Visibili...
# 23  0.312990               (Precipitation(in)_0, Humidity(%)_1)
# 53  0.303836  (Pressure(in)_1, Wind_Chill(F)_1, Temperature(...
# 10  0.303836  (Visibility(mi)_1, Part_of_Day_Afternoon (12-17))
# 56  0.302964  (Pressure(in)_1, Wind_Chill(F)_1, Visibility(m...
# 49  0.301221  (Pressure(in)_1, Wind_Chill(F)_1, Temperature(...
#            antecedents          consequents  antecedent support  \
# 0   (Visibility(mi)_1)      (Humidity(%)_1)            0.809503
# 1      (Humidity(%)_1)   (Visibility(mi)_1)            0.796425
# 4  (Wind_Speed(mph)_0)   (Visibility(mi)_1)            0.769834
# 5   (Visibility(mi)_1)  (Wind_Speed(mph)_0)            0.809503
# 2  (Wind_Speed(mph)_0)      (Humidity(%)_1)            0.769834
# 3      (Humidity(%)_1)  (Wind_Speed(mph)_0)            0.796425
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.796425  0.690061    0.852450  1.070345  0.045352    1.379700
# 1            0.809503  0.690061    0.866448  1.070345  0.045352    1.426385
# 4            0.809503  0.621622    0.807475  0.997494 -0.001562    0.989464
# 5            0.769834  0.621622    0.767905  0.997494 -0.001562    0.991688
# 2            0.796425  0.618134    0.802945  1.008185  0.005019    1.033082
# 3            0.769834  0.618134    0.776136  1.008185  0.005019    1.028148
#
#    zhangs_metric
# 0       0.345003
# 1       0.322840
# 4      -0.010797
# 5      -0.013016
# 2       0.035274
# 3       0.039882
# #################################### Result of Cluster 9 ####################################
#      support                                           itemsets
# 9   0.963197                                 (Visibility(mi)_1)
# 10  0.774974                                (Wind_Speed(mph)_0)
# 8   0.772871                                   (Pressure(in)_0)
# 34  0.751840                 (Visibility(mi)_1, Pressure(in)_0)
# 36  0.746583              (Wind_Speed(mph)_0, Visibility(mi)_1)
# ..       ...                                                ...
# 6   0.302839                                  (Wind_Chill(F)_2)
# 76  0.302839  (Wind_Chill(F)_1, Visibility(mi)_1, Pressure(i...
# 65  0.301788  (Temperature(F)_1, Wind_Chill(F)_1, Visibility...
# 38  0.301788   (Temperature(F)_1, Pressure(in)_0, Weather_Fair)
# 30  0.301788                  (Pressure(in)_0, Wind_Chill(F)_2)
#
# [79 rows x 2 columns]
#            antecedents          consequents  antecedent support  \
# 4   (Visibility(mi)_1)     (Pressure(in)_0)            0.963197
# 5     (Pressure(in)_0)   (Visibility(mi)_1)            0.772871
# 6  (Wind_Speed(mph)_0)   (Visibility(mi)_1)            0.774974
# 7   (Visibility(mi)_1)  (Wind_Speed(mph)_0)            0.963197
# 2   (Visibility(mi)_1)      (Humidity(%)_0)            0.963197
# 3      (Humidity(%)_0)   (Visibility(mi)_1)            0.697161
# 0    (Wind_Chill(F)_1)   (Visibility(mi)_1)            0.643533
# 1   (Visibility(mi)_1)    (Wind_Chill(F)_1)            0.963197
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 4            0.772871  0.751840    0.780568  1.009959  0.007414    1.035077
# 5            0.963197  0.751840    0.972789  1.009959  0.007414    1.352524
# 6            0.963197  0.746583    0.963365  1.000175  0.000130    1.004596
# 7            0.774974  0.746583    0.775109  1.000175  0.000130    1.000602
# 2            0.697161  0.682440    0.708515  1.016287  0.010937    1.038954
# 3            0.963197  0.682440    0.978884  1.016287  0.010937    1.742902
# 0            0.963197  0.618297    0.960784  0.997496 -0.001552    0.938486
# 1            0.643533  0.618297    0.641921  0.997496 -0.001552    0.995499
#
#    zhangs_metric
# 4       0.267932
# 5       0.043415
# 6       0.000777
# 7       0.004748
# 2       0.435439
# 3       0.052918
# 0      -0.006994
# 1      -0.063865
# #################################### Result of Cluster 10 ####################################
#      support                                           itemsets
# 9   0.803109                                 (Visibility(mi)_1)
# 8   0.802245                                   (Pressure(in)_0)
# 10  0.702936                                (Wind_Speed(mph)_0)
# 27  0.658031                 (Visibility(mi)_1, Pressure(in)_0)
# 29  0.577720              (Wind_Speed(mph)_0, Visibility(mi)_1)
# 7   0.563040                                    (Humidity(%)_1)
# 28  0.548359                (Wind_Speed(mph)_0, Pressure(in)_0)
# 5   0.460276                                  (Wind_Chill(F)_1)
# 39  0.458549  (Wind_Speed(mph)_0, Visibility(mi)_1, Pressure...
# 25  0.458549                  (Visibility(mi)_1, Humidity(%)_1)
# 3   0.448187                                 (Temperature(F)_1)
# 24  0.439551                    (Humidity(%)_1, Pressure(in)_0)
# 2   0.438687                                 (Temperature(F)_0)
# 15  0.416235                (Wind_Chill(F)_1, Temperature(F)_1)
# 21  0.414508                (Wind_Chill(F)_1, Visibility(mi)_1)
# 17  0.411054               (Temperature(F)_1, Visibility(mi)_1)
# 4   0.405009                                  (Wind_Chill(F)_0)
# 26  0.392919                 (Wind_Speed(mph)_0, Humidity(%)_1)
# 12  0.385147                (Wind_Chill(F)_0, Temperature(F)_0)
# 32  0.381693  (Temperature(F)_1, Wind_Chill(F)_1, Visibility...
# 16  0.367012                 (Temperature(F)_1, Pressure(in)_0)
# 37  0.360104  (Visibility(mi)_1, Humidity(%)_1, Pressure(in)_0)
# 20  0.352332                  (Wind_Chill(F)_1, Pressure(in)_0)
# 6   0.341969                                    (Humidity(%)_0)
# 31  0.340242  (Wind_Chill(F)_1, Temperature(F)_1, Pressure(i...
# 34  0.339378  (Temperature(F)_1, Visibility(mi)_1, Pressure(...
# 1   0.335924                    (Part_of_Day_Afternoon (12-17))
# 22  0.335060               (Wind_Chill(F)_1, Wind_Speed(mph)_0)
# 14  0.335060                 (Temperature(F)_0, Pressure(in)_0)
# 38  0.332470  (Wind_Speed(mph)_0, Visibility(mi)_1, Humidity...
# 13  0.326425                  (Temperature(F)_0, Humidity(%)_1)
# 19  0.324698                  (Wind_Chill(F)_0, Pressure(in)_0)
# 35  0.323834  (Wind_Chill(F)_1, Visibility(mi)_1, Pressure(i...
# 18  0.316926              (Wind_Speed(mph)_0, Temperature(F)_1)
# 40  0.314335  (Temperature(F)_1, Wind_Chill(F)_1, Visibility...
# 23  0.313472                  (Visibility(mi)_1, Humidity(%)_0)
# 30  0.310017  (Wind_Chill(F)_0, Temperature(F)_0, Pressure(i...
# 11  0.308290                     (Pressure(in)_0, Weather_Fair)
# 0   0.308290                                     (Weather_Fair)
# 36  0.307427  (Wind_Chill(F)_1, Visibility(mi)_1, Wind_Speed...
# 33  0.300518  (Wind_Chill(F)_1, Temperature(F)_1, Wind_Speed...
#           antecedents         consequents  antecedent support  \
# 0  (Visibility(mi)_1)    (Pressure(in)_0)            0.803109
# 1    (Pressure(in)_0)  (Visibility(mi)_1)            0.802245
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.802245  0.658031    0.819355  1.021327  0.013741    1.094714
# 1            0.803109  0.658031    0.820237  1.021327  0.013741    1.095281
#
#    zhangs_metric
# 0       0.106057
# 1       0.105594
# #################################### Result of Cluster 11 ####################################
#      support                                           itemsets
# 6   0.834698                                 (Visibility(mi)_1)
# 5   0.787524                                   (Pressure(in)_1)
# 7   0.763353                                (Wind_Speed(mph)_0)
# 2   0.748538                                 (Temperature(F)_1)
# 4   0.742690                                    (Humidity(%)_1)
# ..       ...                                                ...
# 60  0.326706  (Wind_Speed(mph)_0, Visibility(mi)_1, Wind_Chi...
# 9   0.322807  (Visibility(mi)_1, Part_of_Day_Afternoon (12-17))
# 59  0.322027  (Pressure(in)_1, Wind_Chill(F)_1, Visibility(m...
# 61  0.311111  (Pressure(in)_1, Wind_Speed(mph)_0, Visibility...
# 10  0.306043  (Wind_Speed(mph)_0, Part_of_Day_Afternoon (12-...
#
# [62 rows x 2 columns]
#            antecedents          consequents  antecedent support  \
# 0    (Wind_Chill(F)_1)   (Temperature(F)_1)            0.736062
# 1   (Temperature(F)_1)    (Wind_Chill(F)_1)            0.748538
# 4   (Visibility(mi)_1)      (Humidity(%)_1)            0.834698
# 5      (Humidity(%)_1)   (Visibility(mi)_1)            0.742690
# 6     (Pressure(in)_1)   (Visibility(mi)_1)            0.787524
# 7   (Visibility(mi)_1)     (Pressure(in)_1)            0.834698
# 8  (Wind_Speed(mph)_0)   (Visibility(mi)_1)            0.763353
# 9   (Visibility(mi)_1)  (Wind_Speed(mph)_0)            0.834698
# 2   (Temperature(F)_1)   (Visibility(mi)_1)            0.748538
# 3   (Visibility(mi)_1)   (Temperature(F)_1)            0.834698
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0            0.748538  0.701365    0.952860  1.272962  0.150394    5.334385
# 1            0.736062  0.701365    0.936979  1.272962  0.150394    4.188101
# 4            0.742690  0.671735    0.804764  1.083580  0.051813    1.317944
# 5            0.834698  0.671735    0.904462  1.083580  0.051813    1.730223
# 6            0.834698  0.655361    0.832178  0.996981 -0.001984    0.984986
# 7            0.787524  0.655361    0.785147  0.996981 -0.001984    0.988936
# 8            0.834698  0.642885    0.842186  1.008971  0.005716    1.047449
# 9            0.763353  0.642885    0.770201  1.008971  0.005716    1.029800
# 2            0.834698  0.610526    0.815625  0.977150 -0.014277    0.896554
# 3            0.748538  0.610526    0.731434  0.977150 -0.014277    0.936313
#
#    zhangs_metric
# 0       0.812428
# 1       0.852735
# 4       0.466620
# 5       0.299768
# 6      -0.014050
# 7      -0.017987
# 8       0.037572
# 9       0.053788
# 2      -0.085082
# 3      -0.123932

# %%
# Subset selector
