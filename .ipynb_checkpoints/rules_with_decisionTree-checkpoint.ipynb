# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from six import StringIO
from IPython.display import Image
import pydotplus
from sklearn.tree import export_graphviz
from sklearn.tree import plot_tree
import graphviz
from sklearn import tree
from sklearn.tree import _tree

# %matplotlib inline

# %%
# Load Dataset

abs_path = Path.cwd()
data_address = abs_path.parent.parent/ 'data/' / 'Cleaned_US.csv'
df = pd.read_csv(data_address)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2774575 entries, 0 to 2774574
# Data columns (total 34 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Severity           int64
#  1   Start_Time         object
#  2   Start_Lat          float64
#  3   Start_Lng          float64
#  4   End_Lat            float64
#  5   End_Lng            float64
#  6   Distance(mi)       float64
#  7   City               object
#  8   County             object
#  9   State              object
#  10  Temperature(F)     float64
#  11  Wind_Chill(F)      float64
#  12  Humidity(%)        float64
#  13  Pressure(in)       float64
#  14  Visibility(mi)     float64
#  15  Wind_Speed(mph)    float64
#  16  Precipitation(in)  float64
#  17  Weather_Condition  object
#  18  Amenity            bool
#  19  Bump               bool
#  20  Crossing           bool
#  21  Give_Way           bool
#  22  Junction           bool
#  23  No_Exit            bool
#  24  Railway            bool
#  25  Roundabout         bool
#  26  Station            bool
#  27  Stop               bool
#  28  Traffic_Calming    bool
#  29  Traffic_Signal     bool
#  30  Turning_Loop       bool
#  31  Weekday            object
#  32  Hour               int64
#  33  Month              int64
# dtypes: bool(13), float64(12), int64(3), object(6)
# memory usage: 478.9+ MB

# %%
features = ['Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
            'Visibility(mi)', 'Wind_Speed(mph)', 'Precipitation(in)',
             'Distance(mi)', 'Amenity', 'Bump', 'Crossing',
            'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
            'Stop', 'Traffic_Calming', 'Traffic_Signal']

# %%
X = df[features]
y = df['Severity']

# %%
y.value_counts()
# Out:
# 2    2470962
# 3     151145
# 4     126766
# 1      25702
# Name: Severity, dtype: int64

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2774575 entries, 0 to 2774574
# Data columns (total 20 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   Temperature(F)     float64
#  1   Wind_Chill(F)      float64
#  2   Humidity(%)        float64
#  3   Pressure(in)       float64
#  4   Visibility(mi)     float64
#  5   Wind_Speed(mph)    float64
#  6   Precipitation(in)  float64
#  7   Distance(mi)       float64
#  8   Amenity            bool
#  9   Bump               bool
#  10  Crossing           bool
#  11  Give_Way           bool
#  12  Junction           bool
#  13  No_Exit            bool
#  14  Railway            bool
#  15  Roundabout         bool
#  16  Station            bool
#  17  Stop               bool
#  18  Traffic_Calming    bool
#  19  Traffic_Signal     bool
# dtypes: bool(12), float64(8)
# memory usage: 201.1 MB

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=1)

# %%
dtree = DecisionTreeClassifier()

# %%
dtree = dtree.fit(X_train, y_train)

# %%
y_pred = dtree.predict(X_test)

# %%
# Accuracy, how often classfier predict correct?
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.847279007675407

# %%
dtree.feature_importances_
# Out:
# array([1.18233304e-01, 7.59869952e-02, 1.52882235e-01, 1.97538556e-01,
#        3.47263982e-02, 1.04958952e-01, 5.89228776e-02, 2.19230300e-01,
#        2.43134850e-03, 5.44745451e-05, 8.69913259e-03, 1.27047809e-03,
#        7.28712048e-03, 5.69963902e-04, 2.24666312e-03, 2.89876847e-05,
#        3.57344905e-03, 3.67616303e-03, 1.92463170e-04, 7.49013827e-03])

# %%
dtree_opt = DecisionTreeClassifier(criterion='entropy', max_depth=15)

# %%
dtree_opt = dtree_opt.fit(X_train, y_train)

# %%
y_pred = dtree_opt.predict(X_test)

# %%
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.8930186089694425

# %%
dtree_opt.feature_importances_
# Out:
# array([4.10028321e-02, 1.00041933e-01, 6.51000422e-02, 1.34065417e-01,
#        1.70384875e-02, 4.36001616e-02, 2.51567300e-01, 2.83523670e-01,
#        1.21164649e-03, 5.68513632e-05, 2.14861722e-02, 5.14332771e-04,
#        1.60195359e-02, 2.48603564e-04, 1.07020703e-03, 0.00000000e+00,
#        2.45846446e-03, 2.16074774e-03, 1.65816570e-04, 1.86677777e-02])

# %%
leaf_nodes = np.where(dtree_opt.tree_.children_left == -1)[0]
leaf_node_values = dtree_opt.tree_.value[leaf_nodes]

print(f'Total number of valuable nodes is: {len(leaf_nodes)}')

for node, value in zip(leaf_nodes, leaf_node_values):
    class_counts = value[0]
    node_info = f"Node {node}: Class Counts = {class_counts}"
    print(node_info)
# Out:
# Total number of valuable nodes is: 10286
# Node 7: Class Counts = [0. 2. 0. 0.]
# Node 9: Class Counts = [ 0.  0. 69.  0.]
# Node 12: Class Counts = [0. 0. 0. 1.]
# Node 15: Class Counts = [0. 0. 0. 1.]
# Node 18: Class Counts = [0. 0. 1. 0.]
# Node 19: Class Counts = [0. 0. 0. 1.]
# Node 20: Class Counts = [0. 0. 7. 0.]
# Node 21: Class Counts = [0. 0. 9. 0.]
# Node 26: Class Counts = [0. 0. 1. 0.]
# Node 27: Class Counts = [0. 1. 0. 0.]
# Node 28: Class Counts = [ 0.  0. 11.  0.]
# Node 29: Class Counts = [0. 1. 0. 0.]
# Node 30: Class Counts = [0. 2. 0. 0.]
# Node 38: Class Counts = [0. 0. 1. 0.]
# Node 39: Class Counts = [ 0. 24.  0.  0.]
# Node 43: Class Counts = [0. 2. 0. 0.]
# Node 44: Class Counts = [0. 2. 5. 1.]
# Node 45: Class Counts = [0. 3. 0. 0.]
# Node 46: Class Counts = [0. 4. 0. 0.]
# Node 48: Class Counts = [0. 5. 0. 0.]
# Node 52: Class Counts = [0. 0. 2. 0.]
# Node 53: Class Counts = [0. 7. 2. 0.]
# Node 54: Class Counts = [0. 4. 0. 0.]
# Node 57: Class Counts = [0. 0. 2. 0.]
# Node 58: Class Counts = [0. 4. 0. 0.]
# Node 60: Class Counts = [0. 1. 0. 0.]
# Node 61: Class Counts = [0. 0. 7. 0.]
# Node 66: Class Counts = [0. 0. 0. 1.]
# Node 67: Class Counts = [0. 5. 0. 0.]
# Node 70: Class Counts = [0. 3. 1. 0.]
# Node 71: Class Counts = [0. 0. 0. 1.]
# Node 73: Class Counts = [0. 2. 0. 0.]
# Node 74: Class Counts = [0. 3. 9. 0.]
# Node 76: Class Counts = [0. 9. 0. 0.]
# Node 77: Class Counts = [0. 0. 0. 2.]
# Node 81: Class Counts = [0. 4. 0. 0.]
# Node 83: Class Counts = [ 0.  3. 23.  0.]
# Node 84: Class Counts = [0. 8. 5. 0.]
# Node 85: Class Counts = [ 0.  0. 13.  0.]
# Node 86: Class Counts = [0. 6. 0. 0.]
# Node 88: Class Counts = [ 0.  0. 24.  0.]
# Node 92: Class Counts = [0. 1. 0. 0.]
# Node 93: Class Counts = [4. 0. 0. 0.]
# Node 94: Class Counts = [0. 0. 2. 0.]
# Node 99: Class Counts = [ 0. 12.  2.  1.]
# Node 100: Class Counts = [ 0. 11. 19.  1.]
# Node 102: Class Counts = [0. 1. 0. 0.]
# Node 103: Class Counts = [3. 0. 1. 0.]
# Node 106: Class Counts = [ 0.  0. 12.  0.]
# Node 107: Class Counts = [ 0.  8. 45.  0.]
# Node 109: Class Counts = [2. 9. 4. 1.]
# Node 110: Class Counts = [ 0. 17. 35.  1.]
# Node 111: Class Counts = [0. 7. 0. 0.]
# Node 119: Class Counts = [0. 4. 0. 3.]
# Node 120: Class Counts = [0. 0. 1. 0.]
# Node 121: Class Counts = [0. 0. 1. 0.]
# Node 123: Class Counts = [1. 0. 0. 0.]
# Node 124: Class Counts = [0. 2. 0. 0.]
# Node 125: Class Counts = [3. 0. 0. 0.]
# Node 130: Class Counts = [0. 2. 0. 0.]
# Node 131: Class Counts = [0. 1. 2. 0.]
# Node 132: Class Counts = [0. 0. 6. 0.]
# Node 135: Class Counts = [0. 0. 1. 0.]
# Node 136: Class Counts = [1. 1. 1. 0.]
# Node 138: Class Counts = [ 0. 15.  2.  0.]
# Node 139: Class Counts = [0. 0. 2. 0.]
# Node 141: Class Counts = [0. 0. 0. 1.]
# Node 143: Class Counts = [0. 4. 0. 0.]
# Node 145: Class Counts = [2. 0. 0. 0.]
# Node 146: Class Counts = [0. 2. 0. 0.]
# Node 151: Class Counts = [ 0.  0. 10.  0.]
# Node 153: Class Counts = [0. 1. 5. 0.]
# Node 154: Class Counts = [0. 3. 0. 0.]
# Node 156: Class Counts = [0. 8. 0. 0.]
# Node 158: Class Counts = [0. 0. 4. 0.]
# Node 159: Class Counts = [0. 1. 1. 0.]
# Node 163: Class Counts = [ 5. 16.  3.  0.]
# Node 164: Class Counts = [ 2. 67. 24.  0.]
# Node 166: Class Counts = [0. 0. 4. 0.]
# Node 167: Class Counts = [2. 1. 1. 0.]
# Node 168: Class Counts = [0. 0. 6. 0.]
# Node 170: Class Counts = [0. 0. 7. 0.]
# Node 174: Class Counts = [0. 1. 1. 0.]
# Node 175: Class Counts = [0. 6. 0. 0.]
# Node 176: Class Counts = [0. 0. 1. 0.]
# Node 179: Class Counts = [0. 0. 3. 0.]
# Node 180: Class Counts = [ 0. 10. 10.  0.]
# Node 181: Class Counts = [0. 0. 6. 0.]
# Node 186: Class Counts = [0. 8. 0. 0.]
# Node 188: Class Counts = [0. 0. 1. 0.]
# Node 189: Class Counts = [0. 1. 0. 0.]
# Node 190: Class Counts = [0. 0. 2. 0.]
# Node 193: Class Counts = [ 0.  0. 10.  0.]
# Node 195: Class Counts = [0. 0. 1. 0.]
# Node 196: Class Counts = [0. 1. 0. 0.]
# Node 198: Class Counts = [0. 0. 3. 0.]
# Node 201: Class Counts = [0. 1. 0. 0.]
# Node 202: Class Counts = [0. 0. 1. 0.]
# Node 203: Class Counts = [0. 5. 0. 0.]
# Node 209: Class Counts = [ 0. 12.  2.  0.]
# Node 210: Class Counts = [ 0. 19.  0.  0.]
# Node 212: Class Counts = [1. 0. 0. 0.]
# Node 213: Class Counts = [0. 7. 5. 0.]
# Node 216: Class Counts = [0. 2. 2. 0.]
# Node 217: Class Counts = [ 0. 47.  1.  0.]
# Node 218: Class Counts = [  0. 102.   0.   0.]
# Node 222: Class Counts = [0. 4. 5. 0.]
# Node 223: Class Counts = [0. 0. 3. 0.]
# Node 224: Class Counts = [0. 2. 0. 0.]
# Node 225: Class Counts = [0. 3. 0. 0.]
# Node 228: Class Counts = [0. 0. 2. 0.]
# Node 231: Class Counts = [0. 3. 1. 0.]
# Node 232: Class Counts = [ 0. 28.  0.  0.]
# Node 234: Class Counts = [0. 0. 1. 0.]
# Node 235: Class Counts = [0. 1. 0. 0.]
# Node 238: Class Counts = [0. 0. 3. 0.]
# Node 240: Class Counts = [ 0. 15.  4.  0.]
# Node 241: Class Counts = [0. 3. 8. 0.]
# Node 242: Class Counts = [0. 0. 6. 0.]
# Node 251: Class Counts = [0. 2. 0. 0.]
# Node 252: Class Counts = [0. 2. 5. 0.]
# Node 254: Class Counts = [ 0.  4. 81.  0.]
# Node 255: Class Counts = [ 2.  0. 22.  0.]
# Node 258: Class Counts = [ 0.  1. 15.  0.]
# Node 259: Class Counts = [3. 0. 0. 0.]
# Node 261: Class Counts = [3. 0. 0. 0.]
# Node 262: Class Counts = [0. 2. 0. 0.]
# Node 265: Class Counts = [ 0.  0. 14.  0.]
# Node 267: Class Counts = [ 0.  3. 13.  0.]
# Node 268: Class Counts = [0. 6. 2. 0.]
# Node 269: Class Counts = [0. 4. 0. 0.]
# Node 274: Class Counts = [0. 6. 4. 0.]
# Node 275: Class Counts = [0. 0. 2. 0.]
# Node 276: Class Counts = [0. 5. 0. 0.]
# Node 279: Class Counts = [0. 1. 6. 0.]
# Node 280: Class Counts = [ 0.  0. 14.  0.]
# Node 282: Class Counts = [0. 3. 0. 0.]
# Node 283: Class Counts = [0. 0. 4. 0.]
# Node 284: Class Counts = [0. 4. 0. 0.]
# Node 290: Class Counts = [ 2.  0. 25.  0.]
# Node 291: Class Counts = [0. 3. 5. 0.]
# Node 293: Class Counts = [0. 0. 8. 0.]
# Node 294: Class Counts = [ 2. 26. 30.  0.]
# Node 297: Class Counts = [ 1. 34. 40.  4.]
# Node 298: Class Counts = [ 1. 20.  8.  0.]
# Node 300: Class Counts = [0. 0. 6. 0.]
# Node 301: Class Counts = [1. 2. 3. 3.]
# Node 305: Class Counts = [1. 7. 9. 0.]
# Node 306: Class Counts = [ 0.  2. 21.  0.]
# Node 308: Class Counts = [0. 5. 0. 0.]
# Node 309: Class Counts = [0. 2. 3. 0.]
# Node 311: Class Counts = [2. 0. 0. 0.]
# Node 313: Class Counts = [ 6. 14. 17.  1.]
# Node 314: Class Counts = [12. 77. 44.  0.]
# Node 319: Class Counts = [0. 0. 5. 0.]
# Node 320: Class Counts = [2. 9. 2. 0.]
# Node 322: Class Counts = [0. 0. 9. 3.]
# Node 323: Class Counts = [0. 3. 3. 1.]
# Node 326: Class Counts = [  7.  98. 210.   3.]
# Node 327: Class Counts = [0. 4. 0. 0.]
# Node 329: Class Counts = [0. 3. 0. 0.]
# Node 330: Class Counts = [1. 0. 0. 0.]
# Node 334: Class Counts = [0. 6. 4. 0.]
# Node 335: Class Counts = [0. 4. 0. 0.]
# Node 336: Class Counts = [0. 8. 0. 0.]
# Node 339: Class Counts = [0. 1. 2. 0.]
# Node 340: Class Counts = [0. 3. 0. 0.]
# Node 341: Class Counts = [0. 0. 4. 0.]
# Node 347: Class Counts = [0. 0. 3. 0.]
# Node 349: Class Counts = [5. 5. 4. 0.]
# Node 350: Class Counts = [0. 3. 0. 0.]
# Node 352: Class Counts = [0. 0. 5. 0.]
# Node 354: Class Counts = [0. 0. 1. 0.]
# Node 355: Class Counts = [6. 0. 0. 0.]
# Node 359: Class Counts = [1. 0. 1. 0.]
# Node 360: Class Counts = [0. 0. 1. 0.]
# Node 362: Class Counts = [0. 5. 3. 0.]
# Node 363: Class Counts = [ 0.  5. 15.  0.]
# Node 365: Class Counts = [0. 0. 8. 0.]
# Node 367: Class Counts = [2. 0. 1. 0.]
# Node 368: Class Counts = [0. 0. 2. 0.]
# Node 371: Class Counts = [0. 9. 0. 0.]
# Node 374: Class Counts = [0. 0. 1. 0.]
# Node 375: Class Counts = [1. 0. 1. 0.]
# Node 376: Class Counts = [0. 4. 0. 0.]
# Node 380: Class Counts = [0. 2. 2. 0.]
# Node 381: Class Counts = [ 0.  1. 11.  0.]
# Node 382: Class Counts = [0. 1. 0. 0.]
# Node 384: Class Counts = [0. 5. 0. 0.]
# Node 386: Class Counts = [0. 0. 2. 0.]
# Node 387: Class Counts = [0. 2. 0. 0.]
# Node 393: Class Counts = [0. 1. 2. 1.]
# Node 394: Class Counts = [0. 0. 0. 1.]
# Node 396: Class Counts = [0. 3. 1. 0.]
# Node 397: Class Counts = [0. 0. 2. 0.]
# Node 400: Class Counts = [ 0.  2. 12.  0.]
# Node 401: Class Counts = [ 0.  7. 12.  0.]
# Node 402: Class Counts = [0. 0. 5. 0.]
# Node 405: Class Counts = [0. 6. 0. 0.]
# Node 407: Class Counts = [0. 2. 5. 0.]
# Node 408: Class Counts = [0. 6. 1. 0.]
# Node 411: Class Counts = [0. 2. 0. 0.]
# Node 412: Class Counts = [0. 0. 4. 5.]
# Node 413: Class Counts = [0. 4. 0. 0.]
# Node 418: Class Counts = [ 0.  1. 14.  0.]
# Node 419: Class Counts = [ 3. 13. 15.  0.]
# Node 421: Class Counts = [0. 2. 0. 0.]
# Node 422: Class Counts = [ 0. 18. 25.  0.]
# Node 425: Class Counts = [ 0. 78. 24.  0.]
# Node 426: Class Counts = [0. 1. 7. 0.]
# Node 428: Class Counts = [ 7. 74. 75.  0.]
# Node 429: Class Counts = [ 0. 71. 31.  0.]
# Node 433: Class Counts = [2. 4. 0. 0.]
# Node 434: Class Counts = [0. 8. 3. 0.]
# Node 435: Class Counts = [0. 0. 0. 2.]
# Node 438: Class Counts = [ 1.  1. 14.  2.]
# Node 439: Class Counts = [ 0.  6. 26.  0.]
# Node 441: Class Counts = [1. 0. 0. 0.]
# Node 442: Class Counts = [0. 1. 0. 0.]
# Node 445: Class Counts = [ 0.  0. 34.  0.]
# Node 451: Class Counts = [0. 1. 1. 0.]
# Node 452: Class Counts = [0. 1. 1. 0.]
# Node 453: Class Counts = [ 0.  0. 17.  0.]
# Node 456: Class Counts = [0. 5. 8. 0.]
# Node 457: Class Counts = [0. 4. 0. 0.]
# Node 459: Class Counts = [0. 0. 8. 0.]
# Node 460: Class Counts = [0. 1. 1. 0.]
# Node 463: Class Counts = [0. 0. 2. 0.]
# Node 464: Class Counts = [0. 1. 1. 0.]
# Node 465: Class Counts = [ 0.  0. 21.  0.]
# Node 468: Class Counts = [0. 0. 8. 0.]
# Node 471: Class Counts = [1. 0. 0. 0.]
# Node 472: Class Counts = [1. 0. 1. 0.]
# Node 473: Class Counts = [0. 0. 4. 0.]
# Node 474: Class Counts = [0. 2. 0. 0.]
# Node 476: Class Counts = [0. 8. 0. 0.]
# Node 482: Class Counts = [ 0.  9. 34.  0.]
# Node 483: Class Counts = [0. 1. 0. 0.]
# Node 484: Class Counts = [0. 0. 6. 0.]
# Node 486: Class Counts = [0. 3. 0. 0.]
# Node 488: Class Counts = [0. 2. 3. 0.]
# Node 489: Class Counts = [0. 0. 1. 0.]
# Node 490: Class Counts = [0. 0. 7. 0.]
# Node 493: Class Counts = [1. 0. 0. 0.]
# Node 494: Class Counts = [0. 0. 2. 0.]
# Node 495: Class Counts = [0. 0. 7. 0.]
# Node 501: Class Counts = [0. 0. 1. 0.]
# Node 504: Class Counts = [1. 0. 0. 0.]
# Node 505: Class Counts = [0. 1. 0. 1.]
# Node 506: Class Counts = [0. 3. 0. 0.]
# Node 508: Class Counts = [0. 0. 4. 0.]
# Node 510: Class Counts = [0. 0. 1. 0.]
# Node 511: Class Counts = [0. 2. 0. 0.]
# Node 514: Class Counts = [0. 0. 1. 0.]
# Node 516: Class Counts = [1. 0. 0. 0.]
# Node 517: Class Counts = [3. 1. 0. 0.]
# Node 522: Class Counts = [ 0. 17.  0.  0.]
# Node 523: Class Counts = [1. 0. 0. 0.]
# Node 526: Class Counts = [2. 0. 0. 0.]
# Node 528: Class Counts = [0. 2. 0. 0.]
# Node 529: Class Counts = [1. 0. 0. 0.]
# Node 530: Class Counts = [0. 2. 0. 0.]
# Node 535: Class Counts = [0. 3. 0. 0.]
# Node 536: Class Counts = [0. 0. 1. 0.]
# Node 538: Class Counts = [1. 1. 0. 0.]
# Node 539: Class Counts = [3. 0. 0. 0.]
# Node 542: Class Counts = [0. 0. 3. 0.]
# Node 543: Class Counts = [1. 0. 0. 0.]
# Node 544: Class Counts = [3. 0. 0. 0.]
# Node 548: Class Counts = [1. 3. 0. 0.]
# Node 549: Class Counts = [6. 0. 2. 0.]
# Node 551: Class Counts = [ 0. 16.  0.  0.]
# Node 552: Class Counts = [ 7. 16.  4.  0.]
# Node 555: Class Counts = [0. 1. 1. 0.]
# Node 556: Class Counts = [ 0. 10.  0.  0.]
# Node 557: Class Counts = [0. 0. 1. 0.]
# Node 558: Class Counts = [ 0. 13.  0.  0.]
# Node 560: Class Counts = [0. 0. 0. 4.]
# Node 562: Class Counts = [0. 0. 1. 0.]
# Node 563: Class Counts = [0. 3. 0. 0.]
# Node 567: Class Counts = [0. 0. 5. 0.]
# Node 572: Class Counts = [0. 0. 1. 0.]
# Node 573: Class Counts = [0. 1. 0. 0.]
# Node 574: Class Counts = [0. 8. 0. 0.]
# Node 575: Class Counts = [0. 0. 2. 0.]
# Node 580: Class Counts = [0. 1. 0. 0.]
# Node 581: Class Counts = [2. 0. 0. 0.]
# Node 583: Class Counts = [0. 0. 2. 0.]
# Node 585: Class Counts = [3. 0. 0. 0.]
# Node 586: Class Counts = [0. 0. 1. 0.]
# Node 590: Class Counts = [1. 0. 1. 0.]
# Node 591: Class Counts = [0. 1. 0. 0.]
# Node 592: Class Counts = [0. 4. 0. 0.]
# Node 593: Class Counts = [2. 0. 0. 0.]
# Node 594: Class Counts = [0. 2. 0. 0.]
# Node 598: Class Counts = [0. 0. 3. 0.]
# Node 599: Class Counts = [0. 0. 0. 1.]
# Node 605: Class Counts = [0. 5. 0. 0.]
# Node 606: Class Counts = [1. 0. 0. 0.]
# Node 607: Class Counts = [1. 0. 0. 0.]
# Node 609: Class Counts = [0. 0. 4. 0.]
# Node 611: Class Counts = [0. 2. 1. 0.]
# Node 612: Class Counts = [2. 1. 0. 0.]
# Node 615: Class Counts = [0. 0. 0. 1.]
# Node 616: Class Counts = [1. 0. 0. 0.]
# Node 617: Class Counts = [ 0. 10.  0.  0.]
# Node 619: Class Counts = [0. 0. 4. 0.]
# Node 621: Class Counts = [0. 0. 1. 0.]
# Node 622: Class Counts = [0. 1. 0. 0.]
# Node 628: Class Counts = [0. 1. 0. 0.]
# Node 629: Class Counts = [3. 0. 0. 0.]
# Node 630: Class Counts = [0. 0. 0. 2.]
# Node 632: Class Counts = [0. 0. 1. 0.]
# Node 634: Class Counts = [0. 0. 0. 5.]
# Node 636: Class Counts = [0. 1. 0. 0.]
# Node 637: Class Counts = [0. 0. 0. 1.]
# Node 640: Class Counts = [0. 0. 1. 0.]
# Node 641: Class Counts = [0. 0. 0. 2.]
# Node 645: Class Counts = [0. 5. 0. 0.]
# Node 646: Class Counts = [0. 1. 1. 0.]
# Node 647: Class Counts = [0. 0. 1. 0.]
# Node 648: Class Counts = [0. 0. 2. 0.]
# Node 649: Class Counts = [0. 5. 0. 0.]
# Node 651: Class Counts = [0. 0. 1. 0.]
# Node 652: Class Counts = [4. 0. 0. 0.]
# Node 662: Class Counts = [ 0. 14.  0.  0.]
# Node 665: Class Counts = [ 0. 15.  3.  0.]
# Node 666: Class Counts = [0. 1. 3. 0.]
# Node 667: Class Counts = [0. 7. 0. 0.]
# Node 669: Class Counts = [ 0. 33.  0.  0.]
# Node 671: Class Counts = [0. 2. 0. 0.]
# Node 672: Class Counts = [0. 0. 1. 0.]
# Node 673: Class Counts = [0. 0. 0. 1.]
# Node 679: Class Counts = [ 0. 55. 35.  0.]
# Node 680: Class Counts = [0. 2. 2. 1.]
# Node 682: Class Counts = [0. 0. 5. 0.]
# Node 683: Class Counts = [ 0. 17. 15.  3.]
# Node 684: Class Counts = [0. 8. 0. 0.]
# Node 686: Class Counts = [0. 0. 0. 2.]
# Node 687: Class Counts = [0. 3. 0. 0.]
# Node 692: Class Counts = [1. 0. 0. 0.]
# Node 693: Class Counts = [0. 1. 0. 0.]
# Node 694: Class Counts = [ 0. 14.  0.  0.]
# Node 696: Class Counts = [0. 0. 2. 0.]
# Node 698: Class Counts = [ 1. 44. 13.  0.]
# Node 699: Class Counts = [2. 8. 1. 0.]
# Node 702: Class Counts = [0. 0. 1. 0.]
# Node 704: Class Counts = [0. 1. 0. 0.]
# Node 705: Class Counts = [0. 0. 1. 0.]
# Node 707: Class Counts = [2. 0. 0. 0.]
# Node 708: Class Counts = [0. 0. 0. 1.]
# Node 715: Class Counts = [0. 7. 0. 0.]
# Node 716: Class Counts = [0. 1. 4. 0.]
# Node 718: Class Counts = [ 0. 29.  4.  0.]
# Node 719: Class Counts = [ 0. 69.  1.  0.]
# Node 721: Class Counts = [0. 1. 0. 0.]
# Node 723: Class Counts = [0. 0. 4. 0.]
# Node 724: Class Counts = [0. 1. 0. 0.]
# Node 726: Class Counts = [0. 3. 0. 0.]
# Node 727: Class Counts = [2. 0. 0. 0.]
# Node 730: Class Counts = [  0. 271.   0.   0.]
# Node 733: Class Counts = [  3. 669.  12.   0.]
# Node 734: Class Counts = [   5. 2073.   23.   12.]
# Node 735: Class Counts = [  0. 250.   0.   0.]
# Node 739: Class Counts = [  0. 236.   1.   0.]
# Node 740: Class Counts = [ 0. 50.  2.  0.]
# Node 742: Class Counts = [0. 4. 2. 0.]
# Node 743: Class Counts = [  3. 184.   3.   0.]
# Node 746: Class Counts = [ 1. 16.  0.  0.]
# Node 747: Class Counts = [1. 0. 0. 0.]
# Node 749: Class Counts = [1. 2. 0. 0.]
# Node 750: Class Counts = [0. 0. 2. 0.]
# Node 756: Class Counts = [ 19. 345.   5.   0.]
# Node 757: Class Counts = [0. 4. 2. 0.]
# Node 759: Class Counts = [ 0. 30.  3.  0.]
# Node 760: Class Counts = [0. 2. 3. 0.]
# Node 763: Class Counts = [ 11. 604.   2.   0.]
# Node 764: Class Counts = [  0. 536.   5.   0.]
# Node 766: Class Counts = [ 19. 668.   0.   2.]
# Node 767: Class Counts = [ 14. 187.   2.   0.]
# Node 770: Class Counts = [ 0. 18.  0.  0.]
# Node 772: Class Counts = [29. 45.  0.  0.]
# Node 773: Class Counts = [ 1. 17.  0.  0.]
# Node 776: Class Counts = [ 0. 10.  3.  0.]
# Node 777: Class Counts = [ 1. 54.  0.  1.]
# Node 779: Class Counts = [0. 0. 0. 3.]
# Node 780: Class Counts = [0. 1. 1. 0.]
# Node 785: Class Counts = [0. 8. 2. 0.]
# Node 786: Class Counts = [3. 5. 1. 0.]
# Node 787: Class Counts = [0. 0. 0. 2.]
# Node 790: Class Counts = [  8. 106.   7.   2.]
# Node 791: Class Counts = [  12. 1082.   18.   10.]
# Node 793: Class Counts = [  10. 1420.   59.   11.]
# Node 794: Class Counts = [ 2. 90. 15.  0.]
# Node 798: Class Counts = [  8. 110.   2.   0.]
# Node 799: Class Counts = [2. 1. 0. 0.]
# Node 800: Class Counts = [0. 0. 2. 0.]
# Node 803: Class Counts = [3. 9. 2. 1.]
# Node 804: Class Counts = [  5. 100.   4.   4.]
# Node 806: Class Counts = [ 0. 64.  6.  0.]
# Node 807: Class Counts = [ 0. 67. 20.  2.]
# Node 812: Class Counts = [0. 0. 2. 0.]
# Node 816: Class Counts = [ 0. 12.  0.  0.]
# Node 817: Class Counts = [1. 0. 1. 0.]
# Node 819: Class Counts = [  0. 216.   5.   0.]
# Node 820: Class Counts = [ 0. 97.  0.  0.]
# Node 821: Class Counts = [1. 0. 0. 0.]
# Node 826: Class Counts = [0. 2. 1. 0.]
# Node 827: Class Counts = [ 0. 13.  0.  0.]
# Node 829: Class Counts = [4. 1. 1. 0.]
# Node 830: Class Counts = [ 2. 24. 10.  0.]
# Node 833: Class Counts = [ 43. 803.  12.   1.]
# Node 834: Class Counts = [0. 0. 0. 1.]
# Node 836: Class Counts = [  6. 133.   0.   0.]
# Node 837: Class Counts = [ 34. 224.   8.   8.]
# Node 841: Class Counts = [ 6. 18.  2.  0.]
# Node 842: Class Counts = [ 14. 200.   2.   3.]
# Node 844: Class Counts = [21. 66.  5.  1.]
# Node 845: Class Counts = [ 0. 25.  1.  1.]
# Node 848: Class Counts = [18. 90.  3.  0.]
# Node 849: Class Counts = [24. 41.  1.  0.]
# Node 851: Class Counts = [2. 8. 0. 0.]
# Node 852: Class Counts = [ 0. 15.  8.  0.]
# Node 858: Class Counts = [ 3. 37.  0.  0.]
# Node 859: Class Counts = [0. 0. 1. 0.]
# Node 861: Class Counts = [ 0. 72.  0.  0.]
# Node 862: Class Counts = [ 0. 16.  0.  1.]
# Node 865: Class Counts = [ 0. 24.  4.  1.]
# Node 866: Class Counts = [0. 1. 4. 0.]
# Node 868: Class Counts = [  3. 242.   9.   1.]
# Node 869: Class Counts = [ 0. 13.  5.  0.]
# Node 873: Class Counts = [0. 8. 1. 0.]
# Node 874: Class Counts = [0. 2. 3. 0.]
# Node 876: Class Counts = [1. 0. 0. 0.]
# Node 877: Class Counts = [ 0. 11.  0.  0.]
# Node 880: Class Counts = [0. 3. 3. 0.]
# Node 881: Class Counts = [0. 0. 4. 0.]
# Node 883: Class Counts = [1. 0. 3. 0.]
# Node 884: Class Counts = [2. 4. 1. 0.]
# Node 888: Class Counts = [ 0. 24.  0.  0.]
# Node 889: Class Counts = [0. 0. 0. 1.]
# Node 892: Class Counts = [4. 3. 0. 0.]
# Node 893: Class Counts = [7. 0. 0. 0.]
# Node 895: Class Counts = [0. 1. 0. 2.]
# Node 896: Class Counts = [ 0. 16.  0.  1.]
# Node 900: Class Counts = [ 0. 54.  2.  1.]
# Node 901: Class Counts = [ 0. 34.  8.  0.]
# Node 903: Class Counts = [ 1. 41. 16.  1.]
# Node 904: Class Counts = [0. 0. 5. 0.]
# Node 907: Class Counts = [ 5. 11. 11.  0.]
# Node 908: Class Counts = [0. 9. 6. 0.]
# Node 909: Class Counts = [0. 4. 0. 0.]
# Node 916: Class Counts = [4. 6. 0. 0.]
# Node 917: Class Counts = [0. 7. 1. 0.]
# Node 919: Class Counts = [2. 2. 0. 0.]
# Node 920: Class Counts = [13.  0.  0.  0.]
# Node 921: Class Counts = [ 0. 14.  0.  0.]
# Node 923: Class Counts = [26.  0.  0.  0.]
# Node 925: Class Counts = [10.  0.  0.  0.]
# Node 927: Class Counts = [5. 0. 0. 0.]
# Node 928: Class Counts = [0. 2. 0. 0.]
# Node 930: Class Counts = [ 0. 17.  0.  0.]
# Node 932: Class Counts = [13.  0.  0.  0.]
# Node 935: Class Counts = [2. 5. 2. 0.]
# Node 936: Class Counts = [0. 7. 0. 0.]
# Node 938: Class Counts = [0. 5. 0. 0.]
# Node 939: Class Counts = [17. 15.  0.  0.]
# Node 945: Class Counts = [0. 2. 0. 0.]
# Node 946: Class Counts = [0. 0. 1. 0.]
# Node 948: Class Counts = [4. 9. 0. 0.]
# Node 949: Class Counts = [0. 7. 0. 0.]
# Node 950: Class Counts = [2. 0. 0. 0.]
# Node 953: Class Counts = [0. 7. 0. 0.]
# Node 955: Class Counts = [0. 3. 0. 0.]
# Node 956: Class Counts = [2. 1. 0. 0.]
# Node 958: Class Counts = [ 0. 32.  0.  0.]
# Node 960: Class Counts = [ 0. 25.  1.  0.]
# Node 961: Class Counts = [0. 5. 2. 0.]
# Node 964: Class Counts = [0. 8. 0. 0.]
# Node 965: Class Counts = [2. 0. 0. 0.]
# Node 969: Class Counts = [ 0. 15.  2.  0.]
# Node 970: Class Counts = [0. 0. 1. 0.]
# Node 972: Class Counts = [0. 0. 3. 0.]
# Node 973: Class Counts = [0. 1. 0. 0.]
# Node 975: Class Counts = [0. 2. 0. 0.]
# Node 977: Class Counts = [1. 5. 6. 0.]
# Node 978: Class Counts = [0. 0. 7. 0.]
# Node 984: Class Counts = [ 0. 11.  0.  0.]
# Node 988: Class Counts = [0. 0. 0. 1.]
# Node 989: Class Counts = [0. 0. 1. 0.]
# Node 990: Class Counts = [0. 0. 3. 0.]
# Node 991: Class Counts = [0. 1. 0. 0.]
# Node 994: Class Counts = [ 0. 17.  0.  0.]
# Node 997: Class Counts = [0. 0. 1. 0.]
# Node 998: Class Counts = [ 0. 10.  1.  0.]
# Node 1000: Class Counts = [0. 0. 1. 0.]
# Node 1001: Class Counts = [1. 0. 0. 0.]
# Node 1005: Class Counts = [ 0. 61.  0.  1.]
# Node 1006: Class Counts = [  0. 782.   0.   0.]
# Node 1008: Class Counts = [ 0. 10.  0.  0.]
# Node 1009: Class Counts = [0. 0. 0. 1.]
# Node 1012: Class Counts = [ 0. 14.  0.  2.]
# Node 1013: Class Counts = [ 0. 80.  3.  0.]
# Node 1015: Class Counts = [  0. 163.   0.   0.]
# Node 1016: Class Counts = [ 1. 27.  0.  0.]
# Node 1022: Class Counts = [  0. 432.  12.   0.]
# Node 1023: Class Counts = [  0. 179.   1.   1.]
# Node 1025: Class Counts = [  19. 1716.   72.   20.]
# Node 1026: Class Counts = [  2. 233.  26.   3.]
# Node 1029: Class Counts = [ 0. 45.  0.  0.]
# Node 1030: Class Counts = [  8. 360.  29.   4.]
# Node 1032: Class Counts = [ 5. 70. 15.  7.]
# Node 1033: Class Counts = [ 0. 14.  9.  0.]
# Node 1037: Class Counts = [  0. 217.   0.   0.]
# Node 1038: Class Counts = [ 0. 34.  2.  0.]
# Node 1040: Class Counts = [ 1. 53.  2.  0.]
# Node 1041: Class Counts = [0. 0. 3. 0.]
# Node 1044: Class Counts = [ 0. 93.  2.  2.]
# Node 1045: Class Counts = [  32. 1280.  157.   16.]
# Node 1047: Class Counts = [1. 0. 0. 0.]
# Node 1048: Class Counts = [0. 0. 3. 0.]
# Node 1053: Class Counts = [0. 5. 4. 0.]
# Node 1054: Class Counts = [ 5. 28.  1.  0.]
# Node 1056: Class Counts = [ 0. 35.  6.  0.]
# Node 1057: Class Counts = [ 5. 66. 42.  3.]
# Node 1060: Class Counts = [ 2. 96. 29.  1.]
# Node 1061: Class Counts = [  0. 100.  11.   0.]
# Node 1063: Class Counts = [ 12. 143.  17.   0.]
# Node 1064: Class Counts = [  3. 123.   9.   3.]
# Node 1068: Class Counts = [ 25. 798.  71.  21.]
# Node 1069: Class Counts = [  42. 1663.   76.   11.]
# Node 1071: Class Counts = [ 27. 456.  30.  17.]
# Node 1072: Class Counts = [ 5. 49. 30.  0.]
# Node 1075: Class Counts = [ 61. 740. 109.  11.]
# Node 1076: Class Counts = [ 30. 620.  45.   6.]
# Node 1078: Class Counts = [ 3. 97.  4.  9.]
# Node 1079: Class Counts = [ 0. 15.  8.  2.]
# Node 1085: Class Counts = [ 0. 22.  0.  0.]
# Node 1087: Class Counts = [0. 2. 0. 0.]
# Node 1088: Class Counts = [1. 0. 0. 0.]
# Node 1090: Class Counts = [  0. 395.   0.   0.]
# Node 1092: Class Counts = [ 0. 48.  2.  0.]
# Node 1093: Class Counts = [ 0. 91.  0.  0.]
# Node 1097: Class Counts = [0. 5. 0. 0.]
# Node 1098: Class Counts = [0. 2. 0. 1.]
# Node 1099: Class Counts = [ 0. 45.  0.  0.]
# Node 1101: Class Counts = [1. 0. 0. 0.]
# Node 1103: Class Counts = [2. 3. 0. 0.]
# Node 1104: Class Counts = [ 1. 52.  0.  0.]
# Node 1108: Class Counts = [0. 0. 1. 0.]
# Node 1110: Class Counts = [ 1. 14.  0.  0.]
# Node 1111: Class Counts = [  0. 381.   5.   0.]
# Node 1114: Class Counts = [  4. 113.   2.   2.]
# Node 1115: Class Counts = [  0. 123.   4.   0.]
# Node 1117: Class Counts = [ 0. 57.  0.  0.]
# Node 1118: Class Counts = [ 8. 57.  0.  1.]
# Node 1120: Class Counts = [ 0. 27.  0.  0.]
# Node 1123: Class Counts = [ 0. 90.  6.  4.]
# Node 1124: Class Counts = [ 0. 53.  8.  0.]
# Node 1126: Class Counts = [0. 2. 0. 2.]
# Node 1127: Class Counts = [ 0. 18.  0.  0.]
# Node 1133: Class Counts = [  0. 181.   0.   0.]
# Node 1134: Class Counts = [ 0. 28.  2.  0.]
# Node 1136: Class Counts = [ 34. 998.  60.   8.]
# Node 1137: Class Counts = [ 50. 913. 105.  17.]
# Node 1140: Class Counts = [ 13. 539. 103.   7.]
# Node 1141: Class Counts = [ 31. 293. 107.   9.]
# Node 1143: Class Counts = [ 18. 354.  24.   3.]
# Node 1144: Class Counts = [ 0. 70. 11.  0.]
# Node 1148: Class Counts = [ 13. 531. 118.   7.]
# Node 1149: Class Counts = [ 0. 43. 12. 12.]
# Node 1151: Class Counts = [  8. 244.  80.   4.]
# Node 1152: Class Counts = [ 68. 425. 206.  30.]
# Node 1155: Class Counts = [ 19. 101.   9.   0.]
# Node 1156: Class Counts = [ 32. 423.  49.  12.]
# Node 1158: Class Counts = [ 0. 23. 10.  1.]
# Node 1159: Class Counts = [ 5. 23. 10.  3.]
# Node 1164: Class Counts = [ 1.  2. 10.  1.]
# Node 1165: Class Counts = [ 14. 125.  75.   7.]
# Node 1167: Class Counts = [ 1. 31.  2.  3.]
# Node 1168: Class Counts = [ 12. 111.  40.   2.]
# Node 1171: Class Counts = [ 9. 30. 10.  2.]
# Node 1172: Class Counts = [13. 56. 51.  2.]
# Node 1174: Class Counts = [ 0.  8. 14.  0.]
# Node 1175: Class Counts = [1. 0. 4. 0.]
# Node 1177: Class Counts = [0. 0. 0. 2.]
# Node 1179: Class Counts = [ 0. 14.  0.  0.]
# Node 1181: Class Counts = [0. 1. 0. 1.]
# Node 1182: Class Counts = [0. 1. 0. 0.]
# Node 1188: Class Counts = [0. 6. 0. 0.]
# Node 1189: Class Counts = [0. 0. 1. 0.]
# Node 1190: Class Counts = [0. 0. 1. 0.]
# Node 1191: Class Counts = [ 0. 39.  0.  0.]
# Node 1197: Class Counts = [0. 4. 2. 1.]
# Node 1198: Class Counts = [0. 0. 1. 3.]
# Node 1199: Class Counts = [0. 3. 0. 0.]
# Node 1201: Class Counts = [0. 0. 4. 0.]
# Node 1202: Class Counts = [0. 0. 1. 2.]
# Node 1203: Class Counts = [0. 4. 0. 0.]
# Node 1206: Class Counts = [ 0. 22.  0.  0.]
# Node 1209: Class Counts = [0. 0. 6. 0.]
# Node 1210: Class Counts = [0. 1. 0. 0.]
# Node 1212: Class Counts = [0. 6. 0. 1.]
# Node 1213: Class Counts = [ 0. 12.  4.  0.]
# Node 1217: Class Counts = [ 0.  5. 13.  0.]
# Node 1218: Class Counts = [ 1. 32. 12.  0.]
# Node 1220: Class Counts = [ 0.  2. 23.  0.]
# Node 1221: Class Counts = [ 0. 25. 29.  1.]
# Node 1224: Class Counts = [0. 5. 0. 0.]
# Node 1225: Class Counts = [0. 9. 9. 0.]
# Node 1226: Class Counts = [ 0. 15.  0.  0.]
# Node 1229: Class Counts = [ 0. 53.  0.  0.]
# Node 1234: Class Counts = [ 0. 20. 13.  0.]
# Node 1235: Class Counts = [0. 0. 6. 0.]
# Node 1237: Class Counts = [0. 2. 0. 1.]
# Node 1238: Class Counts = [0. 6. 0. 0.]
# Node 1241: Class Counts = [  1. 173.  32.   0.]
# Node 1242: Class Counts = [ 26. 387.  64.   4.]
# Node 1244: Class Counts = [0. 3. 0. 0.]
# Node 1245: Class Counts = [0. 0. 0. 2.]
# Node 1249: Class Counts = [ 1. 53.  6.  1.]
# Node 1250: Class Counts = [  6. 263. 107.   4.]
# Node 1252: Class Counts = [ 30. 290. 108.   3.]
# Node 1253: Class Counts = [ 0. 86. 19.  0.]
# Node 1255: Class Counts = [0. 7. 0. 0.]
# Node 1257: Class Counts = [ 0. 12.  9.  0.]
# Node 1258: Class Counts = [ 5.  5. 16.  0.]
# Node 1264: Class Counts = [0. 0. 9. 0.]
# Node 1265: Class Counts = [0. 1. 0. 0.]
# Node 1267: Class Counts = [0. 7. 0. 0.]
# Node 1268: Class Counts = [ 0. 11.  9.  0.]
# Node 1271: Class Counts = [ 0. 29.  0.  0.]
# Node 1272: Class Counts = [ 4. 11.  0.  0.]
# Node 1274: Class Counts = [ 3. 84.  6.  3.]
# Node 1275: Class Counts = [ 41. 386.  90.   8.]
# Node 1279: Class Counts = [ 43. 318.  48.   0.]
# Node 1280: Class Counts = [ 1. 24.  0.  0.]
# Node 1281: Class Counts = [0. 0. 2. 0.]
# Node 1284: Class Counts = [0. 7. 2. 0.]
# Node 1285: Class Counts = [ 1. 23.  0.  1.]
# Node 1287: Class Counts = [ 8. 13.  0.  0.]
# Node 1288: Class Counts = [0. 9. 0. 0.]
# Node 1290: Class Counts = [4. 0. 0. 0.]
# Node 1291: Class Counts = [0. 0. 3. 0.]
# Node 1299: Class Counts = [  0. 422.   0.   0.]
# Node 1302: Class Counts = [1. 5. 2. 0.]
# Node 1303: Class Counts = [   9. 1115.   17.    2.]
# Node 1305: Class Counts = [  0. 452.  19.   3.]
# Node 1306: Class Counts = [ 1. 76.  7.  3.]
# Node 1310: Class Counts = [  0. 500.   4.   1.]
# Node 1311: Class Counts = [ 3. 64.  1.  0.]
# Node 1313: Class Counts = [ 0. 99.  0.  3.]
# Node 1314: Class Counts = [   0. 1173.    2.    2.]
# Node 1317: Class Counts = [   6. 1072.    6.    5.]
# Node 1318: Class Counts = [2. 7. 0. 0.]
# Node 1320: Class Counts = [  1. 786.  14.   0.]
# Node 1321: Class Counts = [ 2. 15.  3.  0.]
# Node 1326: Class Counts = [0. 3. 0. 1.]
# Node 1327: Class Counts = [0. 0. 3. 0.]
# Node 1329: Class Counts = [0. 0. 1. 0.]
# Node 1330: Class Counts = [ 0. 15.  0.  1.]
# Node 1332: Class Counts = [0. 0. 5. 0.]
# Node 1334: Class Counts = [0. 0. 0. 1.]
# Node 1335: Class Counts = [0. 1. 0. 0.]
# Node 1339: Class Counts = [0. 7. 0. 1.]
# Node 1340: Class Counts = [  9. 918.  10.   0.]
# Node 1342: Class Counts = [ 7. 91.  1.  0.]
# Node 1343: Class Counts = [0. 0. 2. 0.]
# Node 1346: Class Counts = [ 0. 30.  1.  2.]
# Node 1347: Class Counts = [0. 0. 4. 0.]
# Node 1349: Class Counts = [  7. 197.  15.   0.]
# Node 1350: Class Counts = [ 10. 871.  26.   4.]
# Node 1354: Class Counts = [0. 0. 1. 0.]
# Node 1357: Class Counts = [  1. 173.   2.   0.]
# Node 1358: Class Counts = [  0. 222.   0.   0.]
# Node 1360: Class Counts = [ 0. 14.  0.  0.]
# Node 1361: Class Counts = [0. 6. 2. 0.]
# Node 1365: Class Counts = [  0. 162.   8.   0.]
# Node 1366: Class Counts = [  5. 165.   5.   2.]
# Node 1368: Class Counts = [0. 0. 2. 0.]
# Node 1369: Class Counts = [0. 0. 0. 1.]
# Node 1372: Class Counts = [ 14. 308.   6.   0.]
# Node 1373: Class Counts = [ 9. 26.  0.  0.]
# Node 1374: Class Counts = [  0. 187.   0.   0.]
# Node 1379: Class Counts = [0. 1. 0. 2.]
# Node 1380: Class Counts = [ 0. 11.  0.  1.]
# Node 1382: Class Counts = [0. 3. 4. 0.]
# Node 1383: Class Counts = [ 0. 10.  1.  0.]
# Node 1386: Class Counts = [ 0. 24.  1.  0.]
# Node 1387: Class Counts = [ 0. 33.  0.  0.]
# Node 1389: Class Counts = [ 0. 14.  0.  0.]
# Node 1390: Class Counts = [ 0. 16.  4.  0.]
# Node 1394: Class Counts = [ 0. 58.  7.  0.]
# Node 1395: Class Counts = [0. 9. 3. 2.]
# Node 1397: Class Counts = [0. 1. 1. 0.]
# Node 1398: Class Counts = [3. 7. 0. 0.]
# Node 1401: Class Counts = [ 7. 15.  5.  2.]
# Node 1402: Class Counts = [ 0.  5. 11.  0.]
# Node 1404: Class Counts = [ 0. 17.  0.  1.]
# Node 1405: Class Counts = [2. 2. 1. 0.]
# Node 1412: Class Counts = [  6. 256.  17.   3.]
# Node 1413: Class Counts = [ 0. 50.  3.  7.]
# Node 1415: Class Counts = [ 4. 55.  2.  0.]
# Node 1416: Class Counts = [  0. 169.   9.   0.]
# Node 1419: Class Counts = [0. 0. 5. 0.]
# Node 1420: Class Counts = [0. 1. 0. 0.]
# Node 1422: Class Counts = [ 3. 32.  4.  0.]
# Node 1423: Class Counts = [0. 7. 4. 2.]
# Node 1427: Class Counts = [  2. 103.   6.   4.]
# Node 1428: Class Counts = [  3. 958.  25.   6.]
# Node 1430: Class Counts = [  26. 1891.   18.   12.]
# Node 1431: Class Counts = [  16. 1044.   15.    0.]
# Node 1434: Class Counts = [ 106. 3609.   56.   22.]
# Node 1435: Class Counts = [  3. 203.  14.   3.]
# Node 1437: Class Counts = [  10. 1425.   61.    9.]
# Node 1438: Class Counts = [ 29. 605.  26.   5.]
# Node 1443: Class Counts = [  6. 505.  25.   3.]
# Node 1444: Class Counts = [ 2. 68. 16.  1.]
# Node 1446: Class Counts = [0. 2. 2. 0.]
# Node 1447: Class Counts = [  0. 248.   4.   3.]
# Node 1450: Class Counts = [ 0. 13. 13.  0.]
# Node 1451: Class Counts = [ 0. 43.  9.  1.]
# Node 1453: Class Counts = [3. 0. 0. 0.]
# Node 1454: Class Counts = [0. 4. 0. 0.]
# Node 1458: Class Counts = [  5. 846.  26.  19.]
# Node 1459: Class Counts = [  9. 810.   8.   3.]
# Node 1461: Class Counts = [ 9. 65.  5.  1.]
# Node 1462: Class Counts = [  3. 126.   1.   0.]
# Node 1465: Class Counts = [  70. 1289.   64.   11.]
# Node 1466: Class Counts = [ 236. 7330.  228.   62.]
# Node 1468: Class Counts = [ 188. 2837.   91.   37.]
# Node 1469: Class Counts = [ 15. 149.  23.   7.]
# Node 1475: Class Counts = [  0. 136.   4.   0.]
# Node 1476: Class Counts = [  6. 162.   4.   0.]
# Node 1478: Class Counts = [ 1. 16.  0.  5.]
# Node 1479: Class Counts = [  4. 400.  12.   6.]
# Node 1482: Class Counts = [ 63. 480.  16.   8.]
# Node 1483: Class Counts = [ 215. 3812.   99.   48.]
# Node 1485: Class Counts = [  0. 163.   6.   0.]
# Node 1486: Class Counts = [ 0. 67.  0.  0.]
# Node 1490: Class Counts = [0. 1. 0. 2.]
# Node 1491: Class Counts = [ 29. 828.  47.   7.]
# Node 1493: Class Counts = [ 0. 83.  1.  2.]
# Node 1494: Class Counts = [0. 4. 4. 3.]
# Node 1497: Class Counts = [  5. 126.   9.   1.]
# Node 1498: Class Counts = [0. 2. 0. 2.]
# Node 1500: Class Counts = [4. 0. 0. 1.]
# Node 1501: Class Counts = [11. 50. 11.  2.]
# Node 1506: Class Counts = [ 6. 11.  7.  0.]
# Node 1507: Class Counts = [33. 75.  3.  0.]
# Node 1509: Class Counts = [0. 0. 0. 1.]
# Node 1510: Class Counts = [0. 0. 3. 0.]
# Node 1513: Class Counts = [ 0. 27.  0.  0.]
# Node 1514: Class Counts = [0. 1. 0. 1.]
# Node 1516: Class Counts = [3. 1. 0. 0.]
# Node 1517: Class Counts = [ 0. 10.  1.  0.]
# Node 1521: Class Counts = [0. 6. 0. 0.]
# Node 1522: Class Counts = [ 6. 12.  0.  1.]
# Node 1524: Class Counts = [  1. 136.   0.   2.]
# Node 1525: Class Counts = [  9. 135.   7.   1.]
# Node 1528: Class Counts = [ 6. 37.  9.  0.]
# Node 1529: Class Counts = [3. 2. 0. 0.]
# Node 1530: Class Counts = [0. 0. 3. 0.]
# Node 1537: Class Counts = [ 0. 79.  0.  0.]
# Node 1539: Class Counts = [ 1. 57.  2.  0.]
# Node 1540: Class Counts = [1. 0. 0. 0.]
# Node 1543: Class Counts = [ 1. 98.  2.  0.]
# Node 1544: Class Counts = [3. 1. 0. 0.]
# Node 1546: Class Counts = [ 4. 80.  2.  0.]
# Node 1547: Class Counts = [27. 96.  3.  0.]
# Node 1551: Class Counts = [0. 3. 1. 1.]
# Node 1552: Class Counts = [  2. 184.   0.   0.]
# Node 1554: Class Counts = [  3. 102.   1.   3.]
# Node 1555: Class Counts = [ 0. 46.  6.  3.]
# Node 1558: Class Counts = [0. 1. 2. 0.]
# Node 1559: Class Counts = [ 0. 15.  0.  0.]
# Node 1561: Class Counts = [0. 3. 0. 0.]
# Node 1562: Class Counts = [7. 3. 0. 0.]
# Node 1567: Class Counts = [ 8. 33.  6.  2.]
# Node 1568: Class Counts = [4. 1. 0. 0.]
# Node 1570: Class Counts = [ 3. 49.  0.  1.]
# Node 1571: Class Counts = [ 14. 123.  17.   0.]
# Node 1574: Class Counts = [0. 3. 0. 1.]
# Node 1575: Class Counts = [35. 11.  1.  0.]
# Node 1577: Class Counts = [ 2. 31.  2.  2.]
# Node 1578: Class Counts = [5. 2. 0. 0.]
# Node 1582: Class Counts = [ 19. 248.   8.   0.]
# Node 1583: Class Counts = [ 38. 168.   1.   0.]
# Node 1585: Class Counts = [ 0. 86.  1.  2.]
# Node 1586: Class Counts = [ 12. 113.   3.   4.]
# Node 1589: Class Counts = [ 0. 16.  1.  0.]
# Node 1590: Class Counts = [0. 3. 0. 5.]
# Node 1592: Class Counts = [4. 1. 0. 0.]
# Node 1593: Class Counts = [ 3. 10.  1.  1.]
# Node 1597: Class Counts = [0. 0. 1. 0.]
# Node 1599: Class Counts = [ 0. 60.  0.  0.]
# Node 1601: Class Counts = [0. 6. 1. 2.]
# Node 1602: Class Counts = [ 0. 29.  0.  0.]
# Node 1606: Class Counts = [ 0. 88.  0.  0.]
# Node 1607: Class Counts = [ 0. 14.  1.  0.]
# Node 1609: Class Counts = [ 1. 99.  0.  1.]
# Node 1610: Class Counts = [1. 4. 0. 0.]
# Node 1613: Class Counts = [10. 94.  0.  0.]
# Node 1614: Class Counts = [ 0. 23.  0.  0.]
# Node 1615: Class Counts = [ 0. 38.  0.  0.]
# Node 1618: Class Counts = [ 0. 42.  0.  0.]
# Node 1621: Class Counts = [0. 0. 1. 0.]
# Node 1622: Class Counts = [0. 2. 1. 0.]
# Node 1624: Class Counts = [ 0. 69.  1.  0.]
# Node 1625: Class Counts = [ 0. 47.  5.  0.]
# Node 1626: Class Counts = [1. 0. 0. 0.]
# Node 1631: Class Counts = [0. 4. 0. 0.]
# Node 1634: Class Counts = [0. 0. 2. 0.]
# Node 1635: Class Counts = [1. 0. 0. 1.]
# Node 1637: Class Counts = [1. 2. 0. 0.]
# Node 1638: Class Counts = [ 0. 11. 11.  0.]
# Node 1640: Class Counts = [ 0. 27.  0.  0.]
# Node 1643: Class Counts = [ 0. 10.  0.  0.]
# Node 1644: Class Counts = [1. 2. 0. 0.]
# Node 1646: Class Counts = [0. 8. 4. 0.]
# Node 1647: Class Counts = [0. 1. 2. 1.]
# Node 1652: Class Counts = [ 1. 18.  2.  0.]
# Node 1653: Class Counts = [ 0. 29.  0.  0.]
# Node 1655: Class Counts = [ 2. 10.  2.  0.]
# Node 1656: Class Counts = [0. 0. 2. 0.]
# Node 1657: Class Counts = [ 0. 20.  0.  0.]
# Node 1660: Class Counts = [0. 3. 0. 0.]
# Node 1661: Class Counts = [3. 0. 0. 0.]
# Node 1662: Class Counts = [0. 5. 0. 0.]
# Node 1666: Class Counts = [2. 0. 0. 0.]
# Node 1669: Class Counts = [ 0. 15.  3.  2.]
# Node 1670: Class Counts = [0. 0. 0. 2.]
# Node 1672: Class Counts = [0. 5. 0. 0.]
# Node 1673: Class Counts = [ 0.  3.  0. 12.]
# Node 1676: Class Counts = [2. 0. 0. 0.]
# Node 1678: Class Counts = [1. 0. 0. 0.]
# Node 1679: Class Counts = [0. 3. 0. 0.]
# Node 1682: Class Counts = [ 0. 20.  3.  0.]
# Node 1683: Class Counts = [0. 3. 5. 0.]
# Node 1685: Class Counts = [0. 1. 1. 1.]
# Node 1686: Class Counts = [2. 7. 0. 0.]
# Node 1691: Class Counts = [ 2. 22.  2.  0.]
# Node 1692: Class Counts = [ 1. 23.  0.  0.]
# Node 1694: Class Counts = [1. 0. 0. 0.]
# Node 1695: Class Counts = [2. 6. 0. 0.]
# Node 1698: Class Counts = [4. 2. 1. 0.]
# Node 1699: Class Counts = [ 8. 12.  0.  0.]
# Node 1701: Class Counts = [1. 0. 2. 0.]
# Node 1702: Class Counts = [0. 6. 2. 0.]
# Node 1704: Class Counts = [0. 0. 0. 2.]
# Node 1707: Class Counts = [2. 3. 0. 1.]
# Node 1708: Class Counts = [1. 0. 2. 0.]
# Node 1710: Class Counts = [2. 0. 0. 0.]
# Node 1711: Class Counts = [ 5. 11.  0.  0.]
# Node 1719: Class Counts = [ 0. 34.  0.  0.]
# Node 1721: Class Counts = [1. 0. 0. 0.]
# Node 1722: Class Counts = [0. 3. 0. 0.]
# Node 1724: Class Counts = [  0. 307.   0.   0.]
# Node 1726: Class Counts = [ 0. 64.  0.  0.]
# Node 1727: Class Counts = [ 1. 15.  0.  0.]
# Node 1731: Class Counts = [0. 6. 2. 0.]
# Node 1732: Class Counts = [ 0. 13.  0.  0.]
# Node 1734: Class Counts = [0. 6. 1. 0.]
# Node 1735: Class Counts = [  0. 374.   3.   0.]
# Node 1738: Class Counts = [ 0. 18.  0.  0.]
# Node 1739: Class Counts = [1. 1. 0. 0.]
# Node 1740: Class Counts = [  0. 185.   0.   0.]
# Node 1745: Class Counts = [  3. 385.   1.   0.]
# Node 1746: Class Counts = [0. 6. 1. 0.]
# Node 1748: Class Counts = [  5. 430.  10.   3.]
# Node 1749: Class Counts = [ 4. 68.  0.  0.]
# Node 1752: Class Counts = [ 3. 11.  0.  0.]
# Node 1753: Class Counts = [0. 3. 2. 0.]
# Node 1755: Class Counts = [  4. 188.   0.   3.]
# Node 1756: Class Counts = [2. 7. 1. 0.]
# Node 1759: Class Counts = [ 0. 43.  0.  0.]
# Node 1761: Class Counts = [0. 1. 0. 0.]
# Node 1762: Class Counts = [1. 0. 0. 0.]
# Node 1765: Class Counts = [ 0. 20.  6.  1.]
# Node 1766: Class Counts = [ 0. 27.  0.  1.]
# Node 1768: Class Counts = [1. 0. 0. 0.]
# Node 1769: Class Counts = [0. 3. 2. 0.]
# Node 1773: Class Counts = [ 0. 68.  0.  0.]
# Node 1776: Class Counts = [1. 1. 0. 0.]
# Node 1777: Class Counts = [ 1. 90.  0.  0.]
# Node 1779: Class Counts = [ 2. 45.  0.  0.]
# Node 1780: Class Counts = [ 7. 72.  6.  0.]
# Node 1782: Class Counts = [  0. 134.   0.   0.]
# Node 1785: Class Counts = [0. 3. 0. 0.]
# Node 1786: Class Counts = [0. 1. 1. 0.]
# Node 1787: Class Counts = [ 0. 22.  0.  0.]
# Node 1792: Class Counts = [ 2. 28.  0.  1.]
# Node 1793: Class Counts = [ 0. 18.  1.  0.]
# Node 1795: Class Counts = [1. 3. 0. 0.]
# Node 1796: Class Counts = [0. 0. 1. 1.]
# Node 1799: Class Counts = [ 0. 15.  1.  0.]
# Node 1800: Class Counts = [0. 0. 1. 0.]
# Node 1801: Class Counts = [0. 0. 2. 0.]
# Node 1804: Class Counts = [ 0. 25.  0.  0.]
# Node 1806: Class Counts = [0. 5. 0. 3.]
# Node 1807: Class Counts = [0. 4. 0. 0.]
# Node 1810: Class Counts = [ 11. 285.   4.   8.]
# Node 1811: Class Counts = [  9. 195.   0.   1.]
# Node 1813: Class Counts = [ 3. 12.  0.  0.]
# Node 1814: Class Counts = [0. 0. 1. 0.]
# Node 1821: Class Counts = [  6. 227.   8.   5.]
# Node 1822: Class Counts = [  0. 222.  11.   3.]
# Node 1824: Class Counts = [  5. 163.   0.   0.]
# Node 1825: Class Counts = [ 22. 671.  13.  12.]
# Node 1828: Class Counts = [  0. 288.   3.   0.]
# Node 1829: Class Counts = [ 0. 26.  4.  0.]
# Node 1831: Class Counts = [0. 3. 0. 0.]
# Node 1832: Class Counts = [0. 0. 0. 2.]
# Node 1836: Class Counts = [ 0. 43.  5.  0.]
# Node 1837: Class Counts = [  0. 107.   1.   1.]
# Node 1839: Class Counts = [0. 5. 0. 0.]
# Node 1840: Class Counts = [0. 0. 3. 0.]
# Node 1843: Class Counts = [ 12. 530.  23.   3.]
# Node 1844: Class Counts = [ 31. 411.  15.   6.]
# Node 1846: Class Counts = [  9. 260.  25.   3.]
# Node 1847: Class Counts = [0. 0. 0. 2.]
# Node 1852: Class Counts = [ 1. 70.  0.  3.]
# Node 1853: Class Counts = [  5. 289.   3.   0.]
# Node 1855: Class Counts = [ 4. 26.  2.  2.]
# Node 1856: Class Counts = [ 0. 78.  6.  2.]
# Node 1859: Class Counts = [ 0. 22.  2.  5.]
# Node 1860: Class Counts = [ 43. 895.  76.  14.]
# Node 1862: Class Counts = [ 0. 30.  0.  0.]
# Node 1863: Class Counts = [ 32. 176.  20.   5.]
# Node 1866: Class Counts = [ 0. 45.  0.  0.]
# Node 1868: Class Counts = [2. 0. 0. 3.]
# Node 1869: Class Counts = [0. 6. 2. 1.]
# Node 1872: Class Counts = [12. 88. 27. 10.]
# Node 1873: Class Counts = [11. 61. 10.  0.]
# Node 1875: Class Counts = [0. 3. 0. 5.]
# Node 1876: Class Counts = [0. 9. 1. 0.]
# Node 1880: Class Counts = [ 0. 74.  0.  0.]
# Node 1883: Class Counts = [ 36. 325.  38.   5.]
# Node 1884: Class Counts = [ 0. 54.  2.  1.]
# Node 1886: Class Counts = [0. 0. 0. 1.]
# Node 1887: Class Counts = [0. 0. 3. 0.]
# Node 1891: Class Counts = [ 0. 17.  0.  0.]
# Node 1892: Class Counts = [0. 9. 2. 2.]
# Node 1893: Class Counts = [1. 0. 0. 0.]
# Node 1896: Class Counts = [1. 3. 2. 1.]
# Node 1897: Class Counts = [ 0. 13.  9.  0.]
# Node 1899: Class Counts = [6. 2. 0. 0.]
# Node 1900: Class Counts = [6. 5. 8. 0.]
# Node 1905: Class Counts = [ 0. 11.  2.  0.]
# Node 1906: Class Counts = [0. 5. 0. 0.]
# Node 1907: Class Counts = [ 0. 17.  0.  0.]
# Node 1909: Class Counts = [0. 3. 0. 1.]
# Node 1910: Class Counts = [0. 2. 0. 0.]
# Node 1914: Class Counts = [17. 31. 22.  6.]
# Node 1915: Class Counts = [11. 24.  8.  0.]
# Node 1917: Class Counts = [0. 2. 0. 3.]
# Node 1918: Class Counts = [1. 0. 2. 1.]
# Node 1921: Class Counts = [ 6. 34.  6.  0.]
# Node 1922: Class Counts = [57. 89. 28.  2.]
# Node 1923: Class Counts = [ 0. 11.  0.  0.]
# Node 1930: Class Counts = [0. 0. 3. 0.]
# Node 1932: Class Counts = [0. 0. 0. 1.]
# Node 1933: Class Counts = [0. 0. 1. 0.]
# Node 1936: Class Counts = [  2. 124.  11.   2.]
# Node 1937: Class Counts = [ 0. 19.  9.  0.]
# Node 1939: Class Counts = [ 0. 37.  0.  4.]
# Node 1940: Class Counts = [1. 5. 0. 0.]
# Node 1944: Class Counts = [ 5. 56. 15.  2.]
# Node 1945: Class Counts = [ 0. 20.  1.  1.]
# Node 1947: Class Counts = [0. 0. 1. 1.]
# Node 1948: Class Counts = [ 8. 19.  0.  0.]
# Node 1951: Class Counts = [3. 2. 7. 3.]
# Node 1952: Class Counts = [ 1. 20. 14.  3.]
# Node 1954: Class Counts = [0. 1. 3. 0.]
# Node 1955: Class Counts = [ 4. 15.  2.  0.]
# Node 1958: Class Counts = [0. 0. 2. 0.]
# Node 1961: Class Counts = [0. 0. 0. 1.]
# Node 1962: Class Counts = [0. 1. 0. 0.]
# Node 1964: Class Counts = [ 0. 30.  9.  0.]
# Node 1965: Class Counts = [0. 2. 0. 1.]
# Node 1969: Class Counts = [11. 22.  3.  0.]
# Node 1970: Class Counts = [ 4. 41.  8.  0.]
# Node 1972: Class Counts = [ 6. 12. 12.  0.]
# Node 1973: Class Counts = [16. 31.  5.  3.]
# Node 1974: Class Counts = [ 0. 14.  0.  0.]
# Node 1978: Class Counts = [0. 0. 1. 0.]
# Node 1979: Class Counts = [1. 0. 0. 0.]
# Node 1981: Class Counts = [1. 0. 0. 0.]
# Node 1983: Class Counts = [0. 5. 0. 0.]
# Node 1984: Class Counts = [1. 0. 0. 0.]
# Node 1988: Class Counts = [0. 0. 0. 2.]
# Node 1989: Class Counts = [1. 0. 0. 0.]
# Node 1990: Class Counts = [2. 0. 0. 0.]
# Node 1993: Class Counts = [0. 0. 1. 0.]
# Node 1995: Class Counts = [0. 0. 0. 1.]
# Node 1996: Class Counts = [0. 0. 1. 0.]
# Node 1997: Class Counts = [0. 0. 0. 4.]
# Node 2002: Class Counts = [0. 8. 0. 0.]
# Node 2004: Class Counts = [0. 4. 0. 0.]
# Node 2006: Class Counts = [0. 0. 1. 0.]
# Node 2007: Class Counts = [ 0. 10.  5.  0.]
# Node 2010: Class Counts = [0. 0. 0. 2.]
# Node 2011: Class Counts = [0. 0. 1. 0.]
# Node 2012: Class Counts = [0. 1. 0. 0.]
# Node 2017: Class Counts = [ 3. 17.  1.  0.]
# Node 2018: Class Counts = [9. 5. 2. 0.]
# Node 2019: Class Counts = [ 0. 10.  0.  0.]
# Node 2022: Class Counts = [21. 52. 11.  0.]
# Node 2023: Class Counts = [ 31. 103.  54.   2.]
# Node 2025: Class Counts = [ 0.  6. 13.  0.]
# Node 2026: Class Counts = [4. 6. 3. 0.]
# Node 2030: Class Counts = [1. 0. 0. 0.]
# Node 2031: Class Counts = [0. 2. 0. 0.]
# Node 2033: Class Counts = [6. 0. 0. 0.]
# Node 2034: Class Counts = [5. 2. 0. 0.]
# Node 2037: Class Counts = [ 5. 12.  0.  0.]
# Node 2038: Class Counts = [ 0. 20.  3.  0.]
# Node 2040: Class Counts = [17. 13.  4.  0.]
# Node 2041: Class Counts = [15. 53. 10.  1.]
# Node 2045: Class Counts = [0. 0. 0. 1.]
# Node 2046: Class Counts = [0. 1. 0. 0.]
# Node 2047: Class Counts = [ 0. 18.  0.  0.]
# Node 2050: Class Counts = [0. 3. 0. 0.]
# Node 2052: Class Counts = [0. 0. 2. 0.]
# Node 2054: Class Counts = [0. 5. 1. 0.]
# Node 2055: Class Counts = [0. 0. 1. 0.]
# Node 2056: Class Counts = [0. 5. 0. 0.]
# Node 2063: Class Counts = [0. 0. 1. 0.]
# Node 2065: Class Counts = [0. 5. 0. 0.]
# Node 2067: Class Counts = [0. 0. 1. 0.]
# Node 2068: Class Counts = [0. 2. 0. 0.]
# Node 2070: Class Counts = [0. 0. 5. 0.]
# Node 2071: Class Counts = [0. 1. 0. 0.]
# Node 2074: Class Counts = [ 0. 46.  0.  0.]
# Node 2076: Class Counts = [0. 0. 2. 0.]
# Node 2077: Class Counts = [0. 2. 0. 0.]
# Node 2081: Class Counts = [ 0. 12.  0.  0.]
# Node 2083: Class Counts = [0. 1. 0. 0.]
# Node 2084: Class Counts = [0. 0. 0. 1.]
# Node 2085: Class Counts = [  0. 157.   0.   0.]
# Node 2087: Class Counts = [   0. 1872.    0.    0.]
# Node 2090: Class Counts = [ 0. 23.  0.  0.]
# Node 2092: Class Counts = [0. 0. 1. 0.]
# Node 2093: Class Counts = [0. 5. 0. 0.]
# Node 2094: Class Counts = [  0. 294.   0.   0.]
# Node 2101: Class Counts = [0. 0. 2. 0.]
# Node 2103: Class Counts = [0. 4. 6. 0.]
# Node 2104: Class Counts = [ 0. 10.  1.  0.]
# Node 2106: Class Counts = [0. 0. 2. 0.]
# Node 2108: Class Counts = [ 0. 23.  0.  0.]
# Node 2109: Class Counts = [ 0. 65. 11.  0.]
# Node 2111: Class Counts = [0. 0. 1. 0.]
# Node 2112: Class Counts = [1. 0. 0. 0.]
# Node 2114: Class Counts = [0. 3. 0. 0.]
# Node 2117: Class Counts = [0. 0. 1. 0.]
# Node 2118: Class Counts = [0. 0. 0. 1.]
# Node 2119: Class Counts = [0. 0. 0. 1.]
# Node 2125: Class Counts = [0. 3. 1. 0.]
# Node 2126: Class Counts = [  3. 202.   0.   0.]
# Node 2128: Class Counts = [ 1. 12.  0.  0.]
# Node 2129: Class Counts = [2. 0. 0. 0.]
# Node 2132: Class Counts = [  1. 116.   3.   4.]
# Node 2133: Class Counts = [  0. 111.   2.   0.]
# Node 2135: Class Counts = [ 0. 51.  4.  6.]
# Node 2136: Class Counts = [ 0. 51.  5.  0.]
# Node 2140: Class Counts = [0. 0. 2. 0.]
# Node 2141: Class Counts = [ 0. 47.  2.  0.]
# Node 2143: Class Counts = [ 0. 10. 10.  0.]
# Node 2144: Class Counts = [ 0. 15.  3.  0.]
# Node 2147: Class Counts = [  0. 206.   6.   1.]
# Node 2148: Class Counts = [  0. 145.  12.   1.]
# Node 2150: Class Counts = [ 0. 11.  0.  0.]
# Node 2151: Class Counts = [1. 0. 0. 0.]
# Node 2156: Class Counts = [  3. 906.   5.   1.]
# Node 2157: Class Counts = [ 1. 62.  3.  0.]
# Node 2159: Class Counts = [  2. 523.   6.   0.]
# Node 2160: Class Counts = [  4. 659.  34.   5.]
# Node 2163: Class Counts = [0. 2. 0. 0.]
# Node 2164: Class Counts = [0. 1. 5. 0.]
# Node 2166: Class Counts = [0. 9. 2. 0.]
# Node 2167: Class Counts = [ 0. 18.  0.  0.]
# Node 2170: Class Counts = [  0. 518.   0.   0.]
# Node 2172: Class Counts = [  0. 111.   1.   2.]
# Node 2173: Class Counts = [  0. 150.   0.   0.]
# Node 2176: Class Counts = [  0. 207.   0.   0.]
# Node 2177: Class Counts = [ 1. 26.  1.  0.]
# Node 2179: Class Counts = [0. 4. 0. 2.]
# Node 2180: Class Counts = [ 0. 16.  4.  0.]
# Node 2186: Class Counts = [ 0. 23.  0.  0.]
# Node 2188: Class Counts = [0. 5. 0. 0.]
# Node 2189: Class Counts = [0. 7. 3. 0.]
# Node 2191: Class Counts = [0. 0. 0. 1.]
# Node 2193: Class Counts = [ 0. 13.  0.  2.]
# Node 2194: Class Counts = [ 0. 88.  0.  0.]
# Node 2198: Class Counts = [0. 9. 0. 0.]
# Node 2199: Class Counts = [3. 1. 0. 0.]
# Node 2201: Class Counts = [ 0. 39.  7.  0.]
# Node 2202: Class Counts = [1. 5. 2. 0.]
# Node 2203: Class Counts = [0. 0. 0. 2.]
# Node 2205: Class Counts = [0. 2. 0. 0.]
# Node 2206: Class Counts = [0. 0. 5. 0.]
# Node 2211: Class Counts = [0. 0. 2. 0.]
# Node 2213: Class Counts = [0. 5. 0. 0.]
# Node 2214: Class Counts = [ 0. 12. 14.  0.]
# Node 2215: Class Counts = [0. 3. 0. 0.]
# Node 2216: Class Counts = [0. 4. 0. 0.]
# Node 2217: Class Counts = [0. 0. 3. 0.]
# Node 2224: Class Counts = [ 0. 55.  0.  0.]
# Node 2226: Class Counts = [ 0. 22.  0.  0.]
# Node 2228: Class Counts = [ 0. 21.  3.  0.]
# Node 2229: Class Counts = [0. 0. 1. 0.]
# Node 2231: Class Counts = [  0. 472.   0.   0.]
# Node 2233: Class Counts = [ 0. 62.  0.  0.]
# Node 2235: Class Counts = [0. 4. 1. 0.]
# Node 2236: Class Counts = [ 0. 62.  1.  0.]
# Node 2238: Class Counts = [ 0. 38.  0.  0.]
# Node 2242: Class Counts = [0. 9. 0. 1.]
# Node 2243: Class Counts = [0. 3. 2. 0.]
# Node 2244: Class Counts = [0. 0. 2. 0.]
# Node 2246: Class Counts = [ 0. 37.  0.  0.]
# Node 2248: Class Counts = [ 0. 23.  5.  0.]
# Node 2249: Class Counts = [ 0. 19.  0.  0.]
# Node 2252: Class Counts = [ 0. 10.  0.  0.]
# Node 2255: Class Counts = [0. 2. 0. 0.]
# Node 2257: Class Counts = [0. 1. 2. 0.]
# Node 2258: Class Counts = [0. 0. 4. 0.]
# Node 2261: Class Counts = [0. 7. 4. 0.]
# Node 2262: Class Counts = [0. 0. 3. 0.]
# Node 2264: Class Counts = [ 0. 20.  7.  0.]
# Node 2265: Class Counts = [ 0. 20.  1.  0.]
# Node 2267: Class Counts = [ 0. 45.  0.  0.]
# Node 2271: Class Counts = [ 0. 16.  2.  0.]
# Node 2272: Class Counts = [0. 0. 1. 0.]
# Node 2273: Class Counts = [0. 0. 2. 0.]
# Node 2276: Class Counts = [ 0. 21.  0.  0.]
# Node 2277: Class Counts = [ 0. 13.  5.  0.]
# Node 2279: Class Counts = [ 0. 11.  0.  1.]
# Node 2280: Class Counts = [ 0. 46.  0.  0.]
# Node 2284: Class Counts = [  0. 140.   0.   0.]
# Node 2286: Class Counts = [0. 0. 1. 0.]
# Node 2287: Class Counts = [ 0. 10.  0.  0.]
# Node 2289: Class Counts = [0. 0. 2. 0.]
# Node 2290: Class Counts = [0. 2. 0. 0.]
# Node 2296: Class Counts = [0. 6. 2. 0.]
# ...
# Node 19834: Class Counts = [0. 0. 0. 2.]
# Node 19839: Class Counts = [  0. 443.  14.  19.]
# Node 19840: Class Counts = [0. 1. 2. 0.]
# Node 19842: Class Counts = [  0. 246.   3.  33.]
# Node 19843: Class Counts = [ 0. 70.  4.  0.]
# Node 19846: Class Counts = [ 0. 28.  2.  0.]
# Node 19847: Class Counts = [ 0. 10.  3.  2.]
# Node 19849: Class Counts = [  0. 144.   2.   0.]
# Node 19850: Class Counts = [0. 0. 1. 0.]
# Node 19854: Class Counts = [0. 0. 0. 2.]
# Node 19855: Class Counts = [ 0. 53.  0. 16.]
# Node 19857: Class Counts = [ 0. 45.  1.  6.]
# Node 19858: Class Counts = [ 0. 32.  0.  0.]
# Node 19861: Class Counts = [  1. 894.   9.  61.]
# Node 19862: Class Counts = [ 0. 65.  1.  0.]
# Node 19864: Class Counts = [0. 3. 0. 0.]
# Node 19865: Class Counts = [0. 0. 1. 5.]
# Node 19871: Class Counts = [ 1. 48.  0.  1.]
# Node 19872: Class Counts = [ 0. 30.  0.  7.]
# Node 19874: Class Counts = [0. 5. 1. 0.]
# Node 19875: Class Counts = [5. 1. 0. 0.]
# Node 19878: Class Counts = [0. 0. 0. 8.]
# Node 19879: Class Counts = [0. 0. 2. 0.]
# Node 19881: Class Counts = [0. 5. 0. 0.]
# Node 19882: Class Counts = [0. 0. 0. 5.]
# Node 19886: Class Counts = [3. 0. 0. 0.]
# Node 19887: Class Counts = [0. 7. 0. 0.]
# Node 19889: Class Counts = [  1. 877.  40.  88.]
# Node 19890: Class Counts = [0. 1. 4. 1.]
# Node 19893: Class Counts = [0. 2. 0. 5.]
# Node 19894: Class Counts = [0. 3. 3. 0.]
# Node 19896: Class Counts = [  8. 694.  10.  36.]
# Node 19897: Class Counts = [  4. 797.  35.  32.]
# Node 19900: Class Counts = [ 0. 22.  0.  0.]
# Node 19903: Class Counts = [ 0. 21.  0.  1.]
# Node 19904: Class Counts = [3. 6. 0. 0.]
# Node 19906: Class Counts = [0. 0. 0. 1.]
# Node 19907: Class Counts = [1. 0. 0. 0.]
# Node 19911: Class Counts = [  0. 338.   4.   0.]
# Node 19912: Class Counts = [1. 9. 0. 1.]
# Node 19914: Class Counts = [ 0. 78.  0.  2.]
# Node 19915: Class Counts = [0. 3. 0. 2.]
# Node 19918: Class Counts = [0. 0. 1. 0.]
# Node 19919: Class Counts = [0. 2. 0. 0.]
# Node 19920: Class Counts = [0. 0. 1. 0.]
# Node 19925: Class Counts = [0. 1. 0. 0.]
# Node 19926: Class Counts = [0. 0. 0. 1.]
# Node 19927: Class Counts = [0. 0. 5. 0.]
# Node 19934: Class Counts = [0. 1. 0. 0.]
# Node 19935: Class Counts = [0. 0. 0. 1.]
# Node 19936: Class Counts = [0. 7. 0. 0.]
# Node 19938: Class Counts = [0. 0. 0. 3.]
# Node 19939: Class Counts = [0. 1. 0. 1.]
# Node 19941: Class Counts = [ 0. 22.  0.  0.]
# Node 19944: Class Counts = [0. 8. 9. 0.]
# Node 19945: Class Counts = [ 0. 11.  2.  2.]
# Node 19947: Class Counts = [ 0. 13.  6.  1.]
# Node 19948: Class Counts = [  0. 110.   8.  11.]
# Node 19953: Class Counts = [  0. 169.  18.  18.]
# Node 19954: Class Counts = [ 0. 60.  1.  4.]
# Node 19955: Class Counts = [0. 0. 2. 0.]
# Node 19958: Class Counts = [0. 0. 5. 0.]
# Node 19959: Class Counts = [0. 1. 0. 0.]
# Node 19961: Class Counts = [ 0. 11.  0.  2.]
# Node 19962: Class Counts = [0. 4. 3. 0.]
# Node 19966: Class Counts = [  0. 416.  17.  17.]
# Node 19967: Class Counts = [0. 4. 2. 1.]
# Node 19969: Class Counts = [ 0. 74.  0.  0.]
# Node 19970: Class Counts = [ 0. 43.  0.  2.]
# Node 19973: Class Counts = [ 0. 82.  4. 10.]
# Node 19974: Class Counts = [ 0. 23.  3. 11.]
# Node 19976: Class Counts = [ 0. 38.  5.  0.]
# Node 19977: Class Counts = [ 0. 94.  2.  8.]
# Node 19982: Class Counts = [0. 2. 0. 0.]
# Node 19983: Class Counts = [0. 0. 4. 0.]
# Node 19984: Class Counts = [0. 7. 0. 0.]
# Node 19986: Class Counts = [ 0. 33.  0.  0.]
# Node 19989: Class Counts = [2. 0. 0. 0.]
# Node 19990: Class Counts = [1. 7. 0. 0.]
# Node 19991: Class Counts = [ 0. 12.  0.  0.]
# Node 19995: Class Counts = [ 0. 21.  0.  0.]
# Node 19997: Class Counts = [0. 1. 0. 3.]
# Node 19998: Class Counts = [ 0. 19.  0.  2.]
# Node 20001: Class Counts = [ 0. 11.  0.  0.]
# Node 20002: Class Counts = [0. 3. 2. 0.]
# Node 20004: Class Counts = [0. 2. 0. 1.]
# Node 20005: Class Counts = [ 0. 79.  0.  0.]
# Node 20009: Class Counts = [ 0. 14.  0.  0.]
# Node 20010: Class Counts = [0. 4. 0. 1.]
# Node 20012: Class Counts = [0. 0. 0. 1.]
# Node 20013: Class Counts = [0. 5. 0. 1.]
# Node 20014: Class Counts = [0. 0. 0. 2.]
# Node 20021: Class Counts = [ 0. 11.  0.  0.]
# Node 20023: Class Counts = [ 0. 13.  5.  0.]
# Node 20024: Class Counts = [0. 0. 1. 1.]
# Node 20027: Class Counts = [0. 2. 0. 0.]
# Node 20028: Class Counts = [0. 0. 0. 1.]
# Node 20030: Class Counts = [ 0. 47.  0.  0.]
# Node 20031: Class Counts = [0. 3. 1. 0.]
# Node 20034: Class Counts = [0. 0. 0. 1.]
# Node 20035: Class Counts = [ 0. 11.  0.  0.]
# Node 20038: Class Counts = [0. 0. 0. 3.]
# Node 20039: Class Counts = [0. 1. 0. 1.]
# Node 20040: Class Counts = [0. 4. 0. 0.]
# Node 20044: Class Counts = [0. 0. 0. 1.]
# Node 20045: Class Counts = [0. 0. 1. 0.]
# Node 20048: Class Counts = [ 0. 24.  0.  0.]
# Node 20049: Class Counts = [1. 1. 0. 0.]
# Node 20050: Class Counts = [0. 0. 1. 0.]
# Node 20054: Class Counts = [ 0. 11. 13.  0.]
# Node 20055: Class Counts = [0. 6. 0. 0.]
# Node 20056: Class Counts = [0. 0. 6. 0.]
# Node 20058: Class Counts = [ 0. 13.  0.  0.]
# Node 20060: Class Counts = [0. 0. 2. 0.]
# Node 20061: Class Counts = [0. 3. 0. 0.]
# Node 20065: Class Counts = [ 0. 13.  0.  0.]
# Node 20067: Class Counts = [0. 1. 0. 0.]
# Node 20069: Class Counts = [2. 1. 0. 0.]
# Node 20070: Class Counts = [0. 1. 0. 0.]
# Node 20071: Class Counts = [ 0. 37.  0.  0.]
# Node 20076: Class Counts = [0. 1. 0. 0.]
# Node 20077: Class Counts = [0. 0. 2. 0.]
# Node 20079: Class Counts = [ 0. 13.  0.  0.]
# Node 20080: Class Counts = [0. 1. 2. 0.]
# Node 20082: Class Counts = [ 0. 19.  0.  0.]
# Node 20084: Class Counts = [0. 0. 0. 1.]
# Node 20085: Class Counts = [0. 6. 0. 0.]
# Node 20089: Class Counts = [ 0. 11.  0.  0.]
# Node 20090: Class Counts = [0. 1. 0. 2.]
# Node 20091: Class Counts = [ 0. 50.  0.  0.]
# Node 20092: Class Counts = [0. 0. 0. 1.]
# Node 20098: Class Counts = [0. 0. 0. 1.]
# Node 20099: Class Counts = [0. 1. 0. 0.]
# Node 20101: Class Counts = [0. 0. 5. 0.]
# Node 20102: Class Counts = [0. 1. 0. 0.]
# Node 20105: Class Counts = [ 0. 19.  0.  0.]
# Node 20107: Class Counts = [0. 0. 0. 2.]
# Node 20108: Class Counts = [0. 2. 0. 1.]
# Node 20111: Class Counts = [ 0. 39. 12.  5.]
# Node 20112: Class Counts = [0. 0. 2. 0.]
# Node 20114: Class Counts = [0. 2. 0. 2.]
# Node 20115: Class Counts = [ 0. 10.  0.  0.]
# Node 20119: Class Counts = [0. 4. 0. 0.]
# Node 20120: Class Counts = [0. 0. 2. 0.]
# Node 20121: Class Counts = [0. 0. 6. 0.]
# Node 20122: Class Counts = [0. 3. 0. 0.]
# Node 20125: Class Counts = [0. 0. 0. 3.]
# Node 20126: Class Counts = [0. 1. 0. 0.]
# Node 20128: Class Counts = [0. 8. 0. 0.]
# Node 20130: Class Counts = [1. 0. 0. 0.]
# Node 20131: Class Counts = [0. 1. 0. 0.]
# Node 20142: Class Counts = [0. 3. 0. 2.]
# Node 20143: Class Counts = [   0. 1381.   22.   16.]
# Node 20145: Class Counts = [   5. 2771.   68.   86.]
# Node 20146: Class Counts = [   5. 2654.  100.   39.]
# Node 20148: Class Counts = [0. 3. 0. 0.]
# Node 20149: Class Counts = [0. 0. 0. 4.]
# Node 20153: Class Counts = [  0. 428.   6.   6.]
# Node 20154: Class Counts = [  1. 198.   8.   0.]
# Node 20156: Class Counts = [  0. 156.  11.   0.]
# Node 20157: Class Counts = [1. 0. 0. 0.]
# Node 20160: Class Counts = [  0. 244.   4.   2.]
# Node 20161: Class Counts = [  0. 367.   1.   0.]
# Node 20163: Class Counts = [ 0. 26.  0.  1.]
# Node 20164: Class Counts = [0. 1. 1. 1.]
# Node 20169: Class Counts = [  0. 324.   1.   5.]
# Node 20170: Class Counts = [  5. 332.   8.   3.]
# Node 20172: Class Counts = [ 0. 26.  1.  5.]
# Node 20173: Class Counts = [ 1. 23.  0.  0.]
# Node 20176: Class Counts = [ 0. 33.  1.  6.]
# Node 20177: Class Counts = [ 11. 764.  40.  25.]
# Node 20179: Class Counts = [  0. 244.   9.   2.]
# Node 20180: Class Counts = [  0. 105.   0.   2.]
# Node 20184: Class Counts = [  0. 182.  15.   4.]
# Node 20185: Class Counts = [  0. 137.   2.   0.]
# Node 20187: Class Counts = [  0. 166.   0.   0.]
# Node 20188: Class Counts = [  0. 489.   7.   9.]
# Node 20191: Class Counts = [ 4. 81.  4.  1.]
# Node 20192: Class Counts = [   5. 1331.   22.   27.]
# Node 20194: Class Counts = [  7. 196.   7.   0.]
# Node 20195: Class Counts = [  0. 183.   0.   0.]
# Node 20201: Class Counts = [0. 1. 0. 0.]
# Node 20202: Class Counts = [0. 0. 0. 2.]
# Node 20203: Class Counts = [0. 3. 0. 0.]
# Node 20205: Class Counts = [ 0. 29.  0.  0.]
# Node 20207: Class Counts = [0. 4. 0. 0.]
# Node 20208: Class Counts = [0. 0. 0. 1.]
# Node 20209: Class Counts = [ 0. 82.  0.  0.]
# Node 20210: Class Counts = [  0. 382.   0.   0.]
# Node 20217: Class Counts = [ 0. 11.  0.  7.]
# Node 20218: Class Counts = [0. 0. 1. 0.]
# Node 20219: Class Counts = [ 0. 17.  0.  0.]
# Node 20222: Class Counts = [ 0. 98.  0.  8.]
# Node 20223: Class Counts = [0. 0. 1. 0.]
# Node 20225: Class Counts = [ 0. 71.  1.  0.]
# Node 20226: Class Counts = [0. 2. 1. 0.]
# Node 20230: Class Counts = [ 0. 72.  0.  0.]
# Node 20231: Class Counts = [ 0. 24.  0.  2.]
# Node 20232: Class Counts = [0. 0. 0. 1.]
# Node 20235: Class Counts = [0. 9. 3. 0.]
# Node 20236: Class Counts = [ 0. 18.  0.  0.]
# Node 20238: Class Counts = [  0. 143.   0.   0.]
# Node 20239: Class Counts = [ 0. 25.  1.  0.]
# Node 20244: Class Counts = [0. 9. 0. 0.]
# Node 20245: Class Counts = [3. 4. 0. 1.]
# Node 20246: Class Counts = [ 0. 23.  0.  0.]
# Node 20248: Class Counts = [0. 0. 1. 0.]
# Node 20250: Class Counts = [0. 1. 0. 3.]
# Node 20251: Class Counts = [  0. 102.   0.  11.]
# Node 20253: Class Counts = [0. 0. 1. 0.]
# Node 20255: Class Counts = [0. 1. 0. 0.]
# Node 20256: Class Counts = [1. 0. 0. 0.]
# Node 20257: Class Counts = [2. 0. 0. 0.]
# Node 20260: Class Counts = [ 0. 11.  0.  0.]
# Node 20261: Class Counts = [0. 0. 1. 0.]
# Node 20262: Class Counts = [  0. 515.   0.   0.]
# Node 20270: Class Counts = [0. 4. 0. 0.]
# Node 20272: Class Counts = [0. 0. 0. 1.]
# Node 20273: Class Counts = [0. 1. 0. 1.]
# Node 20274: Class Counts = [ 0. 68.  0.  0.]
# Node 20277: Class Counts = [ 0. 19.  0.  0.]
# Node 20279: Class Counts = [ 0. 10.  2.  5.]
# Node 20280: Class Counts = [ 0. 15.  0.  1.]
# Node 20283: Class Counts = [  3. 171.   8.   2.]
# Node 20284: Class Counts = [  0. 129.  12.   4.]
# Node 20286: Class Counts = [ 0. 16.  4.  3.]
# Node 20287: Class Counts = [ 0. 14.  0.  1.]
# Node 20292: Class Counts = [0. 2. 0. 1.]
# Node 20293: Class Counts = [ 0. 73.  0.  2.]
# Node 20295: Class Counts = [ 0. 39.  4.  1.]
# Node 20296: Class Counts = [0. 1. 2. 2.]
# Node 20298: Class Counts = [ 0. 62.  0.  0.]
# Node 20300: Class Counts = [0. 3. 0. 0.]
# Node 20301: Class Counts = [0. 0. 0. 1.]
# Node 20305: Class Counts = [ 0. 92.  7.  0.]
# Node 20306: Class Counts = [  0. 164.   2.   0.]
# Node 20307: Class Counts = [0. 0. 1. 0.]
# Node 20310: Class Counts = [0. 0. 3. 0.]
# Node 20311: Class Counts = [0. 1. 0. 0.]
# Node 20313: Class Counts = [0. 3. 2. 0.]
# Node 20314: Class Counts = [0. 8. 0. 0.]
# Node 20316: Class Counts = [ 0. 33.  0.  0.]
# Node 20321: Class Counts = [0. 0. 0. 2.]
# Node 20322: Class Counts = [0. 2. 0. 1.]
# Node 20323: Class Counts = [0. 3. 0. 0.]
# Node 20326: Class Counts = [0. 0. 3. 2.]
# Node 20327: Class Counts = [0. 3. 1. 0.]
# Node 20329: Class Counts = [0. 0. 0. 1.]
# Node 20330: Class Counts = [ 0. 57. 11.  3.]
# Node 20334: Class Counts = [ 0. 43.  1.  0.]
# Node 20335: Class Counts = [0. 2. 1. 0.]
# Node 20336: Class Counts = [0. 0. 1. 0.]
# Node 20338: Class Counts = [0. 0. 2. 0.]
# Node 20339: Class Counts = [0. 1. 0. 0.]
# Node 20341: Class Counts = [2. 0. 0. 0.]
# Node 20347: Class Counts = [0. 1. 0. 0.]
# Node 20348: Class Counts = [0. 0. 1. 0.]
# Node 20349: Class Counts = [ 0. 27.  0.  0.]
# Node 20350: Class Counts = [0. 0. 1. 0.]
# Node 20354: Class Counts = [0. 8. 0. 1.]
# Node 20355: Class Counts = [0. 0. 0. 2.]
# Node 20356: Class Counts = [0. 9. 0. 0.]
# Node 20358: Class Counts = [1. 0. 0. 0.]
# Node 20359: Class Counts = [0. 0. 0. 5.]
# Node 20364: Class Counts = [ 0. 29.  3.  0.]
# Node 20365: Class Counts = [0. 0. 1. 0.]
# Node 20367: Class Counts = [ 0. 18.  1.  1.]
# Node 20368: Class Counts = [ 0. 68.  0.  0.]
# Node 20369: Class Counts = [0. 0. 2. 0.]
# Node 20373: Class Counts = [0. 3. 0. 0.]
# Node 20374: Class Counts = [2. 0. 0. 2.]
# Node 20376: Class Counts = [ 1. 19.  0.  0.]
# Node 20377: Class Counts = [1. 0. 0. 0.]
# Node 20380: Class Counts = [0. 1. 0. 0.]
# Node 20381: Class Counts = [0. 0. 2. 0.]
# Node 20383: Class Counts = [ 0. 21.  0.  0.]
# Node 20384: Class Counts = [0. 3. 1. 0.]
# Node 20392: Class Counts = [0. 2. 0. 0.]
# Node 20393: Class Counts = [0. 7. 0. 4.]
# Node 20394: Class Counts = [ 0. 10.  0.  0.]
# Node 20395: Class Counts = [0. 0. 0. 1.]
# Node 20396: Class Counts = [0. 0. 0. 2.]
# Node 20399: Class Counts = [ 0. 15.  0.  0.]
# Node 20401: Class Counts = [0. 0. 0. 1.]
# Node 20402: Class Counts = [0. 1. 0. 0.]
# Node 20405: Class Counts = [0. 1. 0. 0.]
# Node 20406: Class Counts = [0. 0. 2. 0.]
# Node 20407: Class Counts = [0. 4. 0. 0.]
# Node 20408: Class Counts = [ 0. 36.  0.  0.]
# Node 20412: Class Counts = [0. 4. 0. 0.]
# Node 20414: Class Counts = [0. 0. 0. 2.]
# Node 20415: Class Counts = [0. 2. 0. 0.]
# Node 20416: Class Counts = [ 0. 29.  0.  0.]
# Node 20420: Class Counts = [1. 0. 0. 0.]
# Node 20421: Class Counts = [0. 4. 0. 0.]
# Node 20422: Class Counts = [ 0. 24.  0.  0.]
# Node 20423: Class Counts = [  0. 127.   0.   0.]
# Node 20428: Class Counts = [0. 0. 5. 0.]
# Node 20430: Class Counts = [ 0. 21.  0.  0.]
# Node 20432: Class Counts = [0. 0. 1. 0.]
# Node 20433: Class Counts = [0. 3. 0. 0.]
# Node 20436: Class Counts = [2. 0. 0. 0.]
# Node 20439: Class Counts = [ 0. 35.  0.  0.]
# Node 20441: Class Counts = [0. 2. 0. 0.]
# Node 20442: Class Counts = [1. 0. 0. 0.]
# Node 20444: Class Counts = [ 0. 10.  0.  0.]
# Node 20447: Class Counts = [3. 3. 0. 0.]
# Node 20448: Class Counts = [ 1. 15.  0.  0.]
# Node 20449: Class Counts = [2. 0. 0. 0.]
# Node 20452: Class Counts = [0. 1. 0. 0.]
# Node 20453: Class Counts = [0. 0. 2. 0.]
# Node 20457: Class Counts = [0. 1. 0. 0.]
# Node 20458: Class Counts = [0. 0. 1. 0.]
# Node 20459: Class Counts = [0. 6. 0. 0.]
# Node 20460: Class Counts = [ 0. 29.  0.  0.]
# Node 20464: Class Counts = [ 0. 11.  0.  0.]
# Node 20466: Class Counts = [2. 0. 0. 0.]
# Node 20468: Class Counts = [0. 2. 0. 0.]
# Node 20469: Class Counts = [0. 0. 1. 0.]
# Node 20473: Class Counts = [ 0. 11.  0.  0.]
# Node 20475: Class Counts = [0. 0. 0. 3.]
# Node 20477: Class Counts = [0. 0. 0. 2.]
# Node 20478: Class Counts = [0. 3. 0. 0.]
# Node 20480: Class Counts = [0. 0. 0. 6.]
# Node 20482: Class Counts = [0. 0. 0. 1.]
# Node 20483: Class Counts = [0. 1. 0. 0.]
# Node 20484: Class Counts = [ 0. 10.  0.  0.]
# Node 20491: Class Counts = [1. 6. 0. 0.]
# Node 20492: Class Counts = [ 0. 16.  0.  0.]
# Node 20493: Class Counts = [0. 2. 0. 1.]
# Node 20494: Class Counts = [ 0. 57.  0.  0.]
# Node 20497: Class Counts = [0. 0. 0. 1.]
# Node 20498: Class Counts = [0. 9. 0. 0.]
# Node 20499: Class Counts = [0. 0. 0. 2.]
# Node 20502: Class Counts = [ 0. 15.  0.  0.]
# Node 20505: Class Counts = [0. 6. 0. 0.]
# Node 20506: Class Counts = [0. 6. 6. 0.]
# Node 20507: Class Counts = [0. 0. 3. 0.]
# Node 20511: Class Counts = [1. 0. 0. 1.]
# Node 20512: Class Counts = [0. 2. 0. 0.]
# Node 20513: Class Counts = [5. 0. 0. 0.]
# Node 20514: Class Counts = [ 0. 10.  0.  0.]
# Node 20520: Class Counts = [ 0. 11.  0.  0.]
# Node 20521: Class Counts = [0. 2. 0. 1.]
# Node 20523: Class Counts = [1. 0. 0. 0.]
# Node 20524: Class Counts = [0. 1. 0. 0.]
# Node 20526: Class Counts = [ 0. 50.  0.  0.]
# Node 20528: Class Counts = [0. 8. 0. 0.]
# Node 20529: Class Counts = [0. 1. 1. 0.]
# Node 20532: Class Counts = [0. 0. 0. 2.]
# Node 20533: Class Counts = [0. 0. 2. 0.]
# Node 20536: Class Counts = [0. 1. 0. 1.]
# Node 20537: Class Counts = [ 0. 24.  0.  0.]
# Node 20539: Class Counts = [ 1. 14.  0.  0.]
# Node 20540: Class Counts = [ 2. 15.  3.  5.]
# Node 20544: Class Counts = [  0. 104.   0.   0.]
# Node 20546: Class Counts = [1. 1. 0. 0.]
# Node 20547: Class Counts = [ 0. 25.  1.  0.]
# Node 20550: Class Counts = [0. 6. 1. 2.]
# Node 20551: Class Counts = [ 0. 15.  0.  0.]
# Node 20553: Class Counts = [ 0. 68.  0.  0.]
# Node 20554: Class Counts = [ 0. 89.  0.  5.]
# Node 20557: Class Counts = [0. 7. 0. 0.]
# Node 20559: Class Counts = [0. 9. 1. 3.]
# Node 20560: Class Counts = [0. 0. 0. 2.]
# Node 20561: Class Counts = [ 0. 12.  0.  0.]
# Node 20563: Class Counts = [0. 0. 0. 9.]
# Node 20565: Class Counts = [0. 0. 0. 2.]
# Node 20568: Class Counts = [0. 0. 2. 0.]
# Node 20569: Class Counts = [0. 1. 0. 0.]
# Node 20570: Class Counts = [ 0. 15.  0.  0.]

# %%
leaf_nodes = np.where(dtree_opt.tree_.children_left == -1)[0]
counter = 0

for node in leaf_nodes:
    class_counts = dtree_opt.tree_.value[node][0]
    if class_counts[0] == 0 and class_counts[1] == 0:
        node_info = f"Node {node}: Class Counts = {class_counts}"
        print(node_info)
        counter+=1

print(f'Total number of valuable nodes is: {counter}')
# Out:
# Node 9: Class Counts = [ 0.  0. 69.  0.]
# Node 12: Class Counts = [0. 0. 0. 1.]
# Node 15: Class Counts = [0. 0. 0. 1.]
# Node 18: Class Counts = [0. 0. 1. 0.]
# Node 19: Class Counts = [0. 0. 0. 1.]
# Node 20: Class Counts = [0. 0. 7. 0.]
# Node 21: Class Counts = [0. 0. 9. 0.]
# Node 26: Class Counts = [0. 0. 1. 0.]
# Node 28: Class Counts = [ 0.  0. 11.  0.]
# Node 38: Class Counts = [0. 0. 1. 0.]
# Node 52: Class Counts = [0. 0. 2. 0.]
# Node 57: Class Counts = [0. 0. 2. 0.]
# Node 61: Class Counts = [0. 0. 7. 0.]
# Node 66: Class Counts = [0. 0. 0. 1.]
# Node 71: Class Counts = [0. 0. 0. 1.]
# Node 77: Class Counts = [0. 0. 0. 2.]
# Node 85: Class Counts = [ 0.  0. 13.  0.]
# Node 88: Class Counts = [ 0.  0. 24.  0.]
# Node 94: Class Counts = [0. 0. 2. 0.]
# Node 106: Class Counts = [ 0.  0. 12.  0.]
# Node 120: Class Counts = [0. 0. 1. 0.]
# Node 121: Class Counts = [0. 0. 1. 0.]
# Node 132: Class Counts = [0. 0. 6. 0.]
# Node 135: Class Counts = [0. 0. 1. 0.]
# Node 139: Class Counts = [0. 0. 2. 0.]
# Node 141: Class Counts = [0. 0. 0. 1.]
# Node 151: Class Counts = [ 0.  0. 10.  0.]
# Node 158: Class Counts = [0. 0. 4. 0.]
# Node 166: Class Counts = [0. 0. 4. 0.]
# Node 168: Class Counts = [0. 0. 6. 0.]
# Node 170: Class Counts = [0. 0. 7. 0.]
# Node 176: Class Counts = [0. 0. 1. 0.]
# Node 179: Class Counts = [0. 0. 3. 0.]
# Node 181: Class Counts = [0. 0. 6. 0.]
# Node 188: Class Counts = [0. 0. 1. 0.]
# Node 190: Class Counts = [0. 0. 2. 0.]
# Node 193: Class Counts = [ 0.  0. 10.  0.]
# Node 195: Class Counts = [0. 0. 1. 0.]
# Node 198: Class Counts = [0. 0. 3. 0.]
# Node 202: Class Counts = [0. 0. 1. 0.]
# Node 223: Class Counts = [0. 0. 3. 0.]
# Node 228: Class Counts = [0. 0. 2. 0.]
# Node 234: Class Counts = [0. 0. 1. 0.]
# Node 238: Class Counts = [0. 0. 3. 0.]
# Node 242: Class Counts = [0. 0. 6. 0.]
# Node 265: Class Counts = [ 0.  0. 14.  0.]
# Node 275: Class Counts = [0. 0. 2. 0.]
# Node 280: Class Counts = [ 0.  0. 14.  0.]
# Node 283: Class Counts = [0. 0. 4. 0.]
# Node 293: Class Counts = [0. 0. 8. 0.]
# Node 300: Class Counts = [0. 0. 6. 0.]
# Node 319: Class Counts = [0. 0. 5. 0.]
# Node 322: Class Counts = [0. 0. 9. 3.]
# Node 341: Class Counts = [0. 0. 4. 0.]
# Node 347: Class Counts = [0. 0. 3. 0.]
# Node 352: Class Counts = [0. 0. 5. 0.]
# Node 354: Class Counts = [0. 0. 1. 0.]
# Node 360: Class Counts = [0. 0. 1. 0.]
# Node 365: Class Counts = [0. 0. 8. 0.]
# Node 368: Class Counts = [0. 0. 2. 0.]
# Node 374: Class Counts = [0. 0. 1. 0.]
# Node 386: Class Counts = [0. 0. 2. 0.]
# Node 394: Class Counts = [0. 0. 0. 1.]
# Node 397: Class Counts = [0. 0. 2. 0.]
# Node 402: Class Counts = [0. 0. 5. 0.]
# Node 412: Class Counts = [0. 0. 4. 5.]
# Node 435: Class Counts = [0. 0. 0. 2.]
# Node 445: Class Counts = [ 0.  0. 34.  0.]
# Node 453: Class Counts = [ 0.  0. 17.  0.]
# Node 459: Class Counts = [0. 0. 8. 0.]
# Node 463: Class Counts = [0. 0. 2. 0.]
# Node 465: Class Counts = [ 0.  0. 21.  0.]
# Node 468: Class Counts = [0. 0. 8. 0.]
# Node 473: Class Counts = [0. 0. 4. 0.]
# Node 484: Class Counts = [0. 0. 6. 0.]
# Node 489: Class Counts = [0. 0. 1. 0.]
# Node 490: Class Counts = [0. 0. 7. 0.]
# Node 494: Class Counts = [0. 0. 2. 0.]
# Node 495: Class Counts = [0. 0. 7. 0.]
# Node 501: Class Counts = [0. 0. 1. 0.]
# Node 508: Class Counts = [0. 0. 4. 0.]
# Node 510: Class Counts = [0. 0. 1. 0.]
# Node 514: Class Counts = [0. 0. 1. 0.]
# Node 536: Class Counts = [0. 0. 1. 0.]
# Node 542: Class Counts = [0. 0. 3. 0.]
# Node 557: Class Counts = [0. 0. 1. 0.]
# Node 560: Class Counts = [0. 0. 0. 4.]
# Node 562: Class Counts = [0. 0. 1. 0.]
# Node 567: Class Counts = [0. 0. 5. 0.]
# Node 572: Class Counts = [0. 0. 1. 0.]
# Node 575: Class Counts = [0. 0. 2. 0.]
# Node 583: Class Counts = [0. 0. 2. 0.]
# Node 586: Class Counts = [0. 0. 1. 0.]
# Node 598: Class Counts = [0. 0. 3. 0.]
# Node 599: Class Counts = [0. 0. 0. 1.]
# Node 609: Class Counts = [0. 0. 4. 0.]
# Node 615: Class Counts = [0. 0. 0. 1.]
# Node 619: Class Counts = [0. 0. 4. 0.]
# Node 621: Class Counts = [0. 0. 1. 0.]
# Node 630: Class Counts = [0. 0. 0. 2.]
# Node 632: Class Counts = [0. 0. 1. 0.]
# Node 634: Class Counts = [0. 0. 0. 5.]
# Node 637: Class Counts = [0. 0. 0. 1.]
# Node 640: Class Counts = [0. 0. 1. 0.]
# Node 641: Class Counts = [0. 0. 0. 2.]
# Node 647: Class Counts = [0. 0. 1. 0.]
# Node 648: Class Counts = [0. 0. 2. 0.]
# Node 651: Class Counts = [0. 0. 1. 0.]
# Node 672: Class Counts = [0. 0. 1. 0.]
# Node 673: Class Counts = [0. 0. 0. 1.]
# Node 682: Class Counts = [0. 0. 5. 0.]
# Node 686: Class Counts = [0. 0. 0. 2.]
# Node 696: Class Counts = [0. 0. 2. 0.]
# Node 702: Class Counts = [0. 0. 1. 0.]
# Node 705: Class Counts = [0. 0. 1. 0.]
# Node 708: Class Counts = [0. 0. 0. 1.]
# Node 723: Class Counts = [0. 0. 4. 0.]
# Node 750: Class Counts = [0. 0. 2. 0.]
# Node 779: Class Counts = [0. 0. 0. 3.]
# Node 787: Class Counts = [0. 0. 0. 2.]
# Node 800: Class Counts = [0. 0. 2. 0.]
# Node 812: Class Counts = [0. 0. 2. 0.]
# Node 834: Class Counts = [0. 0. 0. 1.]
# Node 859: Class Counts = [0. 0. 1. 0.]
# Node 881: Class Counts = [0. 0. 4. 0.]
# Node 889: Class Counts = [0. 0. 0. 1.]
# Node 904: Class Counts = [0. 0. 5. 0.]
# Node 946: Class Counts = [0. 0. 1. 0.]
# Node 970: Class Counts = [0. 0. 1. 0.]
# Node 972: Class Counts = [0. 0. 3. 0.]
# Node 978: Class Counts = [0. 0. 7. 0.]
# Node 988: Class Counts = [0. 0. 0. 1.]
# Node 989: Class Counts = [0. 0. 1. 0.]
# Node 990: Class Counts = [0. 0. 3. 0.]
# Node 997: Class Counts = [0. 0. 1. 0.]
# Node 1000: Class Counts = [0. 0. 1. 0.]
# Node 1009: Class Counts = [0. 0. 0. 1.]
# Node 1041: Class Counts = [0. 0. 3. 0.]
# Node 1048: Class Counts = [0. 0. 3. 0.]
# Node 1108: Class Counts = [0. 0. 1. 0.]
# Node 1177: Class Counts = [0. 0. 0. 2.]
# Node 1189: Class Counts = [0. 0. 1. 0.]
# Node 1190: Class Counts = [0. 0. 1. 0.]
# Node 1198: Class Counts = [0. 0. 1. 3.]
# Node 1201: Class Counts = [0. 0. 4. 0.]
# Node 1202: Class Counts = [0. 0. 1. 2.]
# Node 1209: Class Counts = [0. 0. 6. 0.]
# Node 1235: Class Counts = [0. 0. 6. 0.]
# Node 1245: Class Counts = [0. 0. 0. 2.]
# Node 1264: Class Counts = [0. 0. 9. 0.]
# Node 1281: Class Counts = [0. 0. 2. 0.]
# Node 1291: Class Counts = [0. 0. 3. 0.]
# Node 1327: Class Counts = [0. 0. 3. 0.]
# Node 1329: Class Counts = [0. 0. 1. 0.]
# Node 1332: Class Counts = [0. 0. 5. 0.]
# Node 1334: Class Counts = [0. 0. 0. 1.]
# Node 1343: Class Counts = [0. 0. 2. 0.]
# Node 1347: Class Counts = [0. 0. 4. 0.]
# Node 1354: Class Counts = [0. 0. 1. 0.]
# Node 1368: Class Counts = [0. 0. 2. 0.]
# Node 1369: Class Counts = [0. 0. 0. 1.]
# Node 1419: Class Counts = [0. 0. 5. 0.]
# Node 1509: Class Counts = [0. 0. 0. 1.]
# Node 1510: Class Counts = [0. 0. 3. 0.]
# Node 1530: Class Counts = [0. 0. 3. 0.]
# Node 1597: Class Counts = [0. 0. 1. 0.]
# Node 1621: Class Counts = [0. 0. 1. 0.]
# Node 1634: Class Counts = [0. 0. 2. 0.]
# Node 1656: Class Counts = [0. 0. 2. 0.]
# Node 1670: Class Counts = [0. 0. 0. 2.]
# Node 1704: Class Counts = [0. 0. 0. 2.]
# Node 1796: Class Counts = [0. 0. 1. 1.]
# Node 1800: Class Counts = [0. 0. 1. 0.]
# Node 1801: Class Counts = [0. 0. 2. 0.]
# Node 1814: Class Counts = [0. 0. 1. 0.]
# Node 1832: Class Counts = [0. 0. 0. 2.]
# Node 1840: Class Counts = [0. 0. 3. 0.]
# Node 1847: Class Counts = [0. 0. 0. 2.]
# Node 1886: Class Counts = [0. 0. 0. 1.]
# Node 1887: Class Counts = [0. 0. 3. 0.]
# Node 1930: Class Counts = [0. 0. 3. 0.]
# Node 1932: Class Counts = [0. 0. 0. 1.]
# Node 1933: Class Counts = [0. 0. 1. 0.]
# Node 1947: Class Counts = [0. 0. 1. 1.]
# Node 1958: Class Counts = [0. 0. 2. 0.]
# Node 1961: Class Counts = [0. 0. 0. 1.]
# Node 1978: Class Counts = [0. 0. 1. 0.]
# Node 1988: Class Counts = [0. 0. 0. 2.]
# Node 1993: Class Counts = [0. 0. 1. 0.]
# Node 1995: Class Counts = [0. 0. 0. 1.]
# Node 1996: Class Counts = [0. 0. 1. 0.]
# Node 1997: Class Counts = [0. 0. 0. 4.]
# Node 2006: Class Counts = [0. 0. 1. 0.]
# Node 2010: Class Counts = [0. 0. 0. 2.]
# Node 2011: Class Counts = [0. 0. 1. 0.]
# Node 2045: Class Counts = [0. 0. 0. 1.]
# Node 2052: Class Counts = [0. 0. 2. 0.]
# Node 2055: Class Counts = [0. 0. 1. 0.]
# Node 2063: Class Counts = [0. 0. 1. 0.]
# Node 2067: Class Counts = [0. 0. 1. 0.]
# Node 2070: Class Counts = [0. 0. 5. 0.]
# Node 2076: Class Counts = [0. 0. 2. 0.]
# Node 2084: Class Counts = [0. 0. 0. 1.]
# Node 2092: Class Counts = [0. 0. 1. 0.]
# Node 2101: Class Counts = [0. 0. 2. 0.]
# Node 2106: Class Counts = [0. 0. 2. 0.]
# Node 2111: Class Counts = [0. 0. 1. 0.]
# Node 2117: Class Counts = [0. 0. 1. 0.]
# Node 2118: Class Counts = [0. 0. 0. 1.]
# Node 2119: Class Counts = [0. 0. 0. 1.]
# Node 2140: Class Counts = [0. 0. 2. 0.]
# Node 2191: Class Counts = [0. 0. 0. 1.]
# Node 2203: Class Counts = [0. 0. 0. 2.]
# Node 2206: Class Counts = [0. 0. 5. 0.]
# Node 2211: Class Counts = [0. 0. 2. 0.]
# Node 2217: Class Counts = [0. 0. 3. 0.]
# Node 2229: Class Counts = [0. 0. 1. 0.]
# Node 2244: Class Counts = [0. 0. 2. 0.]
# Node 2258: Class Counts = [0. 0. 4. 0.]
# Node 2262: Class Counts = [0. 0. 3. 0.]
# Node 2272: Class Counts = [0. 0. 1. 0.]
# Node 2273: Class Counts = [0. 0. 2. 0.]
# Node 2286: Class Counts = [0. 0. 1. 0.]
# Node 2289: Class Counts = [0. 0. 2. 0.]
# Node 2301: Class Counts = [0. 0. 2. 0.]
# Node 2305: Class Counts = [0. 0. 5. 0.]
# Node 2329: Class Counts = [0. 0. 8. 0.]
# Node 2342: Class Counts = [ 0.  0. 15.  0.]
# Node 2344: Class Counts = [0. 0. 3. 0.]
# Node 2358: Class Counts = [0. 0. 1. 0.]
# Node 2360: Class Counts = [ 0.  0. 10.  0.]
# Node 2366: Class Counts = [0. 0. 1. 0.]
# Node 2368: Class Counts = [0. 0. 5. 0.]
# Node 2383: Class Counts = [0. 0. 0. 2.]
# Node 2385: Class Counts = [0. 0. 0. 2.]
# Node 2397: Class Counts = [0. 0. 3. 0.]
# Node 2407: Class Counts = [0. 0. 1. 0.]
# Node 2426: Class Counts = [0. 0. 1. 0.]
# Node 2435: Class Counts = [0. 0. 0. 1.]
# Node 2436: Class Counts = [0. 0. 1. 0.]
# Node 2449: Class Counts = [0. 0. 4. 0.]
# Node 2460: Class Counts = [0. 0. 6. 0.]
# Node 2517: Class Counts = [0. 0. 1. 0.]
# Node 2553: Class Counts = [0. 0. 1. 0.]
# Node 2569: Class Counts = [0. 0. 1. 0.]
# Node 2571: Class Counts = [0. 0. 0. 2.]
# Node 2599: Class Counts = [0. 0. 1. 0.]
# Node 2612: Class Counts = [0. 0. 0. 1.]
# Node 2621: Class Counts = [0. 0. 1. 0.]
# Node 2632: Class Counts = [0. 0. 0. 1.]
# Node 2633: Class Counts = [0. 0. 3. 1.]
# Node 2645: Class Counts = [0. 0. 1. 0.]
# Node 2672: Class Counts = [0. 0. 0. 1.]
# Node 2674: Class Counts = [0. 0. 2. 0.]
# Node 2719: Class Counts = [0. 0. 2. 0.]
# Node 2755: Class Counts = [ 0.  0. 10.  0.]
# Node 2768: Class Counts = [0. 0. 1. 2.]
# Node 2773: Class Counts = [0. 0. 7. 0.]
# Node 2805: Class Counts = [0. 0. 1. 0.]
# Node 2828: Class Counts = [0. 0. 0. 2.]
# Node 2829: Class Counts = [0. 0. 0. 4.]
# Node 2830: Class Counts = [0. 0. 1. 0.]
# Node 2844: Class Counts = [0. 0. 1. 0.]
# Node 2847: Class Counts = [0. 0. 0. 1.]
# Node 2855: Class Counts = [0. 0. 3. 0.]
# Node 2859: Class Counts = [ 0.  0. 10.  0.]
# Node 2862: Class Counts = [0. 0. 1. 1.]
# Node 2869: Class Counts = [0. 0. 2. 0.]
# Node 2901: Class Counts = [0. 0. 2. 0.]
# Node 2903: Class Counts = [0. 0. 2. 0.]
# Node 2963: Class Counts = [0. 0. 3. 2.]
# Node 2987: Class Counts = [0. 0. 1. 0.]
# Node 2999: Class Counts = [0. 0. 2. 0.]
# Node 3044: Class Counts = [0. 0. 0. 2.]
# Node 3058: Class Counts = [0. 0. 6. 0.]
# Node 3084: Class Counts = [0. 0. 1. 0.]
# Node 3112: Class Counts = [0. 0. 1. 0.]
# Node 3114: Class Counts = [0. 0. 4. 2.]
# Node 3137: Class Counts = [0. 0. 0. 1.]
# Node 3166: Class Counts = [0. 0. 2. 0.]
# Node 3172: Class Counts = [0. 0. 1. 6.]
# Node 3197: Class Counts = [0. 0. 1. 0.]
# Node 3206: Class Counts = [0. 0. 8. 0.]
# Node 3210: Class Counts = [0. 0. 6. 0.]
# Node 3212: Class Counts = [0. 0. 1. 0.]
# Node 3243: Class Counts = [0. 0. 0. 1.]
# Node 3263: Class Counts = [0. 0. 4. 0.]
# Node 3265: Class Counts = [0. 0. 2. 0.]
# Node 3277: Class Counts = [0. 0. 0. 1.]
# Node 3332: Class Counts = [0. 0. 2. 0.]
# Node 3349: Class Counts = [0. 0. 1. 0.]
# Node 3385: Class Counts = [0. 0. 1. 0.]
# Node 3389: Class Counts = [0. 0. 1. 0.]
# Node 3391: Class Counts = [0. 0. 2. 0.]
# Node 3416: Class Counts = [0. 0. 1. 0.]
# Node 3471: Class Counts = [0. 0. 0. 1.]
# Node 3481: Class Counts = [0. 0. 3. 0.]
# Node 3483: Class Counts = [0. 0. 9. 0.]
# Node 3500: Class Counts = [0. 0. 4. 0.]
# Node 3503: Class Counts = [0. 0. 1. 0.]
# Node 3530: Class Counts = [0. 0. 1. 0.]
# Node 3535: Class Counts = [0. 0. 6. 0.]
# Node 3573: Class Counts = [0. 0. 1. 0.]
# Node 3576: Class Counts = [0. 0. 1. 0.]
# Node 3591: Class Counts = [0. 0. 0. 4.]
# Node 3605: Class Counts = [0. 0. 1. 0.]
# Node 3616: Class Counts = [0. 0. 1. 0.]
# Node 3626: Class Counts = [0. 0. 0. 1.]
# Node 3627: Class Counts = [0. 0. 1. 1.]
# Node 3635: Class Counts = [0. 0. 3. 0.]
# Node 3639: Class Counts = [0. 0. 5. 0.]
# Node 3647: Class Counts = [0. 0. 1. 0.]
# Node 3654: Class Counts = [0. 0. 2. 0.]
# Node 3655: Class Counts = [0. 0. 4. 0.]
# Node 3674: Class Counts = [0. 0. 0. 1.]
# Node 3676: Class Counts = [0. 0. 0. 3.]
# Node 3701: Class Counts = [0. 0. 2. 0.]
# Node 3707: Class Counts = [0. 0. 0. 3.]
# Node 3751: Class Counts = [0. 0. 1. 0.]
# Node 3755: Class Counts = [0. 0. 1. 0.]
# Node 3777: Class Counts = [0. 0. 3. 0.]
# Node 3787: Class Counts = [0. 0. 1. 0.]
# Node 3794: Class Counts = [0. 0. 3. 0.]
# Node 3796: Class Counts = [0. 0. 2. 0.]
# Node 3801: Class Counts = [0. 0. 2. 0.]
# Node 3818: Class Counts = [0. 0. 2. 0.]
# Node 3822: Class Counts = [0. 0. 1. 0.]
# Node 3824: Class Counts = [0. 0. 2. 0.]
# Node 3828: Class Counts = [0. 0. 2. 0.]
# Node 3847: Class Counts = [0. 0. 4. 0.]
# Node 3859: Class Counts = [0. 0. 0. 2.]
# Node 3867: Class Counts = [0. 0. 1. 0.]
# Node 3873: Class Counts = [0. 0. 1. 0.]
# Node 3877: Class Counts = [0. 0. 3. 0.]
# Node 3890: Class Counts = [0. 0. 0. 1.]
# Node 3892: Class Counts = [0. 0. 4. 0.]
# Node 3903: Class Counts = [0. 0. 0. 3.]
# Node 3908: Class Counts = [0. 0. 0. 2.]
# Node 3912: Class Counts = [0. 0. 0. 1.]
# Node 3924: Class Counts = [0. 0. 1. 0.]
# Node 3943: Class Counts = [0. 0. 2. 0.]
# Node 3945: Class Counts = [0. 0. 0. 2.]
# Node 3949: Class Counts = [0. 0. 0. 1.]
# Node 3950: Class Counts = [0. 0. 2. 0.]
# Node 3954: Class Counts = [0. 0. 2. 0.]
# Node 3956: Class Counts = [0. 0. 6. 0.]
# Node 3975: Class Counts = [0. 0. 2. 0.]
# Node 4036: Class Counts = [0. 0. 2. 0.]
# Node 4038: Class Counts = [0. 0. 5. 0.]
# Node 4049: Class Counts = [0. 0. 1. 0.]
# Node 4052: Class Counts = [0. 0. 1. 0.]
# Node 4056: Class Counts = [0. 0. 5. 0.]
# Node 4060: Class Counts = [0. 0. 0. 1.]
# Node 4071: Class Counts = [0. 0. 1. 0.]
# Node 4078: Class Counts = [0. 0. 0. 1.]
# Node 4101: Class Counts = [0. 0. 2. 0.]
# Node 4113: Class Counts = [0. 0. 1. 0.]
# Node 4115: Class Counts = [0. 0. 1. 0.]
# Node 4136: Class Counts = [0. 0. 3. 0.]
# Node 4142: Class Counts = [0. 0. 1. 0.]
# Node 4153: Class Counts = [0. 0. 1. 0.]
# Node 4155: Class Counts = [0. 0. 3. 0.]
# Node 4177: Class Counts = [0. 0. 2. 0.]
# Node 4180: Class Counts = [0. 0. 2. 0.]
# Node 4189: Class Counts = [0. 0. 0. 1.]
# Node 4196: Class Counts = [0. 0. 2. 0.]
# Node 4203: Class Counts = [0. 0. 6. 0.]
# Node 4207: Class Counts = [0. 0. 2. 0.]
# Node 4211: Class Counts = [0. 0. 1. 2.]
# Node 4213: Class Counts = [0. 0. 2. 0.]
# Node 4225: Class Counts = [0. 0. 2. 0.]
# Node 4229: Class Counts = [0. 0. 2. 0.]
# Node 4252: Class Counts = [0. 0. 1. 0.]
# Node 4255: Class Counts = [0. 0. 0. 1.]
# Node 4262: Class Counts = [0. 0. 2. 0.]
# Node 4267: Class Counts = [0. 0. 1. 0.]
# Node 4272: Class Counts = [0. 0. 1. 0.]
# Node 4274: Class Counts = [0. 0. 2. 0.]
# Node 4279: Class Counts = [0. 0. 3. 0.]
# Node 4287: Class Counts = [0. 0. 2. 0.]
# Node 4289: Class Counts = [0. 0. 2. 0.]
# Node 4314: Class Counts = [0. 0. 0. 1.]
# Node 4315: Class Counts = [0. 0. 3. 0.]
# Node 4317: Class Counts = [0. 0. 0. 3.]
# Node 4322: Class Counts = [0. 0. 4. 0.]
# Node 4342: Class Counts = [0. 0. 1. 0.]
# Node 4375: Class Counts = [0. 0. 5. 0.]
# Node 4390: Class Counts = [0. 0. 4. 0.]
# Node 4410: Class Counts = [0. 0. 3. 0.]
# Node 4414: Class Counts = [0. 0. 1. 1.]
# Node 4417: Class Counts = [0. 0. 9. 0.]
# Node 4419: Class Counts = [0. 0. 1. 0.]
# Node 4425: Class Counts = [0. 0. 0. 1.]
# Node 4432: Class Counts = [0. 0. 2. 0.]
# Node 4434: Class Counts = [0. 0. 1. 0.]
# Node 4439: Class Counts = [0. 0. 2. 0.]
# Node 4443: Class Counts = [0. 0. 0. 1.]
# Node 4444: Class Counts = [0. 0. 8. 0.]
# Node 4450: Class Counts = [0. 0. 0. 1.]
# Node 4464: Class Counts = [0. 0. 0. 3.]
# Node 4472: Class Counts = [0. 0. 3. 0.]
# Node 4484: Class Counts = [0. 0. 1. 0.]
# Node 4488: Class Counts = [0. 0. 1. 0.]
# Node 4498: Class Counts = [0. 0. 3. 0.]
# Node 4501: Class Counts = [0. 0. 0. 1.]
# Node 4539: Class Counts = [0. 0. 4. 0.]
# Node 4544: Class Counts = [0. 0. 2. 0.]
# Node 4548: Class Counts = [0. 0. 6. 0.]
# Node 4563: Class Counts = [0. 0. 2. 0.]
# Node 4616: Class Counts = [0. 0. 0. 3.]
# Node 4626: Class Counts = [0. 0. 1. 0.]
# Node 4643: Class Counts = [0. 0. 0. 1.]
# Node 4654: Class Counts = [0. 0. 1. 0.]
# Node 4661: Class Counts = [0. 0. 1. 8.]
# Node 4662: Class Counts = [0. 0. 1. 0.]
# Node 4672: Class Counts = [0. 0. 4. 0.]
# Node 4675: Class Counts = [0. 0. 1. 0.]
# Node 4708: Class Counts = [0. 0. 2. 0.]
# Node 4717: Class Counts = [0. 0. 1. 0.]
# Node 4725: Class Counts = [0. 0. 1. 0.]
# Node 4747: Class Counts = [0. 0. 0. 1.]
# Node 4763: Class Counts = [0. 0. 0. 1.]
# Node 4785: Class Counts = [0. 0. 2. 0.]
# Node 4794: Class Counts = [0. 0. 1. 0.]
# Node 4795: Class Counts = [0. 0. 0. 1.]
# Node 4807: Class Counts = [0. 0. 3. 0.]
# Node 4821: Class Counts = [0. 0. 2. 0.]
# Node 4840: Class Counts = [0. 0. 2. 0.]
# Node 4866: Class Counts = [0. 0. 1. 0.]
# Node 4870: Class Counts = [0. 0. 0. 1.]
# Node 4879: Class Counts = [0. 0. 4. 0.]
# Node 4886: Class Counts = [0. 0. 3. 0.]
# Node 4899: Class Counts = [0. 0. 2. 0.]
# Node 4903: Class Counts = [0. 0. 0. 2.]
# Node 4914: Class Counts = [0. 0. 0. 4.]
# Node 4916: Class Counts = [0. 0. 1. 0.]
# Node 4917: Class Counts = [0. 0. 0. 3.]
# Node 4919: Class Counts = [0. 0. 3. 0.]
# Node 4932: Class Counts = [0. 0. 1. 0.]
# Node 4933: Class Counts = [0. 0. 0. 1.]
# Node 4940: Class Counts = [0. 0. 0. 2.]
# Node 4945: Class Counts = [0. 0. 0. 2.]
# Node 4946: Class Counts = [0. 0. 0. 3.]
# Node 4962: Class Counts = [0. 0. 1. 0.]
# Node 4967: Class Counts = [0. 0. 2. 0.]
# Node 4969: Class Counts = [0. 0. 1. 0.]
# Node 4980: Class Counts = [0. 0. 0. 1.]
# Node 4989: Class Counts = [0. 0. 0. 1.]
# Node 4990: Class Counts = [0. 0. 1. 0.]
# Node 4995: Class Counts = [ 0.  0. 16.  0.]
# Node 4996: Class Counts = [0. 0. 0. 1.]
# Node 5004: Class Counts = [0. 0. 8. 0.]
# Node 5012: Class Counts = [0. 0. 1. 0.]
# Node 5019: Class Counts = [0. 0. 0. 2.]
# Node 5034: Class Counts = [0. 0. 0. 1.]
# Node 5035: Class Counts = [0. 0. 2. 0.]
# Node 5050: Class Counts = [0. 0. 5. 0.]
# Node 5061: Class Counts = [0. 0. 0. 3.]
# Node 5073: Class Counts = [0. 0. 2. 0.]
# Node 5078: Class Counts = [0. 0. 2. 0.]
# Node 5081: Class Counts = [0. 0. 0. 2.]
# Node 5087: Class Counts = [0. 0. 1. 0.]
# Node 5090: Class Counts = [0. 0. 0. 1.]
# Node 5094: Class Counts = [0. 0. 1. 0.]
# Node 5101: Class Counts = [0. 0. 4. 0.]
# Node 5110: Class Counts = [0. 0. 1. 0.]
# Node 5112: Class Counts = [0. 0. 2. 0.]
# Node 5123: Class Counts = [0. 0. 3. 0.]
# Node 5125: Class Counts = [0. 0. 2. 0.]
# Node 5131: Class Counts = [0. 0. 0. 2.]
# Node 5133: Class Counts = [0. 0. 0. 1.]
# Node 5135: Class Counts = [0. 0. 0. 1.]
# Node 5146: Class Counts = [0. 0. 1. 0.]
# Node 5149: Class Counts = [0. 0. 1. 0.]
# Node 5151: Class Counts = [0. 0. 3. 0.]
# Node 5165: Class Counts = [0. 0. 7. 0.]
# Node 5177: Class Counts = [0. 0. 3. 0.]
# Node 5178: Class Counts = [0. 0. 0. 1.]
# Node 5188: Class Counts = [ 0.  0. 11.  0.]
# Node 5196: Class Counts = [0. 0. 4. 0.]
# Node 5197: Class Counts = [0. 0. 0. 1.]
# Node 5201: Class Counts = [ 0.  0. 21.  0.]
# Node 5205: Class Counts = [0. 0. 4. 0.]
# Node 5214: Class Counts = [0. 0. 2. 0.]
# Node 5221: Class Counts = [0. 0. 0. 1.]
# Node 5227: Class Counts = [0. 0. 0. 1.]
# Node 5232: Class Counts = [0. 0. 0. 5.]
# Node 5235: Class Counts = [0. 0. 2. 0.]
# Node 5236: Class Counts = [0. 0. 0. 1.]
# Node 5244: Class Counts = [0. 0. 0. 1.]
# Node 5245: Class Counts = [0. 0. 1. 0.]
# Node 5246: Class Counts = [0. 0. 0. 7.]
# Node 5247: Class Counts = [0. 0. 2. 0.]
# Node 5257: Class Counts = [0. 0. 0. 3.]
# Node 5262: Class Counts = [0. 0. 0. 8.]
# Node 5267: Class Counts = [0. 0. 3. 0.]
# Node 5275: Class Counts = [0. 0. 0. 3.]
# Node 5281: Class Counts = [0. 0. 4. 0.]
# Node 5291: Class Counts = [0. 0. 0. 1.]
# Node 5300: Class Counts = [0. 0. 2. 0.]
# Node 5310: Class Counts = [0. 0. 0. 2.]
# Node 5313: Class Counts = [0. 0. 2. 0.]
# Node 5319: Class Counts = [0. 0. 5. 0.]
# Node 5321: Class Counts = [0. 0. 1. 0.]
# Node 5326: Class Counts = [0. 0. 1. 0.]
# Node 5327: Class Counts = [0. 0. 0. 3.]
# Node 5331: Class Counts = [0. 0. 1. 0.]
# Node 5333: Class Counts = [0. 0. 1. 0.]
# Node 5334: Class Counts = [0. 0. 0. 2.]
# Node 5337: Class Counts = [0. 0. 5. 0.]
# Node 5343: Class Counts = [0. 0. 1. 0.]
# Node 5354: Class Counts = [0. 0. 1. 0.]
# Node 5361: Class Counts = [0. 0. 3. 0.]
# Node 5365: Class Counts = [0. 0. 3. 0.]
# Node 5369: Class Counts = [0. 0. 4. 0.]
# Node 5372: Class Counts = [0. 0. 1. 0.]
# Node 5373: Class Counts = [0. 0. 0. 2.]
# Node 5378: Class Counts = [0. 0. 1. 0.]
# Node 5379: Class Counts = [0. 0. 0. 2.]
# Node 5385: Class Counts = [0. 0. 1. 0.]
# Node 5388: Class Counts = [ 0.  0. 11.  0.]
# Node 5390: Class Counts = [0. 0. 1. 0.]
# Node 5392: Class Counts = [ 0.  0. 11.  0.]
# Node 5395: Class Counts = [0. 0. 8. 0.]
# Node 5397: Class Counts = [0. 0. 1. 0.]
# Node 5399: Class Counts = [0. 0. 0. 1.]
# Node 5404: Class Counts = [ 0.  0. 42.  0.]
# Node 5406: Class Counts = [0. 0. 3. 0.]
# Node 5408: Class Counts = [0. 0. 1. 0.]
# Node 5409: Class Counts = [0. 0. 0. 2.]
# Node 5411: Class Counts = [0. 0. 1. 0.]
# Node 5412: Class Counts = [0. 0. 0. 2.]
# Node 5413: Class Counts = [ 0.  0. 44.  0.]
# Node 5415: Class Counts = [0. 0. 4. 0.]
# Node 5420: Class Counts = [0. 0. 2. 0.]
# Node 5422: Class Counts = [0. 0. 2. 0.]
# Node 5425: Class Counts = [0. 0. 0. 1.]
# Node 5428: Class Counts = [0. 0. 3. 0.]
# Node 5429: Class Counts = [0. 0. 0. 2.]
# Node 5442: Class Counts = [0. 0. 1. 0.]
# Node 5452: Class Counts = [0. 0. 0. 3.]
# Node 5457: Class Counts = [0. 0. 0. 2.]
# Node 5469: Class Counts = [0. 0. 1. 0.]
# Node 5472: Class Counts = [0. 0. 0. 1.]
# Node 5475: Class Counts = [0. 0. 1. 0.]
# Node 5496: Class Counts = [0. 0. 0. 4.]
# Node 5501: Class Counts = [0. 0. 1. 0.]
# Node 5527: Class Counts = [0. 0. 2. 0.]
# Node 5531: Class Counts = [0. 0. 2. 0.]
# Node 5542: Class Counts = [0. 0. 5. 0.]
# Node 5544: Class Counts = [0. 0. 1. 0.]
# Node 5572: Class Counts = [0. 0. 1. 0.]
# Node 5597: Class Counts = [0. 0. 1. 0.]
# Node 5605: Class Counts = [0. 0. 0. 1.]
# Node 5639: Class Counts = [0. 0. 0. 1.]
# Node 5644: Class Counts = [0. 0. 0. 2.]
# Node 5647: Class Counts = [0. 0. 1. 0.]
# Node 5653: Class Counts = [0. 0. 0. 1.]
# Node 5684: Class Counts = [0. 0. 2. 0.]
# Node 5696: Class Counts = [0. 0. 2. 0.]
# Node 5702: Class Counts = [0. 0. 2. 0.]
# Node 5735: Class Counts = [0. 0. 1. 0.]
# Node 5746: Class Counts = [0. 0. 2. 0.]
# Node 5816: Class Counts = [0. 0. 0. 1.]
# Node 5822: Class Counts = [0. 0. 1. 0.]
# Node 5868: Class Counts = [0. 0. 1. 1.]
# Node 5917: Class Counts = [0. 0. 1. 0.]
# Node 5921: Class Counts = [0. 0. 0. 1.]
# Node 5943: Class Counts = [0. 0. 0. 2.]
# Node 5971: Class Counts = [0. 0. 2. 0.]
# Node 6009: Class Counts = [0. 0. 2. 0.]
# Node 6023: Class Counts = [0. 0. 0. 1.]
# Node 6071: Class Counts = [0. 0. 1. 0.]
# Node 6113: Class Counts = [0. 0. 3. 0.]
# Node 6116: Class Counts = [0. 0. 1. 0.]
# Node 6174: Class Counts = [ 0.  0.  0. 71.]
# Node 6181: Class Counts = [0. 0. 0. 2.]
# Node 6196: Class Counts = [0. 0. 2. 0.]
# Node 6202: Class Counts = [0. 0. 2. 0.]
# Node 6207: Class Counts = [ 0.  0.  0. 15.]
# Node 6237: Class Counts = [0. 0. 4. 0.]
# Node 6251: Class Counts = [0. 0. 1. 0.]
# Node 6295: Class Counts = [0. 0. 0. 2.]
# Node 6320: Class Counts = [0. 0. 1. 0.]
# Node 6341: Class Counts = [0. 0. 0. 1.]
# Node 6343: Class Counts = [0. 0. 0. 2.]
# Node 6348: Class Counts = [0. 0. 1. 0.]
# Node 6373: Class Counts = [0. 0. 1. 0.]
# Node 6398: Class Counts = [0. 0. 0. 4.]
# Node 6403: Class Counts = [0. 0. 0. 2.]
# Node 6410: Class Counts = [0. 0. 0. 5.]
# Node 6411: Class Counts = [ 0.  0.  0. 12.]
# Node 6414: Class Counts = [0. 0. 1. 0.]
# Node 6417: Class Counts = [0. 0. 0. 1.]
# Node 6420: Class Counts = [0. 0. 1. 0.]
# Node 6483: Class Counts = [0. 0. 0. 1.]
# Node 6503: Class Counts = [0. 0. 1. 0.]
# Node 6515: Class Counts = [0. 0. 1. 0.]
# Node 6595: Class Counts = [0. 0. 0. 2.]
# Node 6598: Class Counts = [0. 0. 1. 0.]
# Node 6622: Class Counts = [0. 0. 1. 0.]
# Node 6656: Class Counts = [0. 0. 4. 0.]
# Node 6662: Class Counts = [0. 0. 1. 0.]
# Node 6664: Class Counts = [0. 0. 0. 1.]
# Node 6670: Class Counts = [0. 0. 1. 0.]
# Node 6676: Class Counts = [0. 0. 0. 3.]
# Node 6679: Class Counts = [0. 0. 1. 0.]
# Node 6682: Class Counts = [0. 0. 0. 1.]
# Node 6696: Class Counts = [0. 0. 1. 0.]
# Node 6717: Class Counts = [0. 0. 0. 1.]
# Node 6729: Class Counts = [0. 0. 1. 0.]
# Node 6731: Class Counts = [0. 0. 2. 0.]
# Node 6732: Class Counts = [0. 0. 3. 0.]
# Node 6740: Class Counts = [0. 0. 2. 0.]
# Node 6752: Class Counts = [0. 0. 1. 0.]
# Node 6754: Class Counts = [0. 0. 1. 0.]
# Node 6772: Class Counts = [0. 0. 0. 1.]
# Node 6773: Class Counts = [0. 0. 1. 0.]
# Node 6776: Class Counts = [0. 0. 0. 1.]
# Node 6778: Class Counts = [0. 0. 0. 1.]
# Node 6799: Class Counts = [0. 0. 2. 0.]
# Node 6801: Class Counts = [0. 0. 1. 0.]
# Node 6809: Class Counts = [0. 0. 0. 1.]
# Node 6810: Class Counts = [0. 0. 1. 0.]
# Node 6857: Class Counts = [0. 0. 1. 0.]
# Node 6860: Class Counts = [0. 0. 4. 0.]
# Node 6870: Class Counts = [0. 0. 0. 1.]
# Node 6875: Class Counts = [0. 0. 0. 2.]
# Node 6886: Class Counts = [0. 0. 0. 1.]
# Node 6887: Class Counts = [0. 0. 2. 0.]
# Node 6898: Class Counts = [0. 0. 1. 0.]
# Node 6901: Class Counts = [0. 0. 1. 0.]
# Node 6909: Class Counts = [0. 0. 1. 0.]
# Node 6946: Class Counts = [0. 0. 3. 0.]
# Node 6953: Class Counts = [0. 0. 4. 0.]
# Node 6959: Class Counts = [0. 0. 2. 0.]
# Node 6962: Class Counts = [0. 0. 0. 2.]
# Node 6969: Class Counts = [0. 0. 3. 0.]
# Node 6977: Class Counts = [0. 0. 0. 1.]
# Node 6986: Class Counts = [0. 0. 2. 0.]
# Node 6992: Class Counts = [0. 0. 3. 0.]
# Node 6995: Class Counts = [0. 0. 2. 0.]
# Node 7005: Class Counts = [0. 0. 2. 0.]
# Node 7009: Class Counts = [0. 0. 0. 2.]
# Node 7012: Class Counts = [0. 0. 1. 0.]
# Node 7022: Class Counts = [0. 0. 2. 0.]
# Node 7046: Class Counts = [0. 0. 0. 1.]
# Node 7062: Class Counts = [0. 0. 1. 0.]
# Node 7075: Class Counts = [0. 0. 2. 0.]
# Node 7086: Class Counts = [0. 0. 0. 2.]
# Node 7115: Class Counts = [0. 0. 1. 0.]
# Node 7122: Class Counts = [0. 0. 3. 0.]
# Node 7124: Class Counts = [0. 0. 8. 0.]
# Node 7147: Class Counts = [0. 0. 1. 0.]
# Node 7151: Class Counts = [0. 0. 0. 2.]
# Node 7152: Class Counts = [0. 0. 1. 0.]
# Node 7158: Class Counts = [0. 0. 5. 0.]
# Node 7161: Class Counts = [0. 0. 0. 1.]
# Node 7172: Class Counts = [0. 0. 0. 2.]
# Node 7186: Class Counts = [0. 0. 5. 0.]
# Node 7191: Class Counts = [0. 0. 5. 0.]
# Node 7194: Class Counts = [0. 0. 0. 1.]
# Node 7199: Class Counts = [0. 0. 3. 0.]
# Node 7202: Class Counts = [0. 0. 1. 0.]
# Node 7206: Class Counts = [0. 0. 1. 0.]
# Node 7208: Class Counts = [0. 0. 0. 1.]
# Node 7214: Class Counts = [0. 0. 3. 0.]
# Node 7216: Class Counts = [ 0.  0. 12.  0.]
# Node 7242: Class Counts = [0. 0. 0. 1.]
# Node 7244: Class Counts = [0. 0. 5. 0.]
# Node 7245: Class Counts = [0. 0. 1. 1.]
# Node 7251: Class Counts = [0. 0. 1. 0.]
# Node 7254: Class Counts = [0. 0. 1. 0.]
# Node 7260: Class Counts = [0. 0. 2. 0.]
# Node 7268: Class Counts = [0. 0. 0. 2.]
# Node 7278: Class Counts = [0. 0. 0. 1.]
# Node 7287: Class Counts = [0. 0. 2. 0.]
# Node 7294: Class Counts = [0. 0. 2. 0.]
# Node 7301: Class Counts = [0. 0. 0. 1.]
# Node 7304: Class Counts = [0. 0. 0. 3.]
# Node 7309: Class Counts = [0. 0. 0. 5.]
# Node 7317: Class Counts = [0. 0. 0. 1.]
# Node 7321: Class Counts = [0. 0. 0. 5.]
# Node 7323: Class Counts = [0. 0. 0. 1.]
# Node 7333: Class Counts = [0. 0. 3. 0.]
# Node 7338: Class Counts = [0. 0. 0. 3.]
# Node 7346: Class Counts = [0. 0. 0. 1.]
# Node 7354: Class Counts = [0. 0. 1. 0.]
# Node 7356: Class Counts = [0. 0. 0. 4.]
# Node 7362: Class Counts = [0. 0. 0. 1.]
# Node 7367: Class Counts = [0. 0. 3. 0.]
# Node 7372: Class Counts = [0. 0. 2. 0.]
# Node 7375: Class Counts = [0. 0. 0. 1.]
# Node 7378: Class Counts = [0. 0. 0. 1.]
# Node 7388: Class Counts = [0. 0. 1. 0.]
# Node 7396: Class Counts = [0. 0. 0. 1.]
# Node 7398: Class Counts = [0. 0. 0. 2.]
# Node 7408: Class Counts = [0. 0. 3. 0.]
# Node 7410: Class Counts = [0. 0. 3. 0.]
# Node 7412: Class Counts = [0. 0. 0. 2.]
# Node 7446: Class Counts = [0. 0. 0. 1.]
# Node 7447: Class Counts = [0. 0. 0. 7.]
# Node 7452: Class Counts = [0. 0. 1. 0.]
# Node 7460: Class Counts = [0. 0. 0. 1.]
# Node 7464: Class Counts = [0. 0. 1. 0.]
# Node 7472: Class Counts = [0. 0. 0. 1.]
# Node 7479: Class Counts = [0. 0. 1. 0.]
# Node 7484: Class Counts = [0. 0. 1. 0.]
# Node 7485: Class Counts = [0. 0. 6. 0.]
# Node 7498: Class Counts = [0. 0. 1. 0.]
# Node 7500: Class Counts = [0. 0. 0. 1.]
# Node 7505: Class Counts = [0. 0. 1. 0.]
# Node 7507: Class Counts = [0. 0. 4. 0.]
# Node 7509: Class Counts = [0. 0. 1. 0.]
# Node 7546: Class Counts = [0. 0. 3. 0.]
# Node 7549: Class Counts = [0. 0. 2. 0.]
# Node 7550: Class Counts = [0. 0. 0. 1.]
# Node 7561: Class Counts = [0. 0. 1. 0.]
# Node 7569: Class Counts = [0. 0. 1. 0.]
# Node 7572: Class Counts = [0. 0. 5. 0.]
# Node 7574: Class Counts = [0. 0. 2. 0.]
# Node 7578: Class Counts = [0. 0. 0. 1.]
# Node 7583: Class Counts = [0. 0. 0. 2.]
# Node 7587: Class Counts = [0. 0. 0. 9.]
# Node 7590: Class Counts = [0. 0. 0. 4.]
# Node 7601: Class Counts = [0. 0. 0. 2.]
# Node 7605: Class Counts = [0. 0. 0. 4.]
# Node 7617: Class Counts = [0. 0. 0. 2.]
# Node 7639: Class Counts = [0. 0. 2. 0.]
# Node 7640: Class Counts = [0. 0. 0. 4.]
# Node 7643: Class Counts = [0. 0. 0. 2.]
# Node 7649: Class Counts = [0. 0. 0. 1.]
# Node 7670: Class Counts = [0. 0. 9. 0.]
# Node 7689: Class Counts = [0. 0. 3. 0.]
# Node 7692: Class Counts = [0. 0. 0. 4.]
# Node 7700: Class Counts = [0. 0. 0. 1.]
# Node 7718: Class Counts = [0. 0. 0. 5.]
# Node 7728: Class Counts = [0. 0. 2. 0.]
# Node 7732: Class Counts = [0. 0. 1. 0.]
# Node 7737: Class Counts = [0. 0. 0. 4.]
# Node 7741: Class Counts = [0. 0. 1. 6.]
# Node 7742: Class Counts = [0. 0. 4. 0.]
# Node 7744: Class Counts = [0. 0. 0. 8.]
# Node 7763: Class Counts = [0. 0. 0. 3.]
# Node 7799: Class Counts = [0. 0. 0. 3.]
# Node 7817: Class Counts = [0. 0. 3. 0.]
# Node 7820: Class Counts = [0. 0. 0. 1.]
# Node 7826: Class Counts = [0. 0. 3. 2.]
# Node 7827: Class Counts = [0. 0. 0. 6.]
# Node 7828: Class Counts = [0. 0. 0. 8.]
# Node 7834: Class Counts = [0. 0. 0. 4.]
# Node 7836: Class Counts = [0. 0. 0. 1.]
# Node 7840: Class Counts = [0. 0. 0. 1.]
# Node 7843: Class Counts = [ 0.  0.  0. 16.]
# Node 7847: Class Counts = [0. 0. 0. 8.]
# Node 7854: Class Counts = [0. 0. 0. 2.]
# Node 7859: Class Counts = [0. 0. 0. 2.]
# Node 7862: Class Counts = [0. 0. 2. 0.]
# Node 7869: Class Counts = [0. 0. 0. 3.]
# Node 7873: Class Counts = [0. 0. 0. 7.]
# Node 7877: Class Counts = [0. 0. 0. 1.]
# Node 7879: Class Counts = [0. 0. 0. 7.]
# Node 7881: Class Counts = [0. 0. 1. 0.]
# Node 7882: Class Counts = [0. 0. 0. 1.]
# Node 7889: Class Counts = [0. 0. 0. 1.]
# Node 7893: Class Counts = [0. 0. 0. 1.]
# Node 7897: Class Counts = [0. 0. 0. 5.]
# Node 7901: Class Counts = [0. 0. 1. 0.]
# Node 7903: Class Counts = [0. 0. 2. 0.]
# Node 7909: Class Counts = [0. 0. 1. 0.]
# Node 7911: Class Counts = [0. 0. 0. 1.]
# Node 7923: Class Counts = [0. 0. 3. 0.]
# Node 7925: Class Counts = [0. 0. 3. 0.]
# Node 7927: Class Counts = [ 0.  0.  0. 11.]
# Node 7929: Class Counts = [0. 0. 2. 0.]
# Node 7930: Class Counts = [0. 0. 0. 3.]
# Node 7933: Class Counts = [ 0.  0.  0. 20.]
# Node 7935: Class Counts = [0. 0. 0. 3.]
# Node 7939: Class Counts = [0. 0. 0. 1.]
# Node 7944: Class Counts = [0. 0. 0. 3.]
# Node 7951: Class Counts = [ 0.  0. 11.  0.]
# Node 7953: Class Counts = [0. 0. 2. 0.]
# Node 7956: Class Counts = [0. 0. 1. 0.]
# Node 7963: Class Counts = [0. 0. 0. 2.]
# Node 7965: Class Counts = [0. 0. 0. 1.]
# Node 7967: Class Counts = [0. 0. 8. 0.]
# Node 7968: Class Counts = [0. 0. 1. 1.]
# Node 7970: Class Counts = [0. 0. 0. 4.]
# Node 7971: Class Counts = [0. 0. 1. 0.]
# Node 7972: Class Counts = [0. 0. 5. 0.]
# Node 7975: Class Counts = [0. 0. 4. 0.]
# Node 7979: Class Counts = [0. 0. 7. 0.]
# Node 7980: Class Counts = [0. 0. 0. 2.]
# Node 7988: Class Counts = [0. 0. 1. 0.]
# Node 7990: Class Counts = [0. 0. 9. 0.]
# Node 7992: Class Counts = [0. 0. 8. 0.]
# Node 7993: Class Counts = [ 0.  0. 55.  0.]
# Node 7994: Class Counts = [0. 0. 0. 1.]
# Node 7999: Class Counts = [0. 0. 0. 3.]
# Node 8003: Class Counts = [0. 0. 0. 3.]
# Node 8009: Class Counts = [0. 0. 1. 0.]
# Node 8013: Class Counts = [0. 0. 0. 2.]
# Node 8014: Class Counts = [0. 0. 2. 0.]
# Node 8016: Class Counts = [0. 0. 0. 2.]
# Node 8022: Class Counts = [0. 0. 0. 1.]
# Node 8026: Class Counts = [0. 0. 1. 0.]
# Node 8028: Class Counts = [0. 0. 8. 0.]
# Node 8030: Class Counts = [0. 0. 0. 5.]
# Node 8036: Class Counts = [ 0.  0. 11.  0.]
# Node 8039: Class Counts = [0. 0. 2. 0.]
# Node 8041: Class Counts = [0. 0. 1. 0.]
# Node 8044: Class Counts = [0. 0. 0. 1.]
# Node 8049: Class Counts = [ 0.  0. 12.  0.]
# Node 8050: Class Counts = [0. 0. 0. 1.]
# Node 8051: Class Counts = [0. 0. 0. 1.]
# Node 8054: Class Counts = [0. 0. 2. 0.]
# Node 8055: Class Counts = [0. 0. 0. 1.]
# Node 8056: Class Counts = [0. 0. 0. 2.]
# Node 8058: Class Counts = [0. 0. 0. 4.]
# Node 8060: Class Counts = [0. 0. 0. 1.]
# Node 8061: Class Counts = [0. 0. 1. 0.]
# Node 8066: Class Counts = [0. 0. 0. 2.]
# Node 8073: Class Counts = [0. 0. 6. 0.]
# Node 8075: Class Counts = [ 0.  0. 10.  0.]
# Node 8078: Class Counts = [0. 0. 1. 0.]
# Node 8094: Class Counts = [0. 0. 1. 0.]
# Node 8099: Class Counts = [0. 0. 0. 2.]
# Node 8108: Class Counts = [0. 0. 0. 2.]
# Node 8148: Class Counts = [0. 0. 2. 1.]
# Node 8171: Class Counts = [0. 0. 0. 4.]
# Node 8218: Class Counts = [0. 0. 0. 2.]
# Node 8223: Class Counts = [0. 0. 2. 0.]
# Node 8295: Class Counts = [0. 0. 0. 2.]
# Node 8328: Class Counts = [0. 0. 0. 1.]
# Node 8333: Class Counts = [0. 0. 0. 5.]
# Node 8339: Class Counts = [0. 0. 0. 1.]
# Node 8344: Class Counts = [0. 0. 1. 0.]
# Node 8346: Class Counts = [0. 0. 5. 0.]
# Node 8347: Class Counts = [0. 0. 0. 3.]
# Node 8359: Class Counts = [0. 0. 0. 4.]
# Node 8365: Class Counts = [0. 0. 3. 0.]
# Node 8370: Class Counts = [0. 0. 0. 3.]
# Node 8381: Class Counts = [0. 0. 0. 6.]
# Node 8389: Class Counts = [0. 0. 0. 5.]
# Node 8393: Class Counts = [0. 0. 0. 5.]
# Node 8396: Class Counts = [0. 0. 0. 8.]
# Node 8398: Class Counts = [0. 0. 0. 1.]
# Node 8399: Class Counts = [0. 0. 1. 0.]
# Node 8453: Class Counts = [0. 0. 1. 1.]
# Node 8535: Class Counts = [0. 0. 3. 0.]
# Node 8547: Class Counts = [0. 0. 0. 3.]
# Node 8552: Class Counts = [ 0.  0.  0. 27.]
# Node 8593: Class Counts = [0. 0. 3. 0.]
# Node 8597: Class Counts = [0. 0. 0. 6.]
# Node 8599: Class Counts = [0. 0. 0. 2.]
# Node 8603: Class Counts = [0. 0. 0. 1.]
# Node 8606: Class Counts = [0. 0. 1. 0.]
# Node 8607: Class Counts = [0. 0. 0. 7.]
# Node 8659: Class Counts = [0. 0. 0. 2.]
# Node 8675: Class Counts = [0. 0. 0. 1.]
# Node 8693: Class Counts = [0. 0. 0. 6.]
# Node 8696: Class Counts = [0. 0. 0. 1.]
# Node 8701: Class Counts = [0. 0. 2. 0.]
# Node 8706: Class Counts = [0. 0. 0. 1.]
# Node 8729: Class Counts = [0. 0. 1. 0.]
# Node 8732: Class Counts = [0. 0. 3. 1.]
# Node 8742: Class Counts = [0. 0. 1. 0.]
# Node 8746: Class Counts = [0. 0. 0. 2.]
# Node 8752: Class Counts = [ 0.  0.  0. 11.]
# Node 8755: Class Counts = [0. 0. 3. 1.]
# Node 8756: Class Counts = [0. 0. 0. 2.]
# Node 8769: Class Counts = [0. 0. 2. 9.]
# Node 8772: Class Counts = [0. 0. 0. 4.]
# Node 8775: Class Counts = [0. 0. 1. 3.]
# Node 8778: Class Counts = [0. 0. 6. 0.]
# Node 8791: Class Counts = [0. 0. 0. 1.]
# Node 8792: Class Counts = [0. 0. 1. 0.]
# Node 8798: Class Counts = [ 0.  0.  0. 21.]
# Node 8806: Class Counts = [ 0.  0.  0. 51.]
# Node 8811: Class Counts = [ 0.  0.  0. 12.]
# Node 8814: Class Counts = [0. 0. 0. 4.]
# Node 8816: Class Counts = [0. 0. 0. 1.]
# Node 8825: Class Counts = [0. 0. 2. 0.]
# Node 8838: Class Counts = [0. 0. 1. 0.]
# Node 8853: Class Counts = [0. 0. 3. 0.]
# Node 8885: Class Counts = [0. 0. 0. 4.]
# Node 8886: Class Counts = [0. 0. 1. 0.]
# Node 8889: Class Counts = [0. 0. 0. 1.]
# Node 8895: Class Counts = [0. 0. 0. 4.]
# Node 8900: Class Counts = [0. 0. 0. 4.]
# Node 8907: Class Counts = [0. 0. 0. 1.]
# Node 8909: Class Counts = [0. 0. 0. 4.]
# Node 8913: Class Counts = [0. 0. 0. 2.]
# Node 8930: Class Counts = [0. 0. 3. 0.]
# Node 8932: Class Counts = [0. 0. 0. 2.]
# Node 8935: Class Counts = [0. 0. 5. 0.]
# Node 8939: Class Counts = [0. 0. 0. 2.]
# Node 8954: Class Counts = [0. 0. 4. 0.]
# Node 8956: Class Counts = [0. 0. 1. 0.]
# Node 8961: Class Counts = [0. 0. 1. 0.]
# Node 8963: Class Counts = [0. 0. 1. 0.]
# Node 8971: Class Counts = [0. 0. 1. 0.]
# Node 8974: Class Counts = [0. 0. 0. 4.]
# Node 8977: Class Counts = [0. 0. 0. 1.]
# Node 8980: Class Counts = [ 0.  0.  0. 10.]
# Node 8988: Class Counts = [0. 0. 2. 0.]
# Node 8991: Class Counts = [0. 0. 0. 2.]
# Node 8995: Class Counts = [0. 0. 0. 4.]
# Node 8998: Class Counts = [0. 0. 0. 3.]
# Node 9021: Class Counts = [0. 0. 1. 1.]
# Node 9022: Class Counts = [0. 0. 0. 6.]
# Node 9036: Class Counts = [0. 0. 2. 0.]
# Node 9040: Class Counts = [0. 0. 0. 2.]
# Node 9043: Class Counts = [0. 0. 3. 0.]
# Node 9059: Class Counts = [0. 0. 0. 2.]
# Node 9078: Class Counts = [0. 0. 7. 0.]
# Node 9081: Class Counts = [0. 0. 0. 2.]
# Node 9086: Class Counts = [0. 0. 0. 2.]
# Node 9087: Class Counts = [0. 0. 1. 0.]
# Node 9101: Class Counts = [0. 0. 0. 2.]
# Node 9116: Class Counts = [0. 0. 2. 0.]
# Node 9136: Class Counts = [0. 0. 0. 5.]
# Node 9141: Class Counts = [0. 0. 2. 0.]
# Node 9143: Class Counts = [0. 0. 1. 0.]
# Node 9168: Class Counts = [0. 0. 0. 1.]
# Node 9180: Class Counts = [0. 0. 0. 2.]
# Node 9186: Class Counts = [0. 0. 2. 1.]
# Node 9204: Class Counts = [0. 0. 1. 0.]
# Node 9217: Class Counts = [0. 0. 0. 2.]
# Node 9224: Class Counts = [0. 0. 0. 2.]
# Node 9238: Class Counts = [0. 0. 3. 0.]
# Node 9257: Class Counts = [0. 0. 0. 2.]
# Node 9264: Class Counts = [0. 0. 0. 3.]
# Node 9279: Class Counts = [0. 0. 0. 2.]
# Node 9282: Class Counts = [0. 0. 0. 2.]
# Node 9288: Class Counts = [0. 0. 0. 5.]
# Node 9293: Class Counts = [0. 0. 0. 2.]
# Node 9298: Class Counts = [0. 0. 1. 0.]
# Node 9312: Class Counts = [0. 0. 2. 1.]
# Node 9318: Class Counts = [0. 0. 0. 6.]
# Node 9330: Class Counts = [0. 0. 2. 0.]
# Node 9333: Class Counts = [0. 0. 0. 2.]
# Node 9365: Class Counts = [0. 0. 6. 0.]
# Node 9366: Class Counts = [0. 0. 0. 2.]
# Node 9376: Class Counts = [0. 0. 1. 0.]
# Node 9406: Class Counts = [0. 0. 0. 6.]
# Node 9412: Class Counts = [0. 0. 0. 1.]
# Node 9413: Class Counts = [0. 0. 2. 0.]
# Node 9420: Class Counts = [0. 0. 0. 2.]
# Node 9422: Class Counts = [0. 0. 1. 1.]
# Node 9428: Class Counts = [0. 0. 0. 2.]
# Node 9435: Class Counts = [0. 0. 0. 3.]
# Node 9454: Class Counts = [0. 0. 2. 0.]
# Node 9457: Class Counts = [0. 0. 0. 5.]
# Node 9463: Class Counts = [0. 0. 2. 0.]
# Node 9471: Class Counts = [0. 0. 0. 4.]
# Node 9502: Class Counts = [0. 0. 0. 2.]
# Node 9519: Class Counts = [0. 0. 2. 0.]
# Node 9520: Class Counts = [0. 0. 0. 4.]
# Node 9523: Class Counts = [0. 0. 2. 0.]
# Node 9554: Class Counts = [0. 0. 0. 3.]
# Node 9568: Class Counts = [0. 0. 0. 7.]
# Node 9576: Class Counts = [0. 0. 5. 0.]
# Node 9578: Class Counts = [0. 0. 0. 1.]
# Node 9579: Class Counts = [0. 0. 4. 1.]
# Node 9601: Class Counts = [0. 0. 0. 1.]
# Node 9612: Class Counts = [0. 0. 4. 0.]
# Node 9622: Class Counts = [0. 0. 7. 0.]
# Node 9625: Class Counts = [0. 0. 0. 2.]
# Node 9633: Class Counts = [0. 0. 1. 0.]
# Node 9644: Class Counts = [0. 0. 2. 0.]
# Node 9645: Class Counts = [0. 0. 0. 1.]
# Node 9656: Class Counts = [0. 0. 0. 1.]
# Node 9671: Class Counts = [0. 0. 0. 1.]
# Node 9707: Class Counts = [0. 0. 2. 0.]
# Node 9730: Class Counts = [0. 0. 1. 0.]
# Node 9749: Class Counts = [0. 0. 0. 3.]
# Node 9760: Class Counts = [0. 0. 0. 1.]
# Node 9772: Class Counts = [0. 0. 0. 1.]
# Node 9777: Class Counts = [0. 0. 1. 0.]
# Node 9783: Class Counts = [0. 0. 1. 0.]
# Node 9789: Class Counts = [0. 0. 0. 2.]
# Node 9795: Class Counts = [0. 0. 1. 0.]
# Node 9808: Class Counts = [0. 0. 0. 1.]
# Node 9839: Class Counts = [0. 0. 0. 2.]
# Node 9843: Class Counts = [0. 0. 0. 1.]
# Node 9846: Class Counts = [0. 0. 0. 5.]
# Node 9868: Class Counts = [0. 0. 2. 0.]
# Node 9875: Class Counts = [0. 0. 9. 0.]
# Node 9876: Class Counts = [0. 0. 0. 1.]
# Node 9881: Class Counts = [0. 0. 1. 0.]
# Node 9894: Class Counts = [0. 0. 0. 2.]
# Node 9932: Class Counts = [0. 0. 1. 1.]
# Node 9933: Class Counts = [0. 0. 0. 3.]
# Node 9940: Class Counts = [0. 0. 0. 2.]
# Node 9942: Class Counts = [0. 0. 1. 0.]
# Node 9955: Class Counts = [0. 0. 1. 1.]
# Node 9957: Class Counts = [0. 0. 0. 1.]
# Node 9963: Class Counts = [0. 0. 3. 0.]
# Node 9964: Class Counts = [0. 0. 0. 2.]
# Node 9973: Class Counts = [0. 0. 2. 0.]
# Node 9974: Class Counts = [0. 0. 0. 1.]
# Node 9975: Class Counts = [0. 0. 7. 0.]
# Node 9980: Class Counts = [0. 0. 3. 0.]
# Node 9990: Class Counts = [0. 0. 3. 0.]
# Node 9995: Class Counts = [0. 0. 0. 1.]
# Node 9996: Class Counts = [0. 0. 0. 3.]
# Node 10001: Class Counts = [0. 0. 1. 2.]
# Node 10002: Class Counts = [0. 0. 4. 0.]
# Node 10015: Class Counts = [0. 0. 0. 3.]
# Node 10027: Class Counts = [0. 0. 1. 0.]
# Node 10028: Class Counts = [0. 0. 0. 5.]
# Node 10040: Class Counts = [0. 0. 0. 2.]
# Node 10072: Class Counts = [0. 0. 8. 0.]
# Node 10134: Class Counts = [0. 0. 3. 0.]
# Node 10145: Class Counts = [0. 0. 0. 1.]
# Node 10148: Class Counts = [0. 0. 0. 1.]
# Node 10171: Class Counts = [0. 0. 0. 1.]
# Node 10172: Class Counts = [0. 0. 0. 1.]
# Node 10191: Class Counts = [0. 0. 2. 0.]
# Node 10215: Class Counts = [0. 0. 1. 6.]
# Node 10239: Class Counts = [0. 0. 0. 1.]
# Node 10244: Class Counts = [0. 0. 2. 0.]
# Node 10247: Class Counts = [0. 0. 2. 0.]
# Node 10261: Class Counts = [0. 0. 1. 0.]
# Node 10267: Class Counts = [0. 0. 1. 0.]
# Node 10278: Class Counts = [0. 0. 0. 1.]
# Node 10279: Class Counts = [0. 0. 0. 2.]
# Node 10293: Class Counts = [0. 0. 0. 3.]
# Node 10295: Class Counts = [0. 0. 0. 1.]
# Node 10306: Class Counts = [0. 0. 0. 1.]
# Node 10311: Class Counts = [0. 0. 1. 0.]
# Node 10327: Class Counts = [0. 0. 5. 0.]
# Node 10336: Class Counts = [0. 0. 5. 0.]
# Node 10337: Class Counts = [0. 0. 0. 1.]
# Node 10387: Class Counts = [0. 0. 0. 3.]
# Node 10416: Class Counts = [0. 0. 0. 1.]
# Node 10423: Class Counts = [0. 0. 0. 3.]
# Node 10425: Class Counts = [0. 0. 0. 1.]
# Node 10430: Class Counts = [0. 0. 2. 0.]
# Node 10432: Class Counts = [0. 0. 0. 9.]
# Node 10434: Class Counts = [0. 0. 0. 1.]
# Node 10437: Class Counts = [0. 0. 0. 6.]
# Node 10441: Class Counts = [0. 0. 0. 4.]
# Node 10446: Class Counts = [0. 0. 0. 1.]
# Node 10457: Class Counts = [0. 0. 1. 0.]
# Node 10459: Class Counts = [0. 0. 1. 0.]
# Node 10461: Class Counts = [0. 0. 1. 0.]
# Node 10464: Class Counts = [0. 0. 0. 2.]
# Node 10465: Class Counts = [0. 0. 1. 0.]
# Node 10480: Class Counts = [0. 0. 1. 0.]
# Node 10493: Class Counts = [0. 0. 0. 1.]
# Node 10515: Class Counts = [0. 0. 1. 1.]
# Node 10517: Class Counts = [0. 0. 1. 0.]
# Node 10518: Class Counts = [0. 0. 0. 2.]
# Node 10537: Class Counts = [0. 0. 0. 6.]
# Node 10552: Class Counts = [0. 0. 1. 0.]
# Node 10559: Class Counts = [0. 0. 2. 0.]
# Node 10561: Class Counts = [0. 0. 1. 0.]
# Node 10583: Class Counts = [0. 0. 1. 0.]
# Node 10585: Class Counts = [0. 0. 0. 1.]
# Node 10589: Class Counts = [0. 0. 0. 1.]
# Node 10594: Class Counts = [0. 0. 0. 1.]
# Node 10597: Class Counts = [0. 0. 0. 1.]
# Node 10605: Class Counts = [0. 0. 0. 4.]
# Node 10607: Class Counts = [0. 0. 0. 3.]
# Node 10612: Class Counts = [0. 0. 1. 0.]
# Node 10614: Class Counts = [0. 0. 1. 0.]
# Node 10615: Class Counts = [ 0.  0.  0. 11.]
# Node 10626: Class Counts = [0. 0. 0. 4.]
# Node 10632: Class Counts = [0. 0. 0. 1.]
# Node 10633: Class Counts = [0. 0. 2. 0.]
# Node 10636: Class Counts = [0. 0. 0. 3.]
# Node 10638: Class Counts = [0. 0. 0. 1.]
# Node 10640: Class Counts = [0. 0. 0. 6.]
# Node 10647: Class Counts = [0. 0. 0. 5.]
# Node 10649: Class Counts = [0. 0. 2. 0.]
# Node 10657: Class Counts = [0. 0. 0. 1.]
# Node 10661: Class Counts = [0. 0. 0. 3.]
# Node 10666: Class Counts = [0. 0. 1. 0.]
# Node 10673: Class Counts = [0. 0. 0. 1.]
# Node 10677: Class Counts = [0. 0. 2. 0.]
# Node 10688: Class Counts = [0. 0. 1. 0.]
# Node 10691: Class Counts = [ 0.  0.  0. 22.]
# Node 10699: Class Counts = [0. 0. 0. 7.]
# Node 10705: Class Counts = [0. 0. 4. 0.]
# Node 10718: Class Counts = [0. 0. 3. 0.]
# Node 10739: Class Counts = [0. 0. 0. 1.]
# Node 10754: Class Counts = [0. 0. 0. 4.]
# Node 10771: Class Counts = [0. 0. 2. 0.]
# Node 10782: Class Counts = [0. 0. 0. 2.]
# Node 10788: Class Counts = [0. 0. 1. 0.]
# Node 10792: Class Counts = [0. 0. 4. 4.]
# Node 10793: Class Counts = [0. 0. 0. 6.]
# Node 10801: Class Counts = [0. 0. 5. 0.]
# Node 10822: Class Counts = [0. 0. 1. 0.]
# Node 10833: Class Counts = [0. 0. 0. 1.]
# Node 10847: Class Counts = [0. 0. 0. 2.]
# Node 10870: Class Counts = [0. 0. 2. 0.]
# Node 10877: Class Counts = [0. 0. 3. 0.]
# Node 10880: Class Counts = [0. 0. 1. 0.]
# Node 10891: Class Counts = [0. 0. 3. 0.]
# Node 10894: Class Counts = [0. 0. 2. 0.]
# Node 10910: Class Counts = [0. 0. 0. 1.]
# Node 10913: Class Counts = [0. 0. 0. 1.]
# Node 10915: Class Counts = [0. 0. 0. 1.]
# Node 10922: Class Counts = [0. 0. 0. 1.]
# Node 10926: Class Counts = [0. 0. 0. 1.]
# Node 10933: Class Counts = [0. 0. 0. 1.]
# Node 10948: Class Counts = [0. 0. 0. 1.]
# Node 10950: Class Counts = [0. 0. 0. 1.]
# Node 10954: Class Counts = [0. 0. 0. 1.]
# Node 10955: Class Counts = [0. 0. 1. 0.]
# Node 10966: Class Counts = [0. 0. 0. 1.]
# Node 10967: Class Counts = [0. 0. 6. 0.]
# Node 10996: Class Counts = [0. 0. 1. 0.]
# Node 11016: Class Counts = [ 0.  0. 22.  0.]
# Node 11021: Class Counts = [0. 0. 4. 0.]
# Node 11023: Class Counts = [ 0.  0. 12.  0.]
# Node 11025: Class Counts = [0. 0. 2. 0.]
# Node 11032: Class Counts = [0. 0. 3. 0.]
# Node 11034: Class Counts = [0. 0. 1. 0.]
# Node 11043: Class Counts = [0. 0. 5. 0.]
# Node 11046: Class Counts = [0. 0. 0. 1.]
# Node 11057: Class Counts = [0. 0. 0. 2.]
# Node 11079: Class Counts = [0. 0. 0. 1.]
# Node 11095: Class Counts = [0. 0. 2. 0.]
# Node 11103: Class Counts = [0. 0. 3. 0.]
# Node 11107: Class Counts = [0. 0. 8. 0.]
# Node 11108: Class Counts = [0. 0. 1. 2.]
# Node 11111: Class Counts = [0. 0. 3. 1.]
# Node 11116: Class Counts = [0. 0. 1. 3.]
# Node 11127: Class Counts = [0. 0. 0. 3.]
# Node 11140: Class Counts = [0. 0. 1. 0.]
# Node 11147: Class Counts = [0. 0. 1. 0.]
# Node 11151: Class Counts = [0. 0. 1. 0.]
# Node 11152: Class Counts = [0. 0. 1. 2.]
# Node 11155: Class Counts = [0. 0. 0. 2.]
# Node 11175: Class Counts = [0. 0. 3. 0.]
# Node 11203: Class Counts = [0. 0. 8. 0.]
# Node 11212: Class Counts = [0. 0. 1. 0.]
# Node 11213: Class Counts = [0. 0. 1. 0.]
# Node 11215: Class Counts = [0. 0. 0. 4.]
# Node 11238: Class Counts = [0. 0. 3. 0.]
# Node 11257: Class Counts = [0. 0. 1. 0.]
# Node 11276: Class Counts = [0. 0. 2. 0.]
# Node 11290: Class Counts = [0. 0. 3. 0.]
# Node 11292: Class Counts = [0. 0. 3. 0.]
# Node 11296: Class Counts = [0. 0. 2. 0.]
# Node 11304: Class Counts = [0. 0. 0. 2.]
# Node 11319: Class Counts = [0. 0. 0. 1.]
# Node 11320: Class Counts = [0. 0. 0. 1.]
# Node 11345: Class Counts = [0. 0. 6. 0.]
# Node 11372: Class Counts = [0. 0. 0. 2.]
# Node 11390: Class Counts = [0. 0. 0. 2.]
# Node 11417: Class Counts = [0. 0. 1. 0.]
# Node 11419: Class Counts = [0. 0. 0. 3.]
# Node 11450: Class Counts = [0. 0. 2. 0.]
# Node 11457: Class Counts = [0. 0. 0. 2.]
# Node 11465: Class Counts = [0. 0. 2. 0.]
# Node 11488: Class Counts = [0. 0. 2. 0.]
# Node 11502: Class Counts = [0. 0. 9. 0.]
# Node 11506: Class Counts = [0. 0. 1. 0.]
# Node 11516: Class Counts = [0. 0. 4. 0.]
# Node 11537: Class Counts = [0. 0. 3. 0.]
# Node 11543: Class Counts = [0. 0. 0. 4.]
# Node 11545: Class Counts = [0. 0. 0. 4.]
# Node 11567: Class Counts = [0. 0. 5. 1.]
# Node 11576: Class Counts = [0. 0. 1. 1.]
# Node 11586: Class Counts = [0. 0. 0. 1.]
# Node 11591: Class Counts = [0. 0. 2. 0.]
# Node 11598: Class Counts = [0. 0. 1. 0.]
# Node 11600: Class Counts = [0. 0. 1. 0.]
# Node 11602: Class Counts = [0. 0. 0. 1.]
# Node 11603: Class Counts = [0. 0. 1. 0.]
# Node 11625: Class Counts = [0. 0. 0. 1.]
# Node 11627: Class Counts = [0. 0. 0. 5.]
# Node 11630: Class Counts = [0. 0. 1. 0.]
# Node 11632: Class Counts = [0. 0. 0. 2.]
# Node 11634: Class Counts = [0. 0. 0. 1.]
# Node 11639: Class Counts = [0. 0. 3. 0.]
# Node 11644: Class Counts = [0. 0. 1. 0.]
# Node 11650: Class Counts = [0. 0. 0. 3.]
# Node 11654: Class Counts = [0. 0. 3. 0.]
# Node 11660: Class Counts = [0. 0. 0. 1.]
# Node 11662: Class Counts = [0. 0. 0. 1.]
# Node 11669: Class Counts = [0. 0. 3. 0.]
# Node 11674: Class Counts = [0. 0. 2. 0.]
# Node 11676: Class Counts = [0. 0. 0. 1.]
# Node 11682: Class Counts = [0. 0. 0. 2.]
# Node 11705: Class Counts = [0. 0. 1. 0.]
# Node 11708: Class Counts = [0. 0. 3. 0.]
# Node 11724: Class Counts = [0. 0. 1. 0.]
# Node 11745: Class Counts = [0. 0. 5. 0.]
# ...
# Node 17130: Class Counts = [0. 0. 2. 0.]
# Node 17137: Class Counts = [0. 0. 1. 0.]
# Node 17139: Class Counts = [0. 0. 3. 0.]
# Node 17143: Class Counts = [0. 0. 2. 0.]
# Node 17154: Class Counts = [0. 0. 0. 7.]
# Node 17159: Class Counts = [ 0.  0.  0. 12.]
# Node 17172: Class Counts = [0. 0. 0. 4.]
# Node 17176: Class Counts = [0. 0. 0. 1.]
# Node 17180: Class Counts = [0. 0. 3. 0.]
# Node 17190: Class Counts = [0. 0. 1. 0.]
# Node 17193: Class Counts = [0. 0. 3. 0.]
# Node 17202: Class Counts = [0. 0. 0. 2.]
# Node 17253: Class Counts = [0. 0. 1. 0.]
# Node 17290: Class Counts = [0. 0. 0. 1.]
# Node 17298: Class Counts = [0. 0. 1. 0.]
# Node 17302: Class Counts = [0. 0. 1. 0.]
# Node 17307: Class Counts = [0. 0. 1. 0.]
# Node 17334: Class Counts = [0. 0. 1. 0.]
# Node 17335: Class Counts = [0. 0. 3. 0.]
# Node 17348: Class Counts = [0. 0. 1. 0.]
# Node 17356: Class Counts = [0. 0. 2. 0.]
# Node 17358: Class Counts = [0. 0. 3. 0.]
# Node 17366: Class Counts = [0. 0. 2. 0.]
# Node 17367: Class Counts = [0. 0. 2. 0.]
# Node 17371: Class Counts = [0. 0. 2. 0.]
# Node 17373: Class Counts = [0. 0. 4. 0.]
# Node 17412: Class Counts = [0. 0. 1. 0.]
# Node 17419: Class Counts = [0. 0. 0. 1.]
# Node 17427: Class Counts = [0. 0. 1. 0.]
# Node 17436: Class Counts = [0. 0. 1. 0.]
# Node 17437: Class Counts = [0. 0. 3. 0.]
# Node 17439: Class Counts = [0. 0. 6. 0.]
# Node 17449: Class Counts = [0. 0. 1. 0.]
# Node 17490: Class Counts = [0. 0. 1. 0.]
# Node 17513: Class Counts = [0. 0. 1. 0.]
# Node 17520: Class Counts = [0. 0. 2. 0.]
# Node 17533: Class Counts = [0. 0. 0. 1.]
# Node 17535: Class Counts = [0. 0. 2. 0.]
# Node 17551: Class Counts = [0. 0. 5. 0.]
# Node 17554: Class Counts = [0. 0. 0. 1.]
# Node 17557: Class Counts = [0. 0. 9. 0.]
# Node 17620: Class Counts = [0. 0. 1. 0.]
# Node 17630: Class Counts = [0. 0. 1. 0.]
# Node 17649: Class Counts = [0. 0. 0. 1.]
# Node 17685: Class Counts = [0. 0. 3. 0.]
# Node 17688: Class Counts = [0. 0. 0. 3.]
# Node 17783: Class Counts = [0. 0. 2. 0.]
# Node 17791: Class Counts = [0. 0. 0. 1.]
# Node 17799: Class Counts = [0. 0. 1. 0.]
# Node 17800: Class Counts = [0. 0. 2. 0.]
# Node 17815: Class Counts = [0. 0. 1. 1.]
# Node 17839: Class Counts = [0. 0. 1. 0.]
# Node 17865: Class Counts = [0. 0. 1. 0.]
# Node 17878: Class Counts = [0. 0. 0. 1.]
# Node 17880: Class Counts = [0. 0. 1. 0.]
# Node 17883: Class Counts = [0. 0. 1. 0.]
# Node 17887: Class Counts = [0. 0. 0. 1.]
# Node 17894: Class Counts = [0. 0. 1. 0.]
# Node 17912: Class Counts = [0. 0. 0. 1.]
# Node 17913: Class Counts = [0. 0. 1. 0.]
# Node 17920: Class Counts = [0. 0. 3. 0.]
# Node 17922: Class Counts = [0. 0. 4. 0.]
# Node 17927: Class Counts = [0. 0. 2. 0.]
# Node 17928: Class Counts = [0. 0. 0. 1.]
# Node 17935: Class Counts = [0. 0. 2. 0.]
# Node 17945: Class Counts = [0. 0. 1. 0.]
# Node 17947: Class Counts = [0. 0. 1. 0.]
# Node 17955: Class Counts = [0. 0. 0. 1.]
# Node 17958: Class Counts = [0. 0. 0. 1.]
# Node 17959: Class Counts = [0. 0. 2. 0.]
# Node 17967: Class Counts = [0. 0. 1. 0.]
# Node 17968: Class Counts = [0. 0. 3. 0.]
# Node 17975: Class Counts = [0. 0. 6. 0.]
# Node 18023: Class Counts = [0. 0. 0. 1.]
# Node 18026: Class Counts = [0. 0. 1. 0.]
# Node 18030: Class Counts = [0. 0. 2. 0.]
# Node 18040: Class Counts = [0. 0. 2. 0.]
# Node 18046: Class Counts = [0. 0. 2. 0.]
# Node 18049: Class Counts = [0. 0. 0. 1.]
# Node 18050: Class Counts = [0. 0. 9. 0.]
# Node 18057: Class Counts = [0. 0. 1. 0.]
# Node 18063: Class Counts = [0. 0. 1. 0.]
# Node 18082: Class Counts = [0. 0. 1. 0.]
# Node 18102: Class Counts = [0. 0. 1. 0.]
# Node 18108: Class Counts = [0. 0. 0. 1.]
# Node 18136: Class Counts = [0. 0. 1. 0.]
# Node 18141: Class Counts = [0. 0. 6. 0.]
# Node 18146: Class Counts = [0. 0. 1. 0.]
# Node 18156: Class Counts = [0. 0. 4. 0.]
# Node 18159: Class Counts = [0. 0. 1. 0.]
# Node 18166: Class Counts = [0. 0. 0. 1.]
# Node 18170: Class Counts = [0. 0. 4. 0.]
# Node 18172: Class Counts = [0. 0. 0. 1.]
# Node 18176: Class Counts = [0. 0. 2. 0.]
# Node 18182: Class Counts = [0. 0. 9. 0.]
# Node 18185: Class Counts = [0. 0. 2. 0.]
# Node 18188: Class Counts = [0. 0. 2. 0.]
# Node 18193: Class Counts = [0. 0. 8. 0.]
# Node 18198: Class Counts = [0. 0. 0. 1.]
# Node 18199: Class Counts = [0. 0. 3. 0.]
# Node 18210: Class Counts = [0. 0. 4. 0.]
# Node 18212: Class Counts = [0. 0. 0. 2.]
# Node 18221: Class Counts = [0. 0. 0. 2.]
# Node 18240: Class Counts = [0. 0. 3. 0.]
# Node 18246: Class Counts = [0. 0. 4. 0.]
# Node 18250: Class Counts = [0. 0. 2. 0.]
# Node 18261: Class Counts = [0. 0. 3. 0.]
# Node 18265: Class Counts = [0. 0. 0. 4.]
# Node 18269: Class Counts = [0. 0. 0. 1.]
# Node 18272: Class Counts = [0. 0. 1. 0.]
# Node 18275: Class Counts = [0. 0. 1. 0.]
# Node 18277: Class Counts = [0. 0. 2. 0.]
# Node 18284: Class Counts = [0. 0. 1. 0.]
# Node 18292: Class Counts = [0. 0. 1. 0.]
# Node 18307: Class Counts = [0. 0. 8. 0.]
# Node 18313: Class Counts = [0. 0. 3. 0.]
# Node 18327: Class Counts = [0. 0. 1. 0.]
# Node 18340: Class Counts = [0. 0. 1. 0.]
# Node 18348: Class Counts = [0. 0. 4. 0.]
# Node 18376: Class Counts = [0. 0. 6. 0.]
# Node 18384: Class Counts = [0. 0. 2. 0.]
# Node 18393: Class Counts = [0. 0. 3. 0.]
# Node 18398: Class Counts = [0. 0. 3. 0.]
# Node 18400: Class Counts = [0. 0. 3. 3.]
# Node 18401: Class Counts = [0. 0. 9. 0.]
# Node 18418: Class Counts = [0. 0. 2. 0.]
# Node 18421: Class Counts = [0. 0. 2. 0.]
# Node 18422: Class Counts = [0. 0. 0. 1.]
# Node 18423: Class Counts = [0. 0. 0. 3.]
# Node 18431: Class Counts = [0. 0. 0. 3.]
# Node 18435: Class Counts = [0. 0. 1. 0.]
# Node 18443: Class Counts = [0. 0. 0. 1.]
# Node 18444: Class Counts = [0. 0. 0. 2.]
# Node 18447: Class Counts = [0. 0. 0. 1.]
# Node 18452: Class Counts = [0. 0. 1. 0.]
# Node 18465: Class Counts = [0. 0. 0. 1.]
# Node 18477: Class Counts = [0. 0. 3. 0.]
# Node 18478: Class Counts = [ 0.  0. 15.  0.]
# Node 18491: Class Counts = [0. 0. 6. 0.]
# Node 18493: Class Counts = [0. 0. 1. 0.]
# Node 18504: Class Counts = [0. 0. 2. 0.]
# Node 18507: Class Counts = [0. 0. 1. 0.]
# Node 18508: Class Counts = [0. 0. 2. 0.]
# Node 18516: Class Counts = [0. 0. 1. 0.]
# Node 18518: Class Counts = [0. 0. 1. 0.]
# Node 18520: Class Counts = [0. 0. 1. 0.]
# Node 18540: Class Counts = [0. 0. 6. 0.]
# Node 18543: Class Counts = [0. 0. 1. 0.]
# Node 18547: Class Counts = [0. 0. 1. 0.]
# Node 18552: Class Counts = [0. 0. 1. 0.]
# Node 18555: Class Counts = [0. 0. 2. 0.]
# Node 18582: Class Counts = [0. 0. 0. 1.]
# Node 18603: Class Counts = [0. 0. 6. 0.]
# Node 18617: Class Counts = [0. 0. 2. 0.]
# Node 18632: Class Counts = [0. 0. 0. 2.]
# Node 18634: Class Counts = [0. 0. 6. 0.]
# Node 18635: Class Counts = [0. 0. 0. 1.]
# Node 18640: Class Counts = [0. 0. 0. 1.]
# Node 18645: Class Counts = [0. 0. 1. 0.]
# Node 18648: Class Counts = [0. 0. 0. 1.]
# Node 18659: Class Counts = [ 0.  0. 10.  0.]
# Node 18665: Class Counts = [0. 0. 0. 2.]
# Node 18666: Class Counts = [0. 0. 2. 0.]
# Node 18670: Class Counts = [0. 0. 6. 0.]
# Node 18672: Class Counts = [ 0.  0. 10.  0.]
# Node 18676: Class Counts = [0. 0. 6. 0.]
# Node 18700: Class Counts = [0. 0. 2. 0.]
# Node 18704: Class Counts = [0. 0. 4. 0.]
# Node 18722: Class Counts = [0. 0. 0. 1.]
# Node 18728: Class Counts = [0. 0. 1. 0.]
# Node 18730: Class Counts = [0. 0. 2. 0.]
# Node 18731: Class Counts = [0. 0. 2. 0.]
# Node 18781: Class Counts = [0. 0. 3. 0.]
# Node 18789: Class Counts = [0. 0. 1. 0.]
# Node 18794: Class Counts = [0. 0. 1. 0.]
# Node 18799: Class Counts = [0. 0. 0. 1.]
# Node 18807: Class Counts = [0. 0. 0. 3.]
# Node 18810: Class Counts = [0. 0. 1. 0.]
# Node 18812: Class Counts = [0. 0. 5. 0.]
# Node 18814: Class Counts = [0. 0. 2. 0.]
# Node 18819: Class Counts = [0. 0. 3. 0.]
# Node 18844: Class Counts = [0. 0. 0. 1.]
# Node 18851: Class Counts = [0. 0. 0. 1.]
# Node 18856: Class Counts = [0. 0. 0. 2.]
# Node 18861: Class Counts = [0. 0. 0. 1.]
# Node 18868: Class Counts = [0. 0. 1. 0.]
# Node 18869: Class Counts = [0. 0. 0. 1.]
# Node 18874: Class Counts = [0. 0. 0. 1.]
# Node 18887: Class Counts = [0. 0. 2. 0.]
# Node 18889: Class Counts = [0. 0. 1. 0.]
# Node 18900: Class Counts = [0. 0. 2. 0.]
# Node 18906: Class Counts = [0. 0. 2. 0.]
# Node 18915: Class Counts = [0. 0. 1. 0.]
# Node 18940: Class Counts = [0. 0. 1. 0.]
# Node 18948: Class Counts = [0. 0. 2. 0.]
# Node 18955: Class Counts = [0. 0. 0. 2.]
# Node 18956: Class Counts = [0. 0. 1. 0.]
# Node 18958: Class Counts = [0. 0. 0. 2.]
# Node 18967: Class Counts = [0. 0. 0. 2.]
# Node 18968: Class Counts = [0. 0. 0. 2.]
# Node 18981: Class Counts = [0. 0. 2. 0.]
# Node 18986: Class Counts = [0. 0. 0. 1.]
# Node 18997: Class Counts = [0. 0. 1. 0.]
# Node 19001: Class Counts = [0. 0. 1. 0.]
# Node 19007: Class Counts = [0. 0. 0. 1.]
# Node 19011: Class Counts = [0. 0. 0. 1.]
# Node 19029: Class Counts = [0. 0. 0. 2.]
# Node 19045: Class Counts = [0. 0. 0. 2.]
# Node 19060: Class Counts = [0. 0. 0. 2.]
# Node 19061: Class Counts = [0. 0. 1. 0.]
# Node 19068: Class Counts = [0. 0. 1. 0.]
# Node 19070: Class Counts = [0. 0. 1. 0.]
# Node 19095: Class Counts = [0. 0. 1. 0.]
# Node 19097: Class Counts = [0. 0. 0. 3.]
# Node 19110: Class Counts = [0. 0. 0. 2.]
# Node 19117: Class Counts = [0. 0. 2. 0.]
# Node 19121: Class Counts = [0. 0. 1. 0.]
# Node 19125: Class Counts = [0. 0. 0. 1.]
# Node 19135: Class Counts = [0. 0. 3. 0.]
# Node 19139: Class Counts = [0. 0. 4. 0.]
# Node 19147: Class Counts = [0. 0. 0. 3.]
# Node 19171: Class Counts = [0. 0. 1. 0.]
# Node 19193: Class Counts = [0. 0. 1. 0.]
# Node 19203: Class Counts = [0. 0. 0. 1.]
# Node 19211: Class Counts = [0. 0. 1. 0.]
# Node 19234: Class Counts = [0. 0. 2. 0.]
# Node 19237: Class Counts = [0. 0. 0. 2.]
# Node 19262: Class Counts = [0. 0. 1. 0.]
# Node 19263: Class Counts = [0. 0. 0. 1.]
# Node 19269: Class Counts = [0. 0. 0. 2.]
# Node 19279: Class Counts = [0. 0. 2. 0.]
# Node 19287: Class Counts = [0. 0. 0. 2.]
# Node 19293: Class Counts = [0. 0. 0. 3.]
# Node 19305: Class Counts = [0. 0. 0. 1.]
# Node 19307: Class Counts = [0. 0. 0. 3.]
# Node 19313: Class Counts = [0. 0. 0. 1.]
# Node 19322: Class Counts = [0. 0. 1. 0.]
# Node 19324: Class Counts = [0. 0. 0. 1.]
# Node 19327: Class Counts = [0. 0. 1. 0.]
# Node 19329: Class Counts = [0. 0. 1. 0.]
# Node 19330: Class Counts = [0. 0. 0. 1.]
# Node 19331: Class Counts = [0. 0. 3. 0.]
# Node 19337: Class Counts = [0. 0. 1. 0.]
# Node 19342: Class Counts = [0. 0. 2. 0.]
# Node 19345: Class Counts = [ 0.  0. 12.  0.]
# Node 19348: Class Counts = [0. 0. 1. 0.]
# Node 19358: Class Counts = [0. 0. 0. 1.]
# Node 19360: Class Counts = [0. 0. 0. 2.]
# Node 19361: Class Counts = [0. 0. 0. 2.]
# Node 19365: Class Counts = [0. 0. 5. 0.]
# Node 19373: Class Counts = [0. 0. 0. 2.]
# Node 19377: Class Counts = [0. 0. 7. 1.]
# Node 19382: Class Counts = [0. 0. 0. 9.]
# Node 19384: Class Counts = [0. 0. 0. 1.]
# Node 19387: Class Counts = [0. 0. 0. 5.]
# Node 19402: Class Counts = [0. 0. 0. 1.]
# Node 19410: Class Counts = [0. 0. 0. 1.]
# Node 19416: Class Counts = [0. 0. 3. 0.]
# Node 19417: Class Counts = [0. 0. 1. 7.]
# Node 19423: Class Counts = [0. 0. 0. 2.]
# Node 19425: Class Counts = [0. 0. 0. 3.]
# Node 19487: Class Counts = [0. 0. 0. 4.]
# Node 19491: Class Counts = [0. 0. 0. 1.]
# Node 19493: Class Counts = [0. 0. 0. 8.]
# Node 19502: Class Counts = [0. 0. 1. 0.]
# Node 19508: Class Counts = [0. 0. 1. 0.]
# Node 19513: Class Counts = [0. 0. 1. 0.]
# Node 19517: Class Counts = [0. 0. 0. 4.]
# Node 19519: Class Counts = [0. 0. 0. 3.]
# Node 19520: Class Counts = [0. 0. 1. 1.]
# Node 19523: Class Counts = [0. 0. 1. 0.]
# Node 19538: Class Counts = [0. 0. 1. 0.]
# Node 19545: Class Counts = [0. 0. 0. 2.]
# Node 19549: Class Counts = [0. 0. 2. 0.]
# Node 19552: Class Counts = [0. 0. 0. 2.]
# Node 19557: Class Counts = [0. 0. 0. 1.]
# Node 19561: Class Counts = [0. 0. 0. 2.]
# Node 19567: Class Counts = [0. 0. 0. 2.]
# Node 19570: Class Counts = [0. 0. 0. 1.]
# Node 19572: Class Counts = [0. 0. 0. 3.]
# Node 19579: Class Counts = [0. 0. 0. 2.]
# Node 19580: Class Counts = [0. 0. 2. 0.]
# Node 19582: Class Counts = [0. 0. 2. 0.]
# Node 19585: Class Counts = [0. 0. 1. 0.]
# Node 19603: Class Counts = [0. 0. 1. 0.]
# Node 19605: Class Counts = [0. 0. 0. 1.]
# Node 19644: Class Counts = [0. 0. 2. 1.]
# Node 19648: Class Counts = [0. 0. 0. 3.]
# Node 19659: Class Counts = [0. 0. 0. 1.]
# Node 19667: Class Counts = [0. 0. 0. 2.]
# Node 19671: Class Counts = [0. 0. 0. 2.]
# Node 19680: Class Counts = [0. 0. 1. 0.]
# Node 19692: Class Counts = [0. 0. 3. 0.]
# Node 19724: Class Counts = [0. 0. 0. 1.]
# Node 19727: Class Counts = [0. 0. 2. 0.]
# Node 19733: Class Counts = [0. 0. 1. 0.]
# Node 19744: Class Counts = [0. 0. 0. 3.]
# Node 19747: Class Counts = [0. 0. 0. 1.]
# Node 19762: Class Counts = [0. 0. 0. 5.]
# Node 19780: Class Counts = [0. 0. 3. 0.]
# Node 19797: Class Counts = [0. 0. 2. 0.]
# Node 19802: Class Counts = [0. 0. 0. 1.]
# Node 19834: Class Counts = [0. 0. 0. 2.]
# Node 19850: Class Counts = [0. 0. 1. 0.]
# Node 19854: Class Counts = [0. 0. 0. 2.]
# Node 19865: Class Counts = [0. 0. 1. 5.]
# Node 19878: Class Counts = [0. 0. 0. 8.]
# Node 19879: Class Counts = [0. 0. 2. 0.]
# Node 19882: Class Counts = [0. 0. 0. 5.]
# Node 19906: Class Counts = [0. 0. 0. 1.]
# Node 19918: Class Counts = [0. 0. 1. 0.]
# Node 19920: Class Counts = [0. 0. 1. 0.]
# Node 19926: Class Counts = [0. 0. 0. 1.]
# Node 19927: Class Counts = [0. 0. 5. 0.]
# Node 19935: Class Counts = [0. 0. 0. 1.]
# Node 19938: Class Counts = [0. 0. 0. 3.]
# Node 19955: Class Counts = [0. 0. 2. 0.]
# Node 19958: Class Counts = [0. 0. 5. 0.]
# Node 19983: Class Counts = [0. 0. 4. 0.]
# Node 20012: Class Counts = [0. 0. 0. 1.]
# Node 20014: Class Counts = [0. 0. 0. 2.]
# Node 20024: Class Counts = [0. 0. 1. 1.]
# Node 20028: Class Counts = [0. 0. 0. 1.]
# Node 20034: Class Counts = [0. 0. 0. 1.]
# Node 20038: Class Counts = [0. 0. 0. 3.]
# Node 20044: Class Counts = [0. 0. 0. 1.]
# Node 20045: Class Counts = [0. 0. 1. 0.]
# Node 20050: Class Counts = [0. 0. 1. 0.]
# Node 20056: Class Counts = [0. 0. 6. 0.]
# Node 20060: Class Counts = [0. 0. 2. 0.]
# Node 20077: Class Counts = [0. 0. 2. 0.]
# Node 20084: Class Counts = [0. 0. 0. 1.]
# Node 20092: Class Counts = [0. 0. 0. 1.]
# Node 20098: Class Counts = [0. 0. 0. 1.]
# Node 20101: Class Counts = [0. 0. 5. 0.]
# Node 20107: Class Counts = [0. 0. 0. 2.]
# Node 20112: Class Counts = [0. 0. 2. 0.]
# Node 20120: Class Counts = [0. 0. 2. 0.]
# Node 20121: Class Counts = [0. 0. 6. 0.]
# Node 20125: Class Counts = [0. 0. 0. 3.]
# Node 20149: Class Counts = [0. 0. 0. 4.]
# Node 20202: Class Counts = [0. 0. 0. 2.]
# Node 20208: Class Counts = [0. 0. 0. 1.]
# Node 20218: Class Counts = [0. 0. 1. 0.]
# Node 20223: Class Counts = [0. 0. 1. 0.]
# Node 20232: Class Counts = [0. 0. 0. 1.]
# Node 20248: Class Counts = [0. 0. 1. 0.]
# Node 20253: Class Counts = [0. 0. 1. 0.]
# Node 20261: Class Counts = [0. 0. 1. 0.]
# Node 20272: Class Counts = [0. 0. 0. 1.]
# Node 20301: Class Counts = [0. 0. 0. 1.]
# Node 20307: Class Counts = [0. 0. 1. 0.]
# Node 20310: Class Counts = [0. 0. 3. 0.]
# Node 20321: Class Counts = [0. 0. 0. 2.]
# Node 20326: Class Counts = [0. 0. 3. 2.]
# Node 20329: Class Counts = [0. 0. 0. 1.]
# Node 20336: Class Counts = [0. 0. 1. 0.]
# Node 20338: Class Counts = [0. 0. 2. 0.]
# Node 20348: Class Counts = [0. 0. 1. 0.]
# Node 20350: Class Counts = [0. 0. 1. 0.]
# Node 20355: Class Counts = [0. 0. 0. 2.]
# Node 20359: Class Counts = [0. 0. 0. 5.]
# Node 20365: Class Counts = [0. 0. 1. 0.]
# Node 20369: Class Counts = [0. 0. 2. 0.]
# Node 20381: Class Counts = [0. 0. 2. 0.]
# Node 20395: Class Counts = [0. 0. 0. 1.]
# Node 20396: Class Counts = [0. 0. 0. 2.]
# Node 20401: Class Counts = [0. 0. 0. 1.]
# Node 20406: Class Counts = [0. 0. 2. 0.]
# Node 20414: Class Counts = [0. 0. 0. 2.]
# Node 20428: Class Counts = [0. 0. 5. 0.]
# Node 20432: Class Counts = [0. 0. 1. 0.]
# Node 20453: Class Counts = [0. 0. 2. 0.]
# Node 20458: Class Counts = [0. 0. 1. 0.]
# Node 20469: Class Counts = [0. 0. 1. 0.]
# Node 20475: Class Counts = [0. 0. 0. 3.]
# Node 20477: Class Counts = [0. 0. 0. 2.]
# Node 20480: Class Counts = [0. 0. 0. 6.]
# Node 20482: Class Counts = [0. 0. 0. 1.]
# Node 20497: Class Counts = [0. 0. 0. 1.]
# Node 20499: Class Counts = [0. 0. 0. 2.]
# Node 20507: Class Counts = [0. 0. 3. 0.]
# Node 20532: Class Counts = [0. 0. 0. 2.]
# Node 20533: Class Counts = [0. 0. 2. 0.]
# Node 20560: Class Counts = [0. 0. 0. 2.]
# Node 20563: Class Counts = [0. 0. 0. 9.]
# Node 20565: Class Counts = [0. 0. 0. 2.]
# Node 20568: Class Counts = [0. 0. 2. 0.]
# Total number of valuable nodes is: 2315

# %%
def get_path(node, path):
    if node == -1:
        return path
    feature = dtree_opt.tree_.feature[node]
    threshold = dtree_opt.tree_.threshold[node]
    if feature != -2:  # Not a leaf node
        feature_name = features[feature]
        if path:
            current_path = f"{feature_name} {path}"
        else:
            current_path = feature_name
        parent = np.where(dtree_opt.tree_.children_left == node)[0]
        if parent:
            return get_path(parent[0], current_path)
    return path

leaf_nodes = np.where(dtree_opt.tree_.children_left == -1)[0]

for node in leaf_nodes:
    class_counts = dtree_opt.tree_.value[node][0]
    if class_counts[0] == 0 and class_counts[1] == 0:
        path = get_path(node, "")
        node_info = f"Node {node}: Class Counts = {class_counts}, Rule: {path}"
        print(node_info)
# Out:
# Node 9: Class Counts = [ 0.  0. 69.  0.], Rule:
# Node 12: Class Counts = [0. 0. 0. 1.], Rule:
# Node 15: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19: Class Counts = [0. 0. 0. 1.], Rule:
# Node 20: Class Counts = [0. 0. 7. 0.], Rule:
# Node 21: Class Counts = [0. 0. 9. 0.], Rule:
# Node 26: Class Counts = [0. 0. 1. 0.], Rule:
# Node 28: Class Counts = [ 0.  0. 11.  0.], Rule:
# Node 38: Class Counts = [0. 0. 1. 0.], Rule:
# Node 52: Class Counts = [0. 0. 2. 0.], Rule:
# Node 57: Class Counts = [0. 0. 2. 0.], Rule:
# Node 61: Class Counts = [0. 0. 7. 0.], Rule:
# Node 66: Class Counts = [0. 0. 0. 1.], Rule:
# Node 71: Class Counts = [0. 0. 0. 1.], Rule:
# Node 77: Class Counts = [0. 0. 0. 2.], Rule:
# Node 85: Class Counts = [ 0.  0. 13.  0.], Rule:
# Node 88: Class Counts = [ 0.  0. 24.  0.], Rule:
# Node 94: Class Counts = [0. 0. 2. 0.], Rule:
# Node 106: Class Counts = [ 0.  0. 12.  0.], Rule:
# Node 120: Class Counts = [0. 0. 1. 0.], Rule:
# Node 121: Class Counts = [0. 0. 1. 0.], Rule:
# Node 132: Class Counts = [0. 0. 6. 0.], Rule:
# Node 135: Class Counts = [0. 0. 1. 0.], Rule:
# Node 139: Class Counts = [0. 0. 2. 0.], Rule:
# Node 141: Class Counts = [0. 0. 0. 1.], Rule:
# Node 151: Class Counts = [ 0.  0. 10.  0.], Rule:
# Node 158: Class Counts = [0. 0. 4. 0.], Rule:
# Node 166: Class Counts = [0. 0. 4. 0.], Rule:
# Node 168: Class Counts = [0. 0. 6. 0.], Rule:
# Node 170: Class Counts = [0. 0. 7. 0.], Rule:
# Node 176: Class Counts = [0. 0. 1. 0.], Rule:
# Node 179: Class Counts = [0. 0. 3. 0.], Rule:
# Node 181: Class Counts = [0. 0. 6. 0.], Rule:
# Node 188: Class Counts = [0. 0. 1. 0.], Rule:
# Node 190: Class Counts = [0. 0. 2. 0.], Rule:
# Node 193: Class Counts = [ 0.  0. 10.  0.], Rule:
# Node 195: Class Counts = [0. 0. 1. 0.], Rule:
# Node 198: Class Counts = [0. 0. 3. 0.], Rule:
# Node 202: Class Counts = [0. 0. 1. 0.], Rule:
# Node 223: Class Counts = [0. 0. 3. 0.], Rule:
# Node 228: Class Counts = [0. 0. 2. 0.], Rule:
# Node 234: Class Counts = [0. 0. 1. 0.], Rule:
# Node 238: Class Counts = [0. 0. 3. 0.], Rule:
# Node 242: Class Counts = [0. 0. 6. 0.], Rule:
# Node 265: Class Counts = [ 0.  0. 14.  0.], Rule:
# Node 275: Class Counts = [0. 0. 2. 0.], Rule:
# Node 280: Class Counts = [ 0.  0. 14.  0.], Rule:
# Node 283: Class Counts = [0. 0. 4. 0.], Rule:
# Node 293: Class Counts = [0. 0. 8. 0.], Rule:
# Node 300: Class Counts = [0. 0. 6. 0.], Rule:
# Node 319: Class Counts = [0. 0. 5. 0.], Rule:
# Node 322: Class Counts = [0. 0. 9. 3.], Rule:
# Node 341: Class Counts = [0. 0. 4. 0.], Rule:
# Node 347: Class Counts = [0. 0. 3. 0.], Rule:
# Node 352: Class Counts = [0. 0. 5. 0.], Rule:
# Node 354: Class Counts = [0. 0. 1. 0.], Rule:
# Node 360: Class Counts = [0. 0. 1. 0.], Rule:
# Node 365: Class Counts = [0. 0. 8. 0.], Rule:
# Node 368: Class Counts = [0. 0. 2. 0.], Rule:
# Node 374: Class Counts = [0. 0. 1. 0.], Rule:
# Node 386: Class Counts = [0. 0. 2. 0.], Rule:
# Node 394: Class Counts = [0. 0. 0. 1.], Rule:
# Node 397: Class Counts = [0. 0. 2. 0.], Rule:
# Node 402: Class Counts = [0. 0. 5. 0.], Rule:
# Node 412: Class Counts = [0. 0. 4. 5.], Rule:
# Node 435: Class Counts = [0. 0. 0. 2.], Rule:
# Node 445: Class Counts = [ 0.  0. 34.  0.], Rule:
# Node 453: Class Counts = [ 0.  0. 17.  0.], Rule:
# Node 459: Class Counts = [0. 0. 8. 0.], Rule:
# Node 463: Class Counts = [0. 0. 2. 0.], Rule:
# Node 465: Class Counts = [ 0.  0. 21.  0.], Rule:
# Node 468: Class Counts = [0. 0. 8. 0.], Rule:
# Node 473: Class Counts = [0. 0. 4. 0.], Rule:
# Node 484: Class Counts = [0. 0. 6. 0.], Rule:
# Node 489: Class Counts = [0. 0. 1. 0.], Rule:
# Node 490: Class Counts = [0. 0. 7. 0.], Rule:
# Node 494: Class Counts = [0. 0. 2. 0.], Rule:
# Node 495: Class Counts = [0. 0. 7. 0.], Rule:
# Node 501: Class Counts = [0. 0. 1. 0.], Rule:
# Node 508: Class Counts = [0. 0. 4. 0.], Rule:
# Node 510: Class Counts = [0. 0. 1. 0.], Rule:
# Node 514: Class Counts = [0. 0. 1. 0.], Rule:
# Node 536: Class Counts = [0. 0. 1. 0.], Rule:
# Node 542: Class Counts = [0. 0. 3. 0.], Rule:
# Node 557: Class Counts = [0. 0. 1. 0.], Rule:
# Node 560: Class Counts = [0. 0. 0. 4.], Rule:
# Node 562: Class Counts = [0. 0. 1. 0.], Rule:
# Node 567: Class Counts = [0. 0. 5. 0.], Rule:
# Node 572: Class Counts = [0. 0. 1. 0.], Rule:
# Node 575: Class Counts = [0. 0. 2. 0.], Rule:
# Node 583: Class Counts = [0. 0. 2. 0.], Rule:
# Node 586: Class Counts = [0. 0. 1. 0.], Rule:
# Node 598: Class Counts = [0. 0. 3. 0.], Rule:
# Node 599: Class Counts = [0. 0. 0. 1.], Rule:
# Node 609: Class Counts = [0. 0. 4. 0.], Rule:
# Node 615: Class Counts = [0. 0. 0. 1.], Rule:
# Node 619: Class Counts = [0. 0. 4. 0.], Rule:
# Node 621: Class Counts = [0. 0. 1. 0.], Rule:
# Node 630: Class Counts = [0. 0. 0. 2.], Rule:
# Node 632: Class Counts = [0. 0. 1. 0.], Rule:
# Node 634: Class Counts = [0. 0. 0. 5.], Rule:
# Node 637: Class Counts = [0. 0. 0. 1.], Rule:
# Node 640: Class Counts = [0. 0. 1. 0.], Rule:
# Node 641: Class Counts = [0. 0. 0. 2.], Rule:
# Node 647: Class Counts = [0. 0. 1. 0.], Rule:
# Node 648: Class Counts = [0. 0. 2. 0.], Rule:
# Node 651: Class Counts = [0. 0. 1. 0.], Rule:
# Node 672: Class Counts = [0. 0. 1. 0.], Rule:
# Node 673: Class Counts = [0. 0. 0. 1.], Rule:
# Node 682: Class Counts = [0. 0. 5. 0.], Rule:
# Node 686: Class Counts = [0. 0. 0. 2.], Rule:
# Node 696: Class Counts = [0. 0. 2. 0.], Rule:
# Node 702: Class Counts = [0. 0. 1. 0.], Rule:
# Node 705: Class Counts = [0. 0. 1. 0.], Rule:
# Node 708: Class Counts = [0. 0. 0. 1.], Rule:
# Node 723: Class Counts = [0. 0. 4. 0.], Rule:
# Node 750: Class Counts = [0. 0. 2. 0.], Rule:
# Node 779: Class Counts = [0. 0. 0. 3.], Rule:
# Node 787: Class Counts = [0. 0. 0. 2.], Rule:
# Node 800: Class Counts = [0. 0. 2. 0.], Rule:
# Node 812: Class Counts = [0. 0. 2. 0.], Rule:
# Node 834: Class Counts = [0. 0. 0. 1.], Rule:
# Node 859: Class Counts = [0. 0. 1. 0.], Rule:
# Node 881: Class Counts = [0. 0. 4. 0.], Rule:
# Node 889: Class Counts = [0. 0. 0. 1.], Rule:
# Node 904: Class Counts = [0. 0. 5. 0.], Rule:
# Node 946: Class Counts = [0. 0. 1. 0.], Rule:
# Node 970: Class Counts = [0. 0. 1. 0.], Rule:
# Node 972: Class Counts = [0. 0. 3. 0.], Rule:
# Node 978: Class Counts = [0. 0. 7. 0.], Rule:
# Node 988: Class Counts = [0. 0. 0. 1.], Rule:
# Node 989: Class Counts = [0. 0. 1. 0.], Rule:
# Node 990: Class Counts = [0. 0. 3. 0.], Rule:
# Node 997: Class Counts = [0. 0. 1. 0.], Rule:
# Node 1000: Class Counts = [0. 0. 1. 0.], Rule:
# Node 1009: Class Counts = [0. 0. 0. 1.], Rule:
# Node 1041: Class Counts = [0. 0. 3. 0.], Rule:
# Node 1048: Class Counts = [0. 0. 3. 0.], Rule:
# Node 1108: Class Counts = [0. 0. 1. 0.], Rule:
# Node 1177: Class Counts = [0. 0. 0. 2.], Rule:
# Node 1189: Class Counts = [0. 0. 1. 0.], Rule:
# Node 1190: Class Counts = [0. 0. 1. 0.], Rule:
# Node 1198: Class Counts = [0. 0. 1. 3.], Rule:
# Node 1201: Class Counts = [0. 0. 4. 0.], Rule:
# Node 1202: Class Counts = [0. 0. 1. 2.], Rule:
# Node 1209: Class Counts = [0. 0. 6. 0.], Rule:
# Node 1235: Class Counts = [0. 0. 6. 0.], Rule:
# Node 1245: Class Counts = [0. 0. 0. 2.], Rule:
# Node 1264: Class Counts = [0. 0. 9. 0.], Rule:
# Node 1281: Class Counts = [0. 0. 2. 0.], Rule:
# Node 1291: Class Counts = [0. 0. 3. 0.], Rule:
# Node 1327: Class Counts = [0. 0. 3. 0.], Rule:
# Node 1329: Class Counts = [0. 0. 1. 0.], Rule:
# Node 1332: Class Counts = [0. 0. 5. 0.], Rule:
# Node 1334: Class Counts = [0. 0. 0. 1.], Rule:
# Node 1343: Class Counts = [0. 0. 2. 0.], Rule:
# Node 1347: Class Counts = [0. 0. 4. 0.], Rule:
# Node 1354: Class Counts = [0. 0. 1. 0.], Rule:
# Node 1368: Class Counts = [0. 0. 2. 0.], Rule:
# Node 1369: Class Counts = [0. 0. 0. 1.], Rule:
# Node 1419: Class Counts = [0. 0. 5. 0.], Rule:
# Node 1509: Class Counts = [0. 0. 0. 1.], Rule:
# Node 1510: Class Counts = [0. 0. 3. 0.], Rule:
# Node 1530: Class Counts = [0. 0. 3. 0.], Rule:
# Node 1597: Class Counts = [0. 0. 1. 0.], Rule:
# Node 1621: Class Counts = [0. 0. 1. 0.], Rule:
# Node 1634: Class Counts = [0. 0. 2. 0.], Rule:
# Node 1656: Class Counts = [0. 0. 2. 0.], Rule:
# Node 1670: Class Counts = [0. 0. 0. 2.], Rule:
# Node 1704: Class Counts = [0. 0. 0. 2.], Rule:
# Node 1796: Class Counts = [0. 0. 1. 1.], Rule:
# Node 1800: Class Counts = [0. 0. 1. 0.], Rule:
# Node 1801: Class Counts = [0. 0. 2. 0.], Rule:
# Node 1814: Class Counts = [0. 0. 1. 0.], Rule:
# Node 1832: Class Counts = [0. 0. 0. 2.], Rule:
# Node 1840: Class Counts = [0. 0. 3. 0.], Rule:
# Node 1847: Class Counts = [0. 0. 0. 2.], Rule:
# Node 1886: Class Counts = [0. 0. 0. 1.], Rule:
# Node 1887: Class Counts = [0. 0. 3. 0.], Rule:
# Node 1930: Class Counts = [0. 0. 3. 0.], Rule:
# Node 1932: Class Counts = [0. 0. 0. 1.], Rule:
# Node 1933: Class Counts = [0. 0. 1. 0.], Rule:
# Node 1947: Class Counts = [0. 0. 1. 1.], Rule:
# Node 1958: Class Counts = [0. 0. 2. 0.], Rule:
# Node 1961: Class Counts = [0. 0. 0. 1.], Rule:
# Node 1978: Class Counts = [0. 0. 1. 0.], Rule:
# Node 1988: Class Counts = [0. 0. 0. 2.], Rule:
# Node 1993: Class Counts = [0. 0. 1. 0.], Rule:
# Node 1995: Class Counts = [0. 0. 0. 1.], Rule:
# Node 1996: Class Counts = [0. 0. 1. 0.], Rule:
# Node 1997: Class Counts = [0. 0. 0. 4.], Rule:
# Node 2006: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2010: Class Counts = [0. 0. 0. 2.], Rule:
# Node 2011: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2045: Class Counts = [0. 0. 0. 1.], Rule:
# Node 2052: Class Counts = [0. 0. 2. 0.], Rule:
# Node 2055: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2063: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2067: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2070: Class Counts = [0. 0. 5. 0.], Rule:
# Node 2076: Class Counts = [0. 0. 2. 0.], Rule:
# Node 2084: Class Counts = [0. 0. 0. 1.], Rule:
# Node 2092: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2101: Class Counts = [0. 0. 2. 0.], Rule:
# Node 2106: Class Counts = [0. 0. 2. 0.], Rule:
# Node 2111: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2117: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2118: Class Counts = [0. 0. 0. 1.], Rule:
# Node 2119: Class Counts = [0. 0. 0. 1.], Rule:
# Node 2140: Class Counts = [0. 0. 2. 0.], Rule:
# Node 2191: Class Counts = [0. 0. 0. 1.], Rule:
# Node 2203: Class Counts = [0. 0. 0. 2.], Rule:
# Node 2206: Class Counts = [0. 0. 5. 0.], Rule:
# Node 2211: Class Counts = [0. 0. 2. 0.], Rule:
# Node 2217: Class Counts = [0. 0. 3. 0.], Rule:
# Node 2229: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2244: Class Counts = [0. 0. 2. 0.], Rule:
# Node 2258: Class Counts = [0. 0. 4. 0.], Rule:
# Node 2262: Class Counts = [0. 0. 3. 0.], Rule:
# Node 2272: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2273: Class Counts = [0. 0. 2. 0.], Rule:
# Node 2286: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2289: Class Counts = [0. 0. 2. 0.], Rule:
# Node 2301: Class Counts = [0. 0. 2. 0.], Rule:
# Node 2305: Class Counts = [0. 0. 5. 0.], Rule:
# Node 2329: Class Counts = [0. 0. 8. 0.], Rule:
# Node 2342: Class Counts = [ 0.  0. 15.  0.], Rule:
# Node 2344: Class Counts = [0. 0. 3. 0.], Rule:
# Node 2358: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2360: Class Counts = [ 0.  0. 10.  0.], Rule:
# Node 2366: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2368: Class Counts = [0. 0. 5. 0.], Rule:
# Node 2383: Class Counts = [0. 0. 0. 2.], Rule:
# Node 2385: Class Counts = [0. 0. 0. 2.], Rule:
# Node 2397: Class Counts = [0. 0. 3. 0.], Rule:
# Node 2407: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2426: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2435: Class Counts = [0. 0. 0. 1.], Rule:
# Node 2436: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2449: Class Counts = [0. 0. 4. 0.], Rule:
# Node 2460: Class Counts = [0. 0. 6. 0.], Rule:
# Node 2517: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2553: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2569: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2571: Class Counts = [0. 0. 0. 2.], Rule:
# Node 2599: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2612: Class Counts = [0. 0. 0. 1.], Rule:
# Node 2621: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2632: Class Counts = [0. 0. 0. 1.], Rule:
# Node 2633: Class Counts = [0. 0. 3. 1.], Rule:
# Node 2645: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2672: Class Counts = [0. 0. 0. 1.], Rule:
# Node 2674: Class Counts = [0. 0. 2. 0.], Rule:
# Node 2719: Class Counts = [0. 0. 2. 0.], Rule:
# Node 2755: Class Counts = [ 0.  0. 10.  0.], Rule:
# Node 2768: Class Counts = [0. 0. 1. 2.], Rule:
# Node 2773: Class Counts = [0. 0. 7. 0.], Rule:
# Node 2805: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2828: Class Counts = [0. 0. 0. 2.], Rule:
# Node 2829: Class Counts = [0. 0. 0. 4.], Rule:
# Node 2830: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2844: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2847: Class Counts = [0. 0. 0. 1.], Rule:
# Node 2855: Class Counts = [0. 0. 3. 0.], Rule:
# Node 2859: Class Counts = [ 0.  0. 10.  0.], Rule:
# Node 2862: Class Counts = [0. 0. 1. 1.], Rule:
# Node 2869: Class Counts = [0. 0. 2. 0.], Rule:
# Node 2901: Class Counts = [0. 0. 2. 0.], Rule:
# Node 2903: Class Counts = [0. 0. 2. 0.], Rule:
# Node 2963: Class Counts = [0. 0. 3. 2.], Rule:
# Node 2987: Class Counts = [0. 0. 1. 0.], Rule:
# Node 2999: Class Counts = [0. 0. 2. 0.], Rule:
# Node 3044: Class Counts = [0. 0. 0. 2.], Rule:
# Node 3058: Class Counts = [0. 0. 6. 0.], Rule:
# Node 3084: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3112: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3114: Class Counts = [0. 0. 4. 2.], Rule:
# Node 3137: Class Counts = [0. 0. 0. 1.], Rule:
# Node 3166: Class Counts = [0. 0. 2. 0.], Rule:
# Node 3172: Class Counts = [0. 0. 1. 6.], Rule:
# Node 3197: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3206: Class Counts = [0. 0. 8. 0.], Rule:
# Node 3210: Class Counts = [0. 0. 6. 0.], Rule:
# Node 3212: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3243: Class Counts = [0. 0. 0. 1.], Rule:
# Node 3263: Class Counts = [0. 0. 4. 0.], Rule:
# Node 3265: Class Counts = [0. 0. 2. 0.], Rule:
# Node 3277: Class Counts = [0. 0. 0. 1.], Rule:
# Node 3332: Class Counts = [0. 0. 2. 0.], Rule:
# Node 3349: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3385: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3389: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3391: Class Counts = [0. 0. 2. 0.], Rule:
# Node 3416: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3471: Class Counts = [0. 0. 0. 1.], Rule:
# Node 3481: Class Counts = [0. 0. 3. 0.], Rule:
# Node 3483: Class Counts = [0. 0. 9. 0.], Rule:
# Node 3500: Class Counts = [0. 0. 4. 0.], Rule:
# Node 3503: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3530: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3535: Class Counts = [0. 0. 6. 0.], Rule:
# Node 3573: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3576: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3591: Class Counts = [0. 0. 0. 4.], Rule:
# Node 3605: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3616: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3626: Class Counts = [0. 0. 0. 1.], Rule:
# Node 3627: Class Counts = [0. 0. 1. 1.], Rule:
# Node 3635: Class Counts = [0. 0. 3. 0.], Rule:
# Node 3639: Class Counts = [0. 0. 5. 0.], Rule:
# Node 3647: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3654: Class Counts = [0. 0. 2. 0.], Rule:
# Node 3655: Class Counts = [0. 0. 4. 0.], Rule:
# Node 3674: Class Counts = [0. 0. 0. 1.], Rule:
# Node 3676: Class Counts = [0. 0. 0. 3.], Rule:
# Node 3701: Class Counts = [0. 0. 2. 0.], Rule:
# Node 3707: Class Counts = [0. 0. 0. 3.], Rule:
# Node 3751: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3755: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3777: Class Counts = [0. 0. 3. 0.], Rule:
# Node 3787: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3794: Class Counts = [0. 0. 3. 0.], Rule:
# Node 3796: Class Counts = [0. 0. 2. 0.], Rule:
# Node 3801: Class Counts = [0. 0. 2. 0.], Rule:
# Node 3818: Class Counts = [0. 0. 2. 0.], Rule:
# Node 3822: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3824: Class Counts = [0. 0. 2. 0.], Rule:
# Node 3828: Class Counts = [0. 0. 2. 0.], Rule:
# Node 3847: Class Counts = [0. 0. 4. 0.], Rule:
# Node 3859: Class Counts = [0. 0. 0. 2.], Rule:
# Node 3867: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3873: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3877: Class Counts = [0. 0. 3. 0.], Rule:
# Node 3890: Class Counts = [0. 0. 0. 1.], Rule:
# Node 3892: Class Counts = [0. 0. 4. 0.], Rule:
# Node 3903: Class Counts = [0. 0. 0. 3.], Rule:
# Node 3908: Class Counts = [0. 0. 0. 2.], Rule:
# Node 3912: Class Counts = [0. 0. 0. 1.], Rule:
# Node 3924: Class Counts = [0. 0. 1. 0.], Rule:
# Node 3943: Class Counts = [0. 0. 2. 0.], Rule:
# Node 3945: Class Counts = [0. 0. 0. 2.], Rule:
# Node 3949: Class Counts = [0. 0. 0. 1.], Rule:
# Node 3950: Class Counts = [0. 0. 2. 0.], Rule:
# Node 3954: Class Counts = [0. 0. 2. 0.], Rule:
# Node 3956: Class Counts = [0. 0. 6. 0.], Rule:
# Node 3975: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4036: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4038: Class Counts = [0. 0. 5. 0.], Rule:
# Node 4049: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4052: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4056: Class Counts = [0. 0. 5. 0.], Rule:
# Node 4060: Class Counts = [0. 0. 0. 1.], Rule:
# Node 4071: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4078: Class Counts = [0. 0. 0. 1.], Rule:
# Node 4101: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4113: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4115: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4136: Class Counts = [0. 0. 3. 0.], Rule:
# Node 4142: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4153: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4155: Class Counts = [0. 0. 3. 0.], Rule:
# Node 4177: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4180: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4189: Class Counts = [0. 0. 0. 1.], Rule:
# Node 4196: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4203: Class Counts = [0. 0. 6. 0.], Rule:
# Node 4207: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4211: Class Counts = [0. 0. 1. 2.], Rule:
# Node 4213: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4225: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4229: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4252: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4255: Class Counts = [0. 0. 0. 1.], Rule:
# Node 4262: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4267: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4272: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4274: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4279: Class Counts = [0. 0. 3. 0.], Rule:
# Node 4287: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4289: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4314: Class Counts = [0. 0. 0. 1.], Rule:
# Node 4315: Class Counts = [0. 0. 3. 0.], Rule:
# Node 4317: Class Counts = [0. 0. 0. 3.], Rule:
# Node 4322: Class Counts = [0. 0. 4. 0.], Rule:
# Node 4342: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4375: Class Counts = [0. 0. 5. 0.], Rule:
# Node 4390: Class Counts = [0. 0. 4. 0.], Rule:
# Node 4410: Class Counts = [0. 0. 3. 0.], Rule:
# Node 4414: Class Counts = [0. 0. 1. 1.], Rule:
# Node 4417: Class Counts = [0. 0. 9. 0.], Rule:
# Node 4419: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4425: Class Counts = [0. 0. 0. 1.], Rule:
# Node 4432: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4434: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4439: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4443: Class Counts = [0. 0. 0. 1.], Rule:
# Node 4444: Class Counts = [0. 0. 8. 0.], Rule:
# Node 4450: Class Counts = [0. 0. 0. 1.], Rule:
# Node 4464: Class Counts = [0. 0. 0. 3.], Rule:
# Node 4472: Class Counts = [0. 0. 3. 0.], Rule:
# Node 4484: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4488: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4498: Class Counts = [0. 0. 3. 0.], Rule:
# Node 4501: Class Counts = [0. 0. 0. 1.], Rule:
# Node 4539: Class Counts = [0. 0. 4. 0.], Rule:
# Node 4544: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4548: Class Counts = [0. 0. 6. 0.], Rule:
# Node 4563: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4616: Class Counts = [0. 0. 0. 3.], Rule:
# Node 4626: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4643: Class Counts = [0. 0. 0. 1.], Rule:
# Node 4654: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4661: Class Counts = [0. 0. 1. 8.], Rule:
# Node 4662: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4672: Class Counts = [0. 0. 4. 0.], Rule:
# Node 4675: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4708: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4717: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4725: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4747: Class Counts = [0. 0. 0. 1.], Rule:
# Node 4763: Class Counts = [0. 0. 0. 1.], Rule:
# Node 4785: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4794: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4795: Class Counts = [0. 0. 0. 1.], Rule:
# Node 4807: Class Counts = [0. 0. 3. 0.], Rule:
# Node 4821: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4840: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4866: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4870: Class Counts = [0. 0. 0. 1.], Rule:
# Node 4879: Class Counts = [0. 0. 4. 0.], Rule:
# Node 4886: Class Counts = [0. 0. 3. 0.], Rule:
# Node 4899: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4903: Class Counts = [0. 0. 0. 2.], Rule:
# Node 4914: Class Counts = [0. 0. 0. 4.], Rule:
# Node 4916: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4917: Class Counts = [0. 0. 0. 3.], Rule:
# Node 4919: Class Counts = [0. 0. 3. 0.], Rule:
# Node 4932: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4933: Class Counts = [0. 0. 0. 1.], Rule:
# Node 4940: Class Counts = [0. 0. 0. 2.], Rule:
# Node 4945: Class Counts = [0. 0. 0. 2.], Rule:
# Node 4946: Class Counts = [0. 0. 0. 3.], Rule:
# Node 4962: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4967: Class Counts = [0. 0. 2. 0.], Rule:
# Node 4969: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4980: Class Counts = [0. 0. 0. 1.], Rule:
# Node 4989: Class Counts = [0. 0. 0. 1.], Rule:
# Node 4990: Class Counts = [0. 0. 1. 0.], Rule:
# Node 4995: Class Counts = [ 0.  0. 16.  0.], Rule:
# Node 4996: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5004: Class Counts = [0. 0. 8. 0.], Rule:
# Node 5012: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5019: Class Counts = [0. 0. 0. 2.], Rule:
# Node 5034: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5035: Class Counts = [0. 0. 2. 0.], Rule:
# Node 5050: Class Counts = [0. 0. 5. 0.], Rule:
# Node 5061: Class Counts = [0. 0. 0. 3.], Rule:
# Node 5073: Class Counts = [0. 0. 2. 0.], Rule:
# Node 5078: Class Counts = [0. 0. 2. 0.], Rule:
# Node 5081: Class Counts = [0. 0. 0. 2.], Rule:
# Node 5087: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5090: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5094: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5101: Class Counts = [0. 0. 4. 0.], Rule:
# Node 5110: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5112: Class Counts = [0. 0. 2. 0.], Rule:
# Node 5123: Class Counts = [0. 0. 3. 0.], Rule:
# Node 5125: Class Counts = [0. 0. 2. 0.], Rule:
# Node 5131: Class Counts = [0. 0. 0. 2.], Rule:
# Node 5133: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5135: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5146: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5149: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5151: Class Counts = [0. 0. 3. 0.], Rule:
# Node 5165: Class Counts = [0. 0. 7. 0.], Rule:
# Node 5177: Class Counts = [0. 0. 3. 0.], Rule:
# Node 5178: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5188: Class Counts = [ 0.  0. 11.  0.], Rule:
# Node 5196: Class Counts = [0. 0. 4. 0.], Rule:
# Node 5197: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5201: Class Counts = [ 0.  0. 21.  0.], Rule:
# Node 5205: Class Counts = [0. 0. 4. 0.], Rule:
# Node 5214: Class Counts = [0. 0. 2. 0.], Rule:
# Node 5221: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5227: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5232: Class Counts = [0. 0. 0. 5.], Rule:
# Node 5235: Class Counts = [0. 0. 2. 0.], Rule:
# Node 5236: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5244: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5245: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5246: Class Counts = [0. 0. 0. 7.], Rule:
# Node 5247: Class Counts = [0. 0. 2. 0.], Rule:
# Node 5257: Class Counts = [0. 0. 0. 3.], Rule:
# Node 5262: Class Counts = [0. 0. 0. 8.], Rule:
# Node 5267: Class Counts = [0. 0. 3. 0.], Rule:
# Node 5275: Class Counts = [0. 0. 0. 3.], Rule:
# Node 5281: Class Counts = [0. 0. 4. 0.], Rule:
# Node 5291: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5300: Class Counts = [0. 0. 2. 0.], Rule:
# Node 5310: Class Counts = [0. 0. 0. 2.], Rule:
# Node 5313: Class Counts = [0. 0. 2. 0.], Rule:
# Node 5319: Class Counts = [0. 0. 5. 0.], Rule:
# Node 5321: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5326: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5327: Class Counts = [0. 0. 0. 3.], Rule:
# Node 5331: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5333: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5334: Class Counts = [0. 0. 0. 2.], Rule:
# Node 5337: Class Counts = [0. 0. 5. 0.], Rule:
# Node 5343: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5354: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5361: Class Counts = [0. 0. 3. 0.], Rule:
# Node 5365: Class Counts = [0. 0. 3. 0.], Rule:
# Node 5369: Class Counts = [0. 0. 4. 0.], Rule:
# Node 5372: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5373: Class Counts = [0. 0. 0. 2.], Rule:
# Node 5378: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5379: Class Counts = [0. 0. 0. 2.], Rule:
# Node 5385: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5388: Class Counts = [ 0.  0. 11.  0.], Rule:
# Node 5390: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5392: Class Counts = [ 0.  0. 11.  0.], Rule:
# Node 5395: Class Counts = [0. 0. 8. 0.], Rule:
# Node 5397: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5399: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5404: Class Counts = [ 0.  0. 42.  0.], Rule:
# Node 5406: Class Counts = [0. 0. 3. 0.], Rule:
# Node 5408: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5409: Class Counts = [0. 0. 0. 2.], Rule:
# Node 5411: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5412: Class Counts = [0. 0. 0. 2.], Rule:
# Node 5413: Class Counts = [ 0.  0. 44.  0.], Rule:
# Node 5415: Class Counts = [0. 0. 4. 0.], Rule:
# Node 5420: Class Counts = [0. 0. 2. 0.], Rule:
# Node 5422: Class Counts = [0. 0. 2. 0.], Rule:
# Node 5425: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5428: Class Counts = [0. 0. 3. 0.], Rule:
# Node 5429: Class Counts = [0. 0. 0. 2.], Rule:
# Node 5442: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5452: Class Counts = [0. 0. 0. 3.], Rule:
# Node 5457: Class Counts = [0. 0. 0. 2.], Rule:
# Node 5469: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5472: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5475: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5496: Class Counts = [0. 0. 0. 4.], Rule:
# Node 5501: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5527: Class Counts = [0. 0. 2. 0.], Rule:
# Node 5531: Class Counts = [0. 0. 2. 0.], Rule:
# Node 5542: Class Counts = [0. 0. 5. 0.], Rule:
# Node 5544: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5572: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5597: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5605: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5639: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5644: Class Counts = [0. 0. 0. 2.], Rule:
# Node 5647: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5653: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5684: Class Counts = [0. 0. 2. 0.], Rule:
# Node 5696: Class Counts = [0. 0. 2. 0.], Rule:
# Node 5702: Class Counts = [0. 0. 2. 0.], Rule:
# Node 5735: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5746: Class Counts = [0. 0. 2. 0.], Rule:
# Node 5816: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5822: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5868: Class Counts = [0. 0. 1. 1.], Rule:
# Node 5917: Class Counts = [0. 0. 1. 0.], Rule:
# Node 5921: Class Counts = [0. 0. 0. 1.], Rule:
# Node 5943: Class Counts = [0. 0. 0. 2.], Rule:
# Node 5971: Class Counts = [0. 0. 2. 0.], Rule:
# Node 6009: Class Counts = [0. 0. 2. 0.], Rule:
# Node 6023: Class Counts = [0. 0. 0. 1.], Rule:
# Node 6071: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6113: Class Counts = [0. 0. 3. 0.], Rule:
# Node 6116: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6174: Class Counts = [ 0.  0.  0. 71.], Rule:
# Node 6181: Class Counts = [0. 0. 0. 2.], Rule:
# Node 6196: Class Counts = [0. 0. 2. 0.], Rule:
# Node 6202: Class Counts = [0. 0. 2. 0.], Rule:
# Node 6207: Class Counts = [ 0.  0.  0. 15.], Rule:
# Node 6237: Class Counts = [0. 0. 4. 0.], Rule:
# Node 6251: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6295: Class Counts = [0. 0. 0. 2.], Rule:
# Node 6320: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6341: Class Counts = [0. 0. 0. 1.], Rule:
# Node 6343: Class Counts = [0. 0. 0. 2.], Rule:
# Node 6348: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6373: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6398: Class Counts = [0. 0. 0. 4.], Rule:
# Node 6403: Class Counts = [0. 0. 0. 2.], Rule:
# Node 6410: Class Counts = [0. 0. 0. 5.], Rule:
# Node 6411: Class Counts = [ 0.  0.  0. 12.], Rule:
# Node 6414: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6417: Class Counts = [0. 0. 0. 1.], Rule:
# Node 6420: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6483: Class Counts = [0. 0. 0. 1.], Rule:
# Node 6503: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6515: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6595: Class Counts = [0. 0. 0. 2.], Rule:
# Node 6598: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6622: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6656: Class Counts = [0. 0. 4. 0.], Rule:
# Node 6662: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6664: Class Counts = [0. 0. 0. 1.], Rule:
# Node 6670: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6676: Class Counts = [0. 0. 0. 3.], Rule:
# Node 6679: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6682: Class Counts = [0. 0. 0. 1.], Rule:
# Node 6696: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6717: Class Counts = [0. 0. 0. 1.], Rule:
# Node 6729: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6731: Class Counts = [0. 0. 2. 0.], Rule:
# Node 6732: Class Counts = [0. 0. 3. 0.], Rule:
# Node 6740: Class Counts = [0. 0. 2. 0.], Rule:
# Node 6752: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6754: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6772: Class Counts = [0. 0. 0. 1.], Rule:
# Node 6773: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6776: Class Counts = [0. 0. 0. 1.], Rule:
# Node 6778: Class Counts = [0. 0. 0. 1.], Rule:
# Node 6799: Class Counts = [0. 0. 2. 0.], Rule:
# Node 6801: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6809: Class Counts = [0. 0. 0. 1.], Rule:
# Node 6810: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6857: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6860: Class Counts = [0. 0. 4. 0.], Rule:
# Node 6870: Class Counts = [0. 0. 0. 1.], Rule:
# Node 6875: Class Counts = [0. 0. 0. 2.], Rule:
# Node 6886: Class Counts = [0. 0. 0. 1.], Rule:
# Node 6887: Class Counts = [0. 0. 2. 0.], Rule:
# Node 6898: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6901: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6909: Class Counts = [0. 0. 1. 0.], Rule:
# Node 6946: Class Counts = [0. 0. 3. 0.], Rule:
# Node 6953: Class Counts = [0. 0. 4. 0.], Rule:
# Node 6959: Class Counts = [0. 0. 2. 0.], Rule:
# Node 6962: Class Counts = [0. 0. 0. 2.], Rule:
# Node 6969: Class Counts = [0. 0. 3. 0.], Rule:
# Node 6977: Class Counts = [0. 0. 0. 1.], Rule:
# Node 6986: Class Counts = [0. 0. 2. 0.], Rule:
# Node 6992: Class Counts = [0. 0. 3. 0.], Rule:
# Node 6995: Class Counts = [0. 0. 2. 0.], Rule:
# Node 7005: Class Counts = [0. 0. 2. 0.], Rule:
# Node 7009: Class Counts = [0. 0. 0. 2.], Rule:
# Node 7012: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7022: Class Counts = [0. 0. 2. 0.], Rule:
# Node 7046: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7062: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7075: Class Counts = [0. 0. 2. 0.], Rule:
# Node 7086: Class Counts = [0. 0. 0. 2.], Rule:
# Node 7115: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7122: Class Counts = [0. 0. 3. 0.], Rule:
# Node 7124: Class Counts = [0. 0. 8. 0.], Rule:
# Node 7147: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7151: Class Counts = [0. 0. 0. 2.], Rule:
# Node 7152: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7158: Class Counts = [0. 0. 5. 0.], Rule:
# Node 7161: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7172: Class Counts = [0. 0. 0. 2.], Rule:
# Node 7186: Class Counts = [0. 0. 5. 0.], Rule:
# Node 7191: Class Counts = [0. 0. 5. 0.], Rule:
# Node 7194: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7199: Class Counts = [0. 0. 3. 0.], Rule:
# Node 7202: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7206: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7208: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7214: Class Counts = [0. 0. 3. 0.], Rule:
# Node 7216: Class Counts = [ 0.  0. 12.  0.], Rule:
# Node 7242: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7244: Class Counts = [0. 0. 5. 0.], Rule:
# Node 7245: Class Counts = [0. 0. 1. 1.], Rule:
# Node 7251: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7254: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7260: Class Counts = [0. 0. 2. 0.], Rule:
# Node 7268: Class Counts = [0. 0. 0. 2.], Rule:
# Node 7278: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7287: Class Counts = [0. 0. 2. 0.], Rule:
# Node 7294: Class Counts = [0. 0. 2. 0.], Rule:
# Node 7301: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7304: Class Counts = [0. 0. 0. 3.], Rule:
# Node 7309: Class Counts = [0. 0. 0. 5.], Rule:
# Node 7317: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7321: Class Counts = [0. 0. 0. 5.], Rule:
# Node 7323: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7333: Class Counts = [0. 0. 3. 0.], Rule:
# Node 7338: Class Counts = [0. 0. 0. 3.], Rule:
# Node 7346: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7354: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7356: Class Counts = [0. 0. 0. 4.], Rule:
# Node 7362: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7367: Class Counts = [0. 0. 3. 0.], Rule:
# Node 7372: Class Counts = [0. 0. 2. 0.], Rule:
# Node 7375: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7378: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7388: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7396: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7398: Class Counts = [0. 0. 0. 2.], Rule:
# Node 7408: Class Counts = [0. 0. 3. 0.], Rule:
# Node 7410: Class Counts = [0. 0. 3. 0.], Rule:
# Node 7412: Class Counts = [0. 0. 0. 2.], Rule:
# Node 7446: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7447: Class Counts = [0. 0. 0. 7.], Rule:
# Node 7452: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7460: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7464: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7472: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7479: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7484: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7485: Class Counts = [0. 0. 6. 0.], Rule:
# Node 7498: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7500: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7505: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7507: Class Counts = [0. 0. 4. 0.], Rule:
# Node 7509: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7546: Class Counts = [0. 0. 3. 0.], Rule:
# Node 7549: Class Counts = [0. 0. 2. 0.], Rule:
# Node 7550: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7561: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7569: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7572: Class Counts = [0. 0. 5. 0.], Rule:
# Node 7574: Class Counts = [0. 0. 2. 0.], Rule:
# Node 7578: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7583: Class Counts = [0. 0. 0. 2.], Rule:
# Node 7587: Class Counts = [0. 0. 0. 9.], Rule:
# Node 7590: Class Counts = [0. 0. 0. 4.], Rule:
# Node 7601: Class Counts = [0. 0. 0. 2.], Rule:
# Node 7605: Class Counts = [0. 0. 0. 4.], Rule:
# Node 7617: Class Counts = [0. 0. 0. 2.], Rule:
# Node 7639: Class Counts = [0. 0. 2. 0.], Rule:
# Node 7640: Class Counts = [0. 0. 0. 4.], Rule:
# Node 7643: Class Counts = [0. 0. 0. 2.], Rule:
# Node 7649: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7670: Class Counts = [0. 0. 9. 0.], Rule:
# Node 7689: Class Counts = [0. 0. 3. 0.], Rule:
# Node 7692: Class Counts = [0. 0. 0. 4.], Rule:
# Node 7700: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7718: Class Counts = [0. 0. 0. 5.], Rule:
# Node 7728: Class Counts = [0. 0. 2. 0.], Rule:
# Node 7732: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7737: Class Counts = [0. 0. 0. 4.], Rule:
# Node 7741: Class Counts = [0. 0. 1. 6.], Rule:
# Node 7742: Class Counts = [0. 0. 4. 0.], Rule:
# Node 7744: Class Counts = [0. 0. 0. 8.], Rule:
# Node 7763: Class Counts = [0. 0. 0. 3.], Rule:
# Node 7799: Class Counts = [0. 0. 0. 3.], Rule:
# Node 7817: Class Counts = [0. 0. 3. 0.], Rule:
# Node 7820: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7826: Class Counts = [0. 0. 3. 2.], Rule:
# Node 7827: Class Counts = [0. 0. 0. 6.], Rule:
# Node 7828: Class Counts = [0. 0. 0. 8.], Rule:
# Node 7834: Class Counts = [0. 0. 0. 4.], Rule:
# Node 7836: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7840: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7843: Class Counts = [ 0.  0.  0. 16.], Rule:
# Node 7847: Class Counts = [0. 0. 0. 8.], Rule:
# Node 7854: Class Counts = [0. 0. 0. 2.], Rule:
# Node 7859: Class Counts = [0. 0. 0. 2.], Rule:
# Node 7862: Class Counts = [0. 0. 2. 0.], Rule:
# Node 7869: Class Counts = [0. 0. 0. 3.], Rule:
# Node 7873: Class Counts = [0. 0. 0. 7.], Rule:
# Node 7877: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7879: Class Counts = [0. 0. 0. 7.], Rule:
# Node 7881: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7882: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7889: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7893: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7897: Class Counts = [0. 0. 0. 5.], Rule:
# Node 7901: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7903: Class Counts = [0. 0. 2. 0.], Rule:
# Node 7909: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7911: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7923: Class Counts = [0. 0. 3. 0.], Rule:
# Node 7925: Class Counts = [0. 0. 3. 0.], Rule:
# Node 7927: Class Counts = [ 0.  0.  0. 11.], Rule:
# Node 7929: Class Counts = [0. 0. 2. 0.], Rule:
# Node 7930: Class Counts = [0. 0. 0. 3.], Rule:
# Node 7933: Class Counts = [ 0.  0.  0. 20.], Rule:
# Node 7935: Class Counts = [0. 0. 0. 3.], Rule:
# Node 7939: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7944: Class Counts = [0. 0. 0. 3.], Rule:
# Node 7951: Class Counts = [ 0.  0. 11.  0.], Rule:
# Node 7953: Class Counts = [0. 0. 2. 0.], Rule:
# Node 7956: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7963: Class Counts = [0. 0. 0. 2.], Rule:
# Node 7965: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7967: Class Counts = [0. 0. 8. 0.], Rule:
# Node 7968: Class Counts = [0. 0. 1. 1.], Rule:
# Node 7970: Class Counts = [0. 0. 0. 4.], Rule:
# Node 7971: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7972: Class Counts = [0. 0. 5. 0.], Rule:
# Node 7975: Class Counts = [0. 0. 4. 0.], Rule:
# Node 7979: Class Counts = [0. 0. 7. 0.], Rule:
# Node 7980: Class Counts = [0. 0. 0. 2.], Rule:
# Node 7988: Class Counts = [0. 0. 1. 0.], Rule:
# Node 7990: Class Counts = [0. 0. 9. 0.], Rule:
# Node 7992: Class Counts = [0. 0. 8. 0.], Rule:
# Node 7993: Class Counts = [ 0.  0. 55.  0.], Rule:
# Node 7994: Class Counts = [0. 0. 0. 1.], Rule:
# Node 7999: Class Counts = [0. 0. 0. 3.], Rule:
# Node 8003: Class Counts = [0. 0. 0. 3.], Rule:
# Node 8009: Class Counts = [0. 0. 1. 0.], Rule:
# Node 8013: Class Counts = [0. 0. 0. 2.], Rule:
# Node 8014: Class Counts = [0. 0. 2. 0.], Rule:
# Node 8016: Class Counts = [0. 0. 0. 2.], Rule:
# Node 8022: Class Counts = [0. 0. 0. 1.], Rule:
# Node 8026: Class Counts = [0. 0. 1. 0.], Rule:
# Node 8028: Class Counts = [0. 0. 8. 0.], Rule:
# Node 8030: Class Counts = [0. 0. 0. 5.], Rule:
# Node 8036: Class Counts = [ 0.  0. 11.  0.], Rule:
# Node 8039: Class Counts = [0. 0. 2. 0.], Rule:
# Node 8041: Class Counts = [0. 0. 1. 0.], Rule:
# Node 8044: Class Counts = [0. 0. 0. 1.], Rule:
# Node 8049: Class Counts = [ 0.  0. 12.  0.], Rule:
# Node 8050: Class Counts = [0. 0. 0. 1.], Rule:
# Node 8051: Class Counts = [0. 0. 0. 1.], Rule:
# Node 8054: Class Counts = [0. 0. 2. 0.], Rule:
# Node 8055: Class Counts = [0. 0. 0. 1.], Rule:
# Node 8056: Class Counts = [0. 0. 0. 2.], Rule:
# Node 8058: Class Counts = [0. 0. 0. 4.], Rule:
# Node 8060: Class Counts = [0. 0. 0. 1.], Rule:
# Node 8061: Class Counts = [0. 0. 1. 0.], Rule:
# Node 8066: Class Counts = [0. 0. 0. 2.], Rule:
# Node 8073: Class Counts = [0. 0. 6. 0.], Rule:
# Node 8075: Class Counts = [ 0.  0. 10.  0.], Rule:
# Node 8078: Class Counts = [0. 0. 1. 0.], Rule:
# Node 8094: Class Counts = [0. 0. 1. 0.], Rule:
# Node 8099: Class Counts = [0. 0. 0. 2.], Rule:
# Node 8108: Class Counts = [0. 0. 0. 2.], Rule:
# Node 8148: Class Counts = [0. 0. 2. 1.], Rule:
# Node 8171: Class Counts = [0. 0. 0. 4.], Rule:
# Node 8218: Class Counts = [0. 0. 0. 2.], Rule:
# Node 8223: Class Counts = [0. 0. 2. 0.], Rule:
# Node 8295: Class Counts = [0. 0. 0. 2.], Rule:
# Node 8328: Class Counts = [0. 0. 0. 1.], Rule:
# Node 8333: Class Counts = [0. 0. 0. 5.], Rule:
# Node 8339: Class Counts = [0. 0. 0. 1.], Rule:
# Node 8344: Class Counts = [0. 0. 1. 0.], Rule:
# Node 8346: Class Counts = [0. 0. 5. 0.], Rule:
# Node 8347: Class Counts = [0. 0. 0. 3.], Rule:
# Node 8359: Class Counts = [0. 0. 0. 4.], Rule:
# Node 8365: Class Counts = [0. 0. 3. 0.], Rule:
# Node 8370: Class Counts = [0. 0. 0. 3.], Rule:
# Node 8381: Class Counts = [0. 0. 0. 6.], Rule:
# Node 8389: Class Counts = [0. 0. 0. 5.], Rule:
# Node 8393: Class Counts = [0. 0. 0. 5.], Rule:
# Node 8396: Class Counts = [0. 0. 0. 8.], Rule:
# Node 8398: Class Counts = [0. 0. 0. 1.], Rule:
# Node 8399: Class Counts = [0. 0. 1. 0.], Rule:
# Node 8453: Class Counts = [0. 0. 1. 1.], Rule:
# Node 8535: Class Counts = [0. 0. 3. 0.], Rule:
# Node 8547: Class Counts = [0. 0. 0. 3.], Rule:
# Node 8552: Class Counts = [ 0.  0.  0. 27.], Rule:
# Node 8593: Class Counts = [0. 0. 3. 0.], Rule:
# Node 8597: Class Counts = [0. 0. 0. 6.], Rule:
# Node 8599: Class Counts = [0. 0. 0. 2.], Rule:
# Node 8603: Class Counts = [0. 0. 0. 1.], Rule:
# Node 8606: Class Counts = [0. 0. 1. 0.], Rule:
# Node 8607: Class Counts = [0. 0. 0. 7.], Rule:
# Node 8659: Class Counts = [0. 0. 0. 2.], Rule:
# Node 8675: Class Counts = [0. 0. 0. 1.], Rule:
# Node 8693: Class Counts = [0. 0. 0. 6.], Rule:
# Node 8696: Class Counts = [0. 0. 0. 1.], Rule:
# Node 8701: Class Counts = [0. 0. 2. 0.], Rule:
# Node 8706: Class Counts = [0. 0. 0. 1.], Rule:
# Node 8729: Class Counts = [0. 0. 1. 0.], Rule:
# Node 8732: Class Counts = [0. 0. 3. 1.], Rule:
# Node 8742: Class Counts = [0. 0. 1. 0.], Rule:
# Node 8746: Class Counts = [0. 0. 0. 2.], Rule:
# Node 8752: Class Counts = [ 0.  0.  0. 11.], Rule:
# Node 8755: Class Counts = [0. 0. 3. 1.], Rule:
# Node 8756: Class Counts = [0. 0. 0. 2.], Rule:
# Node 8769: Class Counts = [0. 0. 2. 9.], Rule:
# Node 8772: Class Counts = [0. 0. 0. 4.], Rule:
# Node 8775: Class Counts = [0. 0. 1. 3.], Rule:
# Node 8778: Class Counts = [0. 0. 6. 0.], Rule:
# Node 8791: Class Counts = [0. 0. 0. 1.], Rule:
# Node 8792: Class Counts = [0. 0. 1. 0.], Rule:
# Node 8798: Class Counts = [ 0.  0.  0. 21.], Rule:
# Node 8806: Class Counts = [ 0.  0.  0. 51.], Rule:
# Node 8811: Class Counts = [ 0.  0.  0. 12.], Rule:
# Node 8814: Class Counts = [0. 0. 0. 4.], Rule:
# Node 8816: Class Counts = [0. 0. 0. 1.], Rule:
# Node 8825: Class Counts = [0. 0. 2. 0.], Rule:
# Node 8838: Class Counts = [0. 0. 1. 0.], Rule:
# Node 8853: Class Counts = [0. 0. 3. 0.], Rule:
# Node 8885: Class Counts = [0. 0. 0. 4.], Rule:
# Node 8886: Class Counts = [0. 0. 1. 0.], Rule:
# Node 8889: Class Counts = [0. 0. 0. 1.], Rule:
# Node 8895: Class Counts = [0. 0. 0. 4.], Rule:
# Node 8900: Class Counts = [0. 0. 0. 4.], Rule:
# Node 8907: Class Counts = [0. 0. 0. 1.], Rule:
# Node 8909: Class Counts = [0. 0. 0. 4.], Rule:
# Node 8913: Class Counts = [0. 0. 0. 2.], Rule:
# Node 8930: Class Counts = [0. 0. 3. 0.], Rule:
# Node 8932: Class Counts = [0. 0. 0. 2.], Rule:
# Node 8935: Class Counts = [0. 0. 5. 0.], Rule:
# Node 8939: Class Counts = [0. 0. 0. 2.], Rule:
# Node 8954: Class Counts = [0. 0. 4. 0.], Rule:
# Node 8956: Class Counts = [0. 0. 1. 0.], Rule:
# Node 8961: Class Counts = [0. 0. 1. 0.], Rule:
# Node 8963: Class Counts = [0. 0. 1. 0.], Rule:
# Node 8971: Class Counts = [0. 0. 1. 0.], Rule:
# Node 8974: Class Counts = [0. 0. 0. 4.], Rule:
# Node 8977: Class Counts = [0. 0. 0. 1.], Rule:
# Node 8980: Class Counts = [ 0.  0.  0. 10.], Rule:
# Node 8988: Class Counts = [0. 0. 2. 0.], Rule:
# Node 8991: Class Counts = [0. 0. 0. 2.], Rule:
# Node 8995: Class Counts = [0. 0. 0. 4.], Rule:
# Node 8998: Class Counts = [0. 0. 0. 3.], Rule:
# Node 9021: Class Counts = [0. 0. 1. 1.], Rule:
# Node 9022: Class Counts = [0. 0. 0. 6.], Rule:
# Node 9036: Class Counts = [0. 0. 2. 0.], Rule:
# Node 9040: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9043: Class Counts = [0. 0. 3. 0.], Rule:
# Node 9059: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9078: Class Counts = [0. 0. 7. 0.], Rule:
# Node 9081: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9086: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9087: Class Counts = [0. 0. 1. 0.], Rule:
# Node 9101: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9116: Class Counts = [0. 0. 2. 0.], Rule:
# Node 9136: Class Counts = [0. 0. 0. 5.], Rule:
# Node 9141: Class Counts = [0. 0. 2. 0.], Rule:
# Node 9143: Class Counts = [0. 0. 1. 0.], Rule:
# Node 9168: Class Counts = [0. 0. 0. 1.], Rule:
# Node 9180: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9186: Class Counts = [0. 0. 2. 1.], Rule:
# Node 9204: Class Counts = [0. 0. 1. 0.], Rule:
# Node 9217: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9224: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9238: Class Counts = [0. 0. 3. 0.], Rule:
# Node 9257: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9264: Class Counts = [0. 0. 0. 3.], Rule:
# Node 9279: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9282: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9288: Class Counts = [0. 0. 0. 5.], Rule:
# Node 9293: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9298: Class Counts = [0. 0. 1. 0.], Rule:
# Node 9312: Class Counts = [0. 0. 2. 1.], Rule:
# Node 9318: Class Counts = [0. 0. 0. 6.], Rule:
# Node 9330: Class Counts = [0. 0. 2. 0.], Rule:
# Node 9333: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9365: Class Counts = [0. 0. 6. 0.], Rule:
# Node 9366: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9376: Class Counts = [0. 0. 1. 0.], Rule:
# Node 9406: Class Counts = [0. 0. 0. 6.], Rule:
# Node 9412: Class Counts = [0. 0. 0. 1.], Rule:
# Node 9413: Class Counts = [0. 0. 2. 0.], Rule:
# Node 9420: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9422: Class Counts = [0. 0. 1. 1.], Rule:
# Node 9428: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9435: Class Counts = [0. 0. 0. 3.], Rule:
# Node 9454: Class Counts = [0. 0. 2. 0.], Rule:
# Node 9457: Class Counts = [0. 0. 0. 5.], Rule:
# Node 9463: Class Counts = [0. 0. 2. 0.], Rule:
# Node 9471: Class Counts = [0. 0. 0. 4.], Rule:
# Node 9502: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9519: Class Counts = [0. 0. 2. 0.], Rule:
# Node 9520: Class Counts = [0. 0. 0. 4.], Rule:
# Node 9523: Class Counts = [0. 0. 2. 0.], Rule:
# Node 9554: Class Counts = [0. 0. 0. 3.], Rule:
# Node 9568: Class Counts = [0. 0. 0. 7.], Rule:
# Node 9576: Class Counts = [0. 0. 5. 0.], Rule:
# Node 9578: Class Counts = [0. 0. 0. 1.], Rule:
# Node 9579: Class Counts = [0. 0. 4. 1.], Rule:
# Node 9601: Class Counts = [0. 0. 0. 1.], Rule:
# Node 9612: Class Counts = [0. 0. 4. 0.], Rule:
# Node 9622: Class Counts = [0. 0. 7. 0.], Rule:
# Node 9625: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9633: Class Counts = [0. 0. 1. 0.], Rule:
# Node 9644: Class Counts = [0. 0. 2. 0.], Rule:
# Node 9645: Class Counts = [0. 0. 0. 1.], Rule:
# Node 9656: Class Counts = [0. 0. 0. 1.], Rule:
# Node 9671: Class Counts = [0. 0. 0. 1.], Rule:
# Node 9707: Class Counts = [0. 0. 2. 0.], Rule:
# Node 9730: Class Counts = [0. 0. 1. 0.], Rule:
# Node 9749: Class Counts = [0. 0. 0. 3.], Rule:
# Node 9760: Class Counts = [0. 0. 0. 1.], Rule:
# Node 9772: Class Counts = [0. 0. 0. 1.], Rule:
# Node 9777: Class Counts = [0. 0. 1. 0.], Rule:
# Node 9783: Class Counts = [0. 0. 1. 0.], Rule:
# Node 9789: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9795: Class Counts = [0. 0. 1. 0.], Rule:
# Node 9808: Class Counts = [0. 0. 0. 1.], Rule:
# Node 9839: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9843: Class Counts = [0. 0. 0. 1.], Rule:
# Node 9846: Class Counts = [0. 0. 0. 5.], Rule:
# Node 9868: Class Counts = [0. 0. 2. 0.], Rule:
# Node 9875: Class Counts = [0. 0. 9. 0.], Rule:
# Node 9876: Class Counts = [0. 0. 0. 1.], Rule:
# Node 9881: Class Counts = [0. 0. 1. 0.], Rule:
# Node 9894: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9932: Class Counts = [0. 0. 1. 1.], Rule:
# Node 9933: Class Counts = [0. 0. 0. 3.], Rule:
# Node 9940: Class Counts = [0. 0. 0. 2.], Rule:
# Node 9942: Class Counts = [0. 0. 1. 0.], Rule:
# Node 9955: Class Counts = [0. 0. 1. 1.], Rule:
# Node 9957: Class Counts = [0. 0. 0. 1.], Rule:
# Node 9963: Class Counts = [0. 0. 3. 0.], Rule:
# ...
# Node 17927: Class Counts = [0. 0. 2. 0.], Rule:
# Node 17928: Class Counts = [0. 0. 0. 1.], Rule:
# Node 17935: Class Counts = [0. 0. 2. 0.], Rule:
# Node 17945: Class Counts = [0. 0. 1. 0.], Rule:
# Node 17947: Class Counts = [0. 0. 1. 0.], Rule:
# Node 17955: Class Counts = [0. 0. 0. 1.], Rule:
# Node 17958: Class Counts = [0. 0. 0. 1.], Rule:
# Node 17959: Class Counts = [0. 0. 2. 0.], Rule:
# Node 17967: Class Counts = [0. 0. 1. 0.], Rule:
# Node 17968: Class Counts = [0. 0. 3. 0.], Rule:
# Node 17975: Class Counts = [0. 0. 6. 0.], Rule:
# Node 18023: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18026: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18030: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18040: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18046: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18049: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18050: Class Counts = [0. 0. 9. 0.], Rule:
# Node 18057: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18063: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18082: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18102: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18108: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18136: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18141: Class Counts = [0. 0. 6. 0.], Rule:
# Node 18146: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18156: Class Counts = [0. 0. 4. 0.], Rule:
# Node 18159: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18166: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18170: Class Counts = [0. 0. 4. 0.], Rule:
# Node 18172: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18176: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18182: Class Counts = [0. 0. 9. 0.], Rule:
# Node 18185: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18188: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18193: Class Counts = [0. 0. 8. 0.], Rule:
# Node 18198: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18199: Class Counts = [0. 0. 3. 0.], Rule:
# Node 18210: Class Counts = [0. 0. 4. 0.], Rule:
# Node 18212: Class Counts = [0. 0. 0. 2.], Rule:
# Node 18221: Class Counts = [0. 0. 0. 2.], Rule:
# Node 18240: Class Counts = [0. 0. 3. 0.], Rule:
# Node 18246: Class Counts = [0. 0. 4. 0.], Rule:
# Node 18250: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18261: Class Counts = [0. 0. 3. 0.], Rule:
# Node 18265: Class Counts = [0. 0. 0. 4.], Rule:
# Node 18269: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18272: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18275: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18277: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18284: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18292: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18307: Class Counts = [0. 0. 8. 0.], Rule:
# Node 18313: Class Counts = [0. 0. 3. 0.], Rule:
# Node 18327: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18340: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18348: Class Counts = [0. 0. 4. 0.], Rule:
# Node 18376: Class Counts = [0. 0. 6. 0.], Rule:
# Node 18384: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18393: Class Counts = [0. 0. 3. 0.], Rule:
# Node 18398: Class Counts = [0. 0. 3. 0.], Rule:
# Node 18400: Class Counts = [0. 0. 3. 3.], Rule:
# Node 18401: Class Counts = [0. 0. 9. 0.], Rule:
# Node 18418: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18421: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18422: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18423: Class Counts = [0. 0. 0. 3.], Rule:
# Node 18431: Class Counts = [0. 0. 0. 3.], Rule:
# Node 18435: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18443: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18444: Class Counts = [0. 0. 0. 2.], Rule:
# Node 18447: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18452: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18465: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18477: Class Counts = [0. 0. 3. 0.], Rule:
# Node 18478: Class Counts = [ 0.  0. 15.  0.], Rule:
# Node 18491: Class Counts = [0. 0. 6. 0.], Rule:
# Node 18493: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18504: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18507: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18508: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18516: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18518: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18520: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18540: Class Counts = [0. 0. 6. 0.], Rule:
# Node 18543: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18547: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18552: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18555: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18582: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18603: Class Counts = [0. 0. 6. 0.], Rule:
# Node 18617: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18632: Class Counts = [0. 0. 0. 2.], Rule:
# Node 18634: Class Counts = [0. 0. 6. 0.], Rule:
# Node 18635: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18640: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18645: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18648: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18659: Class Counts = [ 0.  0. 10.  0.], Rule:
# Node 18665: Class Counts = [0. 0. 0. 2.], Rule:
# Node 18666: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18670: Class Counts = [0. 0. 6. 0.], Rule:
# Node 18672: Class Counts = [ 0.  0. 10.  0.], Rule:
# Node 18676: Class Counts = [0. 0. 6. 0.], Rule:
# Node 18700: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18704: Class Counts = [0. 0. 4. 0.], Rule:
# Node 18722: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18728: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18730: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18731: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18781: Class Counts = [0. 0. 3. 0.], Rule:
# Node 18789: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18794: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18799: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18807: Class Counts = [0. 0. 0. 3.], Rule:
# Node 18810: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18812: Class Counts = [0. 0. 5. 0.], Rule:
# Node 18814: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18819: Class Counts = [0. 0. 3. 0.], Rule:
# Node 18844: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18851: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18856: Class Counts = [0. 0. 0. 2.], Rule:
# Node 18861: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18868: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18869: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18874: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18887: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18889: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18900: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18906: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18915: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18940: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18948: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18955: Class Counts = [0. 0. 0. 2.], Rule:
# Node 18956: Class Counts = [0. 0. 1. 0.], Rule:
# Node 18958: Class Counts = [0. 0. 0. 2.], Rule:
# Node 18967: Class Counts = [0. 0. 0. 2.], Rule:
# Node 18968: Class Counts = [0. 0. 0. 2.], Rule:
# Node 18981: Class Counts = [0. 0. 2. 0.], Rule:
# Node 18986: Class Counts = [0. 0. 0. 1.], Rule:
# Node 18997: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19001: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19007: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19011: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19029: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19045: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19060: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19061: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19068: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19070: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19095: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19097: Class Counts = [0. 0. 0. 3.], Rule:
# Node 19110: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19117: Class Counts = [0. 0. 2. 0.], Rule:
# Node 19121: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19125: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19135: Class Counts = [0. 0. 3. 0.], Rule:
# Node 19139: Class Counts = [0. 0. 4. 0.], Rule:
# Node 19147: Class Counts = [0. 0. 0. 3.], Rule:
# Node 19171: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19193: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19203: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19211: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19234: Class Counts = [0. 0. 2. 0.], Rule:
# Node 19237: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19262: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19263: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19269: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19279: Class Counts = [0. 0. 2. 0.], Rule:
# Node 19287: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19293: Class Counts = [0. 0. 0. 3.], Rule:
# Node 19305: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19307: Class Counts = [0. 0. 0. 3.], Rule:
# Node 19313: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19322: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19324: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19327: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19329: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19330: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19331: Class Counts = [0. 0. 3. 0.], Rule:
# Node 19337: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19342: Class Counts = [0. 0. 2. 0.], Rule:
# Node 19345: Class Counts = [ 0.  0. 12.  0.], Rule:
# Node 19348: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19358: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19360: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19361: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19365: Class Counts = [0. 0. 5. 0.], Rule:
# Node 19373: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19377: Class Counts = [0. 0. 7. 1.], Rule:
# Node 19382: Class Counts = [0. 0. 0. 9.], Rule:
# Node 19384: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19387: Class Counts = [0. 0. 0. 5.], Rule:
# Node 19402: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19410: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19416: Class Counts = [0. 0. 3. 0.], Rule:
# Node 19417: Class Counts = [0. 0. 1. 7.], Rule:
# Node 19423: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19425: Class Counts = [0. 0. 0. 3.], Rule:
# Node 19487: Class Counts = [0. 0. 0. 4.], Rule:
# Node 19491: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19493: Class Counts = [0. 0. 0. 8.], Rule:
# Node 19502: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19508: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19513: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19517: Class Counts = [0. 0. 0. 4.], Rule:
# Node 19519: Class Counts = [0. 0. 0. 3.], Rule:
# Node 19520: Class Counts = [0. 0. 1. 1.], Rule:
# Node 19523: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19538: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19545: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19549: Class Counts = [0. 0. 2. 0.], Rule:
# Node 19552: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19557: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19561: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19567: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19570: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19572: Class Counts = [0. 0. 0. 3.], Rule:
# Node 19579: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19580: Class Counts = [0. 0. 2. 0.], Rule:
# Node 19582: Class Counts = [0. 0. 2. 0.], Rule:
# Node 19585: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19603: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19605: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19644: Class Counts = [0. 0. 2. 1.], Rule:
# Node 19648: Class Counts = [0. 0. 0. 3.], Rule:
# Node 19659: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19667: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19671: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19680: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19692: Class Counts = [0. 0. 3. 0.], Rule:
# Node 19724: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19727: Class Counts = [0. 0. 2. 0.], Rule:
# Node 19733: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19744: Class Counts = [0. 0. 0. 3.], Rule:
# Node 19747: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19762: Class Counts = [0. 0. 0. 5.], Rule:
# Node 19780: Class Counts = [0. 0. 3. 0.], Rule:
# Node 19797: Class Counts = [0. 0. 2. 0.], Rule:
# Node 19802: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19834: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19850: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19854: Class Counts = [0. 0. 0. 2.], Rule:
# Node 19865: Class Counts = [0. 0. 1. 5.], Rule:
# Node 19878: Class Counts = [0. 0. 0. 8.], Rule:
# Node 19879: Class Counts = [0. 0. 2. 0.], Rule:
# Node 19882: Class Counts = [0. 0. 0. 5.], Rule:
# Node 19906: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19918: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19920: Class Counts = [0. 0. 1. 0.], Rule:
# Node 19926: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19927: Class Counts = [0. 0. 5. 0.], Rule:
# Node 19935: Class Counts = [0. 0. 0. 1.], Rule:
# Node 19938: Class Counts = [0. 0. 0. 3.], Rule:
# Node 19955: Class Counts = [0. 0. 2. 0.], Rule:
# Node 19958: Class Counts = [0. 0. 5. 0.], Rule:
# Node 19983: Class Counts = [0. 0. 4. 0.], Rule:
# Node 20012: Class Counts = [0. 0. 0. 1.], Rule:
# Node 20014: Class Counts = [0. 0. 0. 2.], Rule:
# Node 20024: Class Counts = [0. 0. 1. 1.], Rule:
# Node 20028: Class Counts = [0. 0. 0. 1.], Rule:
# Node 20034: Class Counts = [0. 0. 0. 1.], Rule:
# Node 20038: Class Counts = [0. 0. 0. 3.], Rule:
# Node 20044: Class Counts = [0. 0. 0. 1.], Rule:
# Node 20045: Class Counts = [0. 0. 1. 0.], Rule:
# Node 20050: Class Counts = [0. 0. 1. 0.], Rule:
# Node 20056: Class Counts = [0. 0. 6. 0.], Rule:
# Node 20060: Class Counts = [0. 0. 2. 0.], Rule:
# Node 20077: Class Counts = [0. 0. 2. 0.], Rule:
# Node 20084: Class Counts = [0. 0. 0. 1.], Rule:
# Node 20092: Class Counts = [0. 0. 0. 1.], Rule:
# Node 20098: Class Counts = [0. 0. 0. 1.], Rule:
# Node 20101: Class Counts = [0. 0. 5. 0.], Rule:
# Node 20107: Class Counts = [0. 0. 0. 2.], Rule:
# Node 20112: Class Counts = [0. 0. 2. 0.], Rule:
# Node 20120: Class Counts = [0. 0. 2. 0.], Rule:
# Node 20121: Class Counts = [0. 0. 6. 0.], Rule:
# Node 20125: Class Counts = [0. 0. 0. 3.], Rule:
# Node 20149: Class Counts = [0. 0. 0. 4.], Rule:
# Node 20202: Class Counts = [0. 0. 0. 2.], Rule:
# Node 20208: Class Counts = [0. 0. 0. 1.], Rule:
# Node 20218: Class Counts = [0. 0. 1. 0.], Rule:
# Node 20223: Class Counts = [0. 0. 1. 0.], Rule:
# Node 20232: Class Counts = [0. 0. 0. 1.], Rule:
# Node 20248: Class Counts = [0. 0. 1. 0.], Rule:
# Node 20253: Class Counts = [0. 0. 1. 0.], Rule:
# Node 20261: Class Counts = [0. 0. 1. 0.], Rule:
# Node 20272: Class Counts = [0. 0. 0. 1.], Rule:
# Node 20301: Class Counts = [0. 0. 0. 1.], Rule:
# Node 20307: Class Counts = [0. 0. 1. 0.], Rule:
# Node 20310: Class Counts = [0. 0. 3. 0.], Rule:
# Node 20321: Class Counts = [0. 0. 0. 2.], Rule:
# Node 20326: Class Counts = [0. 0. 3. 2.], Rule:
# Node 20329: Class Counts = [0. 0. 0. 1.], Rule:
# Node 20336: Class Counts = [0. 0. 1. 0.], Rule:
# Node 20338: Class Counts = [0. 0. 2. 0.], Rule:
# Node 20348: Class Counts = [0. 0. 1. 0.], Rule:
# Node 20350: Class Counts = [0. 0. 1. 0.], Rule:
# Node 20355: Class Counts = [0. 0. 0. 2.], Rule:
# Node 20359: Class Counts = [0. 0. 0. 5.], Rule:
# Node 20365: Class Counts = [0. 0. 1. 0.], Rule:
# Node 20369: Class Counts = [0. 0. 2. 0.], Rule:
# Node 20381: Class Counts = [0. 0. 2. 0.], Rule:
# Node 20395: Class Counts = [0. 0. 0. 1.], Rule:
# Node 20396: Class Counts = [0. 0. 0. 2.], Rule:
# Node 20401: Class Counts = [0. 0. 0. 1.], Rule:
# Node 20406: Class Counts = [0. 0. 2. 0.], Rule:
# Node 20414: Class Counts = [0. 0. 0. 2.], Rule:
# Node 20428: Class Counts = [0. 0. 5. 0.], Rule:
# Node 20432: Class Counts = [0. 0. 1. 0.], Rule:
# Node 20453: Class Counts = [0. 0. 2. 0.], Rule:
# Node 20458: Class Counts = [0. 0. 1. 0.], Rule:
# Node 20469: Class Counts = [0. 0. 1. 0.], Rule:
# Node 20475: Class Counts = [0. 0. 0. 3.], Rule:
# Node 20477: Class Counts = [0. 0. 0. 2.], Rule:
# Node 20480: Class Counts = [0. 0. 0. 6.], Rule:
# Node 20482: Class Counts = [0. 0. 0. 1.], Rule:
# Node 20497: Class Counts = [0. 0. 0. 1.], Rule:
# Node 20499: Class Counts = [0. 0. 0. 2.], Rule:
# Node 20507: Class Counts = [0. 0. 3. 0.], Rule:
# Node 20532: Class Counts = [0. 0. 0. 2.], Rule:
# Node 20533: Class Counts = [0. 0. 2. 0.], Rule:
# Node 20560: Class Counts = [0. 0. 0. 2.], Rule:
# Node 20563: Class Counts = [0. 0. 0. 9.], Rule:
# Node 20565: Class Counts = [0. 0. 0. 2.], Rule:
# Node 20568: Class Counts = [0. 0. 2. 0.], Rule:

# %%
dtree_opt.tree_.node_count
# Out:
# 20571

# %%
dtree_opt.tree_.max_depth
# Out:
# 15

# %%
dtree_opt.tree_.value
# Out:
# array([[[1.926600e+04, 1.853094e+06, 1.134600e+05, 9.511100e+04]],
#
#        [[1.660800e+04, 1.462509e+06, 4.570600e+04, 4.483800e+04]],
#
#        [[1.501900e+04, 1.840430e+05, 2.075700e+04, 3.058000e+03]],
#
#        ...,
#
#        [[0.000000e+00, 0.000000e+00, 2.000000e+00, 0.000000e+00]],
#
#        [[0.000000e+00, 1.000000e+00, 0.000000e+00, 0.000000e+00]],
#
#        [[0.000000e+00, 1.500000e+01, 0.000000e+00, 0.000000e+00]]])

# %%
dtree_opt.children_left[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_713/1215806556.py in <module>
# ----> 1 dtree_opt.children_left[0]
#
# AttributeError: 'DecisionTreeClassifier' object has no attribute 'children_left'

# %%
dtree_opt.tree_.left_children[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_713/3725276733.py in <module>
# ----> 1 dtree_opt.tree_.left_children[0]
#
# AttributeError: 'sklearn.tree._tree.Tree' object has no attribute 'left_children'

# %%
tree.export_text(dtree_opt, feature_names=features)
# Out:
# '|--- Precipitation(in) <= 0.00\n|   |--- Distance(mi) <= 0.00\n|   |   |--- Crossing <= 0.50\n|   |   |   |--- Pressure(in) <= 24.71\n|   |   |   |   |--- Traffic_Signal <= 0.50\n|   |   |   |   |   |--- Pressure(in) <= 22.26\n|   |   |   |   |   |   |--- Pressure(in) <= 20.09\n|   |   |   |   |   |   |   |--- class: 2\n|   |   |   |   |   |   |--- Pressure(in) >  20.09\n|   |   |   |   |   |   |   |--- Pressure(in) <= 20.80\n|   |   |   |   |   |   |   |   |--- class: 3\n|   |   |   |   |   |   |   |--- Pressure(in) >  20.80\n|   |   |   |   |   |   |   |   |--- Temperature(F) <= 36.50\n|   |   |   |   |   |   |   |   |   |--- Pressure(in) <= 20.82\n|   |   |   |   |   |   |   |   |   |   |--- class: 4\n|   |   |   |   |   |   |   |   |   |--- Pressure(in) >  20.82\n|   |   |   |   |   |   |   |   |   |   |--- Wind_Speed(mph) <= 7.20\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4\n|   |   |   |   |   |   |   |   |   |   |--- Wind_Speed(mph) >  7.20\n|   |   |   |   |   |   |   |   |   |   |   |--- class: 3\n|   |   |   |   |   |   |   |   |--- Temperature(F) >  36.50\n|   |   |   |   |   |   |   |   |   |--- Humidity(%) <= 53.50\n|   |   |   |   |   |   |   |   |   |   |--- Wind_Chill(F) <= 71.00\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3\n|   |   |   |   |   |   |   |   |   |   |--- Wind_Chill(F) >  71.00\n|   |   |   |   |   |   |   |   |   |   |   |--- class: 2\n|   |   |   |   |   |   |   |   |   |--- Humidity(%) >  53.50\n|   |   |   |   |   |   |   |   |   |   |--- class: 2\n|   |   |   |   |   |--- Pressure(in) >  22.26\n|   |   |   |   |   |   |--- Pressure(in) <= 24.12\n|   |   |   |   |   |   |   |--- Pressure(in) <= 23.61\n|   |   |   |   |   |   |   |   |--- Pressure(in) <= 23.14\n|   |   |   |   |   |   |   |   |   |--- Wind_Chill(F) <= 27.50\n|   |   |   |   |   |   |   |   |   |   |--- Pressure(in) <= 22.97\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5\n|   |   |   |   |   |   |   |   |   |   |--- Pressure(in) >  22.97\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5\n|   |   |   |   |   |   |   |   |   |--- Wind_Chill(F) >  27.50\n|   |   |   |   |   |   |   |   |   |   |--- Humidity(%) <= 25.50\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5\n|   |   |   |   |   |   |   |   |   |   |--- Humidity(%) >  25.50\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5\n|   |   |   |   |   |   |   |   |--- Pressure(in) >  23.14\n|   |   |   |   |   |   |   |   |   |--- Temperature(F) <= 26.50\n|   |   |   |   |   |   |   |   |   |   |--- class: 3\n|   |   |   |   |   |   |   |   |   |--- Temperature(F) >  26.50\n|   |   |   |   |   |   |   |   |   |   |--- Wind_Chill(F) <= 21.50\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3\n|   |   |   |   |   |   |   |   |   |   |--- Wind_Chill(F) >  21.50\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5\n|   |   |   |   |   |   |   |--- Pressure(in) >  23.61\n|   |   |   |   |   |   |   |   |--- Humidity(%) <= 52.50\n|   |   |   |   |   |   |   |   |   |--- Humidity(%) <= 15.50\n|   |   |   |   |   |   |   |   |   |   |--- Pressure(in) <= 23.90\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5\n|   |   |   |   |   |   |   |   |   |   |--- Pressure(in) >  23.90\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5\n|   |   |   |   |   |   |   |   |   |--- Humidity(%) >  15.50\n|   |   |   |   |   |   |   |   |   |   |--- Wind_Chill(F) <= 70.50\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5\n|   |   |   |   |   |   |   |   |   |   |--- Wind_Chill(F) >  70.50\n|   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5\n|   |   |   |   |   |   |   |   |--- Humidity(%) >  52.50\n|   |   |   |   |   |   |   |   |   |--- Wind_Chill(F) <= 14.50\n|   |  ...

# %%
def get_rules(tree, feature_names, class_names, min_samples=0):
    tree_ = tree.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree_.feature
    ]

    paths = []
    path = []
    
    def recurse(node, path, paths):
        if tree_.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree_.threshold[node]
            p1, p2 = list(path), list(path)
            p1 += [f"({name} <= {np.round(threshold, 3)})"]
            recurse(tree_.children_left[node], p1, paths)
            p2 += [f"({name} > {np.round(threshold, 3)})"]
            recurse(tree_.children_right[node], p2, paths)
        else:
            path += [(tree_.value[node], tree_.n_node_samples[node])]
            paths += [path]
            
    recurse(0, path, paths)

    rules = []
    for path in paths:
        class_counts = path[-1][0][0]
        if (class_counts[0] == 0 and class_counts[1] == 0 and class_counts[2] != 0 and class_counts[3] == 0) or \
           (class_counts[0] == 0 and class_counts[1] == 0 and class_counts[2] == 0 and class_counts[3] != 0):
            if path[-1][1] >= min_samples:
                rule = "if "
                for p in path[:-1]:
                    if rule != "if ":
                        rule += " and "
                    rule += str(p)
                rule += " then "
                if class_names is None:
                    rule += "response: " + str(np.round(path[-1][0][0][0], 3))
                else:
                    classes = path[-1][0][0]
                    l = np.argmax(classes)
                    rule += f"class: {class_names[l]} (proba: {np.round(100.0*classes[l]/np.sum(classes), 2)}%)"
                rule += f" | based on {path[-1][1]:,} samples"

                # Compute support and confidence
                support = path[-1][1] / tree_.n_node_samples[0]
                confidence = classes[l] / np.sum(classes)

                # Add support and confidence to the rule
                rule += f" | support: {support:.3f} | confidence: {confidence:.3f}"
                rules += [rule]
        
    return rules

rules = get_rules(dtree_opt, features, [1,2,3,4], min_samples=10)

with open("temp1.txt", "w") as file:
    for r in rules:
        file.write(r + "\n")

# %%
rules = get_rules(dtree_opt, features, [1,2,3,4], min_samples=10)

with open("temp1.txt", "w") as file:
    for r in rules:
        file.write(r + "\n")
