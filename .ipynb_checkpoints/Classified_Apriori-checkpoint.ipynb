# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import matplotlib.ticker as ticker
import plotly.io as pio
from sklearn.cluster import KMeans
from mlxtend.frequent_patterns import apriori, association_rules

# %matplotlib inline

# %%
# Load Dataset

abs_path = Path.cwd()
data_address = abs_path.parent.parent / 'data/' / 'Cleaned_US.csv'
df = pd.read_csv(data_address)

# %%
sample_size = 100000
sample_df = df.sample( n = sample_size, random_state = 42 )

plt.figure(figsize=(12, 8))
plt.scatter( sample_df['End_Lng'], sample_df['End_Lat'], s=0.3 )
plt.xlabel('End Longitude')
plt.ylabel('End Latitude')
plt.title('Sample US Accident Location')

plt.show()

# %%
sample_size = 400000
sample_df = df.sample(n=sample_size, random_state=42)

# Number of Clusters
n_clusters = 12

# Clustering
X = sample_df[['End_Lng', 'End_Lat']]
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
sample_df['Cluster'] = kmeans.fit_predict(X)

# Plot
plt.figure(figsize=(12, 8))
scatter = plt.scatter(sample_df['End_Lng'], sample_df['End_Lat'], c=sample_df['Cluster'], cmap='tab20', s=0.3)
plt.xlabel('End Longitude')
plt.ylabel('End Latitude')
plt.title('Sample US Accident Location with Clusters')

# Add colorbar
cbar = plt.colorbar(scatter, ticks=range(12))
cbar.set_label('Cluster')

plt.show()

# %%
# Create a dict to store the dataframes for each cluster
cluster_data = {}

# Iterate over unique cluster labels
for cluster_label in sample_df['Cluster'].unique():
    # Filter the dataframe based on the cluster label
    cluster_data[cluster_label] = sample_df[sample_df['Cluster'] == cluster_label].copy()

# %%
def static_convertor(df):
    
    weather_float_columns = ['Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)']

    # Define the thresholds for each weather column
    thresholds = {
        'Temperature(F)': [0, 32, 70, float('inf')],
        'Wind_Chill(F)': [-float('inf'), 20, 50, float('inf')],
        'Humidity(%)': [0, 40, 70, 100],
        'Pressure(in)': [0, 29.5, 30, float('inf')],
    }

    df_static_threshold = pd.DataFrame()

    # Discretize and encode weather columns using one-hot encoding
    for column in weather_float_columns:
        bins = thresholds[column]
        labels = range(len(bins) - 1)
        categories = pd.cut(df[column], bins=bins, labels=labels)
        encoded_cols = pd.get_dummies(categories, prefix=column)
        df_static_threshold = pd.concat([df_static_threshold, encoded_cols], axis=1)
        
    return df_static_threshold

# %%
def dynamic_convertor(df):
    # Define weather float columns
    weather_float_columns = ['Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)']

    # Create a new DataFrame for encoded columns
    df_dynamic_threshold = pd.DataFrame()

    # Discretize and encode weather columns using one-hot encoding
    for column in weather_float_columns:
        column_values = df[column]
        
        # Adjust threshold percentages if they are the same
        if len(set(column_values)) == 1:
            min_value = column_values.min()
            max_value = column_values.max()
            if min_value == max_value:
                thresholds = [0, min_value, min_value + 1, float('inf')]
            else:
                thresholds = [0, min_value, max_value, float('inf')]
        else:
            thresholds = [0, np.percentile(column_values, 15), np.percentile(column_values, 85), float('inf')]
        
        bins = np.unique(thresholds)  # Ensure unique bin edges
        labels = range(len(bins) - 1)
        categories = pd.cut(column_values, bins=bins, labels=labels)
        encoded_cols = pd.get_dummies(categories, prefix=column)
        df_dynamic_threshold = pd.concat([df_dynamic_threshold, encoded_cols], axis=1)

    return df_dynamic_threshold

# %%
def dynamic_convertor(df):
    # Define weather float columns
    weather_float_columns = ['Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
                             'Visibility(mi)', 'Wind_Speed(mph)', 'Precipitation(in)']

    # Create a new DataFrame for encoded columns
    df_dynamic_threshold = pd.DataFrame()

    # Discretize and encode weather columns using one-hot encoding
    for column in weather_float_columns:
        column_values = df[column]
        
        # Adjust threshold percentages if they are the same
        if len(set(column_values)) == 1:
            min_value = column_values.min()
            max_value = column_values.max()
            if min_value == max_value:
                thresholds = [0, min_value, min_value + 1, float('inf')]
            else:
                thresholds = [0, min_value, max_value, float('inf')]
        else:
            thresholds = [0, np.percentile(column_values, 15), np.percentile(column_values, 85), float('inf')]
        
        bins = np.unique(thresholds)  # Ensure unique bin edges
        labels = range(len(bins) - 1)
        categories = pd.cut(column_values, bins=bins, labels=labels)
        encoded_cols = pd.get_dummies(categories, prefix=column)
        df_dynamic_threshold = pd.concat([df_dynamic_threshold, encoded_cols], axis=1)

    return df_dynamic_threshold

# %%
def apply_apriori(df, min_support=0.3, min_threshold=0.6):
    # Apply Apriori algorithm
    frequent_itemsets = apriori(df, min_support=min_support, use_colnames=True)
    rules = association_rules(frequent_itemsets, metric="support", min_threshold=min_threshold)

    print(frequent_itemsets.sort_values('support', ascending=False))
    print(rules.sort_values('support', ascending=False))
    
    return frequent_itemsets, rules

# %%
sample_df_static = static_convertor(sample_df)
apply_apriori(sample_df_static)
# Out:
#      support                             itemsets
# 2   0.753062                    (Wind_Chill(F)_2)
# 0   0.563420                   (Temperature(F)_1)
# 4   0.441462                      (Humidity(%)_2)
# 6   0.424325                     (Pressure(in)_1)
# 3   0.388398                      (Humidity(%)_1)
# 7   0.386163  (Wind_Chill(F)_2, Temperature(F)_1)
# 1   0.363067                   (Temperature(F)_2)
# 8   0.363067  (Wind_Chill(F)_2, Temperature(F)_2)
# 10  0.346728    (Pressure(in)_1, Wind_Chill(F)_2)
# 5   0.320873                     (Pressure(in)_0)
# 9   0.308972     (Humidity(%)_1, Wind_Chill(F)_2)
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
# Index: []
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
# (     support                             itemsets
#  0   0.563420                   (Temperature(F)_1)
#  1   0.363067                   (Temperature(F)_2)
#  2   0.753062                    (Wind_Chill(F)_2)
#  3   0.388398                      (Humidity(%)_1)
#  4   0.441462                      (Humidity(%)_2)
#  5   0.320873                     (Pressure(in)_0)
#  6   0.424325                     (Pressure(in)_1)
#  7   0.386163  (Wind_Chill(F)_2, Temperature(F)_1)
#  8   0.363067  (Wind_Chill(F)_2, Temperature(F)_2)
#  9   0.308972     (Humidity(%)_1, Wind_Chill(F)_2)
#  10  0.346728    (Pressure(in)_1, Wind_Chill(F)_2),
#  Empty DataFrame
#  Columns: [antecedents, consequents, antecedent support, consequent support, support, confidence, lift, leverage, conviction, zhangs_metric]
#  Index: [])

# %%
sample_df_dynamic = dynamic_convertor(sample_df)
apply_apriori(sample_df_dynamic)
# Out:
#      support                                           itemsets
# 3   0.703228                                   (Pressure(in)_1)
# 0   0.701650                                 (Temperature(F)_1)
# 2   0.698242                                    (Humidity(%)_1)
# 1   0.697900                                  (Wind_Chill(F)_1)
# 4   0.658242                (Wind_Chill(F)_1, Temperature(F)_1)
# 6   0.509203                 (Pressure(in)_1, Temperature(F)_1)
# 8   0.505665                  (Pressure(in)_1, Wind_Chill(F)_1)
# 9   0.502720                    (Pressure(in)_1, Humidity(%)_1)
# 5   0.488343                  (Humidity(%)_1, Temperature(F)_1)
# 7   0.481205                   (Humidity(%)_1, Wind_Chill(F)_1)
# 11  0.477202  (Pressure(in)_1, Wind_Chill(F)_1, Temperature(...
# 10  0.455188  (Humidity(%)_1, Wind_Chill(F)_1, Temperature(F...
# 12  0.359932  (Pressure(in)_1, Humidity(%)_1, Temperature(F)_1)
# 13  0.352490   (Pressure(in)_1, Humidity(%)_1, Wind_Chill(F)_1)
# 14  0.334637  (Pressure(in)_1, Humidity(%)_1, Wind_Chill(F)_...
#           antecedents         consequents  antecedent support  \
# 0   (Wind_Chill(F)_1)  (Temperature(F)_1)             0.69790
# 1  (Temperature(F)_1)   (Wind_Chill(F)_1)             0.70165
#
#    consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.70165  0.658242    0.943176  1.344226  0.168561    5.250418
# 1             0.69790  0.658242    0.938135  1.344226  0.168561    4.883222
#
#    zhangs_metric
# 0       0.847657
# 1       0.858312
# /home/abolfazl/anaconda3/envs/py37/lib/python3.7/site-packages/mlxtend/frequent_patterns/fpcommon.py:114: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   DeprecationWarning,
# (     support                                           itemsets
#  0   0.701650                                 (Temperature(F)_1)
#  1   0.697900                                  (Wind_Chill(F)_1)
#  2   0.698242                                    (Humidity(%)_1)
#  3   0.703228                                   (Pressure(in)_1)
#  4   0.658242                (Wind_Chill(F)_1, Temperature(F)_1)
#  5   0.488343                  (Humidity(%)_1, Temperature(F)_1)
#  6   0.509203                 (Pressure(in)_1, Temperature(F)_1)
#  7   0.481205                   (Humidity(%)_1, Wind_Chill(F)_1)
#  8   0.505665                  (Pressure(in)_1, Wind_Chill(F)_1)
#  9   0.502720                    (Pressure(in)_1, Humidity(%)_1)
#  10  0.455188  (Humidity(%)_1, Wind_Chill(F)_1, Temperature(F...
#  11  0.477202  (Pressure(in)_1, Wind_Chill(F)_1, Temperature(...
#  12  0.359932  (Pressure(in)_1, Humidity(%)_1, Temperature(F)_1)
#  13  0.352490   (Pressure(in)_1, Humidity(%)_1, Wind_Chill(F)_1)
#  14  0.334637  (Pressure(in)_1, Humidity(%)_1, Wind_Chill(F)_...,
#            antecedents         consequents  antecedent support  \
#  0   (Wind_Chill(F)_1)  (Temperature(F)_1)             0.69790
#  1  (Temperature(F)_1)   (Wind_Chill(F)_1)             0.70165
#
#     consequent support   support  confidence      lift  leverage  conviction  \
#  0             0.70165  0.658242    0.943176  1.344226  0.168561    5.250418
#  1             0.69790  0.658242    0.938135  1.344226  0.168561    4.883222
#
#     zhangs_metric
#  0       0.847657
#  1       0.858312  )
