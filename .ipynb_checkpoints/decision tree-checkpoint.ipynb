# %% [markdown]
# # Load Dataset

# %%
import pandas
from pathlib import Path

# %%
# get absolute path
abs_path = Path().()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3220/2139737545.py in <module>
#       1 # get absolute path
# ----> 2 abs_path = Path().relative()
#
# AttributeError: 'PosixPath' object has no attribute 'relative'

# %%
data_address = abs_path.parent.parent / 'data/' / 'US1.csv/'

# %%
df = pandas.read_csv(data_address)

# %%
df
# Out:
#             ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0          A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1          A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20  39.865420
# 2          A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39  39.102660
# 3          A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45  41.062130
# 4          A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
# ...        ...       ...                  ...                  ...        ...
# 49995  A-49996         4  2016-10-30 06:45:46  2016-10-30 12:45:46  26.811625
# 49996  A-49997         4  2016-10-30 06:45:46  2016-10-30 12:45:46  26.843520
# 49997  A-49998         3  2016-10-30 07:52:25  2016-10-30 13:52:25  25.925300
# 49998  A-49999         3  2016-10-30 06:56:08  2016-10-30 12:56:08  41.875230
# 49999  A-50000         2  2016-10-30 05:16:37  2016-10-30 12:16:37  41.845950
#
# ...

# %%
# if you want decisiton tree all the types must be numerical
# use map() method of pandas to map string data to numeric one
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     50000 non-null  object
#  1   Severity               50000 non-null  int64
#  2   Start_Time             50000 non-null  object
#  3   End_Time               50000 non-null  object
#  4   Start_Lat              50000 non-null  float64
#  5   Start_Lng              50000 non-null  float64
#  6   End_Lat                50000 non-null  float64
#  7   End_Lng                50000 non-null  float64
#  8   Distance(mi)           50000 non-null  float64
#  9   Description            50000 non-null  object
#  10  Number                 9089 non-null   float64
#  11  Street                 50000 non-null  object
#  12  Side                   50000 non-null  object
#  13  City                   49996 non-null  object
# ...

# %% [markdown]
# # Decision Tree Part

# %%
import pandas as pd

# %%
from sklearn.tree import DecisionTreeClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3220/240913657.py in <module>
# ----> 1 from sklearn.tree import DecisionTreeClassifier
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
transfer_func = {'safe' : 0, 'near-crash' : 1, 'crash' : 2}
df['Label'] = df['Label'].map(transfer_func)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Label'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df
# Out:
#      Car ID  Car Class  Sex  Age  Weather Condition  Road Condition  \
# 0         1          1    1   21                  4               4
# 1         2          3    1   29                  1               3
# 2         3          4    1   68                  1               1
# 3         4          2    1   45                  3               1
# 4         5          2    0   44                  1               4
# ..      ...        ...  ...  ...                ...             ...
# 145     146          2    1   44                  4               2
# 146     147          2    0   24                  4               4
# 147     148          3    1   35                  4               1
# 148     149          2    0   22                  2               2
# 149     150          4    1   36                  4               2
#
#      Lighting Condition  Distraction  Label
# 0                     3            1      1
# 1                     3            0      0
# ...

# %%
# X features and y targer
features = ['Start_Time','End_Time']

X = df[features]
y = df['Severity']

# %%
X
# Out:
#                 Start_Time             End_Time
# 0      2016-02-08 00:37:08  2016-02-08 06:37:08
# 1      2016-02-08 05:56:20  2016-02-08 11:56:20
# 2      2016-02-08 06:15:39  2016-02-08 12:15:39
# 3      2016-02-08 06:51:45  2016-02-08 12:51:45
# 4      2016-02-08 07:53:43  2016-02-08 13:53:43
# ...                    ...                  ...
# 49995  2016-10-30 06:45:46  2016-10-30 12:45:46
# 49996  2016-10-30 06:45:46  2016-10-30 12:45:46
# 49997  2016-10-30 07:52:25  2016-10-30 13:52:25
# 49998  2016-10-30 06:56:08  2016-10-30 12:56:08
# 49999  2016-10-30 05:16:37  2016-10-30 12:16:37
#
# [50000 rows x 2 columns]

# %%
y
# Out:
# 0        3
# 1        2
# 2        2
# 3        2
# 4        3
#         ..
# 49995    4
# 49996    4
# 49997    3
# 49998    3
# 49999    2
# Name: Severity, Length: 50000, dtype: int64

# %%
# now we can create actual decision tree :)

# %%
import pandas 
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1457/1172638911.py in <module>
#       1 import pandas
# ----> 2 from sklearn import tree
#       3 from sklearn.tree import DecisionTreeClassifier
#       4 import matplotlib.pyplot as plt
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
dtree = DecisionTreeClassifier()

# %%
dtree = dtree.fit(X, y)

# %%
fig = plt.figure(figsize=(25,20))
tree.plot_tree(dtree, feature_names = features)
# Out:
# [Text(0.5986842105263158, 0.9444444444444444, 'Age <= 52.0\ngini = 0.195\nsamples = 150\nvalue = [134, 12, 4]'),
#  Text(0.4342105263157895, 0.8333333333333334, 'Age <= 21.5\ngini = 0.164\nsamples = 147\nvalue = [134, 10, 3]'),
#  Text(0.2631578947368421, 0.7222222222222222, 'Weather Condition <= 3.0\ngini = 0.569\nsamples = 12\nvalue = [6, 5, 1]'),
#  Text(0.21052631578947367, 0.6111111111111112, 'Car ID <= 50.5\ngini = 0.494\nsamples = 9\nvalue = [6, 2, 1]'),
#  Text(0.15789473684210525, 0.5, 'Weather Condition <= 1.5\ngini = 0.625\nsamples = 4\nvalue = [1, 2, 1]'),
#  Text(0.10526315789473684, 0.3888888888888889, 'Car ID <= 20.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.05263157894736842, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.15789473684210525, 0.2777777777777778, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.21052631578947367, 0.3888888888888889, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
# ...
