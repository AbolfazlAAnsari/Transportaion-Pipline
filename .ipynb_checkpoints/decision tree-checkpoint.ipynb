# %% [markdown]
# # Load Dataset

# %%
import pandas
from pathlib import Path
import numpy as np

# %%
# get absolute path
abs_path = Path.cwd()

# %%
abs_path
# Out:
# PosixPath('/mnt/c/Users/user/desktop/Project/code/Transportaion-Pipline')

# %%
data_address = abs_path.parent.parent / 'data/' / 'test.csv/'

# %%
df = pandas.read_csv(data_address)

# %%
df
# Out:
#         ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0      A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1      A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20  39.865420
# 2      A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39  39.102660
# 3      A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45  41.062130
# 4      A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
# ..     ...       ...                  ...                  ...        ...
# 494  A-495         4  2016-02-25 18:39:56  2016-02-26 00:39:56  38.860270
# 495  A-496         2  2016-02-25 19:36:06  2016-02-26 01:36:06  39.882030
# 496  A-497         3  2016-02-25 19:58:08  2016-02-26 01:58:08  39.892534
# 497  A-498         4  2016-02-25 20:06:42  2016-02-26 02:21:45  39.896980
# 498  A-499         3  2016-02-26 10:43:39  2016-02-26 16:43:39  41.674390
#
#      Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0   -83.092860  40.112060 -83.031870         3.230
# 1   -84.062800  39.865010 -84.048730         0.747
# 2   -84.524680  39.102090 -84.523960         0.055
# 3   -81.537840  41.062170 -81.535470         0.123
# 4   -84.492792  39.170476 -84.501798         0.500
# ..         ...        ...        ...           ...
# 494 -80.657290  38.913672 -80.582080         5.475
# 495 -83.047480  39.837070 -83.094070         3.969
# 496 -83.038786  39.874830 -83.052280         1.417
# 497 -83.034280  39.844826 -83.087170         4.566
# 498 -83.693727  41.676364 -83.693898         0.137
#
#                                            Description  ...  Roundabout  \
# 0    Between Sawmill Rd/Exit 20 and OH-315/Olentang...  ...       False
# 1                   At OH-4/OH-235/Exit 41 - Accident.  ...       False
# 2                     At I-71/US-50/Exit 1 - Accident.  ...       False
# 3                      At Dart Ave/Exit 21 - Accident.  ...       False
# 4                   At Mitchell Ave/Exit 6 - Accident.  ...       False
# ..                                                 ...  ...         ...
# 494  Closed between CR-5/11/Bridge St/Exit 79 and U...  ...       False
# 495  Between Stringtown Rd/Exit 100 and OH-665/Exit...  ...       False
# 496  Closed between OH-104/Frank Rd/Exit 104 and St...  ...       False
# 497  Closed between I-270/Exit 101 and OH-665/Exit ...  ...       False
# 498        At US-20/OH-120/Central/Exit 13 - Accident.  ...       False
#
#     Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0     False  False           False          False        False          Night
# 1     False  False           False          False        False          Night
# 2     False  False           False          False        False          Night
# 3     False  False           False          False        False          Night
# 4     False  False           False          False        False            Day
# ..      ...    ...             ...            ...          ...            ...
# 494   False  False           False          False        False          Night
# 495   False  False           False          False        False          Night
# 496   False  False           False          False        False          Night
# 497   False  False           False          False        False          Night
# 498   False  False           False          False        False            Day
#
#     Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0            Night             Night                 Night
# 1            Night             Night                 Night
# 2            Night             Night                   Day
# 3            Night               Day                   Day
# 4              Day               Day                   Day
# ..             ...               ...                   ...
# 494          Night               Day                   Day
# 495          Night             Night                   Day
# 496          Night             Night                 Night
# 497          Night             Night                 Night
# 498            Day               Day                   Day
#
# [499 rows x 47 columns]

# %%
# if you want decisiton tree all the types must be numerical
# use map() method of pandas to map string data to numeric one
df.info()

# JUST OBJECTS should map in other type of data to create decision tree
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     499 non-null    object
#  1   Severity               499 non-null    int64
#  2   Start_Time             499 non-null    object
#  3   End_Time               499 non-null    object
#  4   Start_Lat              499 non-null    float64
#  5   Start_Lng              499 non-null    float64
#  6   End_Lat                499 non-null    float64
#  7   End_Lng                499 non-null    float64
#  8   Distance(mi)           499 non-null    float64
#  9   Description            499 non-null    object
#  10  Number                 94 non-null     float64
#  11  Street                 499 non-null    object
#  12  Side                   499 non-null    object
#  13  City                   499 non-null    object
#  14  County                 499 non-null    object
#  15  State                  499 non-null    object
#  16  Zipcode                499 non-null    object
#  17  Country                499 non-null    object
#  18  Timezone               499 non-null    object
#  19  Airport_Code           499 non-null    object
#  20  Weather_Timestamp      496 non-null    object
#  21  Temperature(F)         495 non-null    float64
#  22  Wind_Chill(F)          368 non-null    float64
#  23  Humidity(%)            493 non-null    float64
#  24  Pressure(in)           496 non-null    float64
#  25  Visibility(mi)         494 non-null    float64
#  26  Wind_Direction         496 non-null    object
#  27  Wind_Speed(mph)        454 non-null    float64
#  28  Precipitation(in)      151 non-null    float64
#  29  Weather_Condition      490 non-null    object
#  30  Amenity                499 non-null    bool
#  31  Bump                   499 non-null    bool
#  32  Crossing               499 non-null    bool
#  33  Give_Way               499 non-null    bool
#  34  Junction               499 non-null    bool
#  35  No_Exit                499 non-null    bool
#  36  Railway                499 non-null    bool
#  37  Roundabout             499 non-null    bool
#  38  Station                499 non-null    bool
#  39  Stop                   499 non-null    bool
#  40  Traffic_Calming        499 non-null    bool
#  41  Traffic_Signal         499 non-null    bool
#  42  Turning_Loop           499 non-null    bool
#  43  Sunrise_Sunset         499 non-null    object
#  44  Civil_Twilight         499 non-null    object
#  45  Nautical_Twilight      499 non-null    object
#  46  Astronomical_Twilight  499 non-null    object
# dtypes: bool(13), float64(13), int64(1), object(20)
# memory usage: 139.0+ KB

# %% [markdown]
# # Decision Tree Part

# %%
import pandas as pd

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
features = ['ID', 'Severity', ]

# %%
transfer_func = {'False' : 0, 'True' : 1}
df['Traffic_Signal'] = df['Traffic_Signal'].map(transfer_func)

# %%
df
# Out:
#         ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0      A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1      A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20  39.865420
# 2      A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39  39.102660
# 3      A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45  41.062130
# 4      A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
# ..     ...       ...                  ...                  ...        ...
# 494  A-495         4  2016-02-25 18:39:56  2016-02-26 00:39:56  38.860270
# 495  A-496         2  2016-02-25 19:36:06  2016-02-26 01:36:06  39.882030
# 496  A-497         3  2016-02-25 19:58:08  2016-02-26 01:58:08  39.892534
# 497  A-498         4  2016-02-25 20:06:42  2016-02-26 02:21:45  39.896980
# 498  A-499         3  2016-02-26 10:43:39  2016-02-26 16:43:39  41.674390
#
#      Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0   -83.092860  40.112060 -83.031870         3.230
# 1   -84.062800  39.865010 -84.048730         0.747
# 2   -84.524680  39.102090 -84.523960         0.055
# 3   -81.537840  41.062170 -81.535470         0.123
# 4   -84.492792  39.170476 -84.501798         0.500
# ..         ...        ...        ...           ...
# 494 -80.657290  38.913672 -80.582080         5.475
# 495 -83.047480  39.837070 -83.094070         3.969
# 496 -83.038786  39.874830 -83.052280         1.417
# 497 -83.034280  39.844826 -83.087170         4.566
# 498 -83.693727  41.676364 -83.693898         0.137
#
#                                            Description  ...  Roundabout  \
# 0    Between Sawmill Rd/Exit 20 and OH-315/Olentang...  ...       False
# 1                   At OH-4/OH-235/Exit 41 - Accident.  ...       False
# 2                     At I-71/US-50/Exit 1 - Accident.  ...       False
# 3                      At Dart Ave/Exit 21 - Accident.  ...       False
# 4                   At Mitchell Ave/Exit 6 - Accident.  ...       False
# ..                                                 ...  ...         ...
# 494  Closed between CR-5/11/Bridge St/Exit 79 and U...  ...       False
# 495  Between Stringtown Rd/Exit 100 and OH-665/Exit...  ...       False
# 496  Closed between OH-104/Frank Rd/Exit 104 and St...  ...       False
# 497  Closed between I-270/Exit 101 and OH-665/Exit ...  ...       False
# 498        At US-20/OH-120/Central/Exit 13 - Accident.  ...       False
#
#     Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0     False  False           False          False        False          Night
# 1     False  False           False          False        False          Night
# 2     False  False           False          False        False          Night
# 3     False  False           False          False        False          Night
# 4     False  False           False          False        False            Day
# ..      ...    ...             ...            ...          ...            ...
# 494   False  False           False          False        False          Night
# 495   False  False           False          False        False          Night
# 496   False  False           False          False        False          Night
# 497   False  False           False          False        False          Night
# 498   False  False           False          False        False            Day
#
#     Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0            Night             Night                 Night
# 1            Night             Night                 Night
# 2            Night             Night                   Day
# 3            Night               Day                   Day
# 4              Day               Day                   Day
# ..             ...               ...                   ...
# 494          Night               Day                   Day
# 495          Night             Night                   Day
# 496          Night             Night                 Night
# 497          Night             Night                 Night
# 498            Day               Day                   Day
#
# [499 rows x 47 columns]

# %% [markdown]
# # Decision Tree Based on Weather Condition

# %%
weather_features = ['Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)',
                   'Pressure(in)', 'Visibility(mi)', 'Wind_Speed(mph)']

# %%
# X features and y target

X = df[weather_features]
y = df['Severity']

# %%
X
# Out:
#      Temperature(F)  Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi)  \
# 0              42.1           36.1         58.0         29.76            10.0
# 1              36.9           18.1         91.0         29.68            10.0
# 2              36.0           18.1         97.0         29.70            10.0
# 3              39.0           18.1         55.0         29.65            10.0
# 4              37.0           29.8         93.0         29.69            10.0
# ..              ...            ...          ...           ...             ...
# 494            32.0           22.0         85.0         28.49             6.0
# 495            32.2           21.4         77.0         29.96            10.0
# 496            32.0           21.2         73.0         29.97            10.0
# 497            32.0           20.8         70.0         29.97            10.0
# 498            29.8           23.9         59.0         30.23            10.0
#
#      Wind_Speed(mph)
# 0               10.4
# 1                NaN
# 2                NaN
# 3                NaN
# 4               10.4
# ..               ...
# 494             15.0
# 495             16.1
# 496             16.1
# 497             17.3
# 498              5.8
#
# [499 rows x 6 columns]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Temperature(F)   499 non-null    float64
#  1   Wind_Chill(F)    499 non-null    float64
#  2   Humidity(%)      493 non-null    float64
#  3   Pressure(in)     496 non-null    float64
#  4   Visibility(mi)   494 non-null    float64
#  5   Wind_Speed(mph)  454 non-null    float64
# dtypes: float64(6)
# memory usage: 23.5 KB

# %%
y
# Out:
# 0      3
# 1      2
# 2      2
# 3      2
# 4      3
#       ..
# 494    4
# 495    2
# 496    3
# 497    4
# 498    3
# Name: Severity, Length: 499, dtype: int64

# %%
# Handling Missing Values with AVERAGE
def fill_average(feature):
    df[feature] = df[feature].fillna(round(df[feature].mean(), 1))

# %%
fill_average('Temperature(F)')
fill_average('Wind_Chill(F)')

# %%
a = df['Temperature(F)'].mean()

# %%
round(a, 1)
# Out:
# 32.0

# %%
float('nan') in df['Temperature(F)']
# Out:
# False

# %%
X
# Out:
#      Temperature(F)  Wind_Chill(F)  Humidity(%)  Pressure(in)  Visibility(mi)  \
# 0              42.1           36.1         58.0         29.76            10.0
# 1              36.9            NaN         91.0         29.68            10.0
# 2              36.0            NaN         97.0         29.70            10.0
# 3              39.0            NaN         55.0         29.65            10.0
# 4              37.0           29.8         93.0         29.69            10.0
# ..              ...            ...          ...           ...             ...
# 494            32.0           22.0         85.0         28.49             6.0
# 495            32.2           21.4         77.0         29.96            10.0
# 496            32.0           21.2         73.0         29.97            10.0
# 497            32.0           20.8         70.0         29.97            10.0
# 498            29.8           23.9         59.0         30.23            10.0
#
#      Wind_Speed(mph)
# 0               10.4
# 1                NaN
# 2                NaN
# 3                NaN
# 4               10.4
# ..               ...
# 494             15.0
# 495             16.1
# 496             16.1
# 497             17.3
# 498              5.8
#
# [499 rows x 6 columns]

# %%
import pandas 
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dtree = DecisionTreeClassifier()

# %%
dtree = dtree.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3220/3228970330.py in <module>
# ----> 1 dtree = dtree.fit(X, y)
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     940             sample_weight=sample_weight,
#     941             check_input=check_input,
# --> 942             X_idx_sorted=X_idx_sorted,
#     943         )
#     944         return self
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     164             check_y_params = dict(ensure_2d=False, dtype=None)
#     165             X, y = self._validate_data(
# --> 166                 X, y, validate_separately=(check_X_params, check_y_params)
#     167             )
#     168             if issparse(X):
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     576                 # :(
#     577                 check_X_params, check_y_params = validate_separately
# --> 578                 X = check_array(X, **check_X_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     798
#     799         if force_all_finite:
# --> 800             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     801
#     802     if ensure_min_samples > 0:
#
# ~/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/utils/validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     114             raise ValueError(
#     115                 msg_err.format(
# --> 116                     type_err, msg_dtype if msg_dtype is not None else X.dtype
#     117                 )
#     118             )
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float32').

# %%
fig = plt.figure(figsize=(25,20))
tree.plot_tree(dtree, feature_names = features)
# Out:
# [Text(0.3905745316537468, 0.9772727272727273, 'Start_Lat <= 39.354\ngini = 0.597\nsamples = 499\nvalue = [273, 100, 126]'),
#  Text(0.14470284237726097, 0.9318181818181818, 'Start_Lat <= 39.059\ngini = 0.509\nsamples = 131\nvalue = [84, 35, 12]'),
#  Text(0.0962532299741602, 0.8863636363636364, 'Start_Lat <= 38.816\ngini = 0.595\nsamples = 66\nvalue = [35, 21, 10]'),
#  Text(0.06330749354005168, 0.8409090909090909, 'Start_Lat <= 38.795\ngini = 0.499\nsamples = 49\nvalue = [29, 19, 1]'),
#  Text(0.05813953488372093, 0.7954545454545454, 'Start_Lat <= 38.302\ngini = 0.488\nsamples = 47\nvalue = [29, 17, 1]'),
#  Text(0.025839793281653745, 0.75, 'Start_Lat <= 38.199\ngini = 0.499\nsamples = 19\nvalue = [9, 10, 0]'),
#  Text(0.015503875968992248, 0.7045454545454546, 'Start_Lat <= 38.163\ngini = 0.375\nsamples = 8\nvalue = [6, 2, 0]'),
#  Text(0.0103359173126615, 0.6590909090909091, 'Start_Lat <= 38.124\ngini = 0.5\nsamples = 4\nvalue = [2, 2, 0]'),
#  Text(0.00516795865633075, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.015503875968992248, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.020671834625323, 0.6590909090909091, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.03617571059431524, 0.7045454545454546, 'Start_Lat <= 38.239\ngini = 0.397\nsamples = 11\nvalue = [3, 8, 0]'),
#  Text(0.031007751937984496, 0.6590909090909091, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.041343669250646, 0.6590909090909091, 'Start_Lat <= 38.259\ngini = 0.469\nsamples = 8\nvalue = [3, 5, 0]'),
#  Text(0.03617571059431524, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.046511627906976744, 0.6136363636363636, 'Start_Lat <= 38.284\ngini = 0.278\nsamples = 6\nvalue = [1, 5, 0]'),
#  Text(0.041343669250646, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.05167958656330749, 0.5681818181818182, 'Start_Lat <= 38.294\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.046511627906976744, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.056847545219638244, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.09043927648578812, 0.75, 'Start_Lat <= 38.529\ngini = 0.426\nsamples = 28\nvalue = [20, 7, 1]'),
#  Text(0.07235142118863049, 0.7045454545454546, 'Start_Lat <= 38.33\ngini = 0.335\nsamples = 20\nvalue = [16, 3, 1]'),
#  Text(0.06718346253229975, 0.6590909090909091, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.07751937984496124, 0.6590909090909091, 'Start_Lat <= 38.335\ngini = 0.398\nsamples = 16\nvalue = [12, 3, 1]'),
#  Text(0.06718346253229975, 0.6136363636363636, 'Start_Lat <= 38.334\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.06201550387596899, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.07235142118863049, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.08785529715762273, 0.6136363636363636, 'Start_Lat <= 38.374\ngini = 0.245\nsamples = 14\nvalue = [12, 2, 0]'),
#  Text(0.082687338501292, 0.5681818181818182, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0]'),
#  Text(0.09302325581395349, 0.5681818181818182, 'Start_Lat <= 38.404\ngini = 0.408\nsamples = 7\nvalue = [5, 2, 0]'),
#  Text(0.08785529715762273, 0.5227272727272727, 'Start_Lat <= 38.387\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.082687338501292, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.09302325581395349, 0.4772727272727273, 'Start_Lat <= 38.39\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.08785529715762273, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.09819121447028424, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.09819121447028424, 0.5227272727272727, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.10852713178294573, 0.7045454545454546, 'Start_Lat <= 38.598\ngini = 0.5\nsamples = 8\nvalue = [4, 4, 0]'),
#  Text(0.10335917312661498, 0.6590909090909091, 'Start_Lat <= 38.542\ngini = 0.32\nsamples = 5\nvalue = [1, 4, 0]'),
#  Text(0.09819121447028424, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.10852713178294573, 0.6136363636363636, 'Start_Lat <= 38.562\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.10335917312661498, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.11369509043927649, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.11369509043927649, 0.6590909090909091, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.06847545219638243, 0.7954545454545454, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.12919896640826872, 0.8409090909090909, 'Start_Lat <= 38.865\ngini = 0.581\nsamples = 17\nvalue = [6, 2, 9]'),
#  Text(0.11886304909560723, 0.7954545454545454, 'Start_Lat <= 38.827\ngini = 0.278\nsamples = 6\nvalue = [0, 1, 5]'),
#  Text(0.11369509043927649, 0.75, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.12403100775193798, 0.75, 'Start_Lat <= 38.836\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.11886304909560723, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.12919896640826872, 0.7045454545454546, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.13953488372093023, 0.7954545454545454, 'Start_Lat <= 39.036\ngini = 0.562\nsamples = 11\nvalue = [6, 1, 4]'),
#  Text(0.1343669250645995, 0.75, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0]'),
#  Text(0.14470284237726097, 0.75, 'Start_Lat <= 39.041\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(0.13953488372093023, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.14987080103359174, 0.7045454545454546, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.19315245478036175, 0.8863636363636364, 'Start_Lat <= 39.099\ngini = 0.384\nsamples = 65\nvalue = [49, 14, 2]'),
#  Text(0.187984496124031, 0.8409090909090909, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0]'),
#  Text(0.19832041343669252, 0.8409090909090909, 'Start_Lat <= 39.099\ngini = 0.416\nsamples = 58\nvalue = [42, 14, 2]'),
#  Text(0.19315245478036175, 0.7954545454545454, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.20348837209302326, 0.7954545454545454, 'Start_Lat <= 39.266\ngini = 0.404\nsamples = 57\nvalue = [42, 13, 2]'),
#  Text(0.17958656330749354, 0.75, 'Start_Lat <= 39.122\ngini = 0.374\nsamples = 43\nvalue = [33, 8, 2]'),
#  Text(0.16020671834625322, 0.7045454545454546, 'Start_Lat <= 39.117\ngini = 0.469\nsamples = 8\nvalue = [5, 3, 0]'),
#  Text(0.15503875968992248, 0.6590909090909091, 'Start_Lat <= 39.102\ngini = 0.408\nsamples = 7\nvalue = [5, 2, 0]'),
#  Text(0.14987080103359174, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.16020671834625322, 0.6136363636363636, 'Start_Lat <= 39.102\ngini = 0.48\nsamples = 5\nvalue = [3, 2, 0]'),
#  Text(0.15503875968992248, 0.5681818181818182, 'gini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.165374677002584, 0.5681818181818182, 'Start_Lat <= 39.109\ngini = 0.444\nsamples = 3\nvalue = [2, 1, 0]'),
#  Text(0.16020671834625322, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.17054263565891473, 0.5227272727272727, 'gini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.165374677002584, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.19896640826873385, 0.7045454545454546, 'Start_Lat <= 39.172\ngini = 0.336\nsamples = 35\nvalue = [28, 5, 2]'),
#  Text(0.18604651162790697, 0.6590909090909091, 'Start_Lat <= 39.148\ngini = 0.142\nsamples = 13\nvalue = [12, 0, 1]'),
#  Text(0.18087855297157623, 0.6136363636363636, 'Start_Lat <= 39.143\ngini = 0.278\nsamples = 6\nvalue = [5, 0, 1]'),
#  Text(0.17571059431524547, 0.5681818181818182, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0]'),
#  Text(0.18604651162790697, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.19121447028423771, 0.6136363636363636, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0]'),
#  Text(0.21188630490956073, 0.6590909090909091, 'Start_Lat <= 39.174\ngini = 0.417\nsamples = 22\nvalue = [16, 5, 1]'),
#  Text(0.20155038759689922, 0.6136363636363636, 'Start_Lat <= 39.173\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.19638242894056848, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.20671834625322996, 0.5681818181818182, 'gini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.2222222222222222, 0.6136363636363636, 'Start_Lat <= 39.176\ngini = 0.349\nsamples = 19\nvalue = [15, 3, 1]'),
#  Text(0.21705426356589147, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.22739018087855298, 0.5681818181818182, 'Start_Lat <= 39.178\ngini = 0.398\nsamples = 16\nvalue = [12, 3, 1]'),
#  Text(0.2222222222222222, 0.5227272727272727, 'gini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.23255813953488372, 0.5227272727272727, 'Start_Lat <= 39.211\ngini = 0.357\nsamples = 14\nvalue = [11, 2, 1]'),
#  Text(0.22739018087855298, 0.4772727272727273, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.23772609819121446, 0.4772727272727273, 'Start_Lat <= 39.225\ngini = 0.46\nsamples = 10\nvalue = [7, 2, 1]'),
#  Text(0.22739018087855298, 0.4318181818181818, 'Start_Lat <= 39.225\ngini = 0.667\nsamples = 3\nvalue = [1, 1, 1]'),
#  Text(0.2222222222222222, 0.38636363636363635, 'gini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.23255813953488372, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.24806201550387597, 0.4318181818181818, 'Start_Lat <= 39.249\ngini = 0.245\nsamples = 7\nvalue = [6, 1, 0]'),
#  Text(0.24289405684754523, 0.38636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.2532299741602067, 0.38636363636363635, 'Start_Lat <= 39.25\ngini = 0.375\nsamples = 4\nvalue = [3, 1, 0]'),
#  Text(0.24806201550387597, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.25839793281653745, 0.3409090909090909, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.22739018087855298, 0.75, 'Start_Lat <= 39.269\ngini = 0.459\nsamples = 14\nvalue = [9, 5, 0]'),
#  Text(0.2222222222222222, 0.7045454545454546, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.23255813953488372, 0.7045454545454546, 'Start_Lat <= 39.273\ngini = 0.298\nsamples = 11\nvalue = [9, 2, 0]'),
#  Text(0.22739018087855298, 0.6590909090909091, 'gini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.23772609819121446, 0.6590909090909091, 'Start_Lat <= 39.289\ngini = 0.198\nsamples = 9\nvalue = [8, 1, 0]'),
#  Text(0.23255813953488372, 0.6136363636363636, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0]'),
#  Text(0.24289405684754523, 0.6136363636363636, 'Start_Lat <= 39.292\ngini = 0.375\nsamples = 4\nvalue = [3, 1, 0]'),
#  Text(0.23772609819121446, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.24806201550387597, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.6364462209302325, 0.9318181818181818, 'Start_Lat <= 40.975\ngini = 0.609\nsamples = 368\nvalue = [189, 65, 114]'),
#  Text(0.5171592377260982, 0.8863636363636364, 'Start_Lat <= 40.117\ngini = 0.633\nsamples = 201\nvalue = [91, 39, 71]'),
#  Text(0.37927971576227393, 0.8409090909090909, 'Start_Lat <= 39.726\ngini = 0.609\nsamples = 142\nvalue = [75, 30, 37]'),
#  Text(0.2971576227390181, 0.7954545454545454, 'Start_Lat <= 39.699\ngini = 0.658\nsamples = 15\nvalue = [4, 5, 6]'),
#  Text(0.29198966408268734, 0.75, 'Start_Lat <= 39.587\ngini = 0.653\nsamples = 14\nvalue = [4, 4, 6]'),
#  Text(0.27906976744186046, 0.7045454545454546, 'Start_Lat <= 39.527\ngini = 0.66\nsamples = 10\nvalue = [3, 4, 3]'),
#  Text(0.268733850129199, 0.6590909090909091, 'Start_Lat <= 39.495\ngini = 0.653\nsamples = 7\nvalue = [2, 2, 3]'),
#  Text(0.26356589147286824, 0.6136363636363636, 'Start_Lat <= 39.371\ngini = 0.64\nsamples = 5\nvalue = [2, 2, 1]'),
#  Text(0.25839793281653745, 0.5681818181818182, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.268733850129199, 0.5681818181818182, 'Start_Lat <= 39.415\ngini = 0.444\nsamples = 3\nvalue = [2, 1, 0]'),
#  Text(0.26356589147286824, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.2739018087855297, 0.5227272727272727, 'Start_Lat <= 39.462\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.268733850129199, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.27906976744186046, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.2739018087855297, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.28940568475452194, 0.6590909090909091, 'Start_Lat <= 39.557\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.2842377260981912, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.29457364341085274, 0.6136363636363636, 'Start_Lat <= 39.584\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.28940568475452194, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.2997416020671835, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.3049095607235142, 0.7045454545454546, 'Start_Lat <= 39.631\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 3]'),
#  Text(0.2997416020671835, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.31007751937984496, 0.6590909090909091, 'Start_Lat <= 39.659\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.3049095607235142, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.3152454780361757, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.3023255813953488, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.4614018087855297, 0.7954545454545454, 'Start_Lat <= 39.955\ngini = 0.589\nsamples = 127\nvalue = [71, 25, 31]'),
#  Text(0.3953488372093023, 0.75, 'Start_Lat <= 39.857\ngini = 0.504\nsamples = 61\nvalue = [40, 7, 14]'),
#  Text(0.35658914728682173, 0.7045454545454546, 'Start_Lat <= 39.82\ngini = 0.568\nsamples = 27\nvalue = [15, 3, 9]'),
#  Text(0.3359173126614987, 0.6590909090909091, 'Start_Lat <= 39.744\ngini = 0.401\nsamples = 18\nvalue = [13, 0, 5]'),
#  Text(0.32558139534883723, 0.6136363636363636, 'Start_Lat <= 39.74\ngini = 0.5\nsamples = 4\nvalue = [2, 0, 2]'),
#  Text(0.32041343669250644, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.330749354005168, 0.5681818181818182, 'Start_Lat <= 39.743\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 2]'),
#  Text(0.32558139534883723, 0.5227272727272727, 'gini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.3359173126614987, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.3462532299741602, 0.6136363636363636, 'Start_Lat <= 39.757\ngini = 0.337\nsamples = 14\nvalue = [11, 0, 3]'),
#  Text(0.34108527131782945, 0.5681818181818182, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0]'),
#  Text(0.35142118863049093, 0.5681818181818182, 'Start_Lat <= 39.765\ngini = 0.469\nsamples = 8\nvalue = [5, 0, 3]'),
#  Text(0.3462532299741602, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.35658914728682173, 0.5227272727272727, 'Start_Lat <= 39.776\ngini = 0.408\nsamples = 7\nvalue = [5, 0, 2]'),
#  Text(0.35142118863049093, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.36175710594315247, 0.4772727272727273, 'Start_Lat <= 39.803\ngini = 0.48\nsamples = 5\nvalue = [3, 0, 2]'),
#  Text(0.35658914728682173, 0.4318181818181818, 'Start_Lat <= 39.781\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 2]'),
#  Text(0.35142118863049093, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.36175710594315247, 0.38636363636363635, 'Start_Lat <= 39.788\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.35658914728682173, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.3669250645994832, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.3669250645994832, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.3772609819121447, 0.6590909090909091, 'Start_Lat <= 39.849\ngini = 0.642\nsamples = 9\nvalue = [2, 3, 4]'),
#  Text(0.3669250645994832, 0.6136363636363636, 'Start_Lat <= 39.821\ngini = 0.5\nsamples = 6\nvalue = [0, 3, 3]'),
#  Text(0.36175710594315247, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.37209302325581395, 0.5681818181818182, 'Start_Lat <= 39.828\ngini = 0.48\nsamples = 5\nvalue = [0, 3, 2]'),
#  Text(0.3669250645994832, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.3772609819121447, 0.5227272727272727, 'Start_Lat <= 39.836\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 2]'),
#  Text(0.37209302325581395, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.38242894056847543, 0.4772727272727273, 'Start_Lat <= 39.838\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.3772609819121447, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.3875968992248062, 0.4318181818181818, 'Start_Lat <= 39.842\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.38242894056847543, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.39276485788113696, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.3875968992248062, 0.6136363636363636, 'Start_Lat <= 39.855\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1]'),
#  Text(0.38242894056847543, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.39276485788113696, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.43410852713178294, 0.7045454545454546, 'Start_Lat <= 39.89\ngini = 0.424\nsamples = 34\nvalue = [25, 4, 5]'),
#  Text(0.4289405684754522, 0.6590909090909091, 'gini = 0.0\nsamples = 9\nvalue = [9, 0, 0]'),
#  Text(0.4392764857881137, 0.6590909090909091, 'Start_Lat <= 39.894\ngini = 0.525\nsamples = 25\nvalue = [16, 4, 5]'),
#  Text(0.43410852713178294, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.4444444444444444, 0.6136363636363636, 'Start_Lat <= 39.937\ngini = 0.497\nsamples = 24\nvalue = [16, 3, 5]'),
#  Text(0.4289405684754522, 0.5681818181818182, 'Start_Lat <= 39.935\ngini = 0.595\nsamples = 11\nvalue = [6, 3, 2]'),
#  Text(0.42377260981912146, 0.5227272727272727, 'Start_Lat <= 39.924\ngini = 0.494\nsamples = 9\nvalue = [6, 2, 1]'),
#  Text(0.4186046511627907, 0.4772727272727273, 'Start_Lat <= 39.905\ngini = 0.611\nsamples = 6\nvalue = [3, 2, 1]'),
#  Text(0.4082687338501292, 0.4318181818181818, 'Start_Lat <= 39.896\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1]'),
#  Text(0.40310077519379844, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.4134366925064599, 0.38636363636363635, 'Start_Lat <= 39.901\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.4082687338501292, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.4186046511627907, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.4289405684754522, 0.4318181818181818, 'Start_Lat <= 39.915\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.42377260981912146, 0.38636363636363635, 'gini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.43410852713178294, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.4289405684754522, 0.4772727272727273, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.43410852713178294, 0.5227272727272727, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.4599483204134367, 0.5681818181818182, 'Start_Lat <= 39.949\ngini = 0.355\nsamples = 13\nvalue = [10, 0, 3]'),
#  Text(0.4496124031007752, 0.5227272727272727, 'Start_Lat <= 39.946\ngini = 0.219\nsamples = 8\nvalue = [7, 0, 1]'),
#  Text(0.4444444444444444, 0.4772727272727273, 'Start_Lat <= 39.945\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 1]'),
#  Text(0.4392764857881137, 0.4318181818181818, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.4496124031007752, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.45478036175710596, 0.4772727272727273, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.4702842377260982, 0.5227272727272727, 'Start_Lat <= 39.953\ngini = 0.48\nsamples = 5\nvalue = [3, 0, 2]'),
#  Text(0.46511627906976744, 0.4772727272727273, 'gini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.4754521963824289, 0.4772727272727273, 'gini = 0.444\nsamples = 3\nvalue = [2, 0, 1]'),
#  Text(0.5274547803617571, 0.75, 'Start_Lat <= 39.967\ngini = 0.639\nsamples = 66\nvalue = [31, 18, 17]'),
#  Text(0.5222868217054264, 0.7045454545454546, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6]'),
#  Text(0.5326227390180879, 0.7045454545454546, 'Start_Lat <= 39.968\ngini = 0.609\nsamples = 60\nvalue = [31, 18, 11]'),
#  Text(0.5274547803617571, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.5377906976744186, 0.6590909090909091, 'Start_Lat <= 40.112\ngini = 0.606\nsamples = 59\nvalue = [31, 17, 11]'),
#  Text(0.5326227390180879, 0.6136363636363636, 'Start_Lat <= 40.081\ngini = 0.615\nsamples = 57\nvalue = [29, 17, 11]'),
#  Text(0.5148578811369509, 0.5681818181818182, 'Start_Lat <= 40.049\ngini = 0.578\nsamples = 46\nvalue = [26, 13, 7]'),
#  Text(0.5, 0.5227272727272727, 'Start_Lat <= 39.986\ngini = 0.614\nsamples = 37\nvalue = [18, 13, 6]'),
#  Text(0.48578811369509045, 0.4772727272727273, 'Start_Lat <= 39.975\ngini = 0.645\nsamples = 22\nvalue = [10, 6, 6]'),
#  Text(0.4728682170542636, 0.4318181818181818, 'Start_Lat <= 39.973\ngini = 0.48\nsamples = 10\nvalue = [6, 4, 0]'),
#  Text(0.4625322997416021, 0.38636363636363635, 'Start_Lat <= 39.973\ngini = 0.408\nsamples = 7\nvalue = [5, 2, 0]'),
#  Text(0.4573643410852713, 0.3409090909090909, 'Start_Lat <= 39.971\ngini = 0.48\nsamples = 5\nvalue = [3, 2, 0]'),
#  Text(0.45219638242894056, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.4625322997416021, 0.29545454545454547, 'Start_Lat <= 39.973\ngini = 0.5\nsamples = 4\nvalue = [2, 2, 0]'),
#  Text(0.4573643410852713, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.46770025839793283, 0.25, 'gini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.46770025839793283, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.48320413436692505, 0.38636363636363635, 'Start_Lat <= 39.974\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.4780361757105943, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.4883720930232558, 0.3409090909090909, 'gini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.49870801033591733, 0.4318181818181818, 'Start_Lat <= 39.976\ngini = 0.611\nsamples = 12\nvalue = [4, 2, 6]'),
#  Text(0.4935400516795866, 0.38636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5038759689922481, 0.38636363636363635, 'Start_Lat <= 39.984\ngini = 0.642\nsamples = 9\nvalue = [4, 2, 3]'),
#  Text(0.49870801033591733, 0.3409090909090909, 'Start_Lat <= 39.983\ngini = 0.571\nsamples = 7\nvalue = [4, 2, 1]'),
#  Text(0.4935400516795866, 0.29545454545454547, 'Start_Lat <= 39.981\ngini = 0.64\nsamples = 5\nvalue = [2, 2, 1]'),
#  Text(0.4883720930232558, 0.25, 'Start_Lat <= 39.977\ngini = 0.5\nsamples = 4\nvalue = [2, 2, 0]'),
#  Text(0.48320413436692505, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.4935400516795866, 0.20454545454545456, 'Start_Lat <= 39.978\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.4883720930232558, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.49870801033591733, 0.1590909090909091, 'Start_Lat <= 39.979\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.4935400516795866, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.5038759689922481, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.49870801033591733, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.5038759689922481, 0.29545454545454547, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.5090439276485789, 0.3409090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.5142118863049095, 0.4772727272727273, 'Start_Lat <= 39.987\ngini = 0.498\nsamples = 15\nvalue = [8, 7, 0]'),
#  Text(0.5090439276485789, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.5193798449612403, 0.4318181818181818, 'Start_Lat <= 39.993\ngini = 0.49\nsamples = 14\nvalue = [8, 6, 0]'),
#  Text(0.5142118863049095, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.524547803617571, 0.38636363636363635, 'Start_Lat <= 39.997\ngini = 0.5\nsamples = 12\nvalue = [6, 6, 0]'),
#  Text(0.5193798449612403, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.5297157622739018, 0.3409090909090909, 'Start_Lat <= 40.046\ngini = 0.496\nsamples = 11\nvalue = [6, 5, 0]'),
#  Text(0.524547803617571, 0.29545454545454547, 'Start_Lat <= 40.04\ngini = 0.48\nsamples = 10\nvalue = [6, 4, 0]'),
#  Text(0.5193798449612403, 0.25, 'Start_Lat <= 40.035\ngini = 0.5\nsamples = 8\nvalue = [4, 4, 0]'),
#  Text(0.5142118863049095, 0.20454545454545456, 'Start_Lat <= 40.006\ngini = 0.444\nsamples = 6\nvalue = [4, 2, 0]'),
#  Text(0.5090439276485789, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.5193798449612403, 0.1590909090909091, 'Start_Lat <= 40.015\ngini = 0.48\nsamples = 5\nvalue = [3, 2, 0]'),
#  Text(0.5142118863049095, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.524547803617571, 0.11363636363636363, 'Start_Lat <= 40.024\ngini = 0.375\nsamples = 4\nvalue = [3, 1, 0]'),
#  Text(0.5193798449612403, 0.06818181818181818, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.5297157622739018, 0.06818181818181818, 'Start_Lat <= 40.03\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.524547803617571, 0.022727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.5348837209302325, 0.022727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.524547803617571, 0.20454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.5297157622739018, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.5348837209302325, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.5297157622739018, 0.5227272727272727, 'Start_Lat <= 40.061\ngini = 0.198\nsamples = 9\nvalue = [8, 0, 1]'),
#  Text(0.524547803617571, 0.4772727272727273, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0]'),
#  Text(0.5348837209302325, 0.4772727272727273, 'Start_Lat <= 40.068\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 1]'),
#  Text(0.5297157622739018, 0.4318181818181818, 'gini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.5400516795865633, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.5503875968992248, 0.5681818181818182, 'Start_Lat <= 40.099\ngini = 0.661\nsamples = 11\nvalue = [3, 4, 4]'),
#  Text(0.5452196382428941, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.5555555555555556, 0.5227272727272727, 'Start_Lat <= 40.104\ngini = 0.642\nsamples = 9\nvalue = [3, 4, 2]'),
#  Text(0.5503875968992248, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.5607235142118863, 0.4772727272727273, 'Start_Lat <= 40.111\ngini = 0.625\nsamples = 8\nvalue = [2, 4, 2]'),
#  Text(0.5555555555555556, 0.4318181818181818, 'Start_Lat <= 40.109\ngini = 0.64\nsamples = 5\nvalue = [1, 2, 2]'),
#  Text(0.5452196382428941, 0.38636363636363635, 'Start_Lat <= 40.109\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.5400516795865633, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.5503875968992248, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.5658914728682171, 0.38636363636363635, 'Start_Lat <= 40.11\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.5607235142118863, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.5710594315245479, 0.3409090909090909, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.5658914728682171, 0.4318181818181818, 'gini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.5429586563307494, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.6550387596899225, 0.8409090909090909, 'Start_Lat <= 40.715\ngini = 0.571\nsamples = 59\nvalue = [16, 9, 34]'),
#  Text(0.6304909560723514, 0.7954545454545454, 'Start_Lat <= 40.607\ngini = 0.608\nsamples = 47\nvalue = [15, 8, 24]'),
#  Text(0.6124031007751938, 0.75, 'Start_Lat <= 40.17\ngini = 0.578\nsamples = 43\nvalue = [13, 6, 24]'),
#  Text(0.5917312661498708, 0.7045454545454546, 'Start_Lat <= 40.147\ngini = 0.54\nsamples = 10\nvalue = [1, 3, 6]'),
#  Text(0.5813953488372093, 0.6590909090909091, 'Start_Lat <= 40.128\ngini = 0.449\nsamples = 7\nvalue = [1, 1, 5]'),
#  Text(0.5762273901808785, 0.6136363636363636, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.58656330749354, 0.6136363636363636, 'Start_Lat <= 40.136\ngini = 0.32\nsamples = 5\nvalue = [1, 0, 4]'),
#  Text(0.5813953488372093, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5917312661498708, 0.5681818181818182, 'Start_Lat <= 40.14\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.58656330749354, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.5968992248062015, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6020671834625323, 0.6590909090909091, 'Start_Lat <= 40.154\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.5968992248062015, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6072351421188631, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6330749354005168, 0.7045454545454546, 'Start_Lat <= 40.591\ngini = 0.562\nsamples = 33\nvalue = [12, 3, 18]'),
#  Text(0.627906976744186, 0.6590909090909091, 'Start_Lat <= 40.578\ngini = 0.574\nsamples = 31\nvalue = [12, 3, 16]'),
#  Text(0.6227390180878553, 0.6136363636363636, 'Start_Lat <= 40.526\ngini = 0.566\nsamples = 29\nvalue = [10, 3, 16]'),
#  Text(0.6124031007751938, 0.5681818181818182, 'Start_Lat <= 40.486\ngini = 0.569\nsamples = 24\nvalue = [10, 2, 12]'),
#  Text(0.6072351421188631, 0.5227272727272727, 'Start_Lat <= 40.468\ngini = 0.553\nsamples = 21\nvalue = [7, 2, 12]'),
#  Text(0.6020671834625323, 0.4772727272727273, 'Start_Lat <= 40.312\ngini = 0.515\nsamples = 20\nvalue = [7, 1, 12]'),
#  Text(0.5917312661498708, 0.4318181818181818, 'Start_Lat <= 40.275\ngini = 0.49\nsamples = 7\nvalue = [4, 0, 3]'),
#  Text(0.58656330749354, 0.38636363636363635, 'Start_Lat <= 40.228\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 3]'),
#  Text(0.5813953488372093, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.5917312661498708, 0.3409090909090909, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.5968992248062015, 0.38636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.6124031007751938, 0.4318181818181818, 'Start_Lat <= 40.376\ngini = 0.462\nsamples = 13\nvalue = [3, 1, 9]'),
#  Text(0.6072351421188631, 0.38636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.6175710594315246, 0.38636363636363635, 'Start_Lat <= 40.4\ngini = 0.54\nsamples = 10\nvalue = [3, 1, 6]'),
#  Text(0.6124031007751938, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.6227390180878553, 0.3409090909090909, 'Start_Lat <= 40.421\ngini = 0.494\nsamples = 9\nvalue = [2, 1, 6]'),
#  Text(0.6124031007751938, 0.29545454545454547, 'Start_Lat <= 40.409\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.6072351421188631, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6175710594315246, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.6330749354005168, 0.29545454545454547, 'Start_Lat <= 40.429\ngini = 0.408\nsamples = 7\nvalue = [2, 0, 5]'),
#  Text(0.627906976744186, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.6382428940568475, 0.25, 'Start_Lat <= 40.435\ngini = 0.48\nsamples = 5\nvalue = [2, 0, 3]'),
#  Text(0.6330749354005168, 0.20454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.6434108527131783, 0.20454545454545456, 'Start_Lat <= 40.442\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 3]'),
#  Text(0.6382428940568475, 0.1590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.648578811369509, 0.1590909090909091, 'Start_Lat <= 40.448\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.6434108527131783, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.6537467700258398, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6124031007751938, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.6175710594315246, 0.5227272727272727, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.6330749354005168, 0.5681818181818182, 'Start_Lat <= 40.533\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(0.627906976744186, 0.5227272727272727, 'Start_Lat <= 40.53\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.6227390180878553, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6330749354005168, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.6382428940568475, 0.5227272727272727, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.6330749354005168, 0.6136363636363636, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.6382428940568475, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.648578811369509, 0.75, 'Start_Lat <= 40.639\ngini = 0.5\nsamples = 4\nvalue = [2, 2, 0]'),
#  Text(0.6434108527131783, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.6537467700258398, 0.7045454545454546, 'Start_Lat <= 40.687\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.648578811369509, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.6589147286821705, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.6795865633074936, 0.7954545454545454, 'Start_Lat <= 40.781\ngini = 0.292\nsamples = 12\nvalue = [1, 1, 10]'),
#  Text(0.6692506459948321, 0.75, 'Start_Lat <= 40.774\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6640826873385013, 0.7045454545454546, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.6744186046511628, 0.7045454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.689922480620155, 0.75, 'Start_Lat <= 40.842\ngini = 0.198\nsamples = 9\nvalue = [1, 0, 8]'),
#  Text(0.6847545219638242, 0.7045454545454546, 'Start_Lat <= 40.815\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 3]'),
#  Text(0.6795865633074936, 0.6590909090909091, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.689922480620155, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.6950904392764858, 0.7045454545454546, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5]'),
#  Text(0.755733204134367, 0.8863636363636364, 'Start_Lat <= 41.098\ngini = 0.565\nsamples = 167\nvalue = [98, 26, 43]'),
#  Text(0.7002583979328165, 0.8409090909090909, 'Start_Lat <= 41.062\ngini = 0.083\nsamples = 23\nvalue = [22, 1, 0]'),
#  Text(0.6950904392764858, 0.7954545454545454, 'gini = 0.0\nsamples = 13\nvalue = [13, 0, 0]'),
#  Text(0.7054263565891473, 0.7954545454545454, 'Start_Lat <= 41.062\ngini = 0.18\nsamples = 10\nvalue = [9, 1, 0]'),
#  Text(0.7002583979328165, 0.75, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.710594315245478, 0.75, 'gini = 0.0\nsamples = 9\nvalue = [9, 0, 0]'),
#  Text(0.8112080103359173, 0.8409090909090909, 'Start_Lat <= 41.354\ngini = 0.602\nsamples = 144\nvalue = [76, 25, 43]'),
#  Text(0.7260981912144703, 0.7954545454545454, 'Start_Lat <= 41.35\ngini = 0.615\nsamples = 33\nvalue = [13, 5, 15]'),
#  Text(0.7209302325581395, 0.75, 'Start_Lat <= 41.222\ngini = 0.622\nsamples = 31\nvalue = [13, 5, 13]'),
#  Text(0.710594315245478, 0.7045454545454546, 'Start_Lat <= 41.197\ngini = 0.643\nsamples = 23\nvalue = [8, 5, 10]'),
#  Text(0.7054263565891473, 0.6590909090909091, 'Start_Lat <= 41.18\ngini = 0.608\nsamples = 21\nvalue = [8, 3, 10]'),
#  Text(0.7002583979328165, 0.6136363636363636, 'Start_Lat <= 41.161\ngini = 0.623\nsamples = 18\nvalue = [8, 3, 7]'),
#  Text(0.6808785529715762, 0.5681818181818182, 'Start_Lat <= 41.125\ngini = 0.561\nsamples = 14\nvalue = [7, 1, 6]'),
#  Text(0.6679586563307494, 0.5227272727272727, 'Start_Lat <= 41.104\ngini = 0.568\nsamples = 9\nvalue = [3, 1, 5]'),
#  Text(0.6576227390180879, 0.4772727272727273, 'Start_Lat <= 41.102\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1]'),
#  Text(0.6524547803617571, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6627906976744186, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.6782945736434108, 0.4772727272727273, 'Start_Lat <= 41.119\ngini = 0.5\nsamples = 6\nvalue = [1, 1, 4]'),
#  Text(0.6731266149870802, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.6834625322997416, 0.4318181818181818, 'Start_Lat <= 41.119\ngini = 0.625\nsamples = 4\nvalue = [1, 1, 2]'),
#  Text(0.6782945736434108, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.6886304909560723, 0.38636363636363635, 'Start_Lat <= 41.121\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6834625322997416, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6937984496124031, 0.3409090909090909, 'Start_Lat <= 41.123\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.6886304909560723, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.6989664082687338, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6937984496124031, 0.5227272727272727, 'Start_Lat <= 41.151\ngini = 0.32\nsamples = 5\nvalue = [4, 0, 1]'),
#  Text(0.6886304909560723, 0.4772727272727273, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.6989664082687338, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.7196382428940569, 0.5681818181818182, 'Start_Lat <= 41.172\ngini = 0.625\nsamples = 4\nvalue = [1, 2, 1]'),
#  Text(0.7144702842377261, 0.5227272727272727, 'Start_Lat <= 41.162\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.7093023255813954, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.7196382428940569, 0.4772727272727273, 'Start_Lat <= 41.164\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.7144702842377261, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.7248062015503876, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.7248062015503876, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.710594315245478, 0.6136363636363636, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.7157622739018088, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.7312661498708011, 0.7045454545454546, 'Start_Lat <= 41.262\ngini = 0.469\nsamples = 8\nvalue = [5, 0, 3]'),
#  Text(0.7260981912144703, 0.6590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.7364341085271318, 0.6590909090909091, 'Start_Lat <= 41.275\ngini = 0.5\nsamples = 6\nvalue = [3, 0, 3]'),
#  Text(0.7312661498708011, 0.6136363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.7416020671834626, 0.6136363636363636, 'Start_Lat <= 41.294\ngini = 0.48\nsamples = 5\nvalue = [3, 0, 2]'),
#  Text(0.7364341085271318, 0.5681818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.7467700258397932, 0.5681818181818182, 'Start_Lat <= 41.323\ngini = 0.5\nsamples = 4\nvalue = [2, 0, 2]'),
#  Text(0.7416020671834626, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.751937984496124, 0.5227272727272727, 'Start_Lat <= 41.342\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1]'),
#  Text(0.7467700258397932, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.7571059431524548, 0.4772727272727273, 'Start_Lat <= 41.347\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.751937984496124, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.7622739018087855, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.7312661498708011, 0.75, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.8963178294573644, 0.7954545454545454, 'Start_Lat <= 41.621\ngini = 0.582\nsamples = 111\nvalue = [63, 20, 28]'),
#  Text(0.83656330749354, 0.75, 'Start_Lat <= 41.479\ngini = 0.546\nsamples = 70\nvalue = [43, 16, 11]'),
#  Text(0.7855297157622739, 0.7045454545454546, 'Start_Lat <= 41.474\ngini = 0.506\nsamples = 47\nvalue = [31, 7, 9]'),
#  Text(0.7803617571059431, 0.6590909090909091, 'Start_Lat <= 41.395\ngini = 0.567\nsamples = 39\nvalue = [23, 7, 9]'),
#  Text(0.7751937984496124, 0.6136363636363636, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.7855297157622739, 0.6136363636363636, 'Start_Lat <= 41.398\ngini = 0.599\nsamples = 35\nvalue = [19, 7, 9]'),
#  Text(0.7803617571059431, 0.5681818181818182, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.7906976744186046, 0.5681818181818182, 'Start_Lat <= 41.411\ngini = 0.579\nsamples = 33\nvalue = [19, 7, 7]'),
#  Text(0.772609819121447, 0.5227272727272727, 'Start_Lat <= 41.403\ngini = 0.375\nsamples = 4\nvalue = [1, 3, 0]'),
#  Text(0.7674418604651163, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.7777777777777778, 0.4772727272727273, 'Start_Lat <= 41.408\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.772609819121447, 0.4318181818181818, 'gini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.7829457364341085, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8087855297157622, 0.5227272727272727, 'Start_Lat <= 41.421\ngini = 0.537\nsamples = 29\nvalue = [18, 4, 7]'),
#  Text(0.8036175710594315, 0.4772727272727273, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0]'),
#  Text(0.813953488372093, 0.4772727272727273, 'Start_Lat <= 41.43\ngini = 0.594\nsamples = 24\nvalue = [13, 4, 7]'),
#  Text(0.7932816537467701, 0.4318181818181818, 'Start_Lat <= 41.423\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.7881136950904393, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.7984496124031008, 0.38636363636363635, 'Start_Lat <= 41.425\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.7932816537467701, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8036175710594315, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.834625322997416, 0.4318181818181818, 'Start_Lat <= 41.474\ngini = 0.54\nsamples = 21\nvalue = [13, 3, 5]'),
#  Text(0.8294573643410853, 0.38636363636363635, 'Start_Lat <= 41.467\ngini = 0.515\nsamples = 20\nvalue = [13, 3, 4]'),
#  Text(0.813953488372093, 0.3409090909090909, 'Start_Lat <= 41.465\ngini = 0.568\nsamples = 9\nvalue = [5, 1, 3]'),
#  Text(0.8087855297157622, 0.29545454545454547, 'Start_Lat <= 41.435\ngini = 0.531\nsamples = 8\nvalue = [5, 1, 2]'),
#  Text(0.8036175710594315, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.813953488372093, 0.25, 'Start_Lat <= 41.44\ngini = 0.611\nsamples = 6\nvalue = [3, 1, 2]'),
#  Text(0.8036175710594315, 0.20454545454545456, 'Start_Lat <= 41.438\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.7984496124031008, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8087855297157622, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8242894056847545, 0.20454545454545456, 'Start_Lat <= 41.443\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 1]'),
#  Text(0.8191214470284238, 0.1590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.8294573643410853, 0.1590909090909091, 'Start_Lat <= 41.454\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.8242894056847545, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.834625322997416, 0.11363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.8191214470284238, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8449612403100775, 0.3409090909090909, 'Start_Lat <= 41.474\ngini = 0.43\nsamples = 11\nvalue = [8, 2, 1]'),
#  Text(0.834625322997416, 0.29545454545454547, 'Start_Lat <= 41.467\ngini = 0.37\nsamples = 9\nvalue = [7, 1, 1]'),
#  Text(0.8294573643410853, 0.25, 'gini = 0.444\nsamples = 3\nvalue = [2, 1, 0]'),
#  Text(0.8397932816537468, 0.25, 'Start_Lat <= 41.471\ngini = 0.278\nsamples = 6\nvalue = [5, 0, 1]'),
#  Text(0.834625322997416, 0.20454545454545456, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.8449612403100775, 0.20454545454545456, 'Start_Lat <= 41.473\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1]'),
#  Text(0.8397932816537468, 0.1590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8501291989664083, 0.1590909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.8552971576227391, 0.29545454545454547, 'Start_Lat <= 41.474\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.8501291989664083, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8604651162790697, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.8397932816537468, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.7906976744186046, 0.6590909090909091, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0]'),
#  Text(0.8875968992248062, 0.7045454545454546, 'Amenity <= 0.5\ngini = 0.567\nsamples = 23\nvalue = [12, 9, 2]'),
#  Text(0.8824289405684754, 0.6590909090909091, 'Start_Lat <= 41.539\ngini = 0.533\nsamples = 22\nvalue = [12, 9, 1]'),
#  Text(0.8578811369509044, 0.6136363636363636, 'Start_Lat <= 41.513\ngini = 0.561\nsamples = 14\nvalue = [6, 7, 1]'),
#  Text(0.8397932816537468, 0.5681818181818182, 'Start_Lat <= 41.48\ngini = 0.494\nsamples = 9\nvalue = [5, 4, 0]'),
#  Text(0.834625322997416, 0.5227272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8449612403100775, 0.5227272727272727, 'Start_Lat <= 41.486\ngini = 0.469\nsamples = 8\nvalue = [5, 3, 0]'),
#  Text(0.8397932816537468, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.8501291989664083, 0.4772727272727273, 'Start_Lat <= 41.494\ngini = 0.5\nsamples = 6\nvalue = [3, 3, 0]'),
#  Text(0.8449612403100775, 0.4318181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.8552971576227391, 0.4318181818181818, 'Start_Lat <= 41.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1, 0]'),
#  Text(0.8501291989664083, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.8604651162790697, 0.38636363636363635, 'Start_Lat <= 41.503\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.8552971576227391, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8656330749354005, 0.3409090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.875968992248062, 0.5681818181818182, 'Start_Lat <= 41.525\ngini = 0.56\nsamples = 5\nvalue = [1, 3, 1]'),
#  Text(0.8656330749354005, 0.5227272727272727, 'Start_Lat <= 41.523\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.8604651162790697, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8708010335917312, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8863049095607235, 0.5227272727272727, 'Start_Lat <= 41.526\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.8811369509043928, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8914728682170543, 0.4772727272727273, 'Start_Lat <= 41.532\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.8863049095607235, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.896640826873385, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9069767441860465, 0.6136363636363636, 'Start_Lat <= 41.553\ngini = 0.375\nsamples = 8\nvalue = [6, 2, 0]'),
#  Text(0.9018087855297158, 0.5681818181818182, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.9121447028423773, 0.5681818181818182, 'Start_Lat <= 41.572\ngini = 0.48\nsamples = 5\nvalue = [3, 2, 0]'),
#  Text(0.9069767441860465, 0.5227272727272727, 'Start_Lat <= 41.559\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.9018087855297158, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9121447028423773, 0.4772727272727273, 'Start_Lat <= 41.566\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.9069767441860465, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.917312661498708, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.917312661498708, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.8927648578811369, 0.6590909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.9560723514211886, 0.75, 'Start_Lat <= 41.631\ngini = 0.581\nsamples = 41\nvalue = [20, 4, 17]'),
#  Text(0.9509043927648578, 0.7045454545454546, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 6]'),
#  Text(0.9612403100775194, 0.7045454545454546, 'Start_Lat <= 41.935\ngini = 0.562\nsamples = 35\nvalue = [20, 4, 11]'),
#  Text(0.9560723514211886, 0.6590909090909091, 'Start_Lat <= 41.697\ngini = 0.591\nsamples = 31\nvalue = [16, 4, 11]'),
#  Text(0.937984496124031, 0.6136363636363636, 'Start_Lat <= 41.686\ngini = 0.426\nsamples = 18\nvalue = [13, 1, 4]'),
#  Text(0.9328165374677002, 0.5681818181818182, 'Start_Lat <= 41.658\ngini = 0.521\nsamples = 13\nvalue = [8, 1, 4]'),
#  Text(0.9276485788113695, 0.5227272727272727, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.937984496124031, 0.5227272727272727, 'Start_Lat <= 41.664\ngini = 0.58\nsamples = 10\nvalue = [5, 1, 4]'),
#  Text(0.9328165374677002, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.9431524547803618, 0.4772727272727273, 'Start_Lat <= 41.686\ngini = 0.568\nsamples = 9\nvalue = [5, 1, 3]'),
#  Text(0.937984496124031, 0.4318181818181818, 'Start_Lat <= 41.669\ngini = 0.531\nsamples = 8\nvalue = [5, 1, 2]'),
#  Text(0.9328165374677002, 0.38636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.9431524547803618, 0.38636363636363635, 'Start_Lat <= 41.675\ngini = 0.611\nsamples = 6\nvalue = [3, 1, 2]'),
#  Text(0.9328165374677002, 0.3409090909090909, 'Start_Lat <= 41.673\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.9276485788113695, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.937984496124031, 0.29545454545454547, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9534883720930233, 0.3409090909090909, 'Start_Lat <= 41.678\ngini = 0.375\nsamples = 4\nvalue = [3, 0, 1]'),
#  Text(0.9483204134366925, 0.29545454545454547, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.958656330749354, 0.29545454545454547, 'Start_Lat <= 41.682\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.9534883720930233, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.9638242894056848, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.9483204134366925, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.9431524547803618, 0.5681818181818182, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0]'),
#  Text(0.9741602067183462, 0.6136363636363636, 'Start_Lat <= 41.852\ngini = 0.604\nsamples = 13\nvalue = [3, 3, 7]'),
#  Text(0.9638242894056848, 0.5681818181818182, 'Start_Lat <= 41.716\ngini = 0.656\nsamples = 8\nvalue = [3, 2, 3]'),
#  Text(0.958656330749354, 0.5227272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.9689922480620154, 0.5227272727272727, 'Start_Lat <= 41.817\ngini = 0.611\nsamples = 6\nvalue = [3, 2, 1]'),
#  Text(0.9638242894056848, 0.4772727272727273, 'Start_Lat <= 41.729\ngini = 0.625\nsamples = 4\nvalue = [1, 2, 1]'),
#  Text(0.958656330749354, 0.4318181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.9689922480620154, 0.4318181818181818, 'Start_Lat <= 41.769\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.9638242894056848, 0.38636363636363635, 'gini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.9741602067183462, 0.38636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9741602067183462, 0.4772727272727273, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.9844961240310077, 0.5681818181818182, 'Start_Lat <= 41.897\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(0.979328165374677, 0.5227272727272727, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.9896640826873385, 0.5227272727272727, 'Start_Lat <= 41.915\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.9844961240310077, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9948320413436692, 0.4772727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.9664082687338501, 0.6590909090909091, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]')]
