# %%
import pandas

# %%
df = pandas.read_csv("US1.csv")

# %%
df
# Out:
#             ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0          A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1          A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20  39.865420
# 2          A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39  39.102660
# 3          A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45  41.062130
# 4          A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
# ...        ...       ...                  ...                  ...        ...
# 49995  A-49996         4  2016-10-30 06:45:46  2016-10-30 12:45:46  26.811625
# 49996  A-49997         4  2016-10-30 06:45:46  2016-10-30 12:45:46  26.843520
# 49997  A-49998         3  2016-10-30 07:52:25  2016-10-30 13:52:25  25.925300
# 49998  A-49999         3  2016-10-30 06:56:08  2016-10-30 12:56:08  41.875230
# 49999  A-50000         2  2016-10-30 05:16:37  2016-10-30 12:16:37  41.845950
#
# ...

# %%
# note :change type of feature with map()

# %%
# just an overview to work with pandas:
